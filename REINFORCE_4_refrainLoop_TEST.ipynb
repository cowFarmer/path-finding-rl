# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/agileSoda/
# Out:
# /content/drive/MyDrive/agileSoda

# %%
from string import ascii_uppercase
import numpy as np
import pandas as pd
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

#Hyperparameters
learning_rate = 0.0002
gamma         = 0.98 # 무조건 끝나는 episode라면 gamma == 1도 가능하다. 

# reward
move_reward = 0.1
obs_reward = 0.1
goal_reward = 10
loop_reward = -1
print('reward:' , move_reward, obs_reward, goal_reward, loop_reward)

# etc
max_cum_reward = -9999999999999999

__file__ = '/content/drive/MyDrive/agileSoda/'
local_path = os.path.abspath(os.path.join(os.path.dirname(__file__)))
# Out:
# reward: 0.1 0.1 10 -1

# %%
class Simulator:
    def __init__(self):
        '''
        height : 그리드 높이
        width : 그리드 너비 
        inds : A ~ Q alphabet list
        '''
        # Load train data
        self.files = pd.read_csv(os.path.join(local_path, "./data/factory_order_test.csv"))
        self.height = 10
        self.width = 9
        self.inds = list(ascii_uppercase)[:17]

    def set_box(self):
        '''
        아이템들이 있을 위치를 미리 정해놓고 그 위치 좌표들에 아이템이 들어올 수 있으므로 그리드에 100으로 표시한다.
        데이터 파일에서 이번 에피소드 아이템 정보를 받아 가져와야 할 아이템이 있는 좌표만 -100으로 표시한다.
        self.local_target에 에이전트가 이번에 방문해야할 좌표들을 저장한다.
        따라서 가져와야하는 아이템 좌표와 end point 좌표(처음 시작했던 좌표로 돌아와야하므로)가 들어가게 된다.
        '''
        box_data = pd.read_csv(os.path.join(local_path, "./data/box.csv"))

        # 물건이 들어있을 수 있는 경우
        for box in box_data.itertuples(index = True, name ='Pandas'):
            self.grid[getattr(box, "row")][getattr(box, "col")] = 100

        # 물건이 실제 들어있는 경우
        order_item = list(set(self.inds) & set(self.items))
        order_csv = box_data[box_data['item'].isin(order_item)]

        for order_box in order_csv.itertuples(index = True, name ='Pandas'):
            self.grid[getattr(order_box, "row")][getattr(order_box, "col")] = -100
            # local target에 가야 할 위치 좌표 넣기
            self.local_target.append(
                [getattr(order_box, "row"),
                 getattr(order_box, "col")]
                )

        self.local_target.sort()
        self.local_target.append([9,4]) 

        # 알파벳을 Grid에 넣어서 -> grid에 2Dconv 적용 가능

    def set_obstacle(self):
        '''
        장애물이 있어야하는 위치는 미리 obstacles.csv에 정의되어 있다. 이 좌표들을 0으로 표시한다.
        '''
        obstacles_data = pd.read_csv(os.path.join(local_path, "./data/obstacles.csv"))
        for obstacle in obstacles_data.itertuples(index = True, name ='Pandas'):
            self.grid[getattr(obstacle, "row")][getattr(obstacle, "col")] = 0

    def reset(self, epi):
        '''
        reset()은 첫 스텝에서 사용되며 그리드에서 에이전트 위치가 start point에 있게 한다.
        :param epi: episode, 에피소드 마다 가져와야 할 아이템 리스트를 불러올 때 사용
        :return: 초기셋팅 된 그리드
        :rtype: numpy.ndarray
        _____________________________________________________________________________________
        items : 이번 에피소드에서 가져와야하는 아이템들
        terminal_location : 현재 에이전트가 찾아가야하는 목적지
        local_target : 한 에피소드에서 찾아가야하는 아이템 좌표, 마지막 엔드 포인트 등의 위치좌표들
        actions: visualization을 위해 에이전트 action을 저장하는 리스트
        curloc : 현재 위치
        '''

        # initial episode parameter setting
        self.epi = epi
        self.items = list(self.files.iloc[self.epi])[0]
        self.cumulative_reward = 0
        self.terminal_location = None
        self.local_target = []
        self.actions = []

        # initial grid setting
        self.grid = np.ones((self.height, self.width), dtype="float16")

        # set information about the gridworld
        self.set_box()
        self.set_obstacle()

        # start point를 grid에 표시
        self.curloc = [9, 4]
        self.grid[int(self.curloc[0])][int(self.curloc[1])] = -5

        self.done = False

        return self.grid

    def apply_action(self, action, cur_x, cur_y):
        '''
        에이전트가 행한 action대로 현 에이전트의 위치좌표를 바꾼다.
        action은 discrete하며 4가지 up,down,left,right으로 정의된다.
        
        :param x: 에이전트의 현재 x 좌표
        :param y: 에이전트의 현재 y 좌표
        :return: action에 따라 변한 에이전트의 x 좌표, y 좌표
        :rtype: int, int
        '''
        new_x = cur_x
        new_y = cur_y
        # up
        if action == 0:
            new_x = cur_x - 1
        # down
        elif action == 1:
            new_x = cur_x + 1
        # left
        elif action == 2:
            new_y = cur_y - 1
        # right
        else:
            new_y = cur_y + 1

        return int(new_x), int(new_y)


    def get_reward(self, new_x, new_y, out_of_boundary):
        '''
        get_reward함수는 리워드를 계산하는 함수이며, 상황에 따라 에이전트가 action을 옳게 했는지 판단하는 지표가 된다.
        :param new_x: action에 따른 에이전트 새로운 위치좌표 x
        :param new_y: action에 따른 에이전트 새로운 위치좌표 y
        :param out_of_boundary: 에이전트 위치가 그리드 밖이 되지 않도록 제한
        :return: action에 따른 리워드
        :rtype: float
        '''

        # 바깥으로 나가는 경우
        if any(out_of_boundary):
            reward = obs_reward

        else:
            # 장애물에 부딪히는 경우 
            if self.grid[new_x][new_y] == 0:
                reward = obs_reward  

            # 현재 목표에 도달한 경우
            elif new_x == self.terminal_location[0] and new_y == self.terminal_location[1]:
                reward = goal_reward

            # 그냥 움직이는 경우 
            else:
                reward = move_reward

        return reward

    def step(self, action):
        ''' 
        에이전트의 action에 따라 step을 진행한다.
        action에 따라 에이전트 위치를 변환하고, action에 대해 리워드를 받고, 어느 상황에 에피소드가 종료되어야 하는지 등을 판단한다.
        에이전트가 endpoint에 도착하면 gif로 에피소드에서 에이전트의 행동이 저장된다.
        :param action: 에이전트 행동
        :return:
            grid, 그리드
            reward, 리워드
            cumulative_reward, 누적 리워드
            done, 종료 여부
            goal_ob_reward, goal까지 아이템을 모두 가지고 돌아오는 finish율 계산을 위한 파라미터
        :rtype: numpy.ndarray, float, float, bool, bool/str
        (Hint : 시작 위치 (9,4)에서 up말고 다른 action은 전부 장애물이므로 action을 고정하는 것이 좋음)
        '''

        self.terminal_location = self.local_target[0]
        cur_x,cur_y = self.curloc
        self.actions.append((cur_x, cur_y))

        goal_ob_reward = False

        new_x, new_y = self.apply_action(action, cur_x, cur_y)

        out_of_boundary = [new_x < 0, new_x >= self.height, new_y < 0, new_y >= self.width]

        # 바깥으로 나가는 경우 종료
        if any(out_of_boundary):
            self.done = True
            goal_ob_reward = True
        else:
            # 장애물에 부딪히는 경우 종료
            if self.grid[new_x][new_y] == 0:
                self.done = True
                goal_ob_reward = True

            # 현재 목표에 도달한 경우, 다음 목표설정
            elif new_x == self.terminal_location[0] and new_y == self.terminal_location[1]:

                # end point 일 때
                if [new_x, new_y] == [9,4]:
                    self.done = True

                self.local_target.remove(self.local_target[0])
                self.grid[cur_x][cur_y] = 1
                self.grid[new_x][new_y] = -5
                goal_ob_reward = True
                self.curloc = [new_x, new_y]
            else:
                # 그냥 움직이는 경우 
                self.grid[cur_x][cur_y] = 1
                self.grid[new_x][new_y] = -5
                self.curloc = [new_x,new_y]

        # 보상 계산하기
        reward = self.get_reward(new_x, new_y, out_of_boundary)
        
        # 10번의 행동동안 state 종류가 n개 이하면  -보상 주도록하기
        n = 3
        reward = self.refrain_loop(reward, n)

        self.cumulative_reward += reward

        if self.done == True:
            if [new_x, new_y] == [9, 4]:
                if self.terminal_location == [9, 4]:
                    # 완료되면 GIFS 저장
                    goal_ob_reward = 'finish'

        return self.get_current_state(), reward, self.cumulative_reward, self.done, goal_ob_reward

    def get_current_state(self):
        state = (self.curloc[0], self.curloc[1], self.local_target[0][0], self.local_target[0][1])
        return np.array(state)
        
    # 10번의 행동동안 state 종류가 n개 이하면  -보상 주도록하기
    def refrain_loop(self, reward, n):
        if len(self.actions) <= 10:
            return reward
        
        start_idx = len(self.actions) - 10
        temp = self.actions[start_idx:start_idx+10]
        temp = set(temp)
        if len(temp) <= n:
            return reward + loop_reward
        else:
            return reward

# %%
class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.data = []
        
        # weight를 정의  
        self.fc1 = nn.Linear(4, 128) # fully connected first layer
        self.fc2 = nn.Linear(128, 4) # fully connected second layer

        # optimizer
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)
        
    # 얜 언제 불러지는걸까요?
    def forward(self, x):
        x = F.relu(self.fc1(x)) # first layer 통과 후 비선형 함수 통과 
        x = F.softmax(self.fc2(x), dim=0) # second layer 통과 후 sofrmax로 합이 1이 되는 확률로 만들어
        return x
      
    # s, a pair 저장
    def put_data(self, item): 
        self.data.append(item)
        
    # 2-(C) presudo code
    def train_net(self):
        R = 0
        self.optimizer.zero_grad()
        for r, prob in self.data[::-1]: # return을 재귀적으로 뒤에서부터 더하면서 계산
            R = r + gamma * R # Return Gt
            loss = -torch.log(prob) * R # loss function
            loss.backward() # gradient 계산
        self.optimizer.step() # Adam optimizer update 진해
        self.data = []

# %%
# MAIN

files = pd.read_csv('./data/factory_order_test.csv')
episodes = len(files)

env = Simulator()

model = torch.load(r'/content/drive/MyDrive/agileSoda/REINFORCE_4_refrainLoop_0.1_0.1_10.pt')
pi = Policy()

max_cum_reward = -99999

# ########################################################
# 액션 저장하는 txt파일 만들기
my_file_name='REINFORCE_4_refrainLoop_TEST_'+str(move_reward)+'_'+str(obs_reward)+'_'+str(goal_reward)
f = open(my_file_name+'.txt', 'w')
# ########################################################

for epi in range(episodes):
    state = env.reset(epi)
    state = env.get_current_state()
    print('\n\n▶▶▶{}번째 에피소드 시작, env 초기화 완료.'.format(epi))

    # 아이템 리스트 확인
    items = list(files.iloc[epi])[0]
    print('가져와야 할 아이템 : ' + list(files.iloc[epi])[0] + '\n')
    items = env.local_target

    done = False
    isFinished=False

    while not done:
        prob = pi(torch.from_numpy(state).float())
        m = Categorical(prob) # prob 중 높은 확률 값을 리턴
        action = m.sample()
        
        state_prime, reward, cumul ,done, goal_ob_reward = env.step(action.item())
        pi.put_data((reward, prob[action]))
        print('action', action, 'reward', reward)
        
        state = state_prime
        
        if goal_ob_reward == 'finished':
            isFinished = True
    
    pi.train_net()
    max_cum_reward = max_cum_reward if max_cum_reward > cumul else cumul
    print('▶▶▶ ',epi, 'max cum reward', max_cum_reward, 'isFinished', isFinished, '\n\n')
  

#########################################    
    if len(env.actions) > 5:
        f.write(str(epi)+'/'+str(items)+'/'+str(cumul)+'/'+str(isFinished)+'\n')
        f.write(str(env.actions))
        f.write('\n')

f.close()
#########################################
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ▶▶▶814번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'E', 'F', 'I', 'J', 'K']
#
# action tensor(1) reward 0.1
# ▶▶▶  814 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶815번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'E', 'G', 'H', 'Q']
#
# action tensor(2) reward 0.1
# ▶▶▶  815 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶816번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'F', 'M', 'N', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  816 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶817번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'E', 'F', 'J', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  817 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶818번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['E', 'H', 'I', 'K', 'L', 'M', 'O']
#
# action tensor(2) reward 0.1
# ▶▶▶  818 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶819번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'H', 'J', 'N', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  819 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶820번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'F', 'I', 'J', 'L', 'M']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  820 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶821번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'E', 'G', 'I', 'K', 'L']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  821 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶822번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'E', 'F', 'G', 'I', 'M', 'N']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  822 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶823번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'D', 'E', 'I', 'M', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  823 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶824번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'D', 'E', 'F', 'M', 'N', 'P']
#
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(3) reward 0.1
# ▶▶▶  824 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶825번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'F', 'H', 'J', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# ▶▶▶  825 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶826번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'D', 'G', 'H', 'L', 'M']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  826 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶827번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'G', 'I', 'J', 'K', 'L', 'Q']
#
# action tensor(1) reward 0.1
# ▶▶▶  827 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶828번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'E', 'F', 'G', 'I', 'N', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  828 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶829번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['E', 'G', 'H', 'I', 'J', 'N', 'O']
#
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  829 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶830번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'G', 'K', 'N', 'O', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  830 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶831번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'E', 'K', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  831 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶832번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'F', 'J', 'K', 'L', 'O', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  832 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶833번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'D', 'H', 'L', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# ▶▶▶  833 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶834번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['G', 'K', 'L', 'O', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  834 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶835번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'F', 'H', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  835 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶836번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'E', 'F', 'G', 'N', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  836 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶837번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'I', 'J', 'K', 'O', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  837 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶838번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'E', 'F', 'I', 'J', 'K', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  838 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶839번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'E', 'J', 'K', 'N', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  839 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶840번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'H', 'I', 'J', 'M', 'N', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  840 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶841번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'E', 'F', 'G', 'L', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(1) reward 0.1
# ▶▶▶  841 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶842번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'F', 'J', 'K', 'L', 'M', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  842 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶843번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'K', 'L', 'M', 'N', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  843 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶844번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'I', 'N', 'O', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  844 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶845번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['F', 'G', 'J', 'K', 'L', 'M', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  845 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶846번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'J', 'K', 'M', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  846 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶847번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'E', 'H', 'K', 'N', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  847 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶848번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'D', 'J', 'L', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  848 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶849번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'E', 'F', 'J', 'K', 'M']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  849 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶850번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'D', 'F', 'H', 'K', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  850 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶851번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'E', 'J', 'K', 'M', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  851 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶852번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['E', 'G', 'J', 'L', 'N', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  852 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶853번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'D', 'E', 'I', 'N', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  853 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶854번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['F', 'H', 'L', 'M', 'N', 'O', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  854 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶855번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'D', 'E', 'F', 'H', 'K', 'M']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  855 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶856번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'E', 'G', 'H', 'I', 'K', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  856 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶857번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'G', 'I', 'N', 'O', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  857 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶858번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'F', 'J', 'M', 'N', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  858 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶859번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'D', 'I', 'J', 'K', 'L', 'N']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  859 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶860번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'H', 'L', 'M', 'N', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# ▶▶▶  860 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶861번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'F', 'I', 'L', 'M', 'O', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  861 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶862번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'F', 'I', 'K', 'L', 'M', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  862 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶863번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'F', 'G', 'H', 'I', 'N']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  863 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶864번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'D', 'F', 'I', 'J', 'O', 'Q']
#
# action tensor(1) reward 0.1
# ▶▶▶  864 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶865번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'F', 'G', 'H', 'M', 'N', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  865 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶866번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'E', 'J', 'K', 'M', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  866 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶867번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'I', 'K', 'L', 'N', 'O']
#
# action tensor(3) reward 0.1
# ▶▶▶  867 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶868번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'G', 'I', 'K', 'L']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  868 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶869번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'E', 'F', 'H', 'K', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(2) reward 0.1
# action tensor(3) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(1) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(2) reward 0.1
# action tensor(3) reward 0.1
# action tensor(3) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  869 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶870번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'I', 'L', 'N', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  870 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶871번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'H', 'I', 'J', 'M', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  871 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶872번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'I', 'L', 'M', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  872 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶873번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'E', 'J', 'N', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  873 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶874번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'E', 'F', 'G', 'K', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  874 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶875번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'G', 'H', 'I', 'L']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  875 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶876번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'D', 'J', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  876 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶877번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'E', 'F', 'N', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  877 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶878번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'G', 'K', 'L', 'M', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  878 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶879번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'E', 'H', 'J', 'L', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  879 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶880번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'F', 'I', 'K', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  880 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶881번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'F', 'H', 'K', 'N', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  881 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶882번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'E', 'F', 'H', 'M', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  882 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶883번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'F', 'H', 'I', 'L', 'M', 'O']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(3) reward 0.1
# ▶▶▶  883 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶884번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'H', 'I', 'J', 'P', 'Q']
#
# action tensor(1) reward 0.1
# ▶▶▶  884 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶885번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'E', 'K', 'N', 'P', 'Q']
#
# action tensor(3) reward 0.1
# ▶▶▶  885 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶886번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'H', 'J', 'K', 'M', 'N', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  886 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶887번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'E', 'F', 'I', 'J', 'K', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  887 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶888번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'H', 'I', 'N', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  888 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶889번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'E', 'F', 'I', 'K', 'M', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  889 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶890번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'E', 'G', 'H', 'K', 'L']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  890 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶891번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'E', 'H', 'I', 'J', 'K']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  891 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶892번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'F', 'J', 'L', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  892 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶893번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'D', 'G', 'I', 'J', 'P']
#
# action tensor(2) reward 0.1
# ▶▶▶  893 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶894번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'E', 'H', 'K', 'O', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  894 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶895번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'E', 'I', 'M', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  895 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶896번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'G', 'K', 'M', 'N', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  896 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶897번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'E', 'F', 'G', 'O', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  897 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶898번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'D', 'E', 'I', 'L', 'N', 'O']
#
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  898 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶899번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'E', 'F', 'G', 'L', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  899 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶900번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['E', 'F', 'G', 'H', 'M', 'N', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  900 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶901번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'E', 'H', 'I', 'K', 'L', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  901 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶902번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'E', 'F', 'I', 'K', 'N', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  902 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶903번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'D', 'K', 'M', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  903 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶904번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'F', 'J', 'L', 'N', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  904 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶905번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'E', 'F', 'N', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  905 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶906번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'F', 'I', 'J', 'M', 'P']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  906 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶907번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'G', 'I', 'L', 'M', 'O', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  907 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶908번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['E', 'K', 'N', 'O', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  908 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶909번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'D', 'E', 'G', 'H', 'J', 'M']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  909 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶910번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'J', 'M', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  910 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶911번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'G', 'I', 'J', 'K', 'L', 'M']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  911 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶912번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'E', 'I', 'J', 'L', 'M', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  912 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶913번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'D', 'E', 'H', 'N', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  913 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶914번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'D', 'I', 'J', 'K', 'L', 'M']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# ▶▶▶  914 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶915번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'E', 'F', 'I', 'M', 'N', 'Q']
#
# action tensor(2) reward 0.1
# ▶▶▶  915 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶916번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'F', 'I', 'J', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# ▶▶▶  916 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶917번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'E', 'O', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  917 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶918번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'F', 'H', 'I', 'L', 'N', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  918 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶919번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'E', 'G', 'H', 'K', 'O', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  919 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶920번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'F', 'G', 'I', 'K', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  920 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶921번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'E', 'H', 'M', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  921 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶922번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'E', 'F', 'H', 'J', 'M', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  922 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶923번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'E', 'H', 'I', 'N', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(3) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(2) reward 0.1
# action tensor(2) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(3) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  923 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶924번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'F', 'I', 'L', 'N', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  924 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶925번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'F', 'H', 'I', 'J', 'N']
#
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  925 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶926번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'D', 'F', 'J', 'M', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  926 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶927번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'F', 'G', 'J', 'K', 'O', 'P']
#
# action tensor(1) reward 0.1
# ▶▶▶  927 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶928번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'H', 'I', 'M', 'N', 'O', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  928 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶929번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'F', 'G', 'L', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  929 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶930번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'D', 'G', 'J', 'M', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  930 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶931번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'D', 'K', 'M', 'N', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# ▶▶▶  931 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶932번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'E', 'I', 'K', 'M', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  932 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶933번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'G', 'I', 'J', 'L', 'M']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  933 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶934번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'G', 'J', 'M', 'N', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  934 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶935번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'I', 'J', 'K', 'L', 'N', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  935 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶936번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'G', 'H', 'J', 'K', 'L']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  936 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶937번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'E', 'H', 'J', 'O', 'Q']
#
# action tensor(2) reward 0.1
# ▶▶▶  937 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶938번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'E', 'G', 'J', 'K', 'N']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  938 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶939번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'I', 'M', 'N', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  939 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶940번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'F', 'G', 'J', 'K', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  940 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶941번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'K', 'L', 'N', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  941 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶942번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'F', 'M', 'N', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  942 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶943번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'D', 'I', 'K', 'P', 'Q']
#
# action tensor(2) reward 0.1
# ▶▶▶  943 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶944번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['G', 'H', 'J', 'K', 'L', 'N', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  944 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶945번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'F', 'G', 'I', 'L', 'N', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  945 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶946번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'G', 'H', 'L', 'M', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  946 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶947번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'E', 'F', 'M', 'N', 'O', 'P']
#
# action tensor(3) reward 0.1
# ▶▶▶  947 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶948번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'G', 'I', 'K', 'M', 'N', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  948 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶949번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'E', 'H', 'I', 'K', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  949 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶950번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'H', 'I', 'J', 'N', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  950 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶951번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'F', 'I', 'J', 'M', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  951 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶952번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'F', 'G', 'M', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  952 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶953번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'E', 'F', 'G', 'I', 'K']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  953 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶954번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'G', 'H', 'I', 'J', 'M', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  954 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶955번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'F', 'G', 'H', 'K', 'M', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  955 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶956번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'E', 'G', 'K', 'L', 'N', 'P']
#
# action tensor(1) reward 0.1
# ▶▶▶  956 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶957번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'F', 'G', 'H', 'L', 'M']
#
# action tensor(1) reward 0.1
# ▶▶▶  957 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶958번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['G', 'I', 'J', 'N', 'O', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  958 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶959번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'D', 'I', 'J', 'L', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  959 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶960번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'E', 'F', 'H', 'I', 'K', 'N']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# ▶▶▶  960 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶961번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['G', 'I', 'L', 'M', 'N', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  961 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶962번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'H', 'I', 'K', 'L', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  962 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶963번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'I', 'J', 'K', 'L', 'M', 'O']
#
# action tensor(1) reward 0.1
# ▶▶▶  963 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶964번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'E', 'H', 'I', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  964 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶965번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'D', 'F', 'G', 'H']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  965 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶966번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['E', 'G', 'J', 'K', 'L', 'N', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  966 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶967번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'F', 'I', 'L', 'N', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  967 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶968번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'D', 'E', 'H', 'I', 'J']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# ▶▶▶  968 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶969번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'F', 'H', 'J', 'N', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  969 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶970번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'D', 'E', 'H', 'L', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  970 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶971번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'G', 'I', 'M', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# ▶▶▶  971 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶972번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'F', 'L', 'M', 'N', 'P']
#
# action tensor(2) reward 0.1
# ▶▶▶  972 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶973번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'D', 'E', 'F', 'L', 'O']
#
# action tensor(3) reward 0.1
# ▶▶▶  973 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶974번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'H', 'K', 'L', 'O', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  974 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶975번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'I', 'J', 'L', 'N', 'P']
#
# action tensor(1) reward 0.1
# ▶▶▶  975 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶976번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'D', 'F', 'G', 'L', 'N']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  976 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶977번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'E', 'F', 'G', 'H', 'K', 'P']
#
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  977 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶978번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'F', 'I', 'L', 'M', 'N', 'P']
#
# action tensor(1) reward 0.1
# ▶▶▶  978 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶979번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'E', 'G', 'K', 'M', 'N']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  979 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶980번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['E', 'G', 'L', 'N', 'O', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  980 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶981번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'D', 'F', 'G', 'I', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(2) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  981 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶982번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'G', 'H', 'K', 'M', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  982 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶983번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'F', 'I', 'L', 'N']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  983 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶984번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'H', 'J', 'L', 'M', 'N']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  984 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶985번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'H', 'I', 'K', 'N', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  985 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶986번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['E', 'F', 'H', 'L', 'N', 'O', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  986 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶987번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'E', 'M', 'N', 'O', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  987 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶988번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'F', 'H', 'L', 'N', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  988 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶989번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'E', 'I', 'L', 'M', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  989 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶990번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'F', 'G', 'J', 'O', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  990 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶991번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'E', 'G', 'O', 'Q']
#
# action tensor(3) reward 0.1
# ▶▶▶  991 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶992번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'F', 'M', 'N', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  992 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶993번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'D', 'G', 'H', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  993 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶994번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['F', 'G', 'H', 'I', 'J', 'K', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# ▶▶▶  994 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶995번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'D', 'E', 'F', 'L', 'M']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  995 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶996번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'D', 'E', 'H', 'O', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  996 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶997번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'E', 'F', 'I', 'M', 'N']
#
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  997 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶998번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'E', 'G', 'H', 'I', 'M']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  998 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶999번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'F', 'G', 'K', 'M', 'N', 'O']
#
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(3) reward 0.1
# ▶▶▶  999 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1000번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'E', 'I', 'J', 'L', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1000 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1001번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'E', 'F', 'H', 'I', 'L']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1001 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1002번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'H', 'L', 'M', 'O', 'P', 'Q']
#
# action tensor(2) reward 0.1
# ▶▶▶  1002 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1003번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'D', 'I', 'K', 'M', 'O']
#
# action tensor(2) reward 0.1
# ▶▶▶  1003 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1004번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'G', 'I', 'K', 'L']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1004 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1005번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'D', 'E', 'J', 'N', 'P']
#
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# ▶▶▶  1005 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1006번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'H', 'I', 'J', 'K', 'M', 'N']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1006 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1007번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['E', 'G', 'H', 'I', 'K', 'L', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1007 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1008번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'F', 'H', 'I', 'J', 'K', 'L']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(1) reward 0.1
# ▶▶▶  1008 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1009번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'D', 'F', 'K', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  1009 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1010번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'G', 'J', 'L', 'M', 'O', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1010 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1011번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['G', 'H', 'J', 'K', 'L', 'M', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1011 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1012번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['F', 'G', 'J', 'L', 'M', 'N', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1012 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1013번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'E', 'F', 'G', 'J', 'K', 'P']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ...
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  1166 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1167번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'F', 'I', 'J', 'M', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  1167 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1168번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'G', 'H', 'I', 'L', 'P']
#
# action tensor(3) reward 0.1
# ▶▶▶  1168 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1169번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'F', 'J', 'K', 'M', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1169 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1170번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'F', 'G', 'H', 'J', 'L', 'M']
#
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1170 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1171번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['E', 'H', 'K', 'L', 'N', 'O', 'Q']
#
# action tensor(1) reward 0.1
# ▶▶▶  1171 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1172번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'E', 'F', 'H', 'J', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1172 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1173번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'H', 'J', 'M', 'N', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1173 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1174번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'E', 'F', 'G', 'H', 'M', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1174 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1175번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'D', 'I', 'J', 'M', 'O']
#
# action tensor(1) reward 0.1
# ▶▶▶  1175 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1176번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'F', 'M', 'N', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  1176 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1177번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'I', 'L', 'M', 'O', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(1) reward 0.1
# ▶▶▶  1177 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1178번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'E', 'J', 'K', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  1178 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1179번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'F', 'G', 'H', 'K', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1179 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1180번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'D', 'E', 'G', 'J', 'N']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1180 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1181번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'E', 'G', 'K', 'L', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# ▶▶▶  1181 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1182번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'E', 'G', 'K', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  1182 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1183번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['E', 'G', 'H', 'K', 'M', 'N', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1183 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1184번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'E', 'F', 'H', 'I', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1184 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1185번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'F', 'I', 'J', 'M', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1185 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1186번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'F', 'G', 'I', 'K', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1186 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1187번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'F', 'G', 'H', 'K', 'L']
#
# action tensor(2) reward 0.1
# ▶▶▶  1187 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1188번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'D', 'E', 'G', 'J', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1188 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1189번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'E', 'K', 'L', 'M', 'N', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1189 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1190번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'G', 'J', 'L', 'M', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1190 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1191번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['E', 'F', 'G', 'H', 'K', 'N', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1191 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1192번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'E', 'J', 'K', 'L', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1192 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1193번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'G', 'H', 'I', 'J', 'K', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1193 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1194번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'H', 'J', 'L', 'M', 'N', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1194 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1195번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'D', 'F', 'H', 'I', 'L', 'N']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1195 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1196번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'D', 'F', 'H', 'I', 'J']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1196 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1197번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'D', 'E', 'G', 'H', 'I', 'O']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  1197 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1198번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['F', 'G', 'H', 'I', 'K', 'L', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1198 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1199번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'E', 'H', 'J', 'M', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  1199 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1200번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'D', 'G', 'I', 'J', 'L', 'P']
#
# action tensor(2) reward 0.1
# ▶▶▶  1200 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1201번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'C', 'G', 'J', 'M', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1201 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1202번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'G', 'H', 'I', 'L', 'N', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(2) reward 0.1
# action tensor(1) reward 0.1
# action tensor(3) reward 0.1
# action tensor(2) reward 0.1
# action tensor(3) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(1) reward 0.1
# action tensor(2) reward 0.1
# action tensor(1) reward 0.1
# ▶▶▶  1202 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1203번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'C', 'D', 'E', 'H', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1203 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1204번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'D', 'I', 'K', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(3) reward 0.1
# ▶▶▶  1204 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1205번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'E', 'H', 'J', 'N', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  1205 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1206번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'G', 'H', 'J', 'M', 'N']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1206 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1207번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'F', 'J', 'M', 'O', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  1207 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1208번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'D', 'F', 'G', 'K', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1208 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1209번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'F', 'I', 'K', 'M', 'N', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  1209 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1210번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'D', 'G', 'I', 'K', 'Q']
#
# action tensor(2) reward 0.1
# ▶▶▶  1210 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1211번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'F', 'I', 'J', 'M', 'N']
#
# action tensor(1) reward 0.1
# ▶▶▶  1211 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1212번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['E', 'G', 'I', 'K', 'N', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  1212 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1213번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['D', 'F', 'M', 'N', 'O', 'P', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1213 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1214번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'F', 'G', 'H', 'M', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1214 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1215번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'E', 'F', 'G', 'K', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1215 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1216번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'D', 'F', 'H', 'I', 'J', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1216 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1217번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'I', 'J', 'K', 'M', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1217 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1218번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'G', 'H', 'L', 'N', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1218 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1219번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'C', 'E', 'F', 'I', 'L', 'Q']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1219 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1220번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['B', 'D', 'K', 'L', 'N', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1220 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1221번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'G', 'J', 'K', 'L', 'O', 'P']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1221 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1222번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['C', 'G', 'I', 'J', 'L', 'M', 'O']
#
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(1) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# ▶▶▶  1222 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1223번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['E', 'F', 'H', 'J', 'K', 'L', 'N']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(2) reward 0.1
# action tensor(1) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(3) reward 0.1
# action tensor(2) reward 0.1
# action tensor(2) reward 0.1
# action tensor(1) reward 0.1
# action tensor(1) reward 0.1
# action tensor(3) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1223 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1224번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'B', 'D', 'G', 'H', 'N', 'O']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1224 max cum reward 12.3 isFinished False
#
#
#
#
# ▶▶▶1225번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['A', 'D', 'G', 'H', 'L', 'M', 'N']
#
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# action tensor(0) reward 0.1
# ▶▶▶  1225 max cum reward 12.3 isFinished False

# %%
# path = '/content/drive/MyDrive/agileSoda/'
# weight_name = path+my_file_name+'.pt'
# torch.save(pi.state_dict(), my_file_name)

# %%
# model_name = path+my_file_name+'.pt'
# torch.save(pi, model_name)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# __file__ = '/content/drive/MyDrive/aiffelthon/data'
__file__ = '/content/drive/Othercomputers/MacBook_Air/path-finding-rl/data'
# Out:
# Mounted at /content/drive

# %%
from string import ascii_uppercase
#from draw_utils import *
#from pyglet.gl import *
import numpy as np
import pandas as pd
import os
import random
from datetime import datetime
import pytz
import matplotlib.pyplot as plt

# reward
move_reward = -0.1
obs_reward = -10
goal_reward = 100
###################################
# train or test 모드 지정
train_mode = True
###################################
print('reward:' , move_reward, obs_reward, goal_reward)

#__file__ = '/home/ogangza/heung_path_finding/path-finding-rl/data'

local_path = os.path.abspath(os.path.join(os.path.dirname(__file__)))


class Simulator:
    def __init__(self):
        '''
        height : 그리드 높이
        width : 그리드 너비 
        inds : A ~ Q alphabet list
        '''
        #######################################################################################
        # Load train or test data
        if train_mode:  # 훈련 데이타 읽기
            self.files = pd.read_csv(os.path.join(local_path, "data/factory_order_train.csv"))
            print('data/factory_order_train.csv used')
        else:  # 테스트 데이터 읽기
            self.files = pd.read_csv(os.path.join(local_path, "data/factory_order_test.csv"))
            print('data/factory_order_test.csv used')
        #######################################################################################
        self.height = 10
        self.width = 9
        self.inds = list(ascii_uppercase)[:17]

    def set_box(self):
        '''
        아이템들이 있을 위치를 미리 정해놓고 그 위치 좌표들에 아이템이 들어올 수 있으므로 그리드에 100으로 표시한다.
        데이터 파일에서 이번 에피소드 아이템 정보를 받아 가져와야 할 아이템이 있는 좌표만 -100으로 표시한다.
        self.local_target에 에이전트가 이번에 방문해야할 좌표들을 저장한다.
        따라서 가져와야하는 아이템 좌표와 end point 좌표(처음 시작했던 좌표로 돌아와야하므로)가 들어가게 된다.
        '''
        box_data = pd.read_csv(os.path.join(local_path, "./data/box.csv"))
        
        ######################################
        #print('box data:', box_data)
        ######################################

        # 물건이 들어있을 수 있는 경우
        for box in box_data.itertuples(index = True, name ='Pandas'):
            self.grid[getattr(box, "row")][getattr(box, "col")] = 100
            
            #######################################
            #print('self.grid:', self.grid)
            #######################################

        # 물건이 실제 들어있는 경우
        order_item = list(set(self.inds) & set(self.items))
        order_csv = box_data[box_data['item'].isin(order_item)]
        
        ########################################
        #print('order_csv:', order_csv)
        ########################################

        for order_box in order_csv.itertuples(index = True, name ='Pandas'):
            self.grid[getattr(order_box, "row")][getattr(order_box, "col")] = -100
            # local target에 가야 할 위치 좌표 넣기
            self.local_target.append(
                [getattr(order_box, "row"),
                 getattr(order_box, "col")]
                )

            #######################################
            #print('self.grid:', self.grid)
            #######################################

        ################################################
        #print('self.local_target.sort() 전:', self.local_target)
        ################################################
        
        # self.local_target.sort() 
        self.local_target.append([9,4]) 

        ################################################
        #print('self.local_target.sort():', self.local_target)
        ###############################################
        
        # 알파벳을 Grid에 넣어서 -> grid에 2Dconv 적용 가능

    def set_obstacle(self):
        '''
        장애물이 있어야하는 위치는 미리 obstacles.csv에 정의되어 있다. 이 좌표들을 0으로 표시한다.
        '''
        obstacles_data = pd.read_csv(os.path.join(local_path, "./data/obstacles.csv"))
        for obstacle in obstacles_data.itertuples(index = True, name ='Pandas'):
            self.grid[getattr(obstacle, "row")][getattr(obstacle, "col")] = 0
            
        ##########################################
        #print('self.grid:', self.grid)
        ##########################################
        
    def reset(self, epi):
        '''
        reset()은 첫 스텝에서 사용되며 그리드에서 에이전트 위치가 start point에 있게 한다.

        :param epi: episode, 에피소드 마다 가져와야 할 아이템 리스트를 불러올 때 사용
        :return: 초기셋팅 된 그리드
        :rtype: numpy.ndarray
        _____________________________________________________________________________________
        items : 이번 에피소드에서 가져와야하는 아이템들
        terminal_location : 현재 에이전트가 찾아가야하는 목적지
        local_target : 한 에피소드에서 찾아가야하는 아이템 좌표, 마지막 엔드 포인트 등의 위치좌표들
        actions: visualization을 위해 에이전트 action을 저장하는 리스트
        curloc : 현재 위치
        '''

        # initial episode parameter setting
        self.epi = epi
        self.items = list(self.files.iloc[self.epi])[0]
        self.cumulative_reward = 0
        self.terminal_location = None
        self.local_target = []
        self.actions = []

        # initial grid setting
        self.grid = np.ones((self.height, self.width), dtype="float16")

        # set information about the gridworld
        self.set_box()
        self.set_obstacle()

        # start point를 grid에 표시
        self.curloc = [9, 4]
        self.grid[int(self.curloc[0])][int(self.curloc[1])] = -5
        
        self.done = False
        
        ########################################
        #print('reset curloc:', self.curloc)
        ########################################
        
        return self.grid

    def apply_action(self, action, cur_x, cur_y):
        '''
        에이전트가 행한 action대로 현 에이전트의 위치좌표를 바꾼다.
        action은 discrete하며 4가지 up,down,left,right으로 정의된다.
        
        :param x: 에이전트의 현재 x 좌표
        :param y: 에이전트의 현재 y 좌표
        :return: action에 따라 변한 에이전트의 x 좌표, y 좌표
        :rtype: int, int
        '''
        new_x = cur_x
        new_y = cur_y
        # up
        if action == 0:
            new_x = cur_x - 1
        # down
        elif action == 1:
            new_x = cur_x + 1
        # left
        elif action == 2:
            new_y = cur_y - 1
        # right
        else:
            new_y = cur_y + 1

        return int(new_x), int(new_y)


    def get_reward(self, new_x, new_y, out_of_boundary):
        '''
        get_reward함수는 리워드를 계산하는 함수이며, 상황에 따라 에이전트가 action을 옳게 했는지 판단하는 지표가 된다.

        :param new_x: action에 따른 에이전트 새로운 위치좌표 x
        :param new_y: action에 따른 에이전트 새로운 위치좌표 y
        :param out_of_boundary: 에이전트 위치가 그리드 밖이 되지 않도록 제한
        :return: action에 따른 리워드
        :rtype: float
        '''

        # 바깥으로 나가는 경우
        if any(out_of_boundary):
            reward = obs_reward
                       
        else:
            # 장애물에 부딪히는 경우 
            if self.grid[new_x][new_y] == 0:
                reward = obs_reward  

            # 현재 목표에 도달한 경우
            elif new_x == self.terminal_location[0] and new_y == self.terminal_location[1]:
                reward = goal_reward

            # 그냥 움직이는 경우 
            else:
                reward = move_reward

        return reward

    def step(self, action):
        ''' 
        에이전트의 action에 따라 step을 진행한다.
        action에 따라 에이전트 위치를 변환하고, action에 대해 리워드를 받고, 어느 상황에 에피소드가 종료되어야 하는지 등을 판단한다.
        에이전트가 endpoint에 도착하면 gif로 에피소드에서 에이전트의 행동이 저장된다.

        :param action: 에이전트 행동
        :return:
            grid, 그리드
            reward, 리워드
            cumulative_reward, 누적 리워드
            done, 종료 여부
            goal_ob_reward, goal까지 아이템을 모두 가지고 돌아오는 finish율 계산을 위한 파라미터

        :rtype: numpy.ndarray, float, float, bool, bool/str

        (Hint : 시작 위치 (9,4)에서 up말고 다른 action은 전부 장애물이므로 action을 고정하는 것이 좋음)
        '''

        #print('self.local_target:', self.local_target)
        self.terminal_location = self.local_target[0]
        cur_x,cur_y = self.curloc
        self.actions.append((cur_x, cur_y))

        goal_ob_reward = False
        
        new_x, new_y = self.apply_action(action, cur_x, cur_y)

        out_of_boundary = [new_x < 0, new_x >= self.height, new_y < 0, new_y >= self.width]

        # 바깥으로 나가는 경우 종료
        if any(out_of_boundary):
            
            #원 위치
            #new_x = cur_x
            #new_y = cur_y
            
            self.done = True
            goal_ob_reward = True
            
        else:
            # 장애물에 부딪히는 경우 종료
            if self.grid[new_x][new_y] == 0:
                
                #원 위치
                #new_x = cur_x
                #new_y = cur_y
                
                self.done = True
                goal_ob_reward = True

            # 현재 목표에 도달한 경우, 다음 목표 설정
            elif new_x == self.terminal_location[0] and new_y == self.terminal_location[1]:

                # end point 일 때
                if [new_x, new_y] == [9,4]:
                    self.done = True

                self.local_target.remove(self.local_target[0])
                self.grid[cur_x][cur_y] = 1
                self.grid[new_x][new_y] = -5
                goal_ob_reward = True
                self.curloc = [new_x, new_y]
            else:
                # 그냥 움직이는 경우 
                self.grid[cur_x][cur_y] = 1
                self.grid[new_x][new_y] = -5
                self.curloc = [new_x,new_y]
                
        reward = self.get_reward(new_x, new_y, out_of_boundary)
        self.cumulative_reward += reward
        return self.grid, reward, self.cumulative_reward, self.done, goal_ob_reward
# Out:
# reward: -0.1 -10 100

# %%
import gym
import collections
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# path
# model_path = __file__ + '/model.pt'

#Hyperparameters
learning_rate = 0.0005
gamma         = 0.98
buffer_limit  = 100000 # 5만 -> 10만
batch_size    = 32

class ReplayBuffer():
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit)
    
    def put(self, transition):
        self.buffer.append(transition)
    
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []
        
        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])

        return torch.tensor(np.array(s_lst), dtype=torch.float), torch.tensor(np.array(a_lst)), \
               torch.tensor(np.array(r_lst)), torch.tensor(np.array(s_prime_lst), dtype=torch.float), \
               torch.tensor(np.array(done_mask_lst))
    
    def size(self):
        return len(self.buffer)

class Qnet(nn.Module):
    def __init__(self):
        super(Qnet, self).__init__()
        self.fc1 = nn.Linear(94, 512)
        self.fc2 = nn.Linear(512, 512)
        self.fc3 = nn.Linear(512, 4)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
      
    def sample_action(self, obs, epsilon):
        out = self.forward(obs)
        coin = random.random()
        if coin < epsilon:
            return random.randint(0,3)
        else : 
            return out.argmax().item()

    ###################################################
    def test_action(self, obs):  # Test용 action 추가
        out = self.forward(obs)
        return out.argmax().item()
    ###################################################
            
def train(q, q_target, memory, optimizer):
    for i in range(10):
        s,a,r,s_prime,done_mask = memory.sample(batch_size)

        q_out = q(s)
        q_a = q_out.gather(1,a)
        max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1)
        target = r + gamma * max_q_prime * done_mask
        loss = F.smooth_l1_loss(q_a, target)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

def main():
    tz = pytz.timezone('Asia/Seoul')

    env = Simulator()
    q = Qnet()
    q_target = Qnet()
    q_target.load_state_dict(q.state_dict())
    memory = ReplayBuffer()

    print_interval = 1000
    score = 0.0  
    optimizer = optim.Adam(q.parameters(), lr=learning_rate)
    

    #files = pd.read_csv("./data/factory_order_train.csv") # Simulator 클래스 __init__(self):에서 읽음
    print('len(env.files):', len(env.files))
    
    #path_length = []

    for n_epi in range(len(env.files)): # range()의 인수로 len(env.files) 사용하면 됨 (=39,999)
        epsilon = max(0.01, 0.99 - 0.01*(n_epi/200)) # 상민님 epi/40000
        env.grid = env.reset(n_epi)  # env reset: 에피소드 번호에 해당하는 목표물 리스트 env.local_target 생성, 그리드맵 생성
        
        start_point = [9,4]  # 출발지 지정
        end_point = env.local_target[0]  # 첫 번째 목적지 지정
        #print('list(env.files.iloc[',n_epi,'])[0]:', list(env.files.iloc[n_epi])[0])
        ##print('env.local_target:', env.local_target)

        #######################################################################
        ## 인풋 정보: 그리드맵, 출발지, 목적지
        #######################################################################
        # 그리드 맵 지정
        grid_map = env.grid.reshape(-1)          # 그리드 맵
        # 출발지, 목적지 좌표 지정
        #env.x, env.y = start_point                # 출발지 좌표
        #env.end_x, env.end_y = end_point          # 목적지 좌표
        #######################################################################
        # 목적지 도착 flag (done) 및 인풋 데이터 (s) 초기화
        done = False
        s_temp_1 = np.append(grid_map, start_point)
        s_temp_2 = np.append(s_temp_1, end_point)
        s = np.array(s_temp_2)
        old_score = 0.0

        while not done:
            a = q.sample_action(torch.from_numpy(s).float(), epsilon)
            grid, r, cum_reward, done, goal_ob_reward = env.step(a)
            #s_prime = np.array(env.curloc)
            new_grid_map = grid.reshape(-1)
            s_prime_temp_1 = np.append(new_grid_map, env.curloc)
            s_prime_temp_2 = np.append(s_prime_temp_1, end_point)
            s_prime = np.array(s_prime_temp_2)

            done_mask = 0.0 if done else 1.0
            memory.put((s,a,r/10.0,s_prime, done_mask))
            s = s_prime

            score += r
            '''
            if score > old_score:
                    cur_time = datetime.now(tz)
                    simple_cur_time = cur_time.strftime("%H:%M:%S")
                    print('▶ Episode #', n_epi, 'start time:', simple_cur_time, end='→')
                    print('Score =', score, 'appended actions =', s, end='...')
                    print('경로 길이:', len(env.actions))
            '''
            old_score = score
                       
            if done:
                break

            # while loop 종료

        ############################################################################
                ## memory.size(): 2000 → 10000 → 20000 수정... 이후 훈련 시작
        ############################################################################   
        if memory.size() > 10000: # 20000 -> 10000
            train(q, q_target, memory, optimizer)

        if n_epi % print_interval == 0 and n_epi != 0:
            cur_time = datetime.now(tz)
            simple_cur_time = cur_time.strftime("%H:%M:%S")
            print('▶ Episode #', n_epi, 'start time:', simple_cur_time, end='→')
            q_target.load_state_dict(q.state_dict())
            print("n_episode :{}, score : {:.1f}, n_buffer : {}, eps : {:.1f}%".format(
                                                            n_epi, score/print_interval, memory.size(), epsilon*100))
            print('경로 길이:', len(env.actions))
            
            score = 0.0

            # torch.save(q, model_path)
            torch.save(q, __file__+f"/{n_epi}_model.pt")
        ##### 액션 결과물 확인하기
        if len(env.actions) > 10:
            print(f"move = {move_reward}, obs = {obs_reward}, goal = {goal_reward}")
            print(f"{n_epi}번째 에피소드는 {env.cumulative_reward}점 입니다.")
            print(f"target은 {env.items}, {env.local_target}입니다.")
            print(f"action은 총 {len(env.actions)}번 움직였습니다.\n{env.actions}")
            print("###############")
    # torch.save(q, model_path)
    torch.save(q, __file__+f"/{n_epi}_model.pt")

##########################
## 나중에 수정할 것!!!
##########################

# if __name__ == '__main__':
#     main()

# %%
def test():
    # model = torch.load('/content/drive/MyDrive/aiffelthon/data/model.pt')
    # model = torch.load(model_path)
    model_name = "/10000_model.pt"
    model = torch.load(__file__ + model_name)
    print(f"model path = {model_name}")
    train_mode = False  # False
    tz = pytz.timezone('Asia/Seoul')
    env = Simulator()
    q = Qnet()
    s_before = None
    print_interval = 1
    score = 0.0

    #################################
    # 액션 저장하는 txt파일 만들기
    # my_file_name = f"{model_name}_{move_reward}_{obs_reward}_{goal_reward}"
    # f = open(my_file_name+'.txt', 'w')
    #################################

    for n_epi in range(len(env.files)): # range()의 인수로 len(env.files) 사용하면 됨 (=1225)
        env.grid = env.reset(n_epi)
        grid_map = env.grid.reshape(-1)          # 그리드 맵
        # 출발지, 목적지 좌표 지정
        #env.x, env.y = start_point                # 출발지 좌표
        #env.end_x, env.end_y = end_point          # 목적지 좌표
        start_point = [9,4]  # 출발지 지정
        end_point = env.local_target[0]  # 첫 번째 목적지 지정
        #######################################################################
        # 목적지 도착 flag (done) 및 인풋 데이터 (s) 초기화
        done = False
        s_temp_1 = np.append(grid_map, start_point)
        s_temp_2 = np.append(s_temp_1, end_point)
        s = np.array(s_temp_2)

        while not done:  # OB, 장애물, 최종 목표 도달시 종료
            ####################################################################################
            # # -> 무한 루프
            # # (option) test 경우 추가: 출발점에서는 무조건 위로 올라간다 (action=0)
            # x, y = s[-4:-2]
            # if [x,y] == [9,4]:
            #     a = 0
            # else:
            #     a = q.test_action(torch.from_numpy(s).float())  # test_action 수행 ->
            #####################################################################################
            a = q.test_action(torch.from_numpy(s).float())  # test_action 수행
            #####################################################################################
            grid, r, cum_reward, done, goal_ob_reward = env.step(a)
            # s_prime = np.array(env.curloc)
            new_grid_map = grid.reshape(-1)
            s_prime_temp_1 = np.append(new_grid_map, env.curloc)
            s_prime_temp_2 = np.append(s_prime_temp_1, end_point)
            s_prime = np.array(s_prime_temp_2)

            s = s_prime
            score += r

        # print_interval (=1) 마다 현황 디스플레이하고 q_target 업데이트 및 score 초기화
        if n_epi % print_interval == 0 and n_epi != 0:
            cur_time = datetime.now(tz)
            simple_cur_time = cur_time.strftime("%H:%M:%S")
            print('▶ Episode #', n_epi, end=' → ')
            print('Score =', score, end='...')
            print('경로 길이:', len(env.actions), end=', ')
            if goal_ob_reward == 'finish':
                print('성공 여부: ', goal_ob_reward)
            else:
                print('성공 여부 : 실패', goal_ob_reward)
        
        score = 0.0
        print('→ pred_path:', env.actions)

    # 모든 에피소드 종료 후 결과 디스플레이
    # 코드 추가할 것!!!

# %%
# test 모드 실행
train_mode = False
test()
# Out:
# model path = /10000_model.pt
# data/factory_order_test.csv used
# → pred_path: [(9, 4)]
# ▶ Episode # 1 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 2 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 3 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 4 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 5 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 6 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 7 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 8 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 9 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 10 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 11 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 12 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 13 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 14 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 15 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 16 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 17 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 18 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 19 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 20 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 21 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 22 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 23 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 24 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 25 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 26 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 27 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 28 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 29 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 30 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 31 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 32 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 33 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 34 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 35 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 36 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 37 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 38 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 39 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 40 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 41 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 42 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 43 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 44 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 45 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 46 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 47 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 48 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 49 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 50 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 51 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 52 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 53 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 54 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 55 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 56 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 57 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 58 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 59 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 60 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 61 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 62 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 63 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 64 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 65 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 66 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 67 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 68 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 69 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 70 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 71 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 72 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 73 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 74 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 75 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 76 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 77 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 78 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 79 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 80 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 81 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 82 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 83 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 84 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 85 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 86 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 87 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 88 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 89 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 90 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 91 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 92 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 93 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 94 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 95 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 96 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 97 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 98 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 99 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 100 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 101 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 102 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 103 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 104 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 105 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 106 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 107 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 108 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 109 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 110 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 111 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 112 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 113 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 114 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 115 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 116 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 117 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 118 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 119 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 120 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 121 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 122 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 123 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 124 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 125 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 126 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 127 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 128 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 129 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 130 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 131 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 132 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 133 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 134 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 135 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 136 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 137 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 138 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 139 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 140 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 141 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 142 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 143 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 144 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 145 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 146 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 147 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 148 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 149 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 150 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 151 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 152 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 153 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 154 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 155 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 156 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 157 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 158 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 159 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 160 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 161 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 162 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 163 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 164 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 165 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 166 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 167 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 168 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 169 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 170 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 171 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 172 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 173 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 174 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 175 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 176 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 177 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 178 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 179 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 180 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 181 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 182 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 183 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 184 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 185 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 186 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 187 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 188 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 189 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 190 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 191 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 192 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 193 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 194 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 195 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 196 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 197 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 198 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 199 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 200 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 201 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 202 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 203 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 204 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 205 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 206 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 207 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 208 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 209 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 210 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 211 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 212 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 213 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 214 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 215 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 216 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 217 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 218 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 219 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 220 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 221 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 222 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 223 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 224 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 225 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 226 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 227 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 228 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 229 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 230 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 231 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 232 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 233 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 234 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 235 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 236 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 237 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 238 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 239 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 240 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 241 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 242 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 243 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 244 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 245 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 246 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 247 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 248 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 249 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 250 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 251 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 252 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 253 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 254 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 255 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 256 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 257 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 258 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 259 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 260 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 261 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 262 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 263 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 264 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 265 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 266 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 267 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 268 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 269 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 270 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 271 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 272 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 273 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 274 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 275 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 276 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 277 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 278 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 279 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 280 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 281 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 282 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 283 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 284 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 285 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 286 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 287 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 288 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 289 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 290 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 291 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 292 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 293 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 294 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 295 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 296 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 297 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 298 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 299 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 300 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 301 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 302 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 303 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 304 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 305 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 306 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 307 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 308 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 309 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 310 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 311 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 312 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 313 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 314 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 315 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 316 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 317 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 318 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 319 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 320 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 321 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 322 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 323 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 324 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 325 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 326 → Score = -10.2...경로 길이: 3, 성공 여부 : 실패 True
# → pred_path: [(9, 4), (8, 4), (7, 4)]
# ▶ Episode # 327 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 328 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 329 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 330 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 331 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 332 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 333 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 334 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 335 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 336 → Score = -10.2...경로 길이: 3, 성공 여부 : 실패 True
# → pred_path: [(9, 4), (8, 4), (7, 4)]
# ▶ Episode # 337 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 338 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 339 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 340 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 341 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 342 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 343 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 344 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 345 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 346 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 347 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 348 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 349 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 350 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 351 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 352 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 353 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 354 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 355 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 356 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 357 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 358 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 359 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 360 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 361 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 362 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 363 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 364 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 365 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 366 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 367 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 368 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 369 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 370 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 371 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 372 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 373 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 374 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 375 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 376 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 377 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 378 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 379 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 380 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 381 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 382 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 383 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 384 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 385 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 386 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 387 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 388 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 389 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 390 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 391 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 392 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 393 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 394 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 395 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 396 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 397 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 398 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 399 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 400 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 401 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 402 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 403 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 404 → Score = -10.2...경로 길이: 3, 성공 여부 : 실패 True
# → pred_path: [(9, 4), (8, 4), (7, 4)]
# ▶ Episode # 405 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 406 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 407 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 408 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 409 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 410 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 411 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 412 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 413 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 414 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 415 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 416 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 417 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 418 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 419 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 420 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 421 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 422 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 423 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 424 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 425 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 426 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 427 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 428 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 429 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 430 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 431 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 432 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 433 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 434 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 435 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 436 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 437 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 438 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 439 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 440 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 441 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 442 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 443 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 444 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 445 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 446 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 447 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 448 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 449 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 450 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 451 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 452 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 453 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 454 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 455 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 456 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 457 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 458 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 459 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 460 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 461 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 462 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 463 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 464 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 465 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 466 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 467 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 468 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 469 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 470 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 471 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 472 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 473 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 474 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 475 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 476 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 477 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 478 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 479 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 480 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 481 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 482 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 483 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 484 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 485 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 486 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 487 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 488 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 489 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 490 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 491 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 492 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 493 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 494 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 495 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 496 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 497 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 498 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 499 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 500 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 501 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 502 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 503 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 504 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 505 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 506 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 507 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 508 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 509 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 510 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 511 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 512 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 513 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 514 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 515 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 516 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 517 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 518 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 519 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 520 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 521 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 522 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 523 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 524 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 525 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 526 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 527 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 528 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 529 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 530 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 531 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 532 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 533 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 534 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 535 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 536 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 537 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 538 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 539 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 540 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 541 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 542 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 543 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 544 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 545 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 546 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 547 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 548 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 549 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 550 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 551 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 552 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 553 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 554 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 555 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 556 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 557 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 558 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 559 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 560 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 561 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 562 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 563 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 564 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 565 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 566 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 567 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 568 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 569 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 570 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 571 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 572 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 573 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 574 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 575 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 576 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 577 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 578 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 579 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 580 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 581 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 582 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 583 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 584 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 585 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ...
# → pred_path: [(9, 4)]
# ▶ Episode # 812 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 813 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 814 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 815 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 816 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 817 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 818 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 819 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 820 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 821 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 822 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 823 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 824 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 825 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 826 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 827 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 828 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 829 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 830 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 831 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 832 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 833 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 834 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 835 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 836 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 837 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 838 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 839 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 840 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 841 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 842 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 843 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 844 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 845 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 846 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 847 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 848 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 849 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 850 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 851 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 852 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 853 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 854 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 855 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 856 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 857 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 858 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 859 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 860 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 861 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 862 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 863 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 864 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 865 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 866 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 867 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 868 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 869 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 870 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 871 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 872 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 873 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 874 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 875 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 876 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 877 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 878 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 879 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 880 → Score = -10.2...경로 길이: 3, 성공 여부 : 실패 True
# → pred_path: [(9, 4), (8, 4), (7, 4)]
# ▶ Episode # 881 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 882 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 883 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 884 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 885 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 886 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 887 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 888 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 889 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 890 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 891 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 892 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 893 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 894 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 895 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 896 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 897 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 898 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 899 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 900 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 901 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 902 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 903 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 904 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 905 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 906 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 907 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 908 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 909 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 910 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 911 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 912 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 913 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 914 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 915 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 916 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 917 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 918 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 919 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 920 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 921 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 922 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 923 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 924 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 925 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 926 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 927 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 928 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 929 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 930 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 931 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 932 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 933 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 934 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 935 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 936 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 937 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 938 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 939 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 940 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 941 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 942 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 943 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 944 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 945 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 946 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 947 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 948 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 949 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 950 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 951 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 952 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 953 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 954 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 955 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 956 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 957 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 958 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 959 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 960 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 961 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 962 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 963 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 964 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 965 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 966 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 967 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 968 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 969 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 970 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 971 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 972 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 973 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 974 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 975 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 976 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 977 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 978 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 979 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 980 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 981 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 982 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 983 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 984 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 985 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 986 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 987 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 988 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ▶ Episode # 989 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 True
# → pred_path: [(9, 4)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/drive/Othercomputers/MacBook_Air/path-finding-rl/data in <module>()
#       1 # test 모드 실행
#       2 train_mode = False
# ----> 3 test()
#
# /content/drive/Othercomputers/MacBook_Air/path-finding-rl/data in test()
#      50             new_grid_map = grid.reshape(-1)
#      51             s_prime_temp_1 = np.append(new_grid_map, env.curloc)
# ---> 52             s_prime_temp_2 = np.append(s_prime_temp_1, end_point)
#      53             s_prime = np.array(s_prime_temp_2)
#      54
#
# <__array_function__ internals> in append(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py in append(arr, values, axis)
#    4815         values = ravel(values)
#    4816         axis = arr.ndim-1
# -> 4817     return concatenate((arr, values), axis=axis)
#    4818
#    4819
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/multiarray.py in concatenate(arrays, axis, out, dtype, casting)
#     146
#     147
# --> 148 @array_function_from_c_func_and_dispatcher(_multiarray_umath.concatenate)
#     149 def concatenate(arrays, axis=None, out=None, *, dtype=None, casting=None):
#     150     """
#
# KeyboardInterrupt:

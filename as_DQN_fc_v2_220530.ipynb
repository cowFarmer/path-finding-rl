# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

__file__ = '/content/drive/Othercomputers/MacBook_Air/path-finding-rl/data'
# Out:
# Mounted at /content/drive

# %%
from string import ascii_uppercase
#from draw_utils import *
#from pyglet.gl import *
import numpy as np
import pandas as pd
import os
import random
from datetime import datetime
import pytz
import matplotlib.pyplot as plt

# reward
move_reward = -1
obs_reward = -10
goal_reward = 100

###################################
# train or test 모드 지정
train_mode = True
###################################
print('reward:' , move_reward, obs_reward, goal_reward)

#__file__ = '/home/ogangza/heung_path_finding/path-finding-rl/data'

local_path = os.path.abspath(os.path.join(os.path.dirname(__file__)))


class Simulator:
    def __init__(self):
        '''
        height : 그리드 높이
        width : 그리드 너비 
        inds : A ~ Q alphabet list
        '''
        #######################################################################################
        # Load train or test data
        if train_mode:  # 훈련 데이타 읽기
            self.files = pd.read_csv(os.path.join(local_path, "data/factory_order_train.csv"))
            print('data/factory_order_train.csv used')
        else:  # 테스트 데이터 읽기
            self.files = pd.read_csv(os.path.join(local_path, "data/factory_order_test.csv"))
            print('data/factory_order_test.csv used')
        #######################################################################################
        self.height = 10
        self.width = 9
        self.inds = list(ascii_uppercase)[:17]

    def set_box(self):
        '''
        아이템들이 있을 위치를 미리 정해놓고 그 위치 좌표들에 아이템이 들어올 수 있으므로 그리드에 100으로 표시한다.
        데이터 파일에서 이번 에피소드 아이템 정보를 받아 가져와야 할 아이템이 있는 좌표만 -100으로 표시한다.
        self.local_target에 에이전트가 이번에 방문해야할 좌표들을 저장한다.
        따라서 가져와야하는 아이템 좌표와 end point 좌표(처음 시작했던 좌표로 돌아와야하므로)가 들어가게 된다.
        '''
        box_data = pd.read_csv(os.path.join(local_path, "./data/box.csv"))
        

        ######################################
        # box의 list 만들어서 step에 활용하기
        self.box_list = box_data[['row', 'col']]
        # print(f"box_list = {self.box_list}")
        ######################################
        

        ######################################
        #print('box data:', box_data)
        ######################################

        # 물건이 들어있을 수 있는 경우
        for box in box_data.itertuples(index = True, name ='Pandas'):
            self.grid[getattr(box, "row")][getattr(box, "col")] = -10
            
            #######################################
            #print('self.grid:', self.grid)
            #######################################
        

        # 물건이 실제 들어있는 경우
        order_item = list(set(self.inds) & set(self.items))
        order_csv = box_data[box_data['item'].isin(order_item)]
        
        ########################################
        #print('order_csv:', order_csv)
        ########################################

        for order_box in order_csv.itertuples(index = True, name ='Pandas'):
            self.grid[getattr(order_box, "row")][getattr(order_box, "col")] = 50
            # local target에 가야 할 위치 좌표 넣기
            self.local_target.append(
                [getattr(order_box, "row"),
                 getattr(order_box, "col")]
                )

            #######################################
            #print('self.grid:', self.grid)
            #######################################

        ################################################
        #print('self.local_target.sort() 전:', self.local_target)
        ################################################
        
        # self.local_target.sort() 
        self.local_target.append([9,4]) 

        ###############################
        # local_target을 100으로 두기
        x_temp_local_target, y_temp_local_target = self.local_target[0]
        self.grid[x_temp_local_target][y_temp_local_target] = 100
        ###############################

        ################################################
        #print('self.local_target.sort():', self.local_target)
        ###############################################
        
        # 알파벳을 Grid에 넣어서 -> grid에 2Dconv 적용 가능

    def set_obstacle(self):
        '''
        장애물이 있어야하는 위치는 미리 obstacles.csv에 정의되어 있다. 이 좌표들을 0으로 표시한다.
        '''
        obstacles_data = pd.read_csv(os.path.join(local_path, "./data/obstacles.csv"))
        for obstacle in obstacles_data.itertuples(index = True, name ='Pandas'):
            self.grid[getattr(obstacle, "row")][getattr(obstacle, "col")] = -10
            
        ##########################################
        #print('self.grid:', self.grid)
        ##########################################
        
    def reset(self, epi):
        # initial episode parameter setting
        self.epi = epi
        self.items = list(self.files.iloc[self.epi])[0]
        self.cumulative_reward = 0
        self.terminal_location = None
        self.local_target = []
        self.actions = []

        # initial grid setting
        # self.grid = np.ones((self.height, self.width), dtype="float16")
        self.grid = np.full((self.height, self.width), -1., dtype="float16")

        # set information about the gridworld
        self.set_box()
        self.set_obstacle()

        # start point를 grid에 표시
        self.curloc = [9, 4]
        self.grid[int(self.curloc[0])][int(self.curloc[1])] = 0
        
        self.done = False
        
        ########################################
        #print('reset curloc:', self.curloc)
        ########################################
        
        return self.grid

    def apply_action(self, action, cur_x, cur_y):
        new_x = cur_x
        new_y = cur_y
        # up
        if action == 0:
            new_x = cur_x - 1
        # down
        elif action == 1:
            new_x = cur_x + 1
        # left
        elif action == 2:
            new_y = cur_y - 1
        # right
        else:
            new_y = cur_y + 1

        return int(new_x), int(new_y)


    def get_reward(self, new_x, new_y, out_of_boundary):
        # 바깥으로 나가는 경우
        if any(out_of_boundary):
            reward = obs_reward
        else:
            # 장애물에 부딪히는 경우 
            if self.grid[new_x][new_y] == -10:
                reward = obs_reward  
            # 현재 목표에 도달한 경우
            elif new_x == self.terminal_location[0] and new_y == self.terminal_location[1]:
                reward = goal_reward
            # 그냥 움직이는 경우 
            else:
                reward = move_reward

        return reward

    def step(self, action):
        self.terminal_location = self.local_target[0]
        cur_x,cur_y = self.curloc
        self.actions.append((cur_x, cur_y))

        goal_ob_reward = False
        
        new_x, new_y = self.apply_action(action, cur_x, cur_y)

        out_of_boundary = [new_x < 0, new_x >= self.height, new_y < 0, new_y >= self.width]

        is_box_list = self.box_list.copy()
        is_box_list = is_box_list.loc[(is_box_list['row']==cur_x) & (is_box_list['col']==cur_y)]

        ####################################
        # test용
        # 9,4를 is_box_list에 append해서 결과 확인해보기
        # test_df = pd.DataFrame(data=[[9,4]], index=['17'], columns=['row','col'])
        # is_box_list = pd.concat([is_box_list,test_df],join='inner')
        # is_box_list = is_box_list.loc[(is_box_list['row']==cur_x) & (is_box_list['col']==cur_y)]
        # print(len(is_box_list))
        ####################################

        # 바깥으로 나가는 경우 종료
        if any(out_of_boundary):
            
            #원 위치
            #new_x = cur_x
            #new_y = cur_y
            
            self.done = True
            # goal_ob_reward = True
            
        else:
            # 장애물에 부딪히는 경우 종료
            if self.grid[new_x][new_y] == -10:
                
                #원 위치
                #new_x = cur_x
                #new_y = cur_y
                
                self.done = True
                # goal_ob_reward = True

            # 현재 목표에 도달한 경우, 다음 목표 설정
            elif new_x == self.terminal_location[0] and new_y == self.terminal_location[1]:

                # end point 일 때
                if [new_x, new_y] == [9,4]:
                    self.done = True

                self.local_target.remove(self.local_target[0])
                ##########################
                # local_target
                x_temp_local_target, y_temp_local_target = self.local_target[0]
                self.grid[x_temp_local_target][y_temp_local_target] = 100
                ##########################
                
                self.grid[cur_x][cur_y] = -1
                self.grid[new_x][new_y] = 0
                goal_ob_reward = True
                self.curloc = [new_x, new_y]

                
            else:
                ##########################
                # 현재 좌표가 box_list에 해당하면 움직였을 때 grid값이 1이 아닌 100 넣어주기
                if len(is_box_list) == True:
                    self.grid[cur_x][cur_y] = -10
                else:
                    # 그냥 움직이는 경우 
                    self.grid[cur_x][cur_y] = -1
                ##########################

                self.grid[new_x][new_y] = 0
                self.curloc = [new_x,new_y]
                
        reward = self.get_reward(new_x, new_y, out_of_boundary)
        self.cumulative_reward += reward
        return self.grid, reward, self.cumulative_reward, self.done, goal_ob_reward, self.curloc, self.local_target[0]
# Out:
# reward: -1 -10 100

# %%
import gym
import collections
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#Hyperparameters
learning_rate = 0.0005
gamma         = 0.9
buffer_limit  = 50000 
batch_size    = 2

class ReplayBuffer():
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit)
    
    def put(self, transition):
        self.buffer.append(transition)
    
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst, cur_location_lst, target_location_lst = [], [], [], [], [], [], []
        #######################################################################
        for transition in mini_batch:
            s, a, r, s_prime, done_mask, cur_location, target_location = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])
            cur_location_lst.append([cur_location])
            target_location_lst.append([target_location])

        return torch.tensor(np.array(s_lst), dtype=torch.float), torch.tensor(np.array(a_lst)), \
               torch.tensor(np.array(r_lst)), torch.tensor(np.array(s_prime_lst), dtype=torch.float), \
               torch.tensor(np.array(done_mask_lst)), torch.tensor(np.array(cur_location_lst)), \
               torch.tensor(np.array(target_location_lst))
    
    def size(self):
        return len(self.buffer)

class Qnet(nn.Module):
    def __init__(self):
        super(Qnet, self).__init__()
        self.fc1 = nn.Linear(90, 360)
        self.fc2 = nn.Linear(360, 720)
        self.fc3 = nn.Linear(720, 360)
        self.fc4 = nn.Linear(360, 64)
        self.fc5 = nn.Linear(64, 4)

    def forward(self, x):
        x = x.to(device)
        x = F.relu(self.fc1(x))
        # print(x.shape)
        x = F.relu(self.fc2(x))
        # print(x.shape)
        x = F.relu(self.fc3(x))
        # print(x.shape)
        x = F.relu(self.fc4(x))
        # print(x.shape)
        x = self.fc5(x)
        # print(x.shape)
        x = F.softmax(x, dim=0)
        # print(x.shape)
        return x
      
    def sample_action(self, obs, epsilon):
        out = self.forward(obs)
        coin = random.random()
        if coin < epsilon:
            return random.randint(0,3)
        else : 
            return out.argmax().item()

    ###################################################
    def test_action(self, obs):  # Test용 action 추가
        out = self.forward(obs)
        return out.argmax().item()
    ###################################################
            
def train(q, q_target, memory, optimizer):
    for i in range(10):
        s,a,r,s_prime,done_mask,cur_location,target_location = memory.sample(batch_size)


        q_out = q(s)
        q_a = q_out.gather(1,a.to(device))
        max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1)
        target = r.to(device) + gamma * max_q_prime * done_mask.to(device)

        #####################################
        # print("q_a")
        # print(q_a)
        # print(q_a.shape)
        # print("\n\n\n")
        # print("target")
        # print(target)
        # print(target.shape)
        # print("################")
        #####################################

        # loss = F.smooth_l1_loss(q_a, target)
        loss_fn = nn.MSELoss()
        loss = loss_fn(q_a.to(torch.float32), target.to(torch.float32).detach())
        # print(f"loss = {loss}")
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %%
def main():
    tz = pytz.timezone('Asia/Seoul')

    env = Simulator()
    q = Qnet()
    q.to(device)
    q_target = Qnet()
    q_target.to(device)
    q_target.load_state_dict(q.state_dict())
    memory = ReplayBuffer()

    print_interval = 1000
    score = 0.0  
    optimizer = optim.Adam(q.parameters(), lr=learning_rate)
    
    print('len(env.files):', len(env.files))
    
    #path_length = []

    for epoch in range(10):
        cur_time = datetime.now(tz)
        simple_cur_time = cur_time.strftime("%H:%M:%S")
        print(f"{epoch}번째 epoch, 시작▶{simple_cur_time}")
        for n_epi in range(len(env.files)): # range()의 인수로 len(env.files) 사용하면 됨 (=39,999)
            # epsilon = max(0.01, 1 - 0.01*(epoch/1))
            epsilon = max(0.01, 1 - (0.01*(epoch*10)))
            env.grid = env.reset(n_epi)  # env reset: 에피소드 번호에 해당하는 목표물 리스트 env.local_target 생성, 그리드맵 생성
            start_point = [9,4]  # 출발지 지정
            end_point = env.local_target[0]  # 첫 번째 목적지 지정
            done = False
            ###################
            grid_temp_1 = env.grid.reshape(1,90)
            grid_temp_1 = grid_temp_1.squeeze()
            s = grid_temp_1
            ###################
            old_score = 0.0
            # print(f"env.grid=\n{env.grid}")

            while not done:
                a = q.sample_action(torch.from_numpy(s).float(), epsilon)
                grid, r, cum_reward, done, goal_ob_reward, cur_location, target_location = env.step(a)
                ###################
                grid_temp_2 = grid.reshape(1,90)
                grid_temp_2 = grid_temp_2.squeeze()
                s_prime = grid_temp_2

                # done_mask = 0.0 if done else 1.0 # done = True일 때만 memory.put 진행한다. -> 죽는거만 메모리에 들어가지 않을까?
                if (done == True and cum_reward > 0) or goal_ob_reward == True: # -> target_location에 도착했을 때도 추가해야함
                    memory.put((s,a,r/100.0,s_prime,done,cur_location,target_location)) # 현재 agent 좌표랑 local target 좌표 추가
                s = s_prime
                

                score += r
                '''
                if score > old_score:
                        cur_time = datetime.now(tz)
                        simple_cur_time = cur_time.strftime("%H:%M:%S")
                        print('▶ Episode #', n_epi, 'start time:', simple_cur_time, end='→')
                        print('Score =', score, 'appended actions =', s, end='...')
                        print('경로 길이:', len(env.actions))
                '''
                old_score = score
                        
                if done:
                    break
            if memory.size() > 5: 
                train(q, q_target, memory, optimizer)

            if n_epi % print_interval == 0 and n_epi != 0:
                cur_time = datetime.now(tz)
                simple_cur_time = cur_time.strftime("%H:%M:%S")
                print(f"Epoch # {epoch}, Episode # {n_epi}, start time: {simple_cur_time}")
                q_target.load_state_dict(q.state_dict())
                print(f"score:{score/print_interval:.1f}, n_buffer:{memory.size()}, eps:{epsilon*100:.1f}")
                
                score = 0.0

                # torch.save(q, model_path)
                torch.save(q, __file__+f"/{epoch}_{n_epi}_model.pt")
            ##### 액션 결과물 확인하기
            if env.cumulative_reward > 0:
                print(f"{epoch}번째 에포크로, {n_epi}번째 에피소드는 {env.cumulative_reward:.1f}점 입니다.")
                print(f"target은 {env.items} ▶▶▶ {env.local_target}입니다.")
                print(f"action은 총 {len(env.actions)}번 움직였습니다.\n{env.actions}")
                # print(grid)
                print("###############")

        torch.save(q, __file__+f"/{epoch}_{n_epi}_model.pt")

# if __name__ == '__main__':
#     main()
# Out:
# data/factory_order_train.csv used
# len(env.files): 39999
# 0번째 epoch, 시작▶15:31:37
# Epoch # 0, Episode # 1000, start time: 15:31:52
# score:-11.2, n_buffer:0, eps:100.0
# Epoch # 0, Episode # 2000, start time: 15:32:05
# score:-11.3, n_buffer:0, eps:100.0
# 0번째 에포크로, 2665번째 에피소드는 62.0점 입니다.
# target은 ['A', 'D', 'E', 'J', 'K', 'N', 'O'] ▶▶▶ [[2, 0], [0, 0], [0, 5], [0, 6], [2, 8], [3, 8], [9, 4]]입니다.
# action은 총 30번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 3), (8, 2), (7, 2), (7, 3), (8, 3), (7, 3), (8, 3), (7, 3), (6, 3), (5, 3), (6, 3), (7, 3), (6, 3), (7, 3), (7, 2), (8, 2), (7, 2), (8, 2), (8, 1), (7, 1), (7, 2), (7, 1), (7, 0), (6, 0), (5, 0), (6, 0)]
# ###############
# Epoch # 0, Episode # 3000, start time: 15:32:18
# score:-11.3, n_buffer:2, eps:100.0
# Epoch # 0, Episode # 4000, start time: 15:32:31
# score:-11.3, n_buffer:2, eps:100.0
# Epoch # 0, Episode # 5000, start time: 15:32:45
# score:-11.2, n_buffer:2, eps:100.0
# Epoch # 0, Episode # 6000, start time: 15:32:58
# score:-11.2, n_buffer:2, eps:100.0
# 0번째 에포크로, 6983번째 에피소드는 75.0점 입니다.
# target은 ['A', 'B', 'J', 'K', 'M', 'P', 'Q'] ▶▶▶ [[4, 0], [0, 5], [0, 6], [0, 8], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 17번 움직였습니다.
# [(9, 4), (8, 4), (9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (7, 3), (8, 3), (7, 3), (7, 2), (7, 1), (6, 1), (7, 1), (6, 1), (6, 0), (5, 0)]
# ###############
# Epoch # 0, Episode # 7000, start time: 15:33:11
# score:-11.3, n_buffer:4, eps:100.0
# Epoch # 0, Episode # 8000, start time: 15:33:24
# score:-11.2, n_buffer:4, eps:100.0
# Epoch # 0, Episode # 9000, start time: 15:33:36
# score:-11.2, n_buffer:4, eps:100.0
# Epoch # 0, Episode # 10000, start time: 15:33:50
# score:-11.2, n_buffer:4, eps:100.0
# Epoch # 0, Episode # 11000, start time: 15:34:03
# score:-11.4, n_buffer:4, eps:100.0
# Epoch # 0, Episode # 12000, start time: 15:34:16
# score:-11.4, n_buffer:4, eps:100.0
# 0번째 에포크로, 12463번째 에피소드는 60.0점 입니다.
# target은 ['B', 'C', 'F', 'I', 'L', 'M'] ▶▶▶ [[3, 0], [0, 1], [0, 4], [0, 7], [0, 8], [9, 4]]입니다.
# action은 총 32번 움직였습니다.
# [(9, 4), (8, 4), (8, 5), (8, 6), (8, 7), (7, 7), (6, 7), (5, 7), (6, 7), (7, 7), (8, 7), (8, 6), (8, 7), (8, 6), (8, 5), (8, 4), (7, 4), (8, 4), (8, 3), (8, 4), (7, 4), (7, 3), (7, 2), (7, 1), (6, 1), (5, 1), (4, 1), (3, 1), (2, 1), (3, 1), (4, 1), (4, 0)]
# ###############
# 0번째 에포크로, 12466번째 에피소드는 83.0점 입니다.
# target은 ['A', 'E', 'G', 'I', 'M', 'Q'] ▶▶▶ [[0, 0], [0, 2], [0, 4], [0, 8], [5, 8], [9, 4]]입니다.
# action은 총 9번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (7, 1), (6, 1), (6, 0), (5, 0)]
# ###############
# Epoch # 0, Episode # 13000, start time: 15:34:50
# score:-11.0, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 14000, start time: 15:35:42
# score:-11.4, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 15000, start time: 15:36:34
# score:-11.4, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 16000, start time: 15:37:26
# score:-11.3, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 17000, start time: 15:38:18
# score:-11.2, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 18000, start time: 15:39:10
# score:-11.2, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 19000, start time: 15:40:02
# score:-11.1, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 20000, start time: 15:40:53
# score:-11.4, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 21000, start time: 15:41:45
# score:-11.3, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 22000, start time: 15:42:37
# score:-11.4, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 23000, start time: 15:43:28
# score:-11.3, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 24000, start time: 15:44:20
# score:-11.4, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 25000, start time: 15:45:12
# score:-11.2, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 26000, start time: 15:46:04
# score:-11.3, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 27000, start time: 15:46:56
# score:-11.3, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 28000, start time: 15:47:48
# score:-11.4, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 29000, start time: 15:48:40
# score:-11.2, n_buffer:8, eps:100.0
# Epoch # 0, Episode # 30000, start time: 15:49:33
# score:-11.2, n_buffer:8, eps:100.0
# 0번째 에포크로, 30447번째 에피소드는 177.0점 입니다.
# target은 ['A', 'B', 'D', 'H', 'K', 'L', 'P'] ▶▶▶ [[2, 0], [0, 3], [0, 6], [0, 7], [4, 8], [9, 4]]입니다.
# action은 총 16번 움직였습니다.
# [(9, 4), (8, 4), (9, 4), (8, 4), (8, 3), (8, 4), (8, 3), (8, 2), (8, 1), (7, 1), (6, 1), (5, 1), (4, 1), (4, 0), (5, 0), (4, 0)]
# ###############
# Epoch # 0, Episode # 31000, start time: 15:50:26
# score:-11.1, n_buffer:11, eps:100.0
# Epoch # 0, Episode # 32000, start time: 15:51:17
# score:-11.2, n_buffer:11, eps:100.0
# Epoch # 0, Episode # 33000, start time: 15:52:09
# score:-11.3, n_buffer:11, eps:100.0
# Epoch # 0, Episode # 34000, start time: 15:53:02
# score:-11.3, n_buffer:11, eps:100.0
# Epoch # 0, Episode # 35000, start time: 15:53:54
# score:-11.3, n_buffer:11, eps:100.0
# Epoch # 0, Episode # 36000, start time: 15:54:47
# score:-11.1, n_buffer:11, eps:100.0
# 0번째 에포크로, 36465번째 에피소드는 80.0점 입니다.
# target은 ['A', 'C', 'D', 'H', 'K', 'P', 'Q'] ▶▶▶ [[3, 0], [2, 0], [0, 3], [0, 6], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 12번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (8, 2), (7, 2), (7, 1), (6, 1), (6, 0), (5, 0), (6, 0)]
# ###############
# 0번째 에포크로, 36495번째 에피소드는 81.0점 입니다.
# target은 ['A', 'D', 'G', 'K', 'L', 'P', 'Q'] ▶▶▶ [[2, 0], [0, 2], [0, 6], [0, 7], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (7, 1), (6, 1), (6, 0), (5, 0)]
# ###############
# 0번째 에포크로, 36702번째 에피소드는 80.0점 입니다.
# target은 ['A', 'B', 'C', 'F', 'G', 'J', 'O'] ▶▶▶ [[4, 0], [3, 0], [0, 1], [0, 2], [0, 5], [3, 8], [9, 4]]입니다.
# action은 총 12번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (8, 2), (8, 1), (7, 1), (7, 0), (6, 0), (5, 0), (5, 1)]
# ###############
# 0번째 에포크로, 36741번째 에피소드는 83.0점 입니다.
# target은 ['A', 'C', 'E', 'L', 'M', 'O'] ▶▶▶ [[3, 0], [0, 0], [0, 7], [0, 8], [3, 8], [9, 4]]입니다.
# action은 총 9번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (7, 1), (6, 1), (6, 0), (5, 0)]
# ###############
# Epoch # 0, Episode # 37000, start time: 15:55:39
# score:-11.1, n_buffer:19, eps:100.0
# Epoch # 0, Episode # 38000, start time: 15:56:32
# score:-11.4, n_buffer:19, eps:100.0
# 0번째 에포크로, 38317번째 에피소드는 74.0점 입니다.
# target은 ['A', 'D', 'E', 'F', 'J', 'L', 'O'] ▶▶▶ [[2, 0], [0, 0], [0, 1], [0, 5], [0, 7], [3, 8], [9, 4]]입니다.
# action은 총 18번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 5), (7, 4), (8, 4), (8, 3), (7, 3), (8, 3), (8, 2), (7, 2), (7, 1), (6, 1), (6, 0), (7, 0), (6, 0), (5, 0), (6, 0)]
# ###############
# Epoch # 0, Episode # 39000, start time: 15:57:24
# score:-11.2, n_buffer:21, eps:100.0
# 0번째 에포크로, 39843번째 에피소드는 80.0점 입니다.
# target은 ['A', 'C', 'K', 'L', 'O', 'P'] ▶▶▶ [[3, 0], [0, 6], [0, 7], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 12번 움직였습니다.
# [(9, 4), (8, 4), (9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (7, 1), (7, 0), (6, 0), (5, 0), (5, 1)]
# ###############
# 1번째 epoch, 시작▶15:58:16
# Epoch # 1, Episode # 1000, start time: 15:59:09
# score:-22.6, n_buffer:23, eps:90.0
# Epoch # 1, Episode # 2000, start time: 16:00:02
# score:-11.4, n_buffer:23, eps:90.0
# Epoch # 1, Episode # 3000, start time: 16:00:55
# score:-11.5, n_buffer:23, eps:90.0
# 1번째 에포크로, 3649번째 에피소드는 79.0점 입니다.
# target은 ['A', 'D', 'F', 'I', 'J', 'O', 'P'] ▶▶▶ [[2, 0], [0, 1], [0, 4], [0, 5], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 13번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (8, 3), (7, 3), (6, 3), (7, 3), (7, 2), (7, 1), (6, 1), (6, 0), (5, 0)]
# ###############
# 1번째 에포크로, 3685번째 에피소드는 181.0점 입니다.
# target은 ['A', 'B', 'F', 'H', 'M', 'O', 'P'] ▶▶▶ [[0, 1], [0, 3], [0, 8], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 12번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (8, 0), (7, 0), (6, 0), (5, 0), (4, 0), (4, 1), (3, 1)]
# ###############
# Epoch # 1, Episode # 4000, start time: 16:01:47
# score:-11.2, n_buffer:28, eps:90.0
# Epoch # 1, Episode # 5000, start time: 16:02:40
# score:-11.6, n_buffer:28, eps:90.0
# Epoch # 1, Episode # 6000, start time: 16:03:33
# score:-11.7, n_buffer:28, eps:90.0
# Epoch # 1, Episode # 7000, start time: 16:04:25
# score:-11.6, n_buffer:28, eps:90.0
# Epoch # 1, Episode # 8000, start time: 16:05:15
# score:-11.4, n_buffer:28, eps:90.0
# Epoch # 1, Episode # 9000, start time: 16:06:06
# score:-11.6, n_buffer:28, eps:90.0
# 1번째 에포크로, 9893번째 에피소드는 81.0점 입니다.
# target은 ['A', 'D', 'F', 'I', 'L', 'M', 'N'] ▶▶▶ [[2, 0], [0, 1], [0, 4], [0, 7], [0, 8], [2, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (7, 1), (7, 2), (7, 1), (6, 1), (6, 0), (5, 0)]
# ###############
# Epoch # 1, Episode # 10000, start time: 16:06:56
# score:-11.4, n_buffer:30, eps:90.0
# 1번째 에포크로, 10019번째 에피소드는 75.0점 입니다.
# target은 ['A', 'G', 'J', 'N', 'Q'] ▶▶▶ [[0, 2], [0, 5], [2, 8], [5, 8], [9, 4]]입니다.
# action은 총 17번 움직였습니다.
# [(9, 4), (8, 4), (9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (7, 3), (8, 3), (8, 2), (7, 2), (7, 1), (7, 0), (7, 1), (6, 1), (5, 1), (5, 0)]
# ###############
# 1번째 에포크로, 10132번째 에피소드는 82.0점 입니다.
# target은 ['A', 'I', 'N', 'O', 'Q'] ▶▶▶ [[0, 4], [2, 8], [3, 8], [5, 8], [9, 4]]입니다.
# action은 총 10번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (7, 2), (7, 1), (7, 0), (6, 0), (5, 0), (6, 0)]
# ###############
# 1번째 에포크로, 10972번째 에피소드는 78.0점 입니다.
# target은 ['A', 'B', 'D', 'E', 'F', 'G', 'H'] ▶▶▶ [[4, 0], [2, 0], [0, 0], [0, 1], [0, 2], [0, 3], [9, 4]]입니다.
# action은 총 14번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (7, 1), (7, 2), (7, 1), (6, 1), (7, 1), (6, 1), (6, 0), (5, 0), (5, 1)]
# ###############
# Epoch # 1, Episode # 11000, start time: 16:07:47
# score:-11.2, n_buffer:36, eps:90.0
# Epoch # 1, Episode # 12000, start time: 16:08:37
# score:-11.3, n_buffer:36, eps:90.0
# Epoch # 1, Episode # 13000, start time: 16:09:29
# score:-11.4, n_buffer:36, eps:90.0
# 1번째 에포크로, 13502번째 에피소드는 78.0점 입니다.
# target은 ['A', 'C', 'F', 'J', 'P'] ▶▶▶ [[3, 0], [0, 1], [0, 5], [4, 8], [9, 4]]입니다.
# action은 총 14번 움직였습니다.
# [(9, 4), (8, 4), (8, 5), (8, 4), (7, 4), (7, 3), (7, 2), (7, 3), (7, 2), (7, 1), (6, 1), (6, 0), (5, 0), (5, 1)]
# ###############
# Epoch # 1, Episode # 14000, start time: 16:10:20
# score:-11.5, n_buffer:38, eps:90.0
# 1번째 에포크로, 14732번째 에피소드는 81.0점 입니다.
# target은 ['A', 'C', 'E', 'F', 'G', 'O', 'P'] ▶▶▶ [[3, 0], [0, 0], [0, 1], [0, 2], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 4), (8, 3), (8, 2), (8, 1), (8, 0), (7, 0), (6, 0), (5, 0)]
# ###############
# 1번째 에포크로, 14779번째 에피소드는 72.0점 입니다.
# target은 ['G', 'H', 'I', 'N', 'P'] ▶▶▶ [[0, 3], [0, 4], [2, 8], [4, 8], [9, 4]]입니다.
# action은 총 20번 움직였습니다.
# [(9, 4), (8, 4), (9, 4), (8, 4), (7, 4), (7, 5), (7, 4), (8, 4), (8, 3), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (2, 2), (1, 2), (0, 2)]
# ###############
# Epoch # 1, Episode # 15000, start time: 16:11:11
# score:-11.3, n_buffer:42, eps:90.0
# Epoch # 1, Episode # 16000, start time: 16:12:03
# score:-11.5, n_buffer:42, eps:90.0
# Epoch # 1, Episode # 17000, start time: 16:12:55
# score:-11.6, n_buffer:42, eps:90.0
# 1번째 에포크로, 17515번째 에피소드는 83.0점 입니다.
# target은 ['A', 'E', 'G', 'H', 'Q'] ▶▶▶ [[0, 0], [0, 2], [0, 3], [5, 8], [9, 4]]입니다.
# action은 총 9번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (7, 1), (7, 0), (6, 0), (5, 0)]
# ###############
# Epoch # 1, Episode # 18000, start time: 16:13:47
# score:-11.4, n_buffer:44, eps:90.0
# 1번째 에포크로, 18549번째 에피소드는 80.0점 입니다.
# target은 ['A', 'C', 'E', 'G', 'H', 'P', 'Q'] ▶▶▶ [[3, 0], [0, 0], [0, 2], [0, 3], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 12번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (7, 3), (7, 2), (7, 1), (6, 1), (6, 0), (5, 0), (6, 0)]
# ###############
# Epoch # 1, Episode # 19000, start time: 16:14:39
# score:-11.5, n_buffer:46, eps:90.0
# 1번째 에포크로, 19206번째 에피소드는 76.0점 입니다.
# target은 ['A', 'C', 'D', 'F', 'K', 'L'] ▶▶▶ [[3, 0], [2, 0], [0, 1], [0, 6], [0, 7], [9, 4]]입니다.
# action은 총 16번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (8, 0), (7, 0), (6, 0), (5, 0), (6, 0), (6, 1), (5, 1), (4, 1), (5, 1), (4, 1), (5, 1)]
# ###############
# Epoch # 1, Episode # 20000, start time: 16:15:34
# score:-11.6, n_buffer:48, eps:90.0
# Epoch # 1, Episode # 21000, start time: 16:16:26
# score:-11.5, n_buffer:48, eps:90.0
# Epoch # 1, Episode # 22000, start time: 16:17:18
# score:-11.3, n_buffer:48, eps:90.0
# Epoch # 1, Episode # 23000, start time: 16:18:11
# score:-11.4, n_buffer:48, eps:90.0
# 1번째 에포크로, 23460번째 에피소드는 83.0점 입니다.
# target은 ['A', 'B', 'C', 'D', 'J', 'O', 'P'] ▶▶▶ [[4, 0], [3, 0], [2, 0], [0, 5], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 9번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (7, 1), (6, 1), (6, 0), (5, 0)]
# ###############
# Epoch # 1, Episode # 24000, start time: 16:19:03
# score:-11.3, n_buffer:50, eps:90.0
# Epoch # 1, Episode # 25000, start time: 16:19:55
# score:-11.3, n_buffer:50, eps:90.0
# Epoch # 1, Episode # 26000, start time: 16:20:47
# score:-11.5, n_buffer:50, eps:90.0
# 1번째 에포크로, 26037번째 에피소드는 79.0점 입니다.
# target은 ['A', 'C', 'E', 'F', 'G', 'I', 'M'] ▶▶▶ [[3, 0], [0, 0], [0, 1], [0, 2], [0, 4], [0, 8], [9, 4]]입니다.
# action은 총 13번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (8, 2), (7, 2), (7, 1), (7, 0), (6, 0), (7, 0), (6, 0), (5, 0)]
# ###############
# Epoch # 1, Episode # 27000, start time: 16:21:40
# score:-11.5, n_buffer:52, eps:90.0
# Epoch # 1, Episode # 28000, start time: 16:22:32
# score:-11.3, n_buffer:52, eps:90.0
# Epoch # 1, Episode # 29000, start time: 16:23:23
# score:-11.4, n_buffer:52, eps:90.0
# 1번째 에포크로, 29204번째 에피소드는 81.0점 입니다.
# target은 ['A', 'C', 'D', 'G', 'L', 'N'] ▶▶▶ [[3, 0], [2, 0], [0, 2], [0, 7], [2, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (7, 2), (8, 2), (7, 2), (7, 1), (7, 0), (6, 0), (5, 0)]
# ###############
# 1번째 에포크로, 29990번째 에피소드는 75.0점 입니다.
# target은 ['A', 'C', 'E', 'J', 'N', 'P', 'Q'] ▶▶▶ [[3, 0], [0, 0], [0, 5], [2, 8], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 17번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (8, 2), (7, 2), (8, 2), (8, 1), (8, 0), (7, 0), (7, 1), (7, 0), (7, 1), (7, 0), (6, 0), (5, 0)]
# ###############
# Epoch # 1, Episode # 30000, start time: 16:24:16
# score:-11.2, n_buffer:56, eps:90.0
# 1번째 에포크로, 30654번째 에피소드는 76.0점 입니다.
# target은 ['A', 'C', 'F', 'J', 'L', 'O', 'P'] ▶▶▶ [[3, 0], [0, 1], [0, 5], [0, 7], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 16번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (8, 3), (8, 2), (7, 2), (8, 2), (8, 1), (7, 1), (8, 1), (8, 0), (7, 0), (6, 0), (5, 0), (5, 1)]
# ###############
# Epoch # 1, Episode # 31000, start time: 16:25:07
# score:-11.2, n_buffer:58, eps:90.0
# Epoch # 1, Episode # 32000, start time: 16:25:59
# score:-11.3, n_buffer:58, eps:90.0
# Epoch # 1, Episode # 33000, start time: 16:26:51
# score:-11.2, n_buffer:58, eps:90.0
# 1번째 에포크로, 33706번째 에피소드는 76.0점 입니다.
# target은 ['A', 'C', 'D', 'E', 'F', 'I', 'J'] ▶▶▶ [[3, 0], [2, 0], [0, 0], [0, 1], [0, 4], [0, 5], [9, 4]]입니다.
# action은 총 16번 움직였습니다.
# [(9, 4), (8, 4), (9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (7, 3), (7, 2), (7, 1), (6, 1), (6, 0), (6, 1), (5, 1), (5, 0), (5, 1)]
# ###############
# 1번째 에포크로, 33784번째 에피소드는 83.0점 입니다.
# target은 ['A', 'F', 'H', 'K', 'O', 'Q'] ▶▶▶ [[0, 1], [0, 3], [0, 6], [3, 8], [5, 8], [9, 4]]입니다.
# action은 총 9번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (7, 1), (7, 0), (6, 0), (5, 0)]
# ###############
# Epoch # 1, Episode # 34000, start time: 16:27:42
# score:-11.1, n_buffer:62, eps:90.0
# Epoch # 1, Episode # 35000, start time: 16:28:34
# score:-11.3, n_buffer:62, eps:90.0
# 1번째 에포크로, 35172번째 에피소드는 76.0점 입니다.
# target은 ['A', 'C', 'E', 'H', 'J', 'K', 'N'] ▶▶▶ [[3, 0], [0, 0], [0, 3], [0, 5], [0, 6], [2, 8], [9, 4]]입니다.
# action은 총 16번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (7, 1), (6, 1), (7, 1), (6, 1), (7, 1), (7, 0), (6, 0), (6, 1), (6, 0), (5, 0), (6, 0)]
# ###############
# Epoch # 1, Episode # 36000, start time: 16:29:26
# score:-11.1, n_buffer:64, eps:90.0
# 1번째 에포크로, 36252번째 에피소드는 77.0점 입니다.
# target은 ['A', 'E', 'I', 'J', 'L', 'M', 'P'] ▶▶▶ [[0, 0], [0, 4], [0, 5], [0, 7], [0, 8], [4, 8], [9, 4]]입니다.
# action은 총 15번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (8, 4), (8, 3), (7, 3), (7, 2), (7, 1), (6, 1), (5, 1), (5, 0), (5, 1), (4, 1), (5, 1), (6, 1)]
# ###############
# Epoch # 1, Episode # 37000, start time: 16:30:17
# score:-11.1, n_buffer:66, eps:90.0
# Epoch # 1, Episode # 38000, start time: 16:31:09
# score:-11.3, n_buffer:66, eps:90.0
# Epoch # 1, Episode # 39000, start time: 16:32:01
# score:-11.4, n_buffer:66, eps:90.0
# 1번째 에포크로, 39823번째 에피소드는 75.0점 입니다.
# target은 ['A', 'C', 'E', 'G', 'L', 'M', 'Q'] ▶▶▶ [[3, 0], [0, 0], [0, 2], [0, 7], [0, 8], [5, 8], [9, 4]]입니다.
# action은 총 17번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 4), (8, 3), (8, 4), (8, 3), (8, 2), (7, 2), (8, 2), (8, 1), (7, 1), (7, 2), (7, 1), (6, 1), (5, 1), (5, 0)]
# ###############
# 2번째 epoch, 시작▶16:32:53
# 2번째 에포크로, 881번째 에피소드는 65.0점 입니다.
# target은 ['C', 'E', 'F', 'P', 'Q'] ▶▶▶ [[0, 0], [0, 1], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 27번 움직였습니다.
# [(9, 4), (8, 4), (9, 4), (8, 4), (9, 4), (8, 4), (8, 3), (7, 3), (7, 2), (7, 1), (8, 1), (7, 1), (8, 1), (7, 1), (8, 1), (7, 1), (7, 2), (7, 1), (6, 1), (5, 1), (4, 1), (5, 1), (4, 1), (3, 1), (4, 1), (3, 1), (3, 0)]
# ###############
# Epoch # 2, Episode # 1000, start time: 16:33:45
# score:-22.6, n_buffer:70, eps:80.0
# 2번째 에포크로, 1188번째 에피소드는 81.0점 입니다.
# target은 ['A', 'C', 'H', 'J', 'P'] ▶▶▶ [[3, 0], [0, 3], [0, 5], [4, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (7, 2), (7, 1), (6, 1), (6, 0), (7, 0), (6, 0), (5, 0)]
# ###############
# 2번째 에포크로, 1623번째 에피소드는 79.0점 입니다.
# target은 ['A', 'E', 'F', 'K', 'M', 'O', 'P'] ▶▶▶ [[0, 0], [0, 1], [0, 6], [0, 8], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 13번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 5), (7, 4), (7, 3), (7, 2), (7, 1), (8, 1), (7, 1), (7, 0), (6, 0), (5, 0)]
# ###############
# Epoch # 2, Episode # 2000, start time: 16:34:37
# score:-11.3, n_buffer:74, eps:80.0
# Epoch # 2, Episode # 3000, start time: 16:35:29
# score:-11.4, n_buffer:74, eps:80.0
# Epoch # 2, Episode # 4000, start time: 16:36:21
# score:-11.5, n_buffer:74, eps:80.0
# Epoch # 2, Episode # 5000, start time: 16:37:13
# score:-11.3, n_buffer:74, eps:80.0
# Epoch # 2, Episode # 6000, start time: 16:38:04
# score:-11.4, n_buffer:74, eps:80.0
# Epoch # 2, Episode # 7000, start time: 16:38:56
# score:-11.4, n_buffer:74, eps:80.0
# Epoch # 2, Episode # 8000, start time: 16:39:48
# score:-11.2, n_buffer:74, eps:80.0
# 2번째 에포크로, 8389번째 에피소드는 76.0점 입니다.
# target은 ['B', 'E', 'J', 'K', 'N', 'O'] ▶▶▶ [[0, 0], [0, 5], [0, 6], [2, 8], [3, 8], [9, 4]]입니다.
# action은 총 16번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 3), (7, 3), (7, 2), (7, 1), (7, 0), (8, 0), (7, 0), (6, 0), (6, 1), (5, 1), (4, 1), (4, 0)]
# ###############
# Epoch # 2, Episode # 9000, start time: 16:40:40
# score:-11.4, n_buffer:76, eps:80.0
# Epoch # 2, Episode # 10000, start time: 16:41:32
# score:-11.6, n_buffer:76, eps:80.0
# 2번째 에포크로, 10981번째 에피소드는 81.0점 입니다.
# target은 ['A', 'D', 'F', 'I', 'M'] ▶▶▶ [[2, 0], [0, 1], [0, 4], [0, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (7, 2), (7, 1), (7, 0), (7, 1), (6, 1), (6, 0), (5, 0)]
# ###############
# Epoch # 2, Episode # 11000, start time: 16:42:24
# score:-11.4, n_buffer:78, eps:80.0
# 2번째 에포크로, 11251번째 에피소드는 78.0점 입니다.
# target은 ['B', 'F', 'K', 'M', 'Q'] ▶▶▶ [[0, 1], [0, 6], [0, 8], [5, 8], [9, 4]]입니다.
# action은 총 14번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (7, 1), (8, 1), (7, 1), (7, 2), (7, 1), (6, 1), (5, 1), (4, 1), (4, 0)]
# ###############
# Epoch # 2, Episode # 12000, start time: 16:43:16
# score:-11.4, n_buffer:80, eps:80.0
# 2번째 에포크로, 12229번째 에피소드는 177.0점 입니다.
# target은 ['A', 'B', 'C', 'F', 'G'] ▶▶▶ [[3, 0], [0, 1], [0, 2], [9, 4]]입니다.
# action은 총 16번 움직였습니다.
# [(9, 4), (8, 4), (8, 5), (7, 5), (7, 4), (7, 3), (7, 2), (7, 1), (7, 2), (7, 1), (6, 1), (5, 1), (5, 0), (5, 1), (4, 1), (4, 0)]
# ###############
# Epoch # 2, Episode # 13000, start time: 16:44:08
# score:-11.3, n_buffer:83, eps:80.0
# Epoch # 2, Episode # 14000, start time: 16:45:01
# score:-11.7, n_buffer:83, eps:80.0
# 2번째 에포크로, 14107번째 에피소드는 81.0점 입니다.
# target은 ['A', 'C', 'F', 'K', 'L', 'N', 'O'] ▶▶▶ [[3, 0], [0, 1], [0, 6], [0, 7], [2, 8], [3, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (8, 2), (7, 2), (7, 1), (6, 1), (5, 1), (5, 0)]
# ###############
# Epoch # 2, Episode # 15000, start time: 16:45:53
# score:-11.6, n_buffer:85, eps:80.0
# 2번째 에포크로, 15337번째 에피소드는 82.0점 입니다.
# target은 ['A', 'F', 'G', 'I', 'J', 'M'] ▶▶▶ [[0, 1], [0, 2], [0, 4], [0, 5], [0, 8], [9, 4]]입니다.
# action은 총 10번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (7, 1), (6, 1), (6, 0), (5, 0), (6, 0)]
# ###############
# Epoch # 2, Episode # 16000, start time: 16:46:46
# score:-11.5, n_buffer:87, eps:80.0
# Epoch # 2, Episode # 17000, start time: 16:47:38
# score:-11.6, n_buffer:87, eps:80.0
# Epoch # 2, Episode # 18000, start time: 16:48:30
# score:-11.6, n_buffer:87, eps:80.0
# 2번째 에포크로, 18868번째 에피소드는 75.0점 입니다.
# target은 ['A', 'L', 'O', 'P', 'Q'] ▶▶▶ [[0, 7], [3, 8], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 17번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 4), (7, 4), (7, 3), (7, 2), (7, 3), (7, 2), (7, 1), (7, 0), (8, 0), (8, 1), (8, 0), (7, 0), (6, 0), (5, 0)]
# ###############
# Epoch # 2, Episode # 19000, start time: 16:49:23
# score:-11.7, n_buffer:89, eps:80.0
# Epoch # 2, Episode # 20000, start time: 16:50:15
# score:-11.7, n_buffer:89, eps:80.0
# Epoch # 2, Episode # 21000, start time: 16:51:07
# score:-11.4, n_buffer:89, eps:80.0
# 2번째 에포크로, 21978번째 에피소드는 77.0점 입니다.
# target은 ['A', 'G', 'H', 'I', 'M', 'N'] ▶▶▶ [[0, 2], [0, 3], [0, 4], [0, 8], [2, 8], [9, 4]]입니다.
# action은 총 15번 움직였습니다.
# [(9, 4), (8, 4), (9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (8, 2), (8, 3), (8, 2), (8, 1), (7, 1), (7, 0), (6, 0), (5, 0)]
# ###############
# Epoch # 2, Episode # 22000, start time: 16:51:59
# score:-11.4, n_buffer:91, eps:80.0
# 2번째 에포크로, 22356번째 에피소드는 81.0점 입니다.
# target은 ['A', 'E', 'H', 'J', 'L', 'M', 'O'] ▶▶▶ [[0, 0], [0, 3], [0, 5], [0, 7], [0, 8], [3, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (8, 2), (8, 1), (7, 1), (6, 1), (5, 1), (5, 0)]
# ###############
# Epoch # 2, Episode # 23000, start time: 16:52:51
# score:-11.5, n_buffer:93, eps:80.0
# Epoch # 2, Episode # 24000, start time: 16:53:43
# score:-11.6, n_buffer:93, eps:80.0
# Epoch # 2, Episode # 25000, start time: 16:54:35
# score:-11.5, n_buffer:93, eps:80.0
# 2번째 에포크로, 25607번째 에피소드는 76.0점 입니다.
# target은 ['A', 'D', 'G', 'H', 'J', 'N', 'Q'] ▶▶▶ [[2, 0], [0, 2], [0, 3], [0, 5], [2, 8], [5, 8], [9, 4]]입니다.
# action은 총 16번 움직였습니다.
# [(9, 4), (8, 4), (9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (8, 2), (7, 2), (7, 1), (6, 1), (5, 1), (5, 0), (5, 1), (4, 1), (3, 1)]
# ###############
# 2번째 에포크로, 25851번째 에피소드는 76.0점 입니다.
# target은 ['A', 'B', 'C', 'L', 'N', 'Q'] ▶▶▶ [[4, 0], [3, 0], [0, 7], [2, 8], [5, 8], [9, 4]]입니다.
# action은 총 16번 움직였습니다.
# [(9, 4), (8, 4), (9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (8, 0), (8, 1), (7, 1), (7, 0), (6, 0), (7, 0), (6, 0), (5, 0), (5, 1)]
# ###############
# Epoch # 2, Episode # 26000, start time: 16:55:27
# score:-11.4, n_buffer:97, eps:80.0
# 2번째 에포크로, 26455번째 에피소드는 83.0점 입니다.
# target은 ['A', 'E', 'F', 'I', 'O'] ▶▶▶ [[0, 0], [0, 1], [0, 4], [3, 8], [9, 4]]입니다.
# action은 총 9번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (7, 1), (7, 0), (6, 0), (5, 0)]
# ###############
# Epoch # 2, Episode # 27000, start time: 16:56:19
# score:-11.5, n_buffer:99, eps:80.0
# 2번째 에포크로, 27618번째 에피소드는 77.0점 입니다.
# target은 ['A', 'B', 'C', 'G', 'M', 'N', 'P'] ▶▶▶ [[4, 0], [3, 0], [0, 2], [0, 8], [2, 8], [4, 8], [9, 4]]입니다.
# action은 총 15번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (7, 4), (7, 3), (7, 2), (7, 1), (7, 0), (7, 1), (8, 1), (8, 0), (7, 0), (6, 0), (5, 0)]
# ###############
# Epoch # 2, Episode # 28000, start time: 16:57:11
# score:-11.5, n_buffer:101, eps:80.0
# Epoch # 2, Episode # 29000, start time: 16:58:03
# score:-11.6, n_buffer:101, eps:80.0
# 2번째 에포크로, 29221번째 에피소드는 83.0점 입니다.
# target은 ['A', 'C', 'D', 'M', 'O', 'Q'] ▶▶▶ [[3, 0], [2, 0], [0, 8], [3, 8], [5, 8], [9, 4]]입니다.
# action은 총 9번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (7, 1), (6, 1), (5, 1), (5, 0)]
# ###############
# 2번째 에포크로, 29281번째 에피소드는 83.0점 입니다.
# target은 ['A', 'C', 'D', 'N', 'O', 'P', 'Q'] ▶▶▶ [[3, 0], [2, 0], [2, 8], [3, 8], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 9번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (7, 1), (6, 1), (5, 1), (5, 0)]
# ###############
# Epoch # 2, Episode # 30000, start time: 16:58:56
# score:-11.5, n_buffer:105, eps:80.0
# Epoch # 2, Episode # 31000, start time: 16:59:47
# score:-11.5, n_buffer:105, eps:80.0
# Epoch # 2, Episode # 32000, start time: 17:00:40
# score:-11.6, n_buffer:105, eps:80.0
# Epoch # 2, Episode # 33000, start time: 17:01:32
# score:-11.6, n_buffer:105, eps:80.0
# Epoch # 2, Episode # 34000, start time: 17:02:24
# score:-11.5, n_buffer:105, eps:80.0
# 2번째 에포크로, 34168번째 에피소드는 78.0점 입니다.
# target은 ['A', 'B', 'E', 'F', 'K', 'Q'] ▶▶▶ [[4, 0], [0, 0], [0, 1], [0, 6], [5, 8], [9, 4]]입니다.
# action은 총 14번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 3), (8, 2), (7, 2), (7, 1), (7, 2), (7, 1), (7, 0), (6, 0), (5, 0), (6, 0)]
# ###############
# 2번째 에포크로, 34490번째 에피소드는 81.0점 입니다.
# target은 ['A', 'C', 'E', 'I', 'K', 'P', 'Q'] ▶▶▶ [[3, 0], [0, 0], [0, 4], [0, 6], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 3), (8, 2), (8, 1), (7, 1), (6, 1), (5, 1), (5, 0)]
# ###############
# Epoch # 2, Episode # 35000, start time: 17:03:15
# score:-11.4, n_buffer:109, eps:80.0
# Epoch # 2, Episode # 36000, start time: 17:04:06
# score:-11.5, n_buffer:109, eps:80.0
# 2번째 에포크로, 36703번째 에피소드는 83.0점 입니다.
# target은 ['A', 'D', 'I', 'L', 'M', 'N', 'Q'] ▶▶▶ [[2, 0], [0, 4], [0, 7], [0, 8], [2, 8], [5, 8], [9, 4]]입니다.
# action은 총 9번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (7, 1), (7, 0), (6, 0), (5, 0)]
# ###############
# Epoch # 2, Episode # 37000, start time: 17:04:57
# score:-11.7, n_buffer:111, eps:80.0
# Epoch # 2, Episode # 38000, start time: 17:05:47
# score:-11.7, n_buffer:111, eps:80.0
# Epoch # 2, Episode # 39000, start time: 17:06:37
# score:-11.4, n_buffer:111, eps:80.0
# 3번째 epoch, 시작▶17:07:28
# Epoch # 3, Episode # 1000, start time: 17:08:19
# score:-23.4, n_buffer:111, eps:70.0
# Epoch # 3, Episode # 2000, start time: 17:09:09
# score:-11.6, n_buffer:111, eps:70.0
# 3번째 에포크로, 2043번째 에피소드는 175.0점 입니다.
# target은 ['A', 'B', 'E', 'G', 'L'] ▶▶▶ [[0, 0], [0, 2], [0, 7], [9, 4]]입니다.
# action은 총 18번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (8, 3), (7, 3), (7, 2), (7, 1), (6, 1), (6, 0), (6, 1), (5, 1), (4, 1), (5, 1), (4, 1), (4, 0), (5, 0), (4, 0)]
# ###############
# Epoch # 3, Episode # 3000, start time: 17:09:59
# score:-11.5, n_buffer:114, eps:70.0
# 3번째 에포크로, 3698번째 에피소드는 75.0점 입니다.
# target은 ['F', 'G', 'H', 'K'] ▶▶▶ [[0, 2], [0, 3], [0, 6], [9, 4]]입니다.
# action은 총 17번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (2, 4), (2, 5), (1, 5), (1, 4), (1, 3), (1, 2), (1, 1), (0, 1)]
# ###############
# Epoch # 3, Episode # 4000, start time: 17:10:48
# score:-11.3, n_buffer:116, eps:70.0
# 3번째 에포크로, 4546번째 에피소드는 73.0점 입니다.
# target은 ['H', 'K', 'L', 'M', 'Q'] ▶▶▶ [[0, 6], [0, 7], [0, 8], [5, 8], [9, 4]]입니다.
# action은 총 19번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (6, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (2, 2), (1, 2), (1, 3), (0, 3)]
# ###############
# Epoch # 3, Episode # 5000, start time: 17:11:39
# score:-11.6, n_buffer:118, eps:70.0
# Epoch # 3, Episode # 6000, start time: 17:12:30
# score:-11.8, n_buffer:118, eps:70.0
# 3번째 에포크로, 6996번째 에피소드는 179.0점 입니다.
# target은 ['A', 'B', 'C', 'F', 'O', 'Q'] ▶▶▶ [[3, 0], [0, 1], [3, 8], [5, 8], [9, 4]]입니다.
# action은 총 14번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (8, 2), (8, 1), (7, 1), (6, 1), (6, 0), (5, 0), (4, 0), (4, 1), (3, 1)]
# ###############
# Epoch # 3, Episode # 7000, start time: 17:13:20
# score:-11.8, n_buffer:121, eps:70.0
# 3번째 에포크로, 7062번째 에피소드는 78.0점 입니다.
# target은 ['G', 'H', 'I', 'K', 'L', 'P'] ▶▶▶ [[0, 3], [0, 4], [0, 6], [0, 7], [4, 8], [9, 4]]입니다.
# action은 총 14번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (1, 4), (0, 4), (0, 3), (0, 2)]
# ###############
# 3번째 에포크로, 7275번째 에피소드는 73.0점 입니다.
# target은 ['H', 'I', 'J', 'K', 'Q'] ▶▶▶ [[0, 4], [0, 5], [0, 6], [5, 8], [9, 4]]입니다.
# action은 총 19번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (5, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (2, 3), (1, 3), (1, 2), (1, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 3, Episode # 8000, start time: 17:14:10
# score:-11.6, n_buffer:125, eps:70.0
# 3번째 에포크로, 8514번째 에피소드는 81.0점 입니다.
# target은 ['A', 'J', 'K', 'O', 'P'] ▶▶▶ [[0, 5], [0, 6], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (7, 1), (6, 1), (5, 1), (6, 1), (6, 0), (5, 0)]
# ###############
# Epoch # 3, Episode # 9000, start time: 17:15:00
# score:-11.7, n_buffer:127, eps:70.0
# 3번째 에포크로, 9561번째 에피소드는 81.0점 입니다.
# target은 ['A', 'B', 'C', 'H', 'J', 'M', 'N'] ▶▶▶ [[4, 0], [3, 0], [0, 3], [0, 5], [0, 8], [2, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (8, 3), (8, 2), (8, 1), (7, 1), (6, 1), (6, 0), (5, 0)]
# ###############
# Epoch # 3, Episode # 10000, start time: 17:15:51
# score:-12.1, n_buffer:129, eps:70.0
# Epoch # 3, Episode # 11000, start time: 17:16:42
# score:-12.1, n_buffer:129, eps:70.0
# Epoch # 3, Episode # 12000, start time: 17:17:33
# score:-12.2, n_buffer:129, eps:70.0
# Epoch # 3, Episode # 13000, start time: 17:18:24
# score:-12.1, n_buffer:129, eps:70.0
# Epoch # 3, Episode # 14000, start time: 17:19:14
# score:-11.9, n_buffer:129, eps:70.0
# 3번째 에포크로, 14053번째 에피소드는 80.0점 입니다.
# target은 ['B', 'D', 'F', 'I', 'J', 'M', 'N'] ▶▶▶ [[2, 0], [0, 1], [0, 4], [0, 5], [0, 8], [2, 8], [9, 4]]입니다.
# action은 총 12번 움직였습니다.
# [(9, 4), (8, 4), (9, 4), (8, 4), (8, 3), (7, 3), (7, 2), (7, 1), (6, 1), (5, 1), (4, 1), (4, 0)]
# ###############
# 3번째 에포크로, 14469번째 에피소드는 183.0점 입니다.
# target은 ['A', 'B', 'E', 'G', 'J', 'K'] ▶▶▶ [[0, 0], [0, 2], [0, 5], [0, 6], [9, 4]]입니다.
# action은 총 10번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (8, 0), (7, 0), (6, 0), (5, 0), (4, 0)]
# ###############
# 3번째 에포크로, 14791번째 에피소드는 83.0점 입니다.
# target은 ['A', 'C', 'I', 'J', 'K', 'L', 'O'] ▶▶▶ [[3, 0], [0, 4], [0, 5], [0, 6], [0, 7], [3, 8], [9, 4]]입니다.
# action은 총 9번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (7, 1), (6, 1), (5, 1), (5, 0)]
# ###############
# Epoch # 3, Episode # 15000, start time: 17:20:04
# score:-11.5, n_buffer:136, eps:70.0
# Epoch # 3, Episode # 16000, start time: 17:20:54
# score:-11.7, n_buffer:136, eps:70.0
# 3번째 에포크로, 16088번째 에피소드는 82.0점 입니다.
# target은 ['B', 'G', 'I', 'J', 'P', 'Q'] ▶▶▶ [[0, 2], [0, 4], [0, 5], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 10번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (7, 1), (6, 1), (5, 1), (4, 1), (4, 0)]
# ###############
# Epoch # 3, Episode # 17000, start time: 17:21:43
# score:-11.8, n_buffer:138, eps:70.0
# 3번째 에포크로, 17389번째 에피소드는 74.0점 입니다.
# target은 ['A', 'D', 'F', 'L', 'M', 'N', 'Q'] ▶▶▶ [[2, 0], [0, 1], [0, 7], [0, 8], [2, 8], [5, 8], [9, 4]]입니다.
# action은 총 18번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 4), (9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (7, 3), (7, 2), (7, 1), (6, 1), (6, 0), (7, 0), (6, 0), (5, 0), (5, 1)]
# ###############
# Epoch # 3, Episode # 18000, start time: 17:22:34
# score:-11.8, n_buffer:140, eps:70.0
# Epoch # 3, Episode # 19000, start time: 17:23:25
# score:-11.8, n_buffer:140, eps:70.0
# 3번째 에포크로, 19077번째 에피소드는 74.0점 입니다.
# target은 ['B', 'E', 'G', 'K', 'M', 'O', 'Q'] ▶▶▶ [[0, 0], [0, 2], [0, 6], [0, 8], [3, 8], [5, 8], [9, 4]]입니다.
# action은 총 18번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (7, 1), (7, 2), (7, 1), (8, 1), (7, 1), (8, 1), (7, 1), (6, 1), (5, 1), (4, 1), (4, 0), (4, 1), (3, 1)]
# ###############
# Epoch # 3, Episode # 20000, start time: 17:24:15
# score:-11.6, n_buffer:142, eps:70.0
# Epoch # 3, Episode # 21000, start time: 17:25:04
# score:-11.8, n_buffer:142, eps:70.0
# 3번째 에포크로, 21475번째 에피소드는 81.0점 입니다.
# target은 ['A', 'F', 'I', 'L', 'N', 'O', 'P'] ▶▶▶ [[0, 1], [0, 4], [0, 7], [2, 8], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (7, 1), (7, 0), (7, 1), (6, 1), (6, 0), (5, 0)]
# ###############
# 3번째 에포크로, 21670번째 에피소드는 82.0점 입니다.
# target은 ['A', 'B', 'D', 'E', 'F', 'M', 'N'] ▶▶▶ [[4, 0], [2, 0], [0, 0], [0, 1], [0, 8], [2, 8], [9, 4]]입니다.
# action은 총 10번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (7, 1), (6, 1), (6, 0), (5, 0), (6, 0)]
# ###############
# Epoch # 3, Episode # 22000, start time: 17:25:55
# score:-11.8, n_buffer:146, eps:70.0
# Epoch # 3, Episode # 23000, start time: 17:26:45
# score:-12.0, n_buffer:146, eps:70.0
# 3번째 에포크로, 23105번째 에피소드는 73.0점 입니다.
# target은 ['H', 'I', 'K', 'M', 'P'] ▶▶▶ [[0, 4], [0, 6], [0, 8], [4, 8], [9, 4]]입니다.
# action은 총 19번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (8, 4), (9, 4), (8, 4), (8, 3), (7, 3), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# 3번째 에포크로, 23728번째 에피소드는 79.0점 입니다.
# target은 ['A', 'D', 'G', 'K', 'L', 'M', 'O'] ▶▶▶ [[2, 0], [0, 2], [0, 6], [0, 7], [0, 8], [3, 8], [9, 4]]입니다.
# action은 총 13번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (8, 3), (8, 2), (7, 2), (8, 2), (7, 2), (7, 1), (6, 1), (6, 0), (5, 0)]
# ###############
# Epoch # 3, Episode # 24000, start time: 17:27:36
# score:-11.9, n_buffer:150, eps:70.0
# Epoch # 3, Episode # 25000, start time: 17:28:26
# score:-12.1, n_buffer:150, eps:70.0
# 3번째 에포크로, 25533번째 에피소드는 78.0점 입니다.
# target은 ['D', 'G', 'H', 'K', 'Q'] ▶▶▶ [[0, 2], [0, 3], [0, 6], [5, 8], [9, 4]]입니다.
# action은 총 14번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (7, 1), (7, 0), (7, 1), (6, 1), (5, 1), (4, 1), (3, 1), (2, 1), (2, 0)]
# ###############
# Epoch # 3, Episode # 26000, start time: 17:29:16
# score:-12.0, n_buffer:152, eps:70.0
# 3번째 에포크로, 26105번째 에피소드는 78.0점 입니다.
# target은 ['A', 'B', 'D', 'H', 'I', 'O', 'P'] ▶▶▶ [[4, 0], [2, 0], [0, 3], [0, 4], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 14번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (7, 1), (6, 1), (7, 1), (7, 2), (7, 1), (7, 0), (6, 0), (5, 0), (6, 0)]
# ###############
# Epoch # 3, Episode # 27000, start time: 17:30:07
# score:-11.9, n_buffer:154, eps:70.0
# 3번째 에포크로, 27046번째 에피소드는 73.0점 입니다.
# target은 ['A', 'D', 'F', 'I', 'K', 'O', 'P'] ▶▶▶ [[2, 0], [0, 1], [0, 4], [0, 6], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 19번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (7, 1), (6, 1), (5, 1), (6, 1), (6, 0), (7, 0), (6, 0), (5, 0), (5, 1), (6, 1), (7, 1), (6, 1), (5, 1), (4, 1)]
# ###############
# Epoch # 3, Episode # 28000, start time: 17:30:58
# score:-12.0, n_buffer:156, eps:70.0
# 3번째 에포크로, 28157번째 에피소드는 78.0점 입니다.
# target은 ['B', 'D', 'F', 'G', 'J', 'L', 'M'] ▶▶▶ [[2, 0], [0, 1], [0, 2], [0, 5], [0, 7], [0, 8], [9, 4]]입니다.
# action은 총 14번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 4), (8, 3), (8, 2), (7, 2), (7, 1), (6, 1), (5, 1), (4, 1), (4, 0), (4, 1), (5, 1)]
# ###############
# Epoch # 3, Episode # 29000, start time: 17:31:48
# score:-12.1, n_buffer:158, eps:70.0
# 3번째 에포크로, 29010번째 에피소드는 75.0점 입니다.
# target은 ['A', 'D', 'H', 'I', 'J', 'P', 'Q'] ▶▶▶ [[2, 0], [0, 3], [0, 4], [0, 5], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 17번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (8, 2), (7, 2), (7, 1), (6, 1), (5, 1), (4, 1), (5, 1), (6, 1), (6, 0), (5, 0), (6, 0), (6, 1)]
# ###############
# 3번째 에포크로, 29264번째 에피소드는 183.0점 입니다.
# target은 ['A', 'B', 'D', 'I', 'L', 'P', 'Q'] ▶▶▶ [[2, 0], [0, 4], [0, 7], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 10번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (7, 2), (7, 1), (6, 1), (6, 0), (5, 0), (4, 0)]
# ###############
# 3번째 에포크로, 29600번째 에피소드는 178.0점 입니다.
# target은 ['A', 'B', 'C', 'F', 'H', 'L', 'M'] ▶▶▶ [[3, 0], [0, 1], [0, 3], [0, 7], [0, 8], [9, 4]]입니다.
# action은 총 15번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (8, 3), (8, 2), (7, 2), (7, 1), (6, 1), (6, 0), (5, 0), (4, 0), (5, 0), (5, 1), (4, 1)]
# ###############
# Epoch # 3, Episode # 30000, start time: 17:32:39
# score:-11.6, n_buffer:166, eps:70.0
# 3번째 에포크로, 30650번째 에피소드는 172.0점 입니다.
# target은 ['F', 'G', 'K', 'M', 'N', 'O', 'Q'] ▶▶▶ [[0, 6], [0, 8], [2, 8], [3, 8], [5, 8], [9, 4]]입니다.
# action은 총 21번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (5, 3), (4, 3), (5, 3), (4, 3), (3, 3), (2, 3), (2, 2), (1, 2), (1, 1), (0, 1), (0, 2), (1, 2), (1, 1), (1, 2), (1, 1), (1, 0)]
# ###############
# Epoch # 3, Episode # 31000, start time: 17:33:29
# score:-12.1, n_buffer:169, eps:70.0
# Epoch # 3, Episode # 32000, start time: 17:34:20
# score:-12.1, n_buffer:169, eps:70.0
# 3번째 에포크로, 32128번째 에피소드는 78.0점 입니다.
# target은 ['B', 'C', 'G', 'K', 'M', 'N'] ▶▶▶ [[3, 0], [0, 2], [0, 6], [0, 8], [2, 8], [9, 4]]입니다.
# action은 총 14번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (8, 4), (8, 3), (8, 2), (8, 1), (7, 1), (7, 0), (7, 1), (6, 1), (5, 1), (4, 1), (4, 0)]
# ###############
# Epoch # 3, Episode # 33000, start time: 17:35:11
# score:-12.1, n_buffer:171, eps:70.0
# 3번째 에포크로, 33388번째 에피소드는 77.0점 입니다.
# target은 ['A', 'D', 'E', 'K', 'M', 'P'] ▶▶▶ [[2, 0], [0, 0], [0, 6], [0, 8], [4, 8], [9, 4]]입니다.
# action은 총 15번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (8, 4), (7, 4), (7, 3), (7, 2), (7, 1), (7, 0), (6, 0), (7, 0), (6, 0), (6, 1), (5, 1), (5, 0)]
# ###############
# 3번째 에포크로, 33839번째 에피소드는 70.0점 입니다.
# target은 ['A', 'C', 'F', 'J', 'N', 'Q'] ▶▶▶ [[3, 0], [0, 1], [0, 5], [2, 8], [5, 8], [9, 4]]입니다.
# action은 총 22번 움직였습니다.
# [(9, 4), (8, 4), (8, 5), (8, 4), (8, 5), (8, 4), (9, 4), (8, 4), (8, 3), (7, 3), (7, 4), (7, 3), (7, 2), (8, 2), (8, 1), (8, 0), (7, 0), (6, 0), (6, 1), (5, 1), (5, 0), (6, 0)]
# ###############
# Epoch # 3, Episode # 34000, start time: 17:36:01
# score:-12.0, n_buffer:175, eps:70.0
# 3번째 에포크로, 34516번째 에피소드는 272.0점 입니다.
# target은 ['A', 'B', 'C', 'G', 'O', 'P', 'Q'] ▶▶▶ [[0, 2], [3, 8], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 22번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (8, 4), (8, 3), (7, 3), (7, 2), (7, 1), (7, 0), (6, 0), (7, 0), (6, 0), (7, 0), (7, 1), (6, 1), (6, 0), (6, 1), (6, 0), (5, 0), (4, 0), (3, 0), (4, 0)]
# ###############
# Epoch # 3, Episode # 35000, start time: 17:36:51
# score:-11.9, n_buffer:179, eps:70.0
# Epoch # 3, Episode # 36000, start time: 17:37:41
# score:-12.1, n_buffer:179, eps:70.0
# Epoch # 3, Episode # 37000, start time: 17:38:32
# score:-12.2, n_buffer:179, eps:70.0
# Epoch # 3, Episode # 38000, start time: 17:39:23
# score:-12.2, n_buffer:179, eps:70.0
# Epoch # 3, Episode # 39000, start time: 17:40:13
# score:-11.9, n_buffer:179, eps:70.0
# 4번째 epoch, 시작▶17:41:02
# 4번째 에포크로, 575번째 에피소드는 83.0점 입니다.
# target은 ['A', 'D', 'E', 'F', 'N'] ▶▶▶ [[2, 0], [0, 0], [0, 1], [2, 8], [9, 4]]입니다.
# action은 총 9번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (7, 1), (6, 1), (5, 1), (5, 0)]
# ###############
# Epoch # 4, Episode # 1000, start time: 17:41:53
# score:-24.3, n_buffer:181, eps:60.0
# 4번째 에포크로, 1430번째 에피소드는 83.0점 입니다.
# target은 ['A', 'F', 'K', 'P'] ▶▶▶ [[0, 1], [0, 6], [4, 8], [9, 4]]입니다.
# action은 총 9번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (7, 1), (6, 1), (6, 0), (5, 0)]
# ###############
# 4번째 에포크로, 1678번째 에피소드는 83.0점 입니다.
# target은 ['A', 'C', 'E', 'H'] ▶▶▶ [[3, 0], [0, 0], [0, 3], [9, 4]]입니다.
# action은 총 9번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (7, 1), (6, 1), (6, 0), (5, 0)]
# ###############
# 4번째 에포크로, 1954번째 에피소드는 175.0점 입니다.
# target은 ['B', 'C', 'E', 'H', 'P'] ▶▶▶ [[0, 0], [0, 3], [4, 8], [9, 4]]입니다.
# action은 총 18번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (8, 2), (8, 1), (7, 1), (6, 1), (7, 1), (6, 1), (7, 1), (6, 1), (5, 1), (4, 1), (4, 0), (3, 0), (4, 0)]
# ###############
# Epoch # 4, Episode # 2000, start time: 17:42:44
# score:-11.9, n_buffer:188, eps:60.0
# Epoch # 4, Episode # 3000, start time: 17:43:35
# score:-12.2, n_buffer:188, eps:60.0
# 4번째 에포크로, 3131번째 에피소드는 181.0점 입니다.
# target은 ['A', 'B', 'C', 'F', 'G', 'J', 'M'] ▶▶▶ [[3, 0], [0, 1], [0, 2], [0, 5], [0, 8], [9, 4]]입니다.
# action은 총 12번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (7, 2), (7, 1), (6, 1), (5, 1), (6, 1), (5, 1), (5, 0), (4, 0)]
# ###############
# 4번째 에포크로, 3313번째 에피소드는 81.0점 입니다.
# target은 ['A', 'G', 'L', 'O', 'P'] ▶▶▶ [[0, 2], [0, 7], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (7, 2), (8, 2), (8, 1), (8, 0), (7, 0), (6, 0), (5, 0)]
# ###############
# 4번째 에포크로, 3367번째 에피소드는 71.0점 입니다.
# target은 ['H', 'I', 'L', 'M', 'O'] ▶▶▶ [[0, 4], [0, 7], [0, 8], [3, 8], [9, 4]]입니다.
# action은 총 21번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 5), (8, 5), (7, 5), (8, 5), (7, 5), (6, 5), (7, 5), (8, 5), (7, 5), (7, 4), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 4, Episode # 4000, start time: 17:44:24
# score:-11.9, n_buffer:195, eps:60.0
# Epoch # 4, Episode # 5000, start time: 17:45:14
# score:-12.3, n_buffer:195, eps:60.0
# Epoch # 4, Episode # 6000, start time: 17:46:05
# score:-12.3, n_buffer:195, eps:60.0
# 4번째 에포크로, 6871번째 에피소드는 182.0점 입니다.
# target은 ['A', 'B', 'C', 'E', 'G', 'I'] ▶▶▶ [[3, 0], [0, 0], [0, 2], [0, 4], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (7, 1), (6, 1), (5, 1), (5, 0), (4, 0), (4, 1)]
# ###############
# Epoch # 4, Episode # 7000, start time: 17:46:56
# score:-12.1, n_buffer:198, eps:60.0
# Epoch # 4, Episode # 8000, start time: 17:47:46
# score:-12.4, n_buffer:198, eps:60.0
# 4번째 에포크로, 8446번째 에피소드는 178.0점 입니다.
# target은 ['A', 'B', 'I', 'M', 'N', 'P', 'Q'] ▶▶▶ [[0, 4], [0, 8], [2, 8], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 15번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (8, 2), (8, 1), (7, 1), (7, 2), (7, 1), (6, 1), (5, 1), (5, 0), (4, 0), (4, 1)]
# ###############
# 4번째 에포크로, 8841번째 에피소드는 79.0점 입니다.
# target은 ['A', 'C', 'J', 'L', 'N', 'P'] ▶▶▶ [[3, 0], [0, 5], [0, 7], [2, 8], [4, 8], [9, 4]]입니다.
# action은 총 13번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (8, 2), (8, 1), (7, 1), (6, 1), (7, 1), (6, 1), (6, 0), (5, 0)]
# ###############
# Epoch # 4, Episode # 9000, start time: 17:48:36
# score:-12.0, n_buffer:203, eps:60.0
# 4번째 에포크로, 9947번째 에피소드는 82.0점 입니다.
# target은 ['B', 'D', 'F', 'I', 'L', 'M', 'O'] ▶▶▶ [[2, 0], [0, 1], [0, 4], [0, 7], [0, 8], [3, 8], [9, 4]]입니다.
# action은 총 10번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (8, 1), (7, 1), (6, 1), (5, 1), (4, 1), (4, 0)]
# ###############
# Epoch # 4, Episode # 10000, start time: 17:49:27
# score:-12.2, n_buffer:205, eps:60.0
# Epoch # 4, Episode # 11000, start time: 17:50:17
# score:-12.4, n_buffer:205, eps:60.0
# 4번째 에포크로, 11681번째 에피소드는 79.0점 입니다.
# target은 ['A', 'D', 'E', 'L', 'M', 'O', 'Q'] ▶▶▶ [[2, 0], [0, 0], [0, 7], [0, 8], [3, 8], [5, 8], [9, 4]]입니다.
# action은 총 13번 움직였습니다.
# [(9, 4), (8, 4), (8, 5), (8, 4), (7, 4), (7, 3), (8, 3), (8, 2), (8, 1), (8, 0), (7, 0), (6, 0), (5, 0)]
# ###############
# 4번째 에포크로, 11899번째 에피소드는 182.0점 입니다.
# target은 ['A', 'B', 'C', 'F', 'N'] ▶▶▶ [[3, 0], [0, 1], [2, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (7, 1), (7, 0), (6, 0), (5, 0), (4, 0), (5, 0)]
# ###############
# Epoch # 4, Episode # 12000, start time: 17:51:07
# score:-12.1, n_buffer:210, eps:60.0
# 4번째 에포크로, 12233번째 에피소드는 81.0점 입니다.
# target은 ['A', 'C', 'D', 'G', 'H', 'L', 'M'] ▶▶▶ [[3, 0], [2, 0], [0, 2], [0, 3], [0, 7], [0, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 5), (8, 4), (8, 3), (8, 2), (8, 1), (8, 0), (7, 0), (6, 0), (5, 0)]
# ###############
# Epoch # 4, Episode # 13000, start time: 17:51:57
# score:-12.3, n_buffer:212, eps:60.0
# 4번째 에포크로, 13791번째 에피소드는 78.0점 입니다.
# target은 ['I', 'K', 'M', 'P'] ▶▶▶ [[0, 6], [0, 8], [4, 8], [9, 4]]입니다.
# action은 총 14번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 5), (6, 5), (5, 5), (4, 5), (3, 5), (2, 5), (2, 4), (1, 4), (2, 4), (1, 4), (0, 4)]
# ###############
# Epoch # 4, Episode # 14000, start time: 17:52:47
# score:-12.3, n_buffer:214, eps:60.0
# 4번째 에포크로, 14965번째 에피소드는 79.0점 입니다.
# target은 ['J', 'L', 'P', 'Q'] ▶▶▶ [[0, 7], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 13번 움직였습니다.
# [(9, 4), (8, 4), (8, 5), (7, 5), (6, 5), (5, 5), (4, 5), (3, 5), (2, 5), (3, 5), (2, 5), (1, 5), (0, 5)]
# ###############
# Epoch # 4, Episode # 15000, start time: 17:53:38
# score:-12.1, n_buffer:216, eps:60.0
# 4번째 에포크로, 15431번째 에피소드는 75.0점 입니다.
# target은 ['H', 'I', 'J', 'L', 'M', 'O'] ▶▶▶ [[0, 4], [0, 5], [0, 7], [0, 8], [3, 8], [9, 4]]입니다.
# action은 총 17번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (3, 3), (2, 3), (3, 3), (2, 3), (2, 4), (1, 4), (1, 3), (0, 3)]
# ###############
# 4번째 에포크로, 15869번째 에피소드는 181.0점 입니다.
# target은 ['H', 'I', 'N', 'P'] ▶▶▶ [[2, 8], [4, 8], [9, 4]]입니다.
# action은 총 12번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3), (0, 4)]
# ###############
# Epoch # 4, Episode # 16000, start time: 17:54:28
# score:-11.9, n_buffer:221, eps:60.0
# Epoch # 4, Episode # 17000, start time: 17:55:18
# score:-12.4, n_buffer:221, eps:60.0
# Epoch # 4, Episode # 18000, start time: 17:56:07
# score:-12.1, n_buffer:221, eps:60.0
# Epoch # 4, Episode # 19000, start time: 17:56:57
# score:-12.1, n_buffer:221, eps:60.0
# 4번째 에포크로, 19449번째 에피소드는 81.0점 입니다.
# target은 ['H', 'J', 'K', 'M', 'N'] ▶▶▶ [[0, 5], [0, 6], [0, 8], [2, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 4, Episode # 20000, start time: 17:57:47
# score:-12.1, n_buffer:223, eps:60.0
# Epoch # 4, Episode # 21000, start time: 17:58:37
# score:-12.3, n_buffer:223, eps:60.0
# 4번째 에포크로, 21879번째 에피소드는 78.0점 입니다.
# target은 ['H', 'J', 'K', 'L', 'N', 'O'] ▶▶▶ [[0, 5], [0, 6], [0, 7], [2, 8], [3, 8], [9, 4]]입니다.
# action은 총 14번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3), (1, 3)]
# ###############
# Epoch # 4, Episode # 22000, start time: 17:59:26
# score:-12.2, n_buffer:225, eps:60.0
# Epoch # 4, Episode # 23000, start time: 18:00:16
# score:-12.2, n_buffer:225, eps:60.0
# 4번째 에포크로, 23174번째 에피소드는 178.0점 입니다.
# target은 ['A', 'B', 'E', 'F', 'G', 'P', 'Q'] ▶▶▶ [[0, 0], [0, 1], [0, 2], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 15번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (7, 2), (8, 2), (7, 2), (8, 2), (7, 2), (7, 1), (6, 1), (5, 1), (5, 0), (4, 0), (5, 0)]
# ###############
# Epoch # 4, Episode # 24000, start time: 18:01:07
# score:-12.2, n_buffer:228, eps:60.0
# 4번째 에포크로, 24566번째 에피소드는 81.0점 입니다.
# target은 ['J', 'K', 'M', 'P', 'Q'] ▶▶▶ [[0, 6], [0, 8], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 5), (6, 5), (5, 5), (4, 5), (3, 5), (2, 5), (1, 5), (0, 5)]
# ###############
# Epoch # 4, Episode # 25000, start time: 18:01:56
# score:-12.2, n_buffer:230, eps:60.0
# 4번째 에포크로, 25410번째 에피소드는 80.0점 입니다.
# target은 ['A', 'D', 'F', 'G', 'I', 'Q'] ▶▶▶ [[2, 0], [0, 1], [0, 2], [0, 4], [5, 8], [9, 4]]입니다.
# action은 총 12번 움직였습니다.
# [(9, 4), (8, 4), (9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (7, 1), (6, 1), (5, 1), (5, 0), (6, 0)]
# ###############
# Epoch # 4, Episode # 26000, start time: 18:02:46
# score:-12.3, n_buffer:232, eps:60.0
# Epoch # 4, Episode # 27000, start time: 18:03:36
# score:-12.5, n_buffer:232, eps:60.0
# 4번째 에포크로, 27978번째 에피소드는 75.0점 입니다.
# target은 ['H', 'I', 'J', 'K', 'L', 'Q'] ▶▶▶ [[0, 4], [0, 5], [0, 6], [0, 7], [5, 8], [9, 4]]입니다.
# action은 총 17번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (1, 4), (1, 3), (2, 3), (1, 3), (1, 4), (1, 3), (0, 3)]
# ###############
# Epoch # 4, Episode # 28000, start time: 18:04:26
# score:-12.3, n_buffer:234, eps:60.0
# 4번째 에포크로, 28079번째 에피소드는 78.0점 입니다.
# target은 ['A', 'C', 'E', 'F', 'I', 'O', 'Q'] ▶▶▶ [[3, 0], [0, 0], [0, 1], [0, 4], [3, 8], [5, 8], [9, 4]]입니다.
# action은 총 14번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (7, 1), (6, 1), (6, 0), (5, 0), (5, 1), (6, 1), (7, 1), (7, 0), (8, 0)]
# ###############
# 4번째 에포크로, 28873번째 에피소드는 81.0점 입니다.
# target은 ['A', 'C', 'D', 'F', 'I', 'K', 'L'] ▶▶▶ [[3, 0], [2, 0], [0, 1], [0, 4], [0, 6], [0, 7], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (7, 1), (6, 1), (7, 1), (6, 1), (5, 1), (5, 0)]
# ###############
# Epoch # 4, Episode # 29000, start time: 18:05:17
# score:-12.1, n_buffer:238, eps:60.0
# Epoch # 4, Episode # 30000, start time: 18:06:06
# score:-12.1, n_buffer:238, eps:60.0
# Epoch # 4, Episode # 31000, start time: 18:06:56
# score:-12.2, n_buffer:238, eps:60.0
# 4번째 에포크로, 31027번째 에피소드는 177.0점 입니다.
# target은 ['A', 'B', 'G', 'H', 'I', 'O', 'Q'] ▶▶▶ [[0, 2], [0, 3], [0, 4], [3, 8], [5, 8], [9, 4]]입니다.
# action은 총 16번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (8, 4), (9, 4), (8, 4), (8, 3), (8, 2), (7, 2), (7, 1), (8, 1), (7, 1), (6, 1), (5, 1), (5, 0), (4, 0)]
# ###############
# 4번째 에포크로, 31168번째 에피소드는 81.0점 입니다.
# target은 ['A', 'H', 'I', 'L', 'N', 'O', 'Q'] ▶▶▶ [[0, 3], [0, 4], [0, 7], [2, 8], [3, 8], [5, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (7, 1), (6, 1), (5, 1), (6, 1), (5, 1), (5, 0)]
# ###############
# 4번째 에포크로, 31526번째 에피소드는 82.0점 입니다.
# target은 ['A', 'H', 'I', 'K', 'L', 'M', 'O'] ▶▶▶ [[0, 3], [0, 4], [0, 6], [0, 7], [0, 8], [3, 8], [9, 4]]입니다.
# action은 총 10번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (7, 2), (7, 1), (7, 0), (6, 0), (5, 0), (6, 0)]
# ###############
# Epoch # 4, Episode # 32000, start time: 18:07:46
# score:-12.0, n_buffer:245, eps:60.0
# Epoch # 4, Episode # 33000, start time: 18:08:36
# score:-12.4, n_buffer:245, eps:60.0
# ...
# [(9, 4), (8, 4), (8, 5), (7, 5), (6, 5), (5, 5), (4, 5), (3, 5), (2, 5), (3, 5), (2, 5), (1, 5), (0, 5)]
# ###############
# Epoch # 8, Episode # 4000, start time: 20:03:38
# score:-12.5, n_buffer:496, eps:20.0
# 8번째 에포크로, 4341번째 에피소드는 77.0점 입니다.
# target은 ['J', 'K', 'L', 'P'] ▶▶▶ [[0, 6], [0, 7], [4, 8], [9, 4]]입니다.
# action은 총 15번 움직였습니다.
# [(9, 4), (8, 4), (8, 5), (7, 5), (6, 5), (5, 5), (4, 5), (5, 5), (4, 5), (3, 5), (2, 5), (1, 5), (2, 5), (1, 5), (0, 5)]
# ###############
# 8번째 에포크로, 4838번째 에피소드는 81.0점 입니다.
# target은 ['H', 'I', 'K', 'M', 'O'] ▶▶▶ [[0, 4], [0, 6], [0, 8], [3, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 8, Episode # 5000, start time: 20:04:32
# score:-12.2, n_buffer:500, eps:20.0
# 8번째 에포크로, 5441번째 에피소드는 79.0점 입니다.
# target은 ['H', 'I', 'J', 'O'] ▶▶▶ [[0, 4], [0, 5], [3, 8], [9, 4]]입니다.
# action은 총 13번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# 8번째 에포크로, 5813번째 에피소드는 180.0점 입니다.
# target은 ['G', 'H', 'L', 'N'] ▶▶▶ [[0, 7], [2, 8], [9, 4]]입니다.
# action은 총 13번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (1, 2), (0, 2), (0, 3)]
# ###############
# Epoch # 8, Episode # 6000, start time: 20:05:27
# score:-12.5, n_buffer:505, eps:20.0
# 8번째 에포크로, 6292번째 에피소드는 81.0점 입니다.
# target은 ['H', 'I', 'K', 'O'] ▶▶▶ [[0, 4], [0, 6], [3, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 8, Episode # 7000, start time: 20:06:21
# score:-12.3, n_buffer:507, eps:20.0
# 8번째 에포크로, 7129번째 에피소드는 81.0점 입니다.
# target은 ['H', 'I', 'M'] ▶▶▶ [[0, 4], [0, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# 8번째 에포크로, 7433번째 에피소드는 81.0점 입니다.
# target은 ['H', 'I', 'J', 'K', 'M', 'O'] ▶▶▶ [[0, 4], [0, 5], [0, 6], [0, 8], [3, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# 8번째 에포크로, 7837번째 에피소드는 81.0점 입니다.
# target은 ['H', 'I', 'J', 'O', 'P'] ▶▶▶ [[0, 4], [0, 5], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 8, Episode # 8000, start time: 20:07:14
# score:-12.3, n_buffer:513, eps:20.0
# 8번째 에포크로, 8989번째 에피소드는 77.0점 입니다.
# target은 ['H', 'K', 'L', 'N', 'O'] ▶▶▶ [[0, 6], [0, 7], [2, 8], [3, 8], [9, 4]]입니다.
# action은 총 15번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (8, 4), (9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 8, Episode # 9000, start time: 20:08:09
# score:-12.5, n_buffer:515, eps:20.0
# Epoch # 8, Episode # 10000, start time: 20:09:03
# score:-12.6, n_buffer:515, eps:20.0
# 8번째 에포크로, 10670번째 에피소드는 79.0점 입니다.
# target은 ['H', 'I', 'L', 'M', 'N', 'P'] ▶▶▶ [[0, 4], [0, 7], [0, 8], [2, 8], [4, 8], [9, 4]]입니다.
# action은 총 13번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 8, Episode # 11000, start time: 20:09:57
# score:-12.6, n_buffer:517, eps:20.0
# 8번째 에포크로, 11717번째 에피소드는 79.0점 입니다.
# target은 ['H', 'J', 'K', 'L', 'M', 'O', 'P'] ▶▶▶ [[0, 5], [0, 6], [0, 7], [0, 8], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 13번 움직였습니다.
# [(9, 4), (8, 4), (9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 8, Episode # 12000, start time: 20:10:51
# score:-12.4, n_buffer:519, eps:20.0
# 8번째 에포크로, 12420번째 에피소드는 80.0점 입니다.
# target은 ['G', 'H', 'I', 'N'] ▶▶▶ [[0, 3], [0, 4], [2, 8], [9, 4]]입니다.
# action은 총 12번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3), (0, 2)]
# ###############
# Epoch # 8, Episode # 13000, start time: 20:11:45
# score:-12.4, n_buffer:521, eps:20.0
# Epoch # 8, Episode # 14000, start time: 20:12:39
# score:-12.7, n_buffer:521, eps:20.0
# 8번째 에포크로, 14657번째 에피소드는 77.0점 입니다.
# target은 ['H', 'J', 'L', 'M', 'O'] ▶▶▶ [[0, 5], [0, 7], [0, 8], [3, 8], [9, 4]]입니다.
# action은 총 15번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (7, 3), (6, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 8, Episode # 15000, start time: 20:13:33
# score:-12.5, n_buffer:523, eps:20.0
# Epoch # 8, Episode # 16000, start time: 20:14:28
# score:-12.6, n_buffer:523, eps:20.0
# Epoch # 8, Episode # 17000, start time: 20:15:22
# score:-12.8, n_buffer:523, eps:20.0
# Epoch # 8, Episode # 18000, start time: 20:16:15
# score:-12.5, n_buffer:523, eps:20.0
# Epoch # 8, Episode # 19000, start time: 20:17:09
# score:-12.6, n_buffer:523, eps:20.0
# Epoch # 8, Episode # 20000, start time: 20:18:03
# score:-12.6, n_buffer:523, eps:20.0
# Epoch # 8, Episode # 21000, start time: 20:18:58
# score:-12.5, n_buffer:523, eps:20.0
# 8번째 에포크로, 21039번째 에피소드는 81.0점 입니다.
# target은 ['H', 'I', 'J', 'K', 'L', 'M', 'P'] ▶▶▶ [[0, 4], [0, 5], [0, 6], [0, 7], [0, 8], [4, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 8, Episode # 22000, start time: 20:19:52
# score:-12.5, n_buffer:525, eps:20.0
# Epoch # 8, Episode # 23000, start time: 20:20:46
# score:-12.7, n_buffer:525, eps:20.0
# Epoch # 8, Episode # 24000, start time: 20:21:40
# score:-12.5, n_buffer:525, eps:20.0
# 8번째 에포크로, 24422번째 에피소드는 81.0점 입니다.
# target은 ['H', 'I', 'K', 'L', 'N', 'O'] ▶▶▶ [[0, 4], [0, 6], [0, 7], [2, 8], [3, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 8, Episode # 25000, start time: 20:22:34
# score:-12.6, n_buffer:527, eps:20.0
# Epoch # 8, Episode # 26000, start time: 20:23:27
# score:-12.6, n_buffer:527, eps:20.0
# Epoch # 8, Episode # 27000, start time: 20:24:21
# score:-12.5, n_buffer:527, eps:20.0
# Epoch # 8, Episode # 28000, start time: 20:25:15
# score:-12.7, n_buffer:527, eps:20.0
# 8번째 에포크로, 28581번째 에피소드는 81.0점 입니다.
# target은 ['H', 'I', 'J', 'K', 'N', 'P'] ▶▶▶ [[0, 4], [0, 5], [0, 6], [2, 8], [4, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 8, Episode # 29000, start time: 20:26:08
# score:-12.6, n_buffer:529, eps:20.0
# 8번째 에포크로, 29855번째 에피소드는 80.0점 입니다.
# target은 ['G', 'H', 'I', 'K', 'L', 'M'] ▶▶▶ [[0, 3], [0, 4], [0, 6], [0, 7], [0, 8], [9, 4]]입니다.
# action은 총 12번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3), (0, 2)]
# ###############
# Epoch # 8, Episode # 30000, start time: 20:27:01
# score:-12.4, n_buffer:531, eps:20.0
# 8번째 에포크로, 30435번째 에피소드는 78.0점 입니다.
# target은 ['G', 'J', 'K', 'M', 'O', 'P'] ▶▶▶ [[0, 5], [0, 6], [0, 8], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 14번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (2, 3), (2, 2), (1, 2), (0, 2)]
# ###############
# 8번째 에포크로, 30499번째 에피소드는 78.0점 입니다.
# target은 ['G', 'H', 'J', 'K', 'M', 'P'] ▶▶▶ [[0, 3], [0, 5], [0, 6], [0, 8], [4, 8], [9, 4]]입니다.
# action은 총 14번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (1, 2), (0, 2)]
# ###############
# Epoch # 8, Episode # 31000, start time: 20:27:55
# score:-12.4, n_buffer:535, eps:20.0
# Epoch # 8, Episode # 32000, start time: 20:28:48
# score:-12.4, n_buffer:535, eps:20.0
# Epoch # 8, Episode # 33000, start time: 20:29:41
# score:-12.4, n_buffer:535, eps:20.0
# Epoch # 8, Episode # 34000, start time: 20:30:34
# score:-12.4, n_buffer:535, eps:20.0
# 8번째 에포크로, 34518번째 에피소드는 83.0점 입니다.
# target은 ['A', 'C', 'D', 'F', 'H', 'J', 'K'] ▶▶▶ [[3, 0], [2, 0], [0, 1], [0, 3], [0, 5], [0, 6], [9, 4]]입니다.
# action은 총 9번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (7, 2), (7, 1), (6, 1), (5, 1), (5, 0)]
# ###############
# Epoch # 8, Episode # 35000, start time: 20:31:28
# score:-12.4, n_buffer:537, eps:20.0
# Epoch # 8, Episode # 36000, start time: 20:32:21
# score:-12.8, n_buffer:537, eps:20.0
# Epoch # 8, Episode # 37000, start time: 20:33:15
# score:-12.7, n_buffer:537, eps:20.0
# Epoch # 8, Episode # 38000, start time: 20:34:08
# score:-12.5, n_buffer:537, eps:20.0
# Epoch # 8, Episode # 39000, start time: 20:35:01
# score:-12.4, n_buffer:537, eps:20.0
# 9번째 epoch, 시작▶20:35:54
# 9번째 에포크로, 640번째 에피소드는 81.0점 입니다.
# target은 ['H', 'N', 'Q'] ▶▶▶ [[2, 8], [5, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 9, Episode # 1000, start time: 20:36:47
# score:-24.5, n_buffer:539, eps:10.0
# 9번째 에포크로, 1159번째 에피소드는 81.0점 입니다.
# target은 ['H', 'P', 'Q'] ▶▶▶ [[4, 8], [5, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 9, Episode # 2000, start time: 20:37:40
# score:-12.3, n_buffer:541, eps:10.0
# 9번째 에포크로, 2025번째 에피소드는 81.0점 입니다.
# target은 ['J', 'O', 'P', 'Q'] ▶▶▶ [[3, 8], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 5), (6, 5), (5, 5), (4, 5), (3, 5), (2, 5), (1, 5), (0, 5)]
# ###############
# 9번째 에포크로, 2478번째 에피소드는 80.0점 입니다.
# target은 ['G', 'J', 'K', 'L'] ▶▶▶ [[0, 5], [0, 6], [0, 7], [9, 4]]입니다.
# action은 총 12번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (1, 2), (0, 2)]
# ###############
# Epoch # 9, Episode # 3000, start time: 20:38:33
# score:-12.0, n_buffer:545, eps:10.0
# 9번째 에포크로, 3248번째 에피소드는 79.0점 입니다.
# target은 ['H', 'J', 'M', 'P', 'Q'] ▶▶▶ [[0, 5], [0, 8], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 13번 움직였습니다.
# [(9, 4), (8, 4), (9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 9, Episode # 4000, start time: 20:39:26
# score:-12.1, n_buffer:547, eps:10.0
# Epoch # 9, Episode # 5000, start time: 20:40:20
# score:-12.4, n_buffer:547, eps:10.0
# Epoch # 9, Episode # 6000, start time: 20:41:12
# score:-12.1, n_buffer:547, eps:10.0
# Epoch # 9, Episode # 7000, start time: 20:42:04
# score:-11.9, n_buffer:547, eps:10.0
# Epoch # 9, Episode # 8000, start time: 20:42:56
# score:-11.9, n_buffer:547, eps:10.0
# Epoch # 9, Episode # 9000, start time: 20:43:48
# score:-11.9, n_buffer:547, eps:10.0
# 9번째 에포크로, 9629번째 에피소드는 81.0점 입니다.
# target은 ['H', 'M', 'N', 'P'] ▶▶▶ [[0, 8], [2, 8], [4, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 9, Episode # 10000, start time: 20:44:41
# score:-12.1, n_buffer:549, eps:10.0
# 9번째 에포크로, 10690번째 에피소드는 81.0점 입니다.
# target은 ['H', 'I', 'L', 'N', 'P'] ▶▶▶ [[0, 4], [0, 7], [2, 8], [4, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# 9번째 에포크로, 10835번째 에피소드는 79.0점 입니다.
# target은 ['H', 'K', 'P', 'Q'] ▶▶▶ [[0, 6], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 13번 움직였습니다.
# [(9, 4), (8, 4), (8, 3), (7, 3), (6, 3), (5, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 9, Episode # 11000, start time: 20:45:34
# score:-12.1, n_buffer:553, eps:10.0
# Epoch # 9, Episode # 12000, start time: 20:46:26
# score:-12.2, n_buffer:553, eps:10.0
# Epoch # 9, Episode # 13000, start time: 20:47:19
# score:-12.2, n_buffer:553, eps:10.0
# Epoch # 9, Episode # 14000, start time: 20:48:11
# score:-12.4, n_buffer:553, eps:10.0
# Epoch # 9, Episode # 15000, start time: 20:49:04
# score:-12.3, n_buffer:553, eps:10.0
# Epoch # 9, Episode # 16000, start time: 20:49:58
# score:-12.3, n_buffer:553, eps:10.0
# Epoch # 9, Episode # 17000, start time: 20:50:50
# score:-12.3, n_buffer:553, eps:10.0
# Epoch # 9, Episode # 18000, start time: 20:51:42
# score:-12.3, n_buffer:553, eps:10.0
# Epoch # 9, Episode # 19000, start time: 20:52:35
# score:-12.4, n_buffer:553, eps:10.0
# Epoch # 9, Episode # 20000, start time: 20:53:28
# score:-12.3, n_buffer:553, eps:10.0
# 9번째 에포크로, 20421번째 에피소드는 81.0점 입니다.
# target은 ['H', 'I', 'K', 'L', 'M', 'N', 'Q'] ▶▶▶ [[0, 4], [0, 6], [0, 7], [0, 8], [2, 8], [5, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# 9번째 에포크로, 20775번째 에피소드는 181.0점 입니다.
# target은 ['H', 'I', 'J', 'M', 'N', 'O'] ▶▶▶ [[0, 5], [0, 8], [2, 8], [3, 8], [9, 4]]입니다.
# action은 총 12번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3), (0, 4)]
# ###############
# Epoch # 9, Episode # 21000, start time: 20:54:21
# score:-12.0, n_buffer:558, eps:10.0
# 9번째 에포크로, 21949번째 에피소드는 80.0점 입니다.
# target은 ['I', 'J', 'M', 'N', 'O'] ▶▶▶ [[0, 5], [0, 8], [2, 8], [3, 8], [9, 4]]입니다.
# action은 총 12번 움직였습니다.
# [(9, 4), (8, 4), (8, 5), (7, 5), (6, 5), (5, 5), (4, 5), (3, 5), (2, 5), (1, 5), (0, 5), (0, 4)]
# ###############
# Epoch # 9, Episode # 22000, start time: 20:55:13
# score:-12.2, n_buffer:560, eps:10.0
# Epoch # 9, Episode # 23000, start time: 20:56:06
# score:-12.3, n_buffer:560, eps:10.0
# Epoch # 9, Episode # 24000, start time: 20:56:59
# score:-12.2, n_buffer:560, eps:10.0
# 9번째 에포크로, 24375번째 에피소드는 80.0점 입니다.
# target은 ['G', 'K', 'M', 'N', 'O', 'P'] ▶▶▶ [[0, 6], [0, 8], [2, 8], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 12번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (2, 2), (1, 2), (0, 2)]
# ###############
# Epoch # 9, Episode # 25000, start time: 20:57:51
# score:-12.1, n_buffer:562, eps:10.0
# Epoch # 9, Episode # 26000, start time: 20:58:45
# score:-12.3, n_buffer:562, eps:10.0
# Epoch # 9, Episode # 27000, start time: 20:59:38
# score:-12.1, n_buffer:562, eps:10.0
# Epoch # 9, Episode # 28000, start time: 21:00:31
# score:-12.2, n_buffer:562, eps:10.0
# Epoch # 9, Episode # 29000, start time: 21:01:24
# score:-12.4, n_buffer:562, eps:10.0
# 9번째 에포크로, 29167번째 에피소드는 79.0점 입니다.
# target은 ['H', 'I', 'J', 'K', 'L', 'O'] ▶▶▶ [[0, 4], [0, 5], [0, 6], [0, 7], [3, 8], [9, 4]]입니다.
# action은 총 13번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 9, Episode # 30000, start time: 21:02:17
# score:-12.2, n_buffer:564, eps:10.0
# 9번째 에포크로, 30254번째 에피소드는 81.0점 입니다.
# target은 ['H', 'I', 'J', 'L', 'O', 'P', 'Q'] ▶▶▶ [[0, 4], [0, 5], [0, 7], [3, 8], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# 9번째 에포크로, 30686번째 에피소드는 79.0점 입니다.
# target은 ['H', 'I', 'K', 'M', 'N', 'P', 'Q'] ▶▶▶ [[0, 4], [0, 6], [0, 8], [2, 8], [4, 8], [5, 8], [9, 4]]입니다.
# action은 총 13번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (8, 4), (7, 4), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (0, 3)]
# ###############
# Epoch # 9, Episode # 31000, start time: 21:03:09
# score:-12.0, n_buffer:568, eps:10.0
# Epoch # 9, Episode # 32000, start time: 21:04:02
# score:-12.3, n_buffer:568, eps:10.0
# Epoch # 9, Episode # 33000, start time: 21:04:55
# score:-12.2, n_buffer:568, eps:10.0
# Epoch # 9, Episode # 34000, start time: 21:05:48
# score:-12.3, n_buffer:568, eps:10.0
# 9번째 에포크로, 34786번째 에피소드는 81.0점 입니다.
# target은 ['J', 'K', 'L', 'M', 'N', 'O', 'P'] ▶▶▶ [[0, 6], [0, 7], [0, 8], [2, 8], [3, 8], [4, 8], [9, 4]]입니다.
# action은 총 11번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (7, 5), (6, 5), (5, 5), (4, 5), (3, 5), (2, 5), (1, 5), (0, 5)]
# ###############
# Epoch # 9, Episode # 35000, start time: 21:06:41
# score:-12.1, n_buffer:570, eps:10.0
# Epoch # 9, Episode # 36000, start time: 21:07:34
# score:-12.4, n_buffer:570, eps:10.0
# Epoch # 9, Episode # 37000, start time: 21:08:28
# score:-12.3, n_buffer:570, eps:10.0
# 9번째 에포크로, 37523번째 에피소드는 78.0점 입니다.
# target은 ['I', 'K', 'L', 'M', 'N', 'O'] ▶▶▶ [[0, 6], [0, 7], [0, 8], [2, 8], [3, 8], [9, 4]]입니다.
# action은 총 14번 움직였습니다.
# [(9, 4), (8, 4), (7, 4), (8, 4), (7, 4), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (1, 4), (0, 4)]
# ###############
# Epoch # 9, Episode # 38000, start time: 21:09:21
# score:-12.2, n_buffer:572, eps:10.0
# Epoch # 9, Episode # 39000, start time: 21:10:14
# score:-12.4, n_buffer:572, eps:10.0

# %%
def test():
    model_name = "/9_39998_model.pt"
    model = torch.load(__file__ + model_name)
    print(f"model path = {model_name}")
    train_mode = False  # False
    tz = pytz.timezone('Asia/Seoul')
    env = Simulator()
    q = Qnet()
    q.to(device)
    s_before = None
    print_interval = 1
    score = 0.0


    ################################
    # 액션 저장하는 txt파일 만들기
    # my_file_name = f"{model_name}_{move_reward}_{obs_reward}_{goal_reward}"
    # f = open(my_file_name+'.txt', 'w')
    ################################

    for n_epi in range(len(env.files)): # range()의 인수로 len(env.files) 사용하면 됨 (=1225)
        env.grid = env.reset(n_epi)
        grid_map = env.grid.reshape(1,90)          # 그리드 맵
        

        ################################
        # 아이템 리스트 확인
        items = list(env.files.iloc[n_epi])[0]
        print('가져와야 할 아이템 : ' + list(env.files.iloc[n_epi])[0] + '\n')
        items = env.local_target
        # isFinished flag
        isFinished = False
        ################################

        # 출발지, 목적지 좌표 지정
        start_point = [9,4]  # 출발지 지정
        end_point = env.local_target[0]  # 첫 번째 목적지 지정
        #######################################################################
        # 목적지 도착 flag (done) 및 인풋 데이터 (s) 초기화
        done = False

        grid_temp_1 = env.grid.reshape(1,90)
        grid_temp_1 = grid_temp_1.squeeze()
        s = grid_temp_1
        #######################

        while not done:  # OB, 장애물, 최종 목표 도달시 종료
            a = q.test_action(torch.from_numpy(s).float())  # test_action 수행
            print(a)
            grid, r, cum_reward, done, goal_ob_reward, cur_location, target_location = env.step(a)
            
            grid_temp_2 = grid.reshape(1,90)
            grid_temp_2 = grid_temp_2.squeeze()
            s_prime = grid_temp_2
            s = s_prime
            score += r

        # print_interval (=1) 마다 현황 디스플레이하고 q_target 업데이트 및 score 초기화
        if n_epi % print_interval == 0 and n_epi != 0:
            cur_time = datetime.now(tz)
            simple_cur_time = cur_time.strftime("%H:%M:%S")
            print('▶ Episode #', n_epi, end=' → ')
            print('Score =', score, end='...')
            print('경로 길이:', len(env.actions), end=', ')
            if goal_ob_reward == 'finish':
                print('성공 여부: ', goal_ob_reward)
                isFinished = True
            else:
                print('성공 여부 : 실패', goal_ob_reward)
        
        score = 0.0
        print('→ pred_path:', env.actions)

        ##### 액션 결과물 확인하기
        if len(env.actions) > 15 and env.cumulative_reward > 0:
            print(f"move = {move_reward}, obs = {obs_reward}, goal = {goal_reward}")
            print(f"{n_epi}번째 에피소드는 {env.cumulative_reward:.1f}점 입니다.")
            print(f"target은 {env.items} ▶▶▶ {env.local_target}입니다.")
            print(f"action은 총 {len(env.actions)}번 움직였습니다.\n{env.actions}")
            print(grid)
            print("###############")

    #########################################    
    #     if len(env.actions) > 5:
    #         f.write(str(n_epi)+'/'+str(items)+'/'+str(cum_reward)+'/'+str(isFinished)+'\n')
    #         f.write(str(env.actions))
    #         f.write('\n')

    # f.close()
    #########################################

    # 모든 에피소드 종료 후 결과 디스플레이
    # 코드 추가할 것!!!

# test 모드 실행
train_mode = False
test()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 1
# ▶ Episode # 226 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'G', 'I', 'J', 'N', 'O', 'Q']
#
# 1
# ▶ Episode # 227 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'H', 'K', 'N', 'P', 'Q']
#
# 1
# ▶ Episode # 228 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'H', 'J', 'K', 'P', 'Q']
#
# 1
# ▶ Episode # 229 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'I', 'L', 'N', 'Q']
#
# 1
# ▶ Episode # 230 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'G', 'H', 'I', 'O']
#
# 1
# ▶ Episode # 231 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'I', 'J', 'L', 'M', 'Q']
#
# 1
# ▶ Episode # 232 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'G', 'L', 'P', 'Q']
#
# 1
# ▶ Episode # 233 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'F', 'G', 'J', 'N', 'O', 'P']
#
# 1
# ▶ Episode # 234 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'F', 'I', 'J', 'L', 'Q']
#
# 1
# ▶ Episode # 235 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'J', 'M', 'N', 'Q']
#
# 1
# ▶ Episode # 236 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'F', 'K', 'L', 'M', 'P']
#
# 1
# ▶ Episode # 237 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['G', 'H', 'I', 'K', 'N', 'Q']
#
# 1
# ▶ Episode # 238 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'F', 'I', 'N', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 239 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'G', 'I', 'L', 'N', 'O', 'Q']
#
# 1
# ▶ Episode # 240 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'H', 'K', 'M', 'Q']
#
# 1
# ▶ Episode # 241 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'E', 'H', 'J', 'O']
#
# 1
# ▶ Episode # 242 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'G', 'I', 'L', 'O']
#
# 1
# ▶ Episode # 243 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'G', 'K', 'M', 'N', 'P', 'Q']
#
# 2
# ▶ Episode # 244 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'H', 'I', 'L', 'O', 'Q']
#
# 1
# ▶ Episode # 245 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'F', 'G', 'H', 'L', 'M']
#
# 1
# ▶ Episode # 246 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'H', 'I', 'M', 'P']
#
# 1
# ▶ Episode # 247 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'H', 'J', 'L', 'M', 'N', 'P']
#
# 1
# ▶ Episode # 248 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'F', 'G', 'J', 'O']
#
# 1
# ▶ Episode # 249 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'H', 'I', 'J', 'K', 'L', 'O']
#
# 1
# ▶ Episode # 250 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'F', 'J', 'K', 'M', 'P']
#
# 1
# ▶ Episode # 251 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'F', 'K', 'M', 'O', 'P']
#
# 1
# ▶ Episode # 252 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'H', 'I', 'N', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 253 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'E', 'F', 'I', 'M', 'P']
#
# 1
# ▶ Episode # 254 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'F', 'J', 'L', 'M', 'N', 'P']
#
# 1
# ▶ Episode # 255 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'E', 'H', 'K', 'L']
#
# 1
# ▶ Episode # 256 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'F', 'H', 'I', 'P', 'Q']
#
# 1
# ▶ Episode # 257 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'E', 'H', 'I', 'J', 'L', 'M']
#
# 1
# ▶ Episode # 258 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'G', 'H', 'I', 'J', 'M']
#
# 1
# ▶ Episode # 259 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'F', 'H', 'K', 'M', 'P', 'Q']
#
# 1
# ▶ Episode # 260 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'F', 'I', 'N', 'O', 'P']
#
# 1
# ▶ Episode # 261 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'E', 'G', 'H', 'J', 'M', 'O']
#
# 1
# ▶ Episode # 262 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'H', 'K', 'L', 'M', 'O', 'P']
#
# 1
# ▶ Episode # 263 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'F', 'I', 'J', 'K', 'L']
#
# 1
# ▶ Episode # 264 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'F', 'L', 'M', 'N']
#
# 1
# ▶ Episode # 265 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'F', 'G', 'I', 'Q']
#
# 1
# ▶ Episode # 266 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'F', 'H', 'I', 'K', 'L', 'P']
#
# 1
# ▶ Episode # 267 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'G', 'L', 'N', 'O']
#
# 1
# ▶ Episode # 268 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'E', 'F', 'G', 'H', 'Q']
#
# 1
# ▶ Episode # 269 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'F', 'G', 'H', 'I', 'J']
#
# 1
# ▶ Episode # 270 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'E', 'F', 'L', 'O', 'P']
#
# 1
# ▶ Episode # 271 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'E', 'I', 'N', 'Q']
#
# 1
# ▶ Episode # 272 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'J', 'M', 'N', 'O', 'P']
#
# 1
# ▶ Episode # 273 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'E', 'L', 'M', 'O', 'Q']
#
# 1
# ▶ Episode # 274 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['I', 'J', 'K', 'L', 'N', 'P', 'Q']
#
# 1
# ▶ Episode # 275 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'E', 'N', 'P', 'Q']
#
# 1
# ▶ Episode # 276 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'F', 'H', 'K', 'Q']
#
# 1
# ▶ Episode # 277 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'F', 'K', 'M', 'Q']
#
# 1
# ▶ Episode # 278 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'F', 'H', 'I', 'M', 'Q']
#
# 1
# ▶ Episode # 279 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['H', 'I', 'J', 'M', 'N', 'P', 'Q']
#
# 1
# ▶ Episode # 280 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'E', 'J', 'K', 'M', 'O']
#
# 1
# ▶ Episode # 281 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'J', 'L', 'M', 'O', 'P']
#
# 1
# ▶ Episode # 282 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'F', 'G', 'J', 'L', 'O', 'P']
#
# 1
# ▶ Episode # 283 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'F', 'H', 'K', 'O', 'Q']
#
# 1
# ▶ Episode # 284 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'G', 'K', 'L', 'N', 'P']
#
# 1
# ▶ Episode # 285 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'J', 'L', 'M', 'O', 'P']
#
# 1
# ▶ Episode # 286 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'G', 'H', 'M', 'N', 'Q']
#
# 1
# ▶ Episode # 287 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'E', 'F', 'N']
#
# 1
# ▶ Episode # 288 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'G', 'I', 'K', 'N', 'P']
#
# 1
# ▶ Episode # 289 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'E', 'J', 'L', 'P']
#
# 1
# ▶ Episode # 290 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'F', 'I', 'N', 'O', 'Q']
#
# 1
# ▶ Episode # 291 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'F', 'H', 'M', 'O']
#
# 1
# ▶ Episode # 292 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'F', 'H', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 293 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'F', 'I', 'O', 'Q']
#
# 1
# ▶ Episode # 294 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'F', 'H', 'M', 'P']
#
# 1
# ▶ Episode # 295 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'F', 'I', 'J', 'Q']
#
# 1
# ▶ Episode # 296 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'E', 'H', 'I', 'O']
#
# 1
# ▶ Episode # 297 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'H', 'J', 'K']
#
# 1
# ▶ Episode # 298 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'F', 'G', 'J', 'N', 'O']
#
# 1
# ▶ Episode # 299 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'F', 'K', 'L', 'M', 'O']
#
# 1
# ▶ Episode # 300 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'E', 'G', 'H', 'N', 'O']
#
# 1
# ▶ Episode # 301 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'I', 'J', 'L', 'N', 'Q']
#
# 1
# ▶ Episode # 302 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'F', 'H', 'I', 'K', 'L', 'N']
#
# 1
# ▶ Episode # 303 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'H', 'I', 'J', 'L', 'Q']
#
# 1
# ▶ Episode # 304 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'I', 'J', 'K']
#
# 1
# ▶ Episode # 305 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'E', 'H', 'K', 'N', 'O']
#
# 1
# ▶ Episode # 306 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'G', 'L', 'M', 'N', 'P']
#
# 1
# ▶ Episode # 307 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'E', 'G', 'K', 'O', 'P']
#
# 1
# ▶ Episode # 308 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 309 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'F', 'G', 'H', 'K', 'M', 'N']
#
# 1
# ▶ Episode # 310 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'H', 'I', 'J', 'M', 'Q']
#
# 1
# ▶ Episode # 311 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'H', 'I', 'K', 'N', 'O']
#
# 1
# ▶ Episode # 312 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'F', 'I', 'J', 'N', 'P']
#
# 1
# ▶ Episode # 313 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'G', 'I', 'M', 'Q']
#
# 1
# ▶ Episode # 314 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'G', 'M', 'N', 'O', 'Q']
#
# 1
# ▶ Episode # 315 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'F', 'H', 'I', 'K', 'L', 'N']
#
# 1
# ▶ Episode # 316 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'J', 'N', 'O', 'P']
#
# 1
# ▶ Episode # 317 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'F', 'K', 'N', 'P']
#
# 1
# ▶ Episode # 318 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'D', 'E', 'F', 'K']
#
# 1
# ▶ Episode # 319 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'G', 'I', 'K', 'L', 'P']
#
# 1
# ▶ Episode # 320 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'G', 'J', 'L', 'M', 'O', 'Q']
#
# 1
# ▶ Episode # 321 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'K', 'M', 'P']
#
# 1
# ▶ Episode # 322 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'F', 'G', 'H', 'L', 'O', 'Q']
#
# 1
# ▶ Episode # 323 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'J', 'K', 'L', 'M', 'O']
#
# 1
# ▶ Episode # 324 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'H', 'J', 'K', 'N', 'P']
#
# 1
# ▶ Episode # 325 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'F', 'G', 'I', 'L', 'O', 'Q']
#
# 1
# ▶ Episode # 326 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'J', 'K', 'N', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 327 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'J', 'K', 'N', 'O', 'Q']
#
# 1
# ▶ Episode # 328 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'F', 'K', 'L', 'M', 'N', 'O']
#
# 1
# ▶ Episode # 329 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'G', 'J', 'K', 'M', 'O', 'Q']
#
# 1
# ▶ Episode # 330 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'I', 'K', 'M', 'N', 'O']
#
# 1
# ▶ Episode # 331 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'G', 'K', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 332 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['F', 'H', 'J', 'K', 'L', 'M', 'N']
#
# 1
# ▶ Episode # 333 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'F', 'J', 'K', 'N']
#
# 1
# ▶ Episode # 334 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['H', 'J', 'M', 'N', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 335 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'E', 'I', 'J', 'O', 'Q']
#
# 1
# ▶ Episode # 336 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'E', 'F', 'I', 'J', 'L']
#
# 1
# ▶ Episode # 337 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'F', 'G', 'H', 'I', 'L', 'P']
#
# 1
# ▶ Episode # 338 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'G', 'H', 'I', 'L', 'N']
#
# 1
# ▶ Episode # 339 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'J', 'L', 'N', 'O', 'P']
#
# 1
# ▶ Episode # 340 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'G', 'J', 'L', 'M']
#
# 1
# ▶ Episode # 341 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'D', 'F', 'M', 'O']
#
# 1
# ▶ Episode # 342 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'F', 'I', 'J', 'L', 'N']
#
# 1
# ▶ Episode # 343 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'F', 'H', 'I', 'M', 'P']
#
# 1
# ▶ Episode # 344 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'E', 'F', 'M', 'O', 'P']
#
# 1
# ▶ Episode # 345 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'F', 'I', 'L', 'P', 'Q']
#
# 1
# ▶ Episode # 346 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'E', 'H', 'L', 'M', 'Q']
#
# 1
# ▶ Episode # 347 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'F', 'J', 'M', 'O', 'Q']
#
# 1
# ▶ Episode # 348 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'F', 'G', 'J', 'K', 'L', 'Q']
#
# 1
# ▶ Episode # 349 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'F', 'G', 'H', 'N', 'O', 'Q']
#
# 1
# ▶ Episode # 350 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'F', 'G', 'I', 'M']
#
# 1
# ▶ Episode # 351 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'G', 'I', 'J', 'N', 'Q']
#
# 1
# ▶ Episode # 352 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'E', 'F', 'L', 'M', 'O']
#
# 1
# ▶ Episode # 353 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'I', 'J', 'K', 'P', 'Q']
#
# 1
# ▶ Episode # 354 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'F', 'G', 'I', 'N']
#
# 1
# ▶ Episode # 355 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'F', 'G', 'H', 'K']
#
# 1
# ▶ Episode # 356 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'F', 'G', 'J', 'K', 'L']
#
# 1
# ▶ Episode # 357 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'G', 'H', 'I', 'M', 'O']
#
# 1
# ▶ Episode # 358 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'H', 'J', 'L', 'M', 'O']
#
# 1
# ▶ Episode # 359 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'G', 'J', 'N', 'O', 'Q']
#
# 1
# ▶ Episode # 360 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'I', 'K', 'L', 'O', 'Q']
#
# 1
# ▶ Episode # 361 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'H', 'I', 'L', 'N', 'P']
#
# 1
# ▶ Episode # 362 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'G', 'H', 'J', 'L', 'M', 'N']
#
# 1
# ▶ Episode # 363 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'F', 'K', 'L', 'M', 'N']
#
# 1
# ▶ Episode # 364 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'G', 'I', 'L', 'M', 'O']
#
# 1
# ▶ Episode # 365 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'G', 'J', 'K', 'O', 'P']
#
# 1
# ▶ Episode # 366 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'E', 'F', 'J', 'M', 'P']
#
# 1
# ▶ Episode # 367 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'J', 'N', 'P', 'Q']
#
# 1
# ▶ Episode # 368 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'G', 'J', 'K', 'N']
#
# 1
# ▶ Episode # 369 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'G', 'I', 'J', 'P']
#
# 1
# ▶ Episode # 370 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'J', 'K', 'L', 'N', 'P']
#
# 1
# ▶ Episode # 371 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'G', 'I', 'K', 'L', 'N', 'P']
#
# 1
# ▶ Episode # 372 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'G', 'I', 'J', 'N', 'O', 'P']
#
# 1
# ▶ Episode # 373 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'G', 'J', 'M', 'N', 'P']
#
# 2
# ▶ Episode # 374 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'F', 'I', 'L', 'M', 'O']
#
# 1
# ▶ Episode # 375 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'J', 'K', 'N', 'Q']
#
# 1
# ▶ Episode # 376 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'F', 'H', 'I', 'L']
#
# 1
# ▶ Episode # 377 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'H', 'I', 'M', 'P', 'Q']
#
# 1
# ▶ Episode # 378 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'I', 'N', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 379 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'G', 'J', 'K', 'L', 'N']
#
# 1
# ▶ Episode # 380 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'G', 'H', 'J', 'L']
#
# 1
# ▶ Episode # 381 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'E', 'F', 'I', 'J', 'K', 'M']
#
# 1
# ▶ Episode # 382 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'F', 'H', 'J', 'L', 'M', 'Q']
#
# 1
# ▶ Episode # 383 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'E', 'J', 'M', 'N']
#
# 1
# ▶ Episode # 384 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['G', 'K', 'L', 'M', 'O', 'P']
#
# 1
# ▶ Episode # 385 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'H', 'J', 'M', 'N', 'P']
#
# 1
# ▶ Episode # 386 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'H', 'K', 'L', 'Q']
#
# 1
# ▶ Episode # 387 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'F', 'J', 'L', 'M', 'N', 'Q']
#
# 2
# ▶ Episode # 388 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'E', 'H', 'J', 'L', 'M', 'P']
#
# 1
# ▶ Episode # 389 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'E', 'L', 'N', 'O', 'Q']
#
# 1
# ▶ Episode # 390 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'E', 'G', 'H', 'J', 'Q']
#
# 1
# ▶ Episode # 391 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'E', 'I', 'J', 'Q']
#
# 1
# ▶ Episode # 392 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'H', 'K', 'L', 'M', 'P', 'Q']
#
# 1
# ▶ Episode # 393 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'G', 'K', 'L', 'M', 'P']
#
# 1
# ▶ Episode # 394 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'F', 'K', 'L', 'M', 'N']
#
# 1
# ▶ Episode # 395 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'G', 'I', 'J', 'N', 'Q']
#
# 1
# ▶ Episode # 396 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'F', 'H', 'K', 'M', 'O']
#
# 1
# ▶ Episode # 397 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'G', 'I', 'M', 'N', 'P']
#
# 1
# ▶ Episode # 398 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'E', 'I', 'L', 'P']
#
# 1
# ▶ Episode # 399 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['F', 'G', 'H', 'I', 'M', 'N', 'O']
#
# 1
# ▶ Episode # 400 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'E', 'H', 'J', 'M', 'N']
#
# 1
# ▶ Episode # 401 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'G', 'H', 'J', 'L', 'O', 'P']
#
# 1
# ▶ Episode # 402 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'F', 'G', 'L', 'M', 'O']
#
# 1
# ▶ Episode # 403 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'F', 'G', 'K', 'P']
#
# 1
# ▶ Episode # 404 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'H', 'I', 'J', 'L', 'M', 'N']
#
# 1
# ▶ Episode # 405 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'E', 'H', 'K', 'M', 'P']
#
# 1
# ▶ Episode # 406 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['G', 'H', 'I', 'K', 'L', 'M', 'O']
#
# 1
# ▶ Episode # 407 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'F', 'K', 'L', 'M', 'N']
#
# 1
# ▶ Episode # 408 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'F', 'G', 'H', 'I', 'N']
#
# 1
# ▶ Episode # 409 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'E', 'H', 'I', 'L', 'O', 'Q']
#
# 1
# ▶ Episode # 410 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'F', 'I', 'M', 'O', 'Q']
#
# 1
# ▶ Episode # 411 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'E', 'H', 'M', 'Q']
#
# 1
# ▶ Episode # 412 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'F', 'K', 'L', 'M', 'O', 'P']
#
# 1
# ▶ Episode # 413 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'E', 'G', 'H', 'I', 'P']
#
# 2
# ▶ Episode # 414 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'I', 'J', 'K', 'P', 'Q']
#
# 1
# ▶ Episode # 415 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'F', 'G', 'J', 'K', 'L', 'O']
#
# 1
# ▶ Episode # 416 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'E', 'G', 'H', 'N', 'P']
#
# 1
# ▶ Episode # 417 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'F', 'G', 'H', 'O']
#
# 1
# ▶ Episode # 418 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'I', 'K', 'N', 'P', 'Q']
#
# 1
# ▶ Episode # 419 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'F', 'H', 'J', 'N', 'P', 'Q']
#
# 1
# ▶ Episode # 420 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'G', 'K', 'L', 'M', 'O']
#
# 1
# ▶ Episode # 421 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'F', 'G', 'I', 'J', 'K']
#
# 1
# ▶ Episode # 422 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'F', 'G', 'I', 'O', 'Q']
#
# 1
# ▶ Episode # 423 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'E', 'F', 'L', 'M', 'N']
#
# 1
# ▶ Episode # 424 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'E', 'H', 'M', 'P', 'Q']
#
# 1
# ▶ Episode # 425 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'E', 'J', 'M', 'P', 'Q']
#
# 1
# ▶ Episode # 426 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'J', 'M', 'N', 'O']
#
# 1
# ▶ Episode # 427 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'F', 'H', 'K', 'Q']
#
# 1
# ▶ Episode # 428 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'F', 'J', 'L', 'M', 'O', 'Q']
#
# 1
# ▶ Episode # 429 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'F', 'K', 'M', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 430 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'F', 'H', 'K', 'M', 'Q']
#
# 1
# ▶ Episode # 431 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'G', 'H', 'I', 'L', 'P', 'Q']
#
# 1
# ▶ Episode # 432 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'E', 'H', 'I', 'N', 'O']
#
# 1
# ▶ Episode # 433 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'G', 'J', 'K', 'L', 'M', 'Q']
#
# 1
# ▶ Episode # 434 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'I', 'J', 'M', 'N']
#
# 1
# ▶ Episode # 435 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'E', 'H', 'J', 'N']
#
# 1
# ▶ Episode # 436 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'F', 'K', 'L', 'O', 'Q']
#
# 1
# ▶ Episode # 437 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'H', 'I', 'L', 'O']
#
# 1
# ▶ Episode # 438 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'F', 'H', 'K', 'M', 'N', 'P']
#
# 1
# ▶ Episode # 439 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'E', 'F', 'J', 'N', 'P']
#
# 1
# ▶ Episode # 440 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'G', 'H', 'I', 'M', 'N', 'Q']
#
# 1
# ▶ Episode # 441 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'E', 'H', 'I', 'M', 'O']
#
# 1
# ▶ Episode # 442 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'E', 'H', 'N', 'O']
#
# 1
# ▶ Episode # 443 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'I', 'L', 'M', 'N', 'Q']
#
# 1
# ▶ Episode # 444 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'F', 'G', 'H', 'I', 'K', 'N']
#
# 1
# ▶ Episode # 445 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'I', 'N', 'O']
#
# 1
# ▶ Episode # 446 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'G', 'I', 'L', 'P']
#
# 1
# ▶ Episode # 447 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'F', 'G', 'H', 'O']
#
# 1
# ▶ Episode # 448 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'G', 'J', 'K', 'M', 'Q']
#
# 2
# ▶ Episode # 449 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'F', 'H', 'I', 'J', 'P']
#
# 1
# ▶ Episode # 450 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'F', 'J', 'L', 'P', 'Q']
#
# 1
# ▶ Episode # 451 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'G', 'M', 'N', 'P']
#
# 1
# ▶ Episode # 452 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'F', 'H', 'J', 'K', 'L', 'O']
#
# 1
# ▶ Episode # 453 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'H', 'L', 'O', 'Q']
#
# 1
# ▶ Episode # 454 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'E', 'G', 'H', 'J', 'M']
#
# 1
# ▶ Episode # 455 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'F', 'H', 'I', 'M']
#
# 1
# ▶ Episode # 456 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'H', 'J', 'L', 'O', 'Q']
#
# 1
# ▶ Episode # 457 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'E', 'H', 'J', 'K', 'N']
#
# 1
# ▶ Episode # 458 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'J', 'M', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 459 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'G', 'H', 'I', 'M', 'P']
#
# 1
# ▶ Episode # 460 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'F', 'L', 'N', 'O']
#
# 1
# ▶ Episode # 461 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'F', 'H', 'J', 'L', 'Q']
#
# 1
# ▶ Episode # 462 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'M', 'N', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 463 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'G', 'K', 'L', 'M', 'P', 'Q']
#
# 1
# ▶ Episode # 464 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'F', 'I', 'J', 'N', 'Q']
#
# 1
# ▶ Episode # 465 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['F', 'H', 'J', 'K', 'L', 'N', 'P']
#
# 1
# ▶ Episode # 466 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'E', 'G', 'H', 'I', 'L', 'M']
#
# 1
# ▶ Episode # 467 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'H', 'J', 'K', 'L', 'Q']
#
# 1
# ▶ Episode # 468 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'F', 'H', 'J', 'M', 'O', 'Q']
#
# 1
# ▶ Episode # 469 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'G', 'H', 'I', 'J', 'L']
#
# 1
# ▶ Episode # 470 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'G', 'H', 'J', 'Q']
#
# 1
# ▶ Episode # 471 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'F', 'H', 'I', 'M']
#
# 1
# ▶ Episode # 472 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'H', 'I', 'N', 'P']
#
# 2
# ▶ Episode # 473 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'J', 'M', 'O', 'Q']
#
# 1
# ▶ Episode # 474 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'G', 'H', 'K', 'O', 'P']
#
# 1
# ▶ Episode # 475 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'F', 'G', 'K', 'L', 'O']
#
# 1
# ▶ Episode # 476 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'G', 'I', 'M', 'P', 'Q']
#
# 1
# ▶ Episode # 477 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'I', 'K', 'N', 'Q']
#
# 1
# ▶ Episode # 478 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'F', 'L', 'M', 'O', 'Q']
#
# 1
# ▶ Episode # 479 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'E', 'H', 'N', 'O', 'Q']
#
# 1
# ▶ Episode # 480 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'I', 'J', 'N', 'O', 'P']
#
# 1
# ▶ Episode # 481 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'E', 'H', 'K', 'L', 'O']
#
# 1
# ▶ Episode # 482 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'H', 'I', 'J', 'L', 'O', 'P']
#
# 1
# ▶ Episode # 483 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'E', 'I', 'J', 'M', 'Q']
#
# 1
# ▶ Episode # 484 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'F', 'G', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 485 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['F', 'G', 'L', 'M', 'N', 'O', 'Q']
#
# 1
# ▶ Episode # 486 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'F', 'H', 'J', 'O', 'P']
#
# 1
# ▶ Episode # 487 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'H', 'I', 'K', 'M', 'Q']
#
# 1
# ▶ Episode # 488 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'H', 'J', 'K', 'L', 'N', 'O']
#
# 1
# ▶ Episode # 489 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'H', 'N', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 490 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'E', 'F', 'K', 'Q']
#
# 1
# ▶ Episode # 491 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'F', 'H', 'K', 'M', 'N']
#
# 1
# ▶ Episode # 492 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'I', 'K', 'L', 'M', 'N', 'O']
#
# 1
# ▶ Episode # 493 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'E', 'F', 'H', 'J', 'O', 'P']
#
# 1
# ▶ Episode # 494 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['F', 'G', 'H', 'L', 'P', 'Q']
#
# 1
# ▶ Episode # 495 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'I', 'J', 'M', 'N', 'Q']
#
# 1
# ▶ Episode # 496 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'E', 'H', 'I', 'L', 'N', 'O']
#
# 1
# ▶ Episode # 497 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'F', 'H', 'J', 'M', 'P']
#
# 1
# ▶ Episode # 498 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'F', 'J', 'P', 'Q']
#
# 1
# ▶ Episode # 499 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'F', 'K', 'L', 'P']
#
# 1
# ▶ Episode # 500 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'H', 'I', 'L', 'O']
#
# 1
# ▶ Episode # 501 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'D', 'H', 'K', 'O']
#
# 1
# ▶ Episode # 502 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'G', 'H', 'I', 'L', 'M']
#
# 1
# ▶ Episode # 503 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'F', 'G', 'J', 'L', 'N']
#
# 1
# ▶ Episode # 504 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'F', 'H', 'I', 'N', 'O', 'Q']
#
# 1
# ▶ Episode # 505 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'G', 'I', 'J', 'K', 'P', 'Q']
#
# 1
# ▶ Episode # 506 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'E', 'F', 'G', 'I', 'J', 'M']
#
# 1
# ▶ Episode # 507 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'H', 'I', 'K', 'L', 'N']
#
# 1
# ▶ Episode # 508 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'F', 'J', 'M', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 509 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'I', 'J', 'K', 'L', 'O', 'Q']
#
# 1
# ▶ Episode # 510 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'F', 'G', 'J', 'K', 'P']
#
# 1
# ▶ Episode # 511 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'G', 'H', 'K', 'L', 'N', 'P']
#
# 1
# ▶ Episode # 512 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'E', 'H', 'J', 'L', 'M']
#
# 1
# ▶ Episode # 513 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'H', 'L', 'N', 'O']
#
# 1
# ▶ Episode # 514 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'F', 'K', 'N', 'P', 'Q']
#
# 1
# ▶ Episode # 515 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'K', 'M', 'N', 'P', 'Q']
#
# 1
# ▶ Episode # 516 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'I', 'J', 'N', 'Q']
#
# 1
# ▶ Episode # 517 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'E', 'F', 'H', 'J', 'L', 'Q']
#
# 1
# ▶ Episode # 518 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'F', 'H', 'J', 'M', 'O', 'P']
#
# 1
# ▶ Episode # 519 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'G', 'H', 'J', 'L']
#
# 1
# ▶ Episode # 520 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'H', 'L', 'M', 'Q']
#
# 1
# ▶ Episode # 521 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'G', 'I', 'J', 'L', 'N', 'O']
#
# 1
# ▶ Episode # 522 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'F', 'J', 'N', 'P', 'Q']
#
# 1
# ▶ Episode # 523 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'F', 'G', 'H', 'I', 'O', 'P']
#
# 1
# ▶ Episode # 524 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'E', 'G', 'J', 'L', 'Q']
#
# 1
# ▶ Episode # 525 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'G', 'I', 'N', 'P', 'Q']
#
# 1
# ▶ Episode # 526 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'F', 'I', 'M', 'O', 'Q']
#
# 1
# ▶ Episode # 527 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'F', 'G', 'H', 'I', 'M', 'Q']
#
# 1
# ▶ Episode # 528 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'F', 'H', 'J', 'K', 'N', 'O']
#
# 1
# ▶ Episode # 529 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'I', 'J', 'O', 'P']
#
# 1
# ▶ Episode # 530 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'J', 'K', 'M', 'O', 'P']
#
# 1
# ▶ Episode # 531 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'J', 'K', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 532 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'E', 'G', 'H', 'L', 'M', 'N']
#
# 1
# ▶ Episode # 533 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'E', 'F', 'I', 'K', 'N', 'O']
#
# 1
# ▶ Episode # 534 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'F', 'G', 'I', 'K', 'L', 'P']
#
# 1
# ▶ Episode # 535 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'I', 'J', 'K', 'L']
#
# 1
# ▶ Episode # 536 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'G', 'N', 'O', 'P']
#
# 1
# ▶ Episode # 537 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'F', 'I', 'K', 'P', 'Q']
#
# 1
# ▶ Episode # 538 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'I', 'K', 'L', 'M', 'N', 'Q']
#
# 1
# ▶ Episode # 539 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'I', 'N', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 540 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'F', 'G', 'J', 'O', 'Q']
#
# 1
# ▶ Episode # 541 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'H', 'I', 'J', 'O']
#
# 1
# ▶ Episode # 542 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'H', 'K', 'M', 'O', 'P']
#
# 1
# ▶ Episode # 543 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'F', 'J', 'K', 'L', 'O']
#
# 1
# ▶ Episode # 544 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'G', 'I', 'J', 'K', 'M', 'O']
#
# 1
# ▶ Episode # 545 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'G', 'H', 'I', 'M', 'P']
#
# 1
# ▶ Episode # 546 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'E', 'G', 'H', 'L', 'M', 'Q']
#
# 1
# ▶ Episode # 547 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'F', 'G', 'I', 'K', 'L', 'P']
#
# 1
# ▶ Episode # 548 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'G', 'N', 'O', 'P']
#
# 1
# ▶ Episode # 549 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'E', 'H', 'J', 'L', 'M']
#
# 1
# ▶ Episode # 550 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'G', 'I', 'K', 'M', 'P']
#
# 1
# ▶ Episode # 551 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'E', 'H', 'J', 'P', 'Q']
#
# 1
# ▶ Episode # 552 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'F', 'I', 'K', 'L', 'P']
#
# 1
# ▶ Episode # 553 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'E', 'I', 'N', 'O', 'P']
#
# 1
# ▶ Episode # 554 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'H', 'I', 'K', 'O', 'P']
#
# 1
# ▶ Episode # 555 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'E', 'F', 'N', 'P', 'Q']
#
# 1
# ▶ Episode # 556 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'H', 'J', 'O', 'Q']
#
# 1
# ▶ Episode # 557 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'H', 'J', 'M', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 558 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'E', 'G', 'H', 'I', 'P']
#
# 1
# ▶ Episode # 559 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'F', 'I', 'K', 'M', 'P']
#
# 1
# ▶ Episode # 560 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'K', 'L', 'N', 'Q']
#
# 1
# ▶ Episode # 561 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'G', 'I', 'L', 'N', 'Q']
#
# 1
# ▶ Episode # 562 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'L', 'M', 'P', 'Q']
#
# 1
# ▶ Episode # 563 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'F', 'J', 'L', 'O', 'P']
#
# 1
# ▶ Episode # 564 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'F', 'L', 'M', 'O']
#
# 1
# ▶ Episode # 565 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'G', 'J', 'O', 'P']
#
# 1
# ▶ Episode # 566 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'I', 'J', 'L', 'O', 'Q']
#
# 1
# ▶ Episode # 567 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'G', 'I', 'J', 'M', 'P', 'Q']
#
# 1
# ▶ Episode # 568 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'E', 'H', 'M', 'N', 'P', 'Q']
#
# 1
# ▶ Episode # 569 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'H', 'J', 'L', 'Q']
#
# 1
# ▶ Episode # 570 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'F', 'L', 'M', 'N', 'O', 'P']
#
# 2
# ▶ Episode # 571 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'G', 'H', 'L', 'N']
#
# 1
# ▶ Episode # 572 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'L', 'M', 'N', 'O', 'P']
#
# 1
# ▶ Episode # 573 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'E', 'G', 'H', 'N', 'O', 'P']
#
# 1
# ▶ Episode # 574 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'F', 'I', 'J', 'M', 'Q']
#
# 1
# ▶ Episode # 575 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'E', 'F', 'J', 'L', 'N']
#
# 1
# ▶ Episode # 576 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'F', 'H', 'J', 'L', 'O', 'Q']
#
# 1
# ▶ Episode # 577 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'H', 'I', 'K', 'L', 'N', 'Q']
#
# 1
# ▶ Episode # 578 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'E', 'F', 'J', 'K', 'M']
#
# 1
# ▶ Episode # 579 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'F', 'J', 'L', 'M', 'O']
#
# 1
# ▶ Episode # 580 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'F', 'G', 'H', 'J', 'N']
#
# 1
# ▶ Episode # 581 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'E', 'H', 'M', 'O', 'P']
#
# 1
# ▶ Episode # 582 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# ...
#
# 1
# ▶ Episode # 1108 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'H', 'I', 'L', 'M', 'O']
#
# 1
# ▶ Episode # 1109 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'G', 'J', 'K', 'L', 'M', 'P']
#
# 1
# ▶ Episode # 1110 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'F', 'I', 'M']
#
# 1
# ▶ Episode # 1111 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'K', 'L', 'O', 'P']
#
# 1
# ▶ Episode # 1112 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'I', 'K', 'L', 'P', 'Q']
#
# 1
# ▶ Episode # 1113 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'F', 'H', 'L', 'N']
#
# 1
# ▶ Episode # 1114 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'F', 'G', 'H', 'I', 'L', 'P']
#
# 1
# ▶ Episode # 1115 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'E', 'J', 'M', 'N', 'P', 'Q']
#
# 1
# ▶ Episode # 1116 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'G', 'K', 'M', 'O', 'Q']
#
# 1
# ▶ Episode # 1117 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'F', 'I', 'K', 'L', 'N']
#
# 1
# ▶ Episode # 1118 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'F', 'G', 'L', 'M', 'O', 'P']
#
# 1
# ▶ Episode # 1119 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'F', 'G', 'L', 'N']
#
# 1
# ▶ Episode # 1120 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'D', 'K', 'M', 'O']
#
# 1
# ▶ Episode # 1121 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'J', 'L', 'M', 'N', 'P']
#
# 1
# ▶ Episode # 1122 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['F', 'G', 'H', 'J', 'K', 'N', 'Q']
#
# 1
# ▶ Episode # 1123 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'G', 'I', 'J', 'K', 'P']
#
# 1
# ▶ Episode # 1124 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'D', 'F', 'O', 'P']
#
# 1
# ▶ Episode # 1125 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'H', 'I', 'K', 'N', 'P']
#
# 1
# ▶ Episode # 1126 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'E', 'G', 'H', 'N', 'P']
#
# 1
# ▶ Episode # 1127 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'F', 'J', 'M', 'Q']
#
# 1
# ▶ Episode # 1128 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'I', 'L', 'N', 'O']
#
# 1
# ▶ Episode # 1129 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'G', 'I', 'J', 'M', 'O']
#
# 1
# ▶ Episode # 1130 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'H', 'I', 'J', 'K', 'P', 'Q']
#
# 1
# ▶ Episode # 1131 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'G', 'H', 'K', 'L', 'P']
#
# 1
# ▶ Episode # 1132 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'G', 'I', 'L', 'O']
#
# 1
# ▶ Episode # 1133 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'I', 'M', 'N', 'Q']
#
# 1
# ▶ Episode # 1134 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'H', 'I', 'L', 'N', 'O', 'Q']
#
# 1
# ▶ Episode # 1135 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'F', 'G', 'H', 'I', 'K', 'L']
#
# 1
# ▶ Episode # 1136 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'G', 'I', 'K', 'M', 'O', 'Q']
#
# 1
# ▶ Episode # 1137 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'F', 'G', 'I', 'J', 'L', 'N']
#
# 1
# ▶ Episode # 1138 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'H', 'I', 'J', 'M', 'Q']
#
# 1
# ▶ Episode # 1139 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'J', 'L', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 1140 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'E', 'G', 'H', 'P']
#
# 1
# ▶ Episode # 1141 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'G', 'H', 'I', 'N', 'O', 'P']
#
# 1
# ▶ Episode # 1142 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'E', 'F', 'L', 'M', 'O', 'Q']
#
# 1
# ▶ Episode # 1143 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'H', 'I', 'J', 'N']
#
# 1
# ▶ Episode # 1144 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'F', 'G', 'J', 'N', 'O', 'P']
#
# 1
# ▶ Episode # 1145 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'H', 'I', 'J', 'L', 'M']
#
# 1
# ▶ Episode # 1146 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'F', 'L', 'M', 'P']
#
# 1
# ▶ Episode # 1147 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'E', 'J', 'M', 'N']
#
# 1
# ▶ Episode # 1148 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'E', 'H', 'I', 'P']
#
# 1
# ▶ Episode # 1149 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'I', 'L', 'O', 'P']
#
# 1
# ▶ Episode # 1150 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'G', 'I', 'M', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 1151 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'D', 'F', 'K', 'M', 'Q']
#
# 1
# ▶ Episode # 1152 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'I', 'J', 'K', 'O', 'P']
#
# 1
# ▶ Episode # 1153 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'J', 'K', 'L', 'M', 'N', 'O']
#
# 1
# ▶ Episode # 1154 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'F', 'I', 'J', 'M', 'O']
#
# 1
# ▶ Episode # 1155 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'I', 'K', 'M', 'O', 'Q']
#
# 1
# ▶ Episode # 1156 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'G', 'H', 'N', 'P']
#
# 1
# ▶ Episode # 1157 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'F', 'G', 'H', 'I', 'M', 'P']
#
# 1
# ▶ Episode # 1158 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'F', 'G', 'I', 'K', 'N', 'Q']
#
# 1
# ▶ Episode # 1159 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'E', 'I', 'K', 'L', 'O', 'Q']
#
# 1
# ▶ Episode # 1160 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'G', 'H', 'I', 'J', 'O', 'P']
#
# 1
# ▶ Episode # 1161 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'F', 'H', 'I', 'K', 'M', 'N']
#
# 1
# ▶ Episode # 1162 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'J', 'L', 'M', 'N', 'P']
#
# 1
# ▶ Episode # 1163 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'H', 'I', 'M', 'P']
#
# 1
# ▶ Episode # 1164 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'F', 'J', 'M', 'Q']
#
# 1
# ▶ Episode # 1165 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'G', 'H', 'K', 'L', 'M', 'Q']
#
# 1
# ▶ Episode # 1166 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'F', 'I', 'J', 'M', 'O']
#
# 1
# ▶ Episode # 1167 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'G', 'H', 'I', 'L', 'P']
#
# 1
# ▶ Episode # 1168 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'F', 'J', 'K', 'M', 'O', 'P']
#
# 1
# ▶ Episode # 1169 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'F', 'G', 'H', 'J', 'L', 'M']
#
# 1
# ▶ Episode # 1170 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'H', 'K', 'L', 'N', 'O', 'Q']
#
# 1
# ▶ Episode # 1171 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'F', 'H', 'J', 'O']
#
# 1
# ▶ Episode # 1172 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'H', 'J', 'M', 'N', 'P', 'Q']
#
# 1
# ▶ Episode # 1173 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'E', 'F', 'G', 'H', 'M', 'O']
#
# 1
# ▶ Episode # 1174 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'I', 'J', 'M', 'O']
#
# 1
# ▶ Episode # 1175 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'F', 'M', 'N', 'P', 'Q']
#
# 1
# ▶ Episode # 1176 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'I', 'L', 'M', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 1177 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'E', 'J', 'K', 'O', 'P']
#
# 1
# ▶ Episode # 1178 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'F', 'G', 'H', 'K', 'O', 'P']
#
# 1
# ▶ Episode # 1179 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'E', 'G', 'J', 'N']
#
# 1
# ▶ Episode # 1180 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'G', 'K', 'L', 'O']
#
# 1
# ▶ Episode # 1181 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'E', 'G', 'K', 'O', 'P']
#
# 1
# ▶ Episode # 1182 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'G', 'H', 'K', 'M', 'N', 'P']
#
# 1
# ▶ Episode # 1183 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'F', 'H', 'I', 'P', 'Q']
#
# 1
# ▶ Episode # 1184 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'F', 'I', 'J', 'M', 'Q']
#
# 1
# ▶ Episode # 1185 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'F', 'G', 'I', 'K', 'O', 'P']
#
# 1
# ▶ Episode # 1186 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'F', 'G', 'H', 'K', 'L']
#
# 1
# ▶ Episode # 1187 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'E', 'G', 'J', 'P', 'Q']
#
# 1
# ▶ Episode # 1188 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'K', 'L', 'M', 'N', 'Q']
#
# 1
# ▶ Episode # 1189 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'G', 'J', 'L', 'M', 'P']
#
# 1
# ▶ Episode # 1190 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'F', 'G', 'H', 'K', 'N', 'O']
#
# 1
# ▶ Episode # 1191 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'E', 'J', 'K', 'L', 'O']
#
# 1
# ▶ Episode # 1192 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'G', 'H', 'I', 'J', 'K', 'P']
#
# 1
# ▶ Episode # 1193 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'H', 'J', 'L', 'M', 'N', 'Q']
#
# 1
# ▶ Episode # 1194 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'F', 'H', 'I', 'L', 'N']
#
# 1
# ▶ Episode # 1195 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'F', 'H', 'I', 'J']
#
# 1
# ▶ Episode # 1196 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'E', 'G', 'H', 'I', 'O']
#
# 1
# ▶ Episode # 1197 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['F', 'G', 'H', 'I', 'K', 'L', 'P']
#
# 1
# ▶ Episode # 1198 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'E', 'H', 'J', 'M', 'P', 'Q']
#
# 2
# ▶ Episode # 1199 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'G', 'I', 'J', 'L', 'P']
#
# 1
# ▶ Episode # 1200 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'C', 'G', 'J', 'M', 'P', 'Q']
#
# 1
# ▶ Episode # 1201 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'G', 'H', 'I', 'L', 'N', 'Q']
#
# 1
# ▶ Episode # 1202 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'C', 'D', 'E', 'H', 'P']
#
# 1
# ▶ Episode # 1203 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'I', 'K', 'P', 'Q']
#
# 1
# ▶ Episode # 1204 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'E', 'H', 'J', 'N', 'O']
#
# 1
# ▶ Episode # 1205 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'G', 'H', 'J', 'M', 'N']
#
# 1
# ▶ Episode # 1206 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'F', 'J', 'M', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 1207 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'F', 'G', 'K', 'Q']
#
# 1
# ▶ Episode # 1208 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'F', 'I', 'K', 'M', 'N', 'O']
#
# 1
# ▶ Episode # 1209 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'D', 'G', 'I', 'K', 'Q']
#
# 1
# ▶ Episode # 1210 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'F', 'I', 'J', 'M', 'N']
#
# 1
# ▶ Episode # 1211 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'G', 'I', 'K', 'N', 'P', 'Q']
#
# 2
# ▶ Episode # 1212 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['D', 'F', 'M', 'N', 'O', 'P', 'Q']
#
# 1
# ▶ Episode # 1213 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'F', 'G', 'H', 'M', 'P']
#
# 1
# ▶ Episode # 1214 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'E', 'F', 'G', 'K', 'O']
#
# 1
# ▶ Episode # 1215 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'D', 'F', 'H', 'I', 'J', 'P']
#
# 1
# ▶ Episode # 1216 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'I', 'J', 'K', 'M', 'Q']
#
# 1
# ▶ Episode # 1217 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'G', 'H', 'L', 'N', 'O', 'P']
#
# 1
# ▶ Episode # 1218 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'C', 'E', 'F', 'I', 'L', 'Q']
#
# 1
# ▶ Episode # 1219 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['B', 'D', 'K', 'L', 'N', 'O', 'P']
#
# 1
# ▶ Episode # 1220 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'G', 'J', 'K', 'L', 'O', 'P']
#
# 1
# ▶ Episode # 1221 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['C', 'G', 'I', 'J', 'L', 'M', 'O']
#
# 1
# ▶ Episode # 1222 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['E', 'F', 'H', 'J', 'K', 'L', 'N']
#
# 1
# ▶ Episode # 1223 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'B', 'D', 'G', 'H', 'N', 'O']
#
# 1
# ▶ Episode # 1224 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]
# 가져와야 할 아이템 : ['A', 'D', 'G', 'H', 'L', 'M', 'N']
#
# 1
# ▶ Episode # 1225 → Score = -10.0...경로 길이: 1, 성공 여부 : 실패 False
# → pred_path: [(9, 4)]

# %% [markdown]
# ### 기존 main(), test() 코드

# %%
# def main():
#     tz = pytz.timezone('Asia/Seoul')

#     env = Simulator()
#     q = Qnet()
#     q.to(device)
#     q_target = Qnet()
#     q_target.to(device)
#     q_target.load_state_dict(q.state_dict())
#     memory = ReplayBuffer()

#     print_interval = 1000
#     score = 0.0  
#     optimizer = optim.Adam(q.parameters(), lr=learning_rate)
    
#     print('len(env.files):', len(env.files))
    
#     #path_length = []

    
#     for n_epi in range(len(env.files)): # range()의 인수로 len(env.files) 사용하면 됨 (=39,999)
#     # for n_epi in range(1): # test용

#         epsilon = max(0.01, 1 - 0.01*(n_epi/200)) # 상민님 epi/40000
#         env.grid = env.reset(n_epi)  # env reset: 에피소드 번호에 해당하는 목표물 리스트 env.local_target 생성, 그리드맵 생성
#         start_point = [9,4]  # 출발지 지정
#         end_point = env.local_target[0]  # 첫 번째 목적지 지정
#         done = False
#         ###################
#         grid_temp_1 = env.grid.reshape(1,90)
#         grid_temp_1 = grid_temp_1.squeeze()
#         s = grid_temp_1
#         ###################
#         old_score = 0.0
#         # print(f"env.grid=\n{env.grid}")

#         while not done:
#             a = q.sample_action(torch.from_numpy(s).float(), epsilon)
#             grid, r, cum_reward, done, goal_ob_reward, cur_location, target_location = env.step(a)
#             ###################
#             grid_temp_2 = grid.reshape(1,90)
#             grid_temp_2 = grid_temp_2.squeeze()
#             s_prime = grid_temp_2

#             # done_mask = 0.0 if done else 1.0 # done = True일 때만 memory.put 진행한다. -> 죽는거만 메모리에 들어가지 않을까?
#             if done == True and cum_reward > 0:
#                 memory.put((s,a,r/100.0,s_prime,done,cur_location,target_location)) # 현재 agent 좌표랑 local target 좌표 추가
#             s = s_prime
            

#             score += r
#             '''
#             if score > old_score:
#                     cur_time = datetime.now(tz)
#                     simple_cur_time = cur_time.strftime("%H:%M:%S")
#                     print('▶ Episode #', n_epi, 'start time:', simple_cur_time, end='→')
#                     print('Score =', score, 'appended actions =', s, end='...')
#                     print('경로 길이:', len(env.actions))
#             '''
#             old_score = score
                       
#             if done:
#                 break

#             # while loop 종료

#         ############################################################################
#                 ## memory.size(): 2000 → 10000 → 20000 수정... 이후 훈련 시작
#         ############################################################################   
#         if memory.size() > 10000: # 20000 -> 10000
#             train(q, q_target, memory, optimizer)

#         if n_epi % print_interval == 0 and n_epi != 0:
#             cur_time = datetime.now(tz)
#             simple_cur_time = cur_time.strftime("%H:%M:%S")
#             print('▶ Episode #', n_epi, 'start time:', simple_cur_time, end='→')
#             q_target.load_state_dict(q.state_dict())
#             print("n_episode :{}, score : {:.1f}, n_buffer : {}, eps : {:.1f}%".format(
#                                                             n_epi, score/print_interval, memory.size(), epsilon*100))
            
#             score = 0.0

#             # torch.save(q, model_path)
#             torch.save(q, __file__+f"/{n_epi}_model.pt")
#         ##### 액션 결과물 확인하기
#         if env.cumulative_reward > 0:
#             print(f"move = {move_reward}, obs = {obs_reward}, goal = {goal_reward}")
#             print(f"{n_epi}번째 에피소드는 {env.cumulative_reward:.1f}점 입니다.")
#             print(f"target은 {env.items} ▶▶▶ {env.local_target}입니다.")
#             print(f"action은 총 {len(env.actions)}번 움직였습니다.\n{env.actions}")
#             print(grid)
#             print("###############")

#     # torch.save(q, model_path)
#     torch.save(q, __file__+f"/{n_epi}_model.pt")

# if __name__ == '__main__':
#     main()

# %%
# def test():
#     # model = torch.load('/content/drive/MyDrive/aiffelthon/data/model.pt')
#     # model = torch.load(model_path)
#     model_name = "/5000_model.pt"
#     model = torch.load(__file__ + model_name)
#     print(f"model path = {model_name}")
#     train_mode = False  # False
#     tz = pytz.timezone('Asia/Seoul')
#     env = Simulator()
#     q = Qnet()
#     s_before = None
#     print_interval = 1
#     score = 0.0

#     ################################
#     # 액션 저장하는 txt파일 만들기
#     # my_file_name = f"{model_name}_{move_reward}_{obs_reward}_{goal_reward}"
#     # f = open(my_file_name+'.txt', 'w')
#     ################################

#     for n_epi in range(len(env.files)): # range()의 인수로 len(env.files) 사용하면 됨 (=1225)
#         env.grid = env.reset(n_epi)
#         grid_map = env.grid.reshape(-1)          # 그리드 맵

#         ################################
#         # 아이템 리스트 확인
#         items = list(env.files.iloc[n_epi])[0]
#         print('가져와야 할 아이템 : ' + list(env.files.iloc[n_epi])[0] + '\n')
#         items = env.local_target
#         # isFinished flag
#         isFinished = False
#         ################################

#         # 출발지, 목적지 좌표 지정
#         #env.x, env.y = start_point                # 출발지 좌표
#         #env.end_x, env.end_y = end_point          # 목적지 좌표
#         start_point = [9,4]  # 출발지 지정
#         end_point = env.local_target[0]  # 첫 번째 목적지 지정
#         #######################################################################
#         # 목적지 도착 flag (done) 및 인풋 데이터 (s) 초기화
#         done = False
#         # s_temp_1 = np.append(grid_map, start_point)
#         # s_temp_2 = np.append(s_temp_1, end_point)
#         # s = np.array(s_temp_2)
#         #######################
#         grid_temp_1 = env.grid.reshape(1,90)
#         grid_temp_1 = grid_temp_1.squeeze()
#         s = grid_temp_1
#         #######################

#         while not done:  # OB, 장애물, 최종 목표 도달시 종료
#             ####################################################################################
#             # # -> 무한 루프
#             # # (option) test 경우 추가: 출발점에서는 무조건 위로 올라간다 (action=0)
#             # x, y = s[-4:-2]
#             # if [x,y] == [9,4]:
#             #     a = 0
#             # else:
#             #     a = q.test_action(torch.from_numpy(s).float())  # test_action 수행 ->
#             #####################################################################################
#             a = q.test_action(torch.from_numpy(s).float())  # test_action 수행
#             #####################################################################################
#             grid, r, cum_reward, done, goal_ob_reward = env.step(a)
            
#             ######################################
#             # new_grid_map = grid.reshape(-1)
#             # s_prime_temp_1 = np.append(new_grid_map, env.curloc)
#             # s_prime_temp_2 = np.append(s_prime_temp_1, end_point)
#             # s_prime = np.array(s_prime_temp_2)
#             ######################################
#             grid_temp_2 = grid.reshape(1,90)
#             grid_temp_2 = grid_temp_2.squeeze()
#             s_prime = grid_temp_2

#             s = s_prime
#             score += r

#         # print_interval (=1) 마다 현황 디스플레이하고 q_target 업데이트 및 score 초기화
#         if n_epi % print_interval == 0 and n_epi != 0:
#             cur_time = datetime.now(tz)
#             simple_cur_time = cur_time.strftime("%H:%M:%S")
#             print('▶ Episode #', n_epi, end=' → ')
#             print('Score =', score, end='...')
#             print('경로 길이:', len(env.actions), end=', ')
#             if goal_ob_reward == 'finish':
#                 print('성공 여부: ', goal_ob_reward)
#                 isFinished = True
#             else:
#                 print('성공 여부 : 실패', goal_ob_reward)
        
#         score = 0.0
#         print('→ pred_path:', env.actions)

#         ##### 액션 결과물 확인하기
#         if len(env.actions) > 15 and env.cumulative_reward > 0:
#             print(f"move = {move_reward}, obs = {obs_reward}, goal = {goal_reward}")
#             print(f"{n_epi}번째 에피소드는 {env.cumulative_reward:.1f}점 입니다.")
#             print(f"target은 {env.items} ▶▶▶ {env.local_target}입니다.")
#             print(f"action은 총 {len(env.actions)}번 움직였습니다.\n{env.actions}")
#             print(grid)
#             print("###############")

#     #########################################    
#     #     if len(env.actions) > 5:
#     #         f.write(str(n_epi)+'/'+str(items)+'/'+str(cum_reward)+'/'+str(isFinished)+'\n')
#     #         f.write(str(env.actions))
#     #         f.write('\n')

#     # f.close()
#     #########################################

#     # 모든 에피소드 종료 후 결과 디스플레이
#     # 코드 추가할 것!!!

# # test 모드 실행
# train_mode = False
# test()

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

__file__ = '/content/drive/Othercomputers/MacBook_Air/path-finding-rl/data'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Env
# - 경로 이동 제한 사항 반영: del apply_action() 수정
# - def grid_box(self):  # 그리드 박스 초기화 용도로 정의
# - 그리드값 변경
#   - target_gridval (목표물)  = 10, 9, 8, ...
#   - curloc_gridval (현 위치) = 1
#   - default_gridval (기본)   = 0
#   - rack_gridval (선반)      = -1
#   - obs_gridval (장애물)     = -10
# - 종료 조건
#   - **그리드월드 밖**으로 나가는 경우 **종료하지 않음**
#   - **장애물**에 부딪히는 경우 **종료**

# %%
from string import ascii_uppercase
import numpy as np
import pandas as pd
import os
import random
from datetime import datetime
import pytz
import matplotlib.pyplot as plt

###################################
# 보상 Reward
move_reward = -1  # 0.1
obs_reward = -10  # 0.1
goal_reward = 10  # 10
###################################
# 그리드값
# target_gridval = 10, 9, 8... # 목표물: 10, 9, 8, ...
curloc_gridval  = 1            # 현 위치: 1
default_gridval = 0            # 기본: 0
rack_gridval    = -1           # 선반: -1
obs_gridval     = -10          # 장애물: -10
###################################
# train / test 모드 지정
train_mode = True
###################################
print('reward:' , move_reward, obs_reward, goal_reward)

#__file__ = '/home/ogangza/heung_path_finding/path-finding-rl/data'

local_path = os.path.abspath(os.path.join(os.path.dirname(__file__)))

class Simulator:
    def __init__(self):
        # Load train or test data
        # if train_mode:  # 훈련 데이타 읽기
        #     self.files = pd.read_csv(os.path.join(local_path, "data/factory_order_train.csv"))
        #     print('data/factory_order_train.csv used')
        # else:           # 테스트 데이터 읽기
        #     self.files = pd.read_csv(os.path.join(local_path, "data/factory_order_test.csv"))
        #     print('data/factory_order_test.csv used')
        ##########################################################################################
        self.height = 10  # 그리드 높이
        self.width = 9    #  그리드 너비
        self.inds = list(ascii_uppercase)[:17]  # A ~ Q alphabet list

    def set_box(self):  # 선반 위치, 목적지 그리드값 설정. 목적지 리스트 생성
        box_data = pd.read_csv(os.path.join(local_path, "data/box.csv"))
        for box in box_data.itertuples(index = True, name ='Pandas'):  # 선반 위치: 그리드값 = rack_gridval
            self.grid[getattr(box, "row")][getattr(box, "col")] = rack_gridval
        order_item = list(set(self.inds) & set(self.items))
        order_csv = box_data[box_data['item'].isin(order_item)]
        for i, order_box in enumerate(order_csv.itertuples(index = True, name ='Pandas')):  # 목적지: 그리드값 = target_gridval
            self.grid[getattr(order_box, "row")][getattr(order_box, "col")] = 10 - i
            self.local_target.append([getattr(order_box, "row"), getattr(order_box, "col")])  # 목적지 리스트 생성: local_target
        # self.local_target.sort() # 불필요. 인풋 데이터 A, B, C순 정렬되어 있음... 정렬 필요시 코드 바꾸어야 함
        self.local_target.append([9,4]) # 목적지 리스트에 최종 목적지(9,4) 추가
        self.local_target_original = self.local_target.copy()  # gif 생성을 위해 추가.  에피소드의 경로 저장
        self.target_length = len(self.local_target_original)  # 목적지 그리드값 10, 9, 8, ... 지정 위해 추가
        self.grid[9,4] = 10 + 1 - self.target_length  # 최종 목적지 [9,4] 그리드값 지정 위해 추가

    def set_obstacle(self):  # 장애물 위치 그리드값 설정 = obs_gridval
        obstacles_data = pd.read_csv(os.path.join(local_path, "data/obstacles.csv"))
        for obstacle in obstacles_data.itertuples(index = True, name ='Pandas'):
            self.grid[getattr(obstacle, "row")][getattr(obstacle, "col")] = obs_gridval

    def grid_box(self):  # 그리드 박스 초기화 용도로 정의: 선반, 목적지, 장애물 그리드값 초기화
        box_data = pd.read_csv(os.path.join(local_path, "data/box.csv"))
        for box in box_data.itertuples(index = True, name ='Pandas'):  # 선반 위치: 그리드값 = rack_gridval
            self.grid[getattr(box, "row")][getattr(box, "col")] = rack_gridval
        order_item = list(set(self.inds) & set(self.items))
        order_csv = box_data[box_data['item'].isin(order_item)]
        for i, order_box in enumerate(order_csv.itertuples(index = True, name ='Pandas')):  # 목적지: 그리드값 = target_gridval
            self.grid[getattr(order_box, "row")][getattr(order_box, "col")] = 10 - i
        self.grid[9,4] = 10 + 1 - self.target_length  # 최종 목적지 [9,4] 그리드값 지정 위해 추가
        self.set_obstacle()  # 장애물 위치 그리드값 설정 = obs_gridval
        
    def reset(self, epi):  # 에피소드 시작시 12개 값 초기화
        self.epi = epi                                            #1. 에피소드 번호 받기
        # self.items = list(self.files.iloc[self.epi])[0]           #2. 에피소드의 목적지 받기: [ 'H', 'L', 'M']
        #####################################################################################
        coin = random.randint(0,16)
        self.items = [chr(coin+65)]  # A~Q 까지 1개 랜덤으로 받아서 items에 1개 넣어주기, 반복 횟수는 main의 epochs 조절하기
        ####################################################################################
        self.cumulative_reward = 0                                #3. 누적 보상값 = 0
        self.terminal_location = None                             #4. 최초 목적지
        self.local_target = []                                    #5. 목적지 리스트 초기화
        self.actions = []                                         #6. 지나온 경로 리스트 초기화
        self.grid = np.zeros((self.height, self.width), dtype="float16")  #7. 그리드월드 전체 그리드값(default_gridval) 초기화
        self.set_box()                                            #8. 선반 위치, 목적지 그리드값 설정. 목적지 리스트 생성
        self.set_obstacle()                                       #9. 장애물 그리드값 설정
        ######################
        # print('최초 그리드맵:')  # 그리드맵 확인
        # print(self.grid.reshape(10,9))
        ######################
        self.curloc = [9, 4]                                      #10. 현재 위치를 출발점으로 세팅
        self.grid[int(self.curloc[0])][int(self.curloc[1])] = curloc_gridval  #11. 현재 위치(출발점) 그리드값 세팅
        self.done = False                                         #12. 경로 찾기 종료 여부 = False
        self.goal_ob_reward = False                      # (추가) #13. 최종 목적지 도착 여부 = False
        ######################
        # print('현 위치 추가:')   # 그리드맵 확인
        # print(self.grid.reshape(10,9))
        ######################
        self.move_track = [[9,4]]                                        #14. 이동하는 경로를 저장하는 변수, 에피소드 시작시 에이전트가 [9,4]에 있으므로 [[9,4]]로 초기화
        self.isReset =  False                                       #15. 처음으로 terminal_location == 9,4가 되면, moveTrack을 초기화해주기 위해 필요한 변수 isFinal -> isReset 로 변경(처음으로 불러졌냐 안불러졌냐)
        self.prior_distance = 9999                                  #16. 이전 time step의 거리와 현재 거리를 비교하기 위해서 필요한 변수
        ######################
        return self.grid

    def apply_action(self, action, cur_x, cur_y):  # action에 따른 새 좌표값 반환
        new_x = cur_x
        new_y = cur_y
        if action == 0:          # up
            #new_x = cur_x - 1
            new_x = self.move_up(cur_x, cur_y, new_x, new_y)
        elif action == 1:        # down
            #new_x = cur_x + 1
            new_x = self.move_down(cur_x, cur_y, new_x, new_y)
        elif action == 2:        # left
            #new_y = cur_y - 1
            new_y = self.move_left(cur_x, cur_y, new_x, new_y)
        else:                    # right
            #new_y = cur_y + 1
            new_y = self.move_right(cur_x, cur_y, new_x, new_y)
        return int(new_x), int(new_y)
    
    # >>> 현재 위치에서 이동이 불가한 위치 추가 (시작) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
    def move_up(self, cur_x, cur_y, new_x, new_y):  # action == 0:
        if cur_x in [6,5,4,3,2] and cur_y in [0,8]:
            pass
        else:
            new_x = cur_x - 1
        return new_x
    def move_down(self, cur_x, cur_y, new_x, new_y): # action == 1:
        if cur_x in [1,2,3,4,5] and cur_y in [0,8]:
            pass
        else:
            new_x = cur_x + 1
        return new_x
    def move_left(self, cur_x, cur_y, new_x, new_y): # left elif action == 2:
        if cur_y in [1,2,3,4,5,6,7,8] and cur_x == 0:
            pass
        else:
            new_y = cur_y - 1
        return new_y
    def move_right(self, cur_x, cur_y, new_x, new_y): # right else: action == 3:
        if cur_y in [0,1,2,3,4,5,6,7] and cur_x == 0:
            pass
        else:
            new_y = cur_y + 1
        return new_y
    # >>> 추가 (끝) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

    def get_reward(self, new_x, new_y, out_of_boundary):  # action에 의해 이동시 얻는 보상
        if any(out_of_boundary):                                        # 바깥으로 나가는 경우
            reward = obs_reward
        else:
            if self.grid[new_x][new_y] == obs_gridval :     # 장애물에 부딪히는 경우
                reward = obs_reward
                self.grid[new_x][new_y] = curloc_gridval   # 현 위치(장애물)에서 종료되었음을 표시. 원래는 장애물이었음                
            elif self.grid[new_x][new_y] == rack_gridval:   # 선반에 부딪히는 경우
                reward = obs_reward
                new_x = self.curloc[0]  # 선반인 경우 못들어가고, 현재 위치로 유지
                new_y = self.curloc[1]  # 선반인 경우 못들어가고, 현재 위치로 유지
            elif new_x == self.terminal_location[0] and new_y == self.terminal_location[1]:  # 현재 목적지에 도달한 경우
                reward = goal_reward
            # 그냥 움직이는 경우 
            else: 
                cur_distance = self.get_distance()
                if self.prior_distance > cur_distance :                         # 이전의 거리 > 현재의 거리 = 현재 아이템에 더 가깝다 => + 보상얻기
                    reward = self.get_positive_distance_reward(cur_distance)
                    # print('posi', reward)
                else:                                                           # 이전의 거리 < 현재의 거리 = 현재 아이템에서 멀어졌다 => - 보상얻기
                    reward = self.get_negative_distance_reward(cur_distance)
                    # print('nega', reward)
                self.prior_distance = cur_distance      

                if [new_x, new_y] not in self.move_track:                           # 이동한 곳이 처음온 곳이면 move_track에 추가
                    self.move_track.append([new_x, new_y])
                else:                                                           # 이동한 곳이 이미 왔던 곳이면 기존 보상에서 -1
                    reward = reward -1
        return reward

    def step(self, action):  # action에 따른 이동 실행
        self.terminal_location = self.local_target[0]           # 목적지 리스트의 첫 번째 요소를 목적지로 설정
        cur_x, cur_y = self.curloc                              # 현재 위치 기억
        new_x, new_y = self.apply_action(action, cur_x, cur_y)  # 다음 위치 받기
        self.actions.append((cur_x, cur_y))                     # 현재 위치(지나온 위치)를 경로 리스트에 추가
        self.goal_ob_reward = False                             # 최종 목적지에 도착한 경우에 True. self.reset()에서 초기화
        out_of_boundary = [new_x < 0, new_x >= self.height, new_y < 0, new_y >= self.width]  # 그리드월드 밖으로 나갔는가? OB = True

        if any(out_of_boundary):  #1. 바깥으로 나가는 경우, 빈 선반에 부딪치는 경우 종료하지 않음
            #print('OB')
            new_x = cur_x  # 종료 처리할 경우 코멘트 처리
            new_y = cur_y  # 종료 처리할 경우 코멘트 처리
            ######################################################종료 처리할 경우 실행
            #self.done = True                             # while loop 종료
            #self.grid_box()                              # 선반, 목적지, 장애물 그리드값 초기화
            #self.actions.append((new_x,new_y))           # 경로 리스트에 최종 위치 추가. (주의) 좌표값이 그리드월드를 벗어나는 값 발생!
            ######################################################
        else:
            if self.grid[new_x][new_y] == obs_gridval:  #2. 장애물에 부딪히는 경우 종료
                # print('장애물')
                # new_x = cur_x  # 종료 처리할 경우 코멘트 처리
                # new_y = cur_y  # 종료 처리할 경우 코멘트 처리
                ###################################################종료 처리할 경우 실행
                self.done = True                           # while loop 종료
                self.grid[cur_x][cur_y] = default_gridval  # 현 위치의 그리드값을 기본값으로 초기화
                self.grid_box()                            # 선반, 목적지, 장애물 그리드값 초기화
                self.actions.append((new_x,new_y))         # 경로 리스트에 최종 위치 추가
                ###################################################
            elif self.grid[new_x][new_y] == rack_gridval:
                pass
            elif new_x == self.terminal_location[0] and new_y == self.terminal_location[1]:  #3. 현재 목적지에 도착한 경우 다음 목적지 설정
                #print('목적지 도착')
                if [new_x, new_y] == [9, 4]:            #3-1. 최종 목적지에 도착한 경우 종료
                    self.done = True                       # while loop 종료
                    self.goal_ob_reward = True             # True = 1 (OB, 장애물 종료 처리 할 경우 self.done=True가 많아지므로 이때 사용)
                    self.actions.append((new_x,new_y))     # 경로 리스트에 최종 위치 추가

                self.local_target.remove(self.local_target[0])  # 다음 목적지 설정. 최종 목적지에 도착한 경우에는 마지막 요소인 [9,4]를  제거
                self.grid[cur_x][cur_y] = default_gridval  # 현 위치의 그리드값을 기본값으로 초기화
                self.grid_box()                            # 선반, 목적지, 장애물 그리드값 초기화
                self.grid[new_x][new_y] = curloc_gridval   # 현 위치(목적지)에서 종료되었음을 표시. 원래는 목적지이었음
                self.curloc = [new_x, new_y]               # 새로 도착한 위치를 현재 위치로 변경
            
            else:                                       #4. 그냥 움직이는 경우
                #print('이동')
                self.grid[cur_x][cur_y] = default_gridval  # 현 위치의 그리드값을 기본값으로 초기화
                self.grid_box()                            # 선반, 목적지, 장애물 그리드값 초기화
                self.grid[new_x][new_y] = curloc_gridval   # 현 위치에서 종료되었음을 표시
                self.curloc = [new_x,new_y]

        ############################### 보상받는 처리 시작 ###############################
        # 마지막 위치에서 위로 올라가는 행동을 한다면 - 보상받음 태양
        if self.terminal_location == [9, 4]:
            if not self.isReset:                                    # 처음으로 terminal_location == [9,4]가 되었다면,,
                self.move_track = []                                # 아이템을 찾으러 돌아다니는 경로 초기화
                self.isReset = True                                 # move_track이 초기화 되었으니 isReset = True
            reward = self.get_reward(new_x, new_y, out_of_boundary)
            if action == 0:
                reward = obs_reward                                # 처음위치로 갈 때 위로 올라가는거 금지
        else : 
            reward = self.get_reward(new_x, new_y, out_of_boundary)
        ############################### 보상받는 처리 끝 ###############################   

        self.cumulative_reward += reward
        return self.grid, reward, self.cumulative_reward, self.done

    # >>> distance를 입력으로 받아 + 보상을 계산하는 메소드 (시작) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<< 
    def get_positive_distance_reward(self, distance):
        positive_reward = (20 - distance) / 200     # 0.095 ~ 0.001
        return positive_reward
    # >>> 추가 (끝) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

    # >>> distance를 입력으로 받아 - 보상을 계산하는 메소드 (시작) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
    def get_negative_distance_reward(self, distance):
        negative_reward = -(distance / 200)
        return negative_reward
    # >>> 추가 (끝) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<    

    # >>> 현재 위치에서 타겟까지의 거리를 구하는 메소드 (시작) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
    def get_distance(self): 
        cur_x, cur_y, target_x, target_y = self.get_current_state()
        
        distance = (abs(cur_x-target_x) + abs(cur_y-target_y))
        # print(cur_x, cur_y, target_x, target_y)
        # print('distance : ', distance)
        return distance
    # >>> 추가 (끝) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<    

    # >>> 현재 상황에 대한 정보를 구하는 메소드 (시작) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
    def get_current_state(self):
        # if len(self.local_target) != 0:
        #     state = (self.curloc[0], self.curloc[1], self.local_target[0][0], self.local_target[0][1])
        # else :
        state = (self.curloc[0], self.curloc[1], self.terminal_location[0], self.terminal_location[1])
        return np.array(state) #(cur_x, cur_y, tar_x, tar_y)
    # >>> 추가 (끝) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Out:
# reward: -1 -10 10

# %% [markdown]
# ## Agent
# - def test_action(self, obs): 추가

# %%
import collections
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

class ReplayBuffer():  # 리플레이 버퍼: 경험 저장소
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit)
    
    def put(self, transition):  # 리플레이 버퍼(메모리)를 경험(transition)으로 채우기
        self.buffer.append(transition)
    
    def sample(self, n):  # memory.sample(batch_size)로 사용
        mini_batch = random.sample(self.buffer, n)  # 미니배치 샘플링
        '''
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []
        for transition in mini_batch:  # 경험의 각 요소들을 각각의 미니배치로 구성
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])
        return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
               torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
               torch.tensor(done_mask_lst)
        '''
        state1_batch = torch.cat([s1 for (s1,a,r,s2,d) in mini_batch])
        action_batch = torch.Tensor([a for (s1,a,r,s2,d) in mini_batch])
        reward_batch = torch.Tensor([r for (s1,a,r,s2,d) in mini_batch])
        state2_batch = torch.cat([s2 for (s1,a,r,s2,d) in mini_batch])
        done_batch = torch.Tensor([d for (s1,a,r,s2,d) in mini_batch])

        return state1_batch, action_batch, reward_batch, state2_batch, done_batch
    
    def size(self):  # 메모리 크기
        return len(self.buffer)

class Qnet(nn.Module):
    '''##### Linear 모델 #####
    def __init__(self):
        super(Qnet, self).__init__()

        in_size = 90  # input 크기
        L1 = 250
        L2 = 150
        out_size  = 4

        self.fc1 = nn.Linear(in_size, L1)
        self.fc2 = nn.Linear(L1, L2)
        self.fc3 = nn.Linear(L2, out_size)

    def forward(self, x):
        x = x.to(device)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
    '''
    ##### Convolution 모델 #####
    def __init__(self):
        super(Qnet, self).__init__()

        self.conv1 = nn.Conv2d(4, 32, 3, 1) #### 1이었던 부분을 4로 변경
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.conv3 = nn.Conv2d(64, 64, 3, 1)
        self.fc1 = nn.Linear(768, 512)
        self.fc2 = nn.Linear(512, 4)

    def forward(self, x):
        x = x.to(device)               # (N, 4, 10, 9)
        x = F.relu(self.conv1(x))      # (N, 32, 8, 7)
        x = F.relu(self.conv2(x))      # (N, 64, 6, 5)
        x = F.relu(self.conv3(x))
        x = torch.flatten(x, 1)        # (N, 64, 30)
        x = F.relu(self.fc1(x))        # (N, 1920) -> (N, 128)
        x = self.fc2(x)                # (N, 128)  -> (N, 4)
        return x

    def sample_action(self, obs, epsilon):  # Qnet()을 실행해서 모든 action에 대한 Qval을 구한 후 action 선택
        out = self.forward(obs)  # out = Q_value, obs = state = 그리드맵
        coin = random.random()  # e-greedy로 action 선택
        if coin < epsilon:
            return random.randint(0,3)
        else : 
            return out.argmax().item()
    
    def test_action(self, obs):  # Qnet()을 실행해서 모든 action에 대한 Qvalue을 구한 후 action 선택
        out = self.forward(obs)  # out = Q_value, obs = state = 그리드맵
        return out.argmax().item()

def train(q, q_target, memory, optimizer):  # 메모리에 경험이 미니배치 크기 이상 쌓이면 미니배치 훈련 시작
    '''
    for i in range(10):
        s, a, r, cr, s_prime, done_mask, gr = memory.sample(batch_size)
        q_out = q(s)
        q_a = q_out.gather(1,a.to(device))
        
        max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1)
        target = r.to(device) + gamma * max_q_prime * done_mask.to(device)
        
        loss = F.smooth_l1_loss(q_a, target)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    '''
    s,a,r,s_prime,done_mask = memory.sample(batch_size)  # 메모리에서 미니배치를 뽑기: batch_size=1600
    Q1 = q(s)  # Qnet의 Qvalue
    X = Q1.gather(dim=1,index=a.long().unsqueeze(dim=1).to(device)).squeeze() # Qnet의 Qvalue 변환
    with torch.no_grad():
        Q2 = q_target(s_prime)
    Y = r.to(device) + gamma * done_mask.to(device) * torch.max(Q2,dim=1)[0]
    loss = F.smooth_l1_loss(X, Y.detach())
    #loss = nn.MSELoss(X.to(torch.float32), Y.detach().to(torch.float32))  # 손실함수 변경. target.detach()로 변경
    optimizer.zero_grad()  # gradient값 초기화
    loss.backward()  # 자동미분
    optimizer.step()  # gradient 업데이트
    return loss.item()

# %% [markdown]
# ## Main: DQN...
#   - GPU를 사용할 경우 구현
#   - 학습한 모델 불러올 수 있는 코드 추가
#     - '#' 제거하고 실행시키면 됨

# %%
#def main(): # DQN... Total Path 학습 모델

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # GPU를 사용할 경우 ???
print('tensor in', device)  # GPU 사용 확인
# PATH = '/content/drive/MyDrive/aiffelthon/data/model_conv_colab.pt'
PATH = __file__ + '/model_conv_colab_epsilon_v2.pt' ## PATH 경로 쉽게 수정
##############################################
tz = pytz.timezone('Asia/Seoul')
cur_time = datetime.now(tz)
start_time = cur_time.strftime("%H:%M:%S")

### 중요 Hyperparameters #####################
buffer_limit  = 100000     #1. 50000
batch_size    = 200        #2. 32
learning_rate = 0.00025    #3. 0.0005
sync_freq = 500            #4. q 네트워크 파라미터를 q_target 네트워크에 복사하는 주기
train_start = 50000   # (추가)
##############################################
env = Simulator()  # 데이터셋 읽기. 그리드월드 크기 지정
q = Qnet()
q.to(device)
optimizer = optim.Adam(q.parameters(), lr=learning_rate)

train_model_load = False  # 학습한 모델을 불러와서 계속 학습시키고자 하는 경우 True로 바꾼다!!
if train_model_load:
    ###############################################################
    ## 학습한 모델 불러오기
    ###############################################################
    checkpoint = torch.load(PATH)
    q.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    epoch = checkpoint['epoch']
    loss = checkpoint['loss']
    q.train()
###############################################################
q_target = Qnet()
q_target.to(device)
q_target.load_state_dict(q.state_dict())
memory = ReplayBuffer()

### Hyperparameters #####################
gamma = 0.99             #5. 0.98
####################################################################
# epochs = len(env.files)  #6. 훈련용 데이터 갯수
epochs = 80000  # 한 군데 갔다 오는 경우에 사용. 반복 횟수는 각자 지정
####################################################################
losses = []
cum_rewards =[]
moves = []
max_moves = 100          #7.
print_interval = 5000    #8.
j = 0
goal_ob_reward_count = 0 #9. epoch를 반복하면서 finish 카운팅
# epsilon = 0.3            #10. annealing 대신 고정
loss = 0.0
##############################################
# __file__ = '/content/drive/MyDrive/aiffelthon/data' 
### 액션 저장하는 txt파일 만들기 #######################
f = open(__file__ + '/ogz_conv_epsilon_v2_gif' + '.txt', 'w')
########################################################

for n_epi in range(epochs):
    # n_epi = n_epi % 39999
    epsilon = max(0.05, 1.00 - 0.1*(n_epi/2000)) # Linear annealing from 100% to 5%
    gridmap = env.reset(n_epi)  # 에피소드 시작시 12개 값 초기화
        # self.epi = epi                                            #1. 에피소드 번호 받기
        # self.items = list(self.files.iloc[self.epi])[0]           #2. 에피소드의 목적지 받기: [ 'H', 'L', 'M']
        # self.cumulative_reward = 0                                #3. 누적 보상값 = 0
        # self.terminal_location = None                             #4. 최초 목적지
        # self.local_target = []                                    #5. 목적지 리스트 초기화
        # self.actions = []                                         #6. 지나온 경로 리스트 초기화
        # self.grid = np.ones((self.height, self.width), dtype="float16")  #7. 그리드월드 전체 그리드값(1)로 초기화
        # self.set_box()                                            #8. 선반 위치(0), 목적지(2) 그리드값 설정.  목적지 리스트 생성
        # self.set_obstacle()                                       #9. 장애물 그리드값(0) 설정
        # self.curloc = [9, 4]                                      #10. 현재 위치를 출발점으로 세팅
        # self.grid[int(self.curloc[0])][int(self.curloc[1])] = -1  #11. 현재 위치(출발점) 그리드값(-1) 세팅
        # self.done = False                                         #12. 경로 찾기 종료 여부 = False
        # return self.grid

    # 초기 input은 (시작화면*4장)으로 들어감
    #####################################################################################
    history1 = np.stack((gridmap,gridmap,gridmap,gridmap), axis = 0) # 초기 state로 히스토리 초기화 (4,10,9)
    history1 = np.reshape([history1], (1,4,10,9)) # (배치, 채널, 가로, 세로) 로 reshape
    history1 = torch.from_numpy(history1).float() # 텐서로 변환   
    #####################################################################################

    done = False
    mov = 0

    while (not done):  # 최종 목적지 [9,4] 도착 또는 max_moves (=350) 초과하면 종료
        j += 1
        mov += 1
        # 상태 state1에서 action 결정
        #####################################################################################
        if env.curloc == [9,4]:  # 출발점에서는 무조건 위로 올라간다 (action=0)
            action = 0
        elif env.curloc[0] == 0 and env.curloc[1] in [0,1,2,3,4,5,6,7,8]:  # (0,0)~(0,8)에서는 무조건 아래로
            action = 1
        elif env.curloc[0] in [2,3,4,5] and env.curloc[1] == 8:  # (2,8)~(5,8)에서는 무조건 왼쪽으로
            action = 2
        elif env.curloc[0] in [2,3,4,5] and env.curloc[1] == 0:  # (2,0)~(5,0)에서는 무조건 오른쪽으로
            action = 3
        else:  # 위 경우를 제외하곤 e-greedy로 액션 선택
            action = q.sample_action(history1, epsilon)
        #####################################################################################
        # action = q.sample_action(state1, epsilon)  # 위 조건을 적용 안 할 경우
        # make Move... action에 따른 이동
        gridmap, reward, cum_reward, done = env.step(action)
            # self.actions.append((new_x, new_y))...새로 도착한 위치를 경로 리스트에 추가
            # 누적 보상 계산
        ###########################
        # print(gridmap.reshape(10,9))
        ###########################

        #####################################################################################
        # next input 만들어주기
        next_gridmap = np.reshape([gridmap],(1,1,10,9))                                             # 다음 그리드를 히스토리 사이즈에 맞게 reshape
        next_gridmap = torch.from_numpy(next_gridmap).float()                                       # 텐서로 변환
        history2 = torch.cat([next_gridmap,history1[:,:3,:,:]],dim=1) # (1,1+3,10,9)                # 지금 있는 히스토리중 마지막 채널을 지우고 new를 제일 앞에 붙임

        done_mask = 0.0 if done else 1.0
        memory.put((history1, action, reward, history2, done_mask))  # 경험을 메모리에 저장
        history1 = history2
        #####################################################################################

        # if memory.size() > train_start:  # 메모리에 train_start 크기 이상 쌓이면... 미니배치 훈련
        if j > train_start:  # 메모리에 미니배치 크기 이상 쌓이면... 미니배치 훈련
            #print('memory size:', memory.size())
            loss = train(q, q_target, memory, optimizer)
            if j % print_interval == 0:
                print('epiode #:', n_epi, 'loss:', loss, 'j:', j)
            losses.append(loss)
            cum_rewards.append(cum_reward)
            moves.append(mov)
            

            if j % sync_freq == 0:  # sync_freq마다 q 네트워크 파라미터를 q_target 네트워크로 복사
                q_target.load_state_dict(q.state_dict())

        ############## 현황 모니터링 #############################################################
        if done and j % 100 == 0:  # 100번 마다 mov 횟수 저장:
        #     moves.append(mov)
            print('종료: done =', done, '... j =', j, ' move =', mov)
        if env.goal_ob_reward:  # 최종 목적지 도달한 경우에만 화면에 표시
            goal_ob_reward_count += 1
            print(env.items, '종료: env.goal_ob_reward =', env.goal_ob_reward, '... j =', j, ' move =', mov, '@ 에피소드 #', n_epi)
            print(f"{n_epi}번째 에피소드까지 총 {goal_ob_reward_count}번 finish 했습니다.")
        ##########################################################################################

        if done or mov > max_moves:
            mov = 0
            done = True
    
    # while loop 종료 ----- 최종 목적지 [9,4] 도착 또는 max_moves (=350) 초과

    if j > train_start:  # 메모리에 train_start 크기 이상 쌓이면... 미니배치 훈련
        if (n_epi % 10000 == 0 and n_epi != 0) or n_epi >= epochs - 1:
            torch.save({'epoch': n_epi, 
                        'model_state_dict': q.state_dict(), 
                        'optimizer_state_dict': optimizer.state_dict(), 
                        'loss': loss, 
                        }, PATH)
            print('▶ 모델 저장됨!!! @ 에피소드', n_epi)

        ##### gif 생성을 위한 경로(env.actions) 저장 ####################################    
        if n_epi % 1000 == 0 or env.goal_ob_reward:
            f.write(str(n_epi)+'/'+str(env.local_target_original)+'\n')
            f.write(str(env.actions))
            f.write('\n')
        ######################################### 
f.close()
#########################################
## 프로그램 시작 및 종료 시간 출력
cur_time = datetime.now(tz)
end_time = cur_time.strftime("%H:%M:%S")
print ('실행 종료!', 'Start@', start_time, 'End@', end_time)
        #cur_time = datetime.now(tz)
        #simple_cur_time = cur_time.strftime("%H:%M:%S")
        #print('▶ Episode #', iter, 'start time:', simple_cur_time, end='→')

print(gridmap.reshape(10,9))  # 최종 그리드맵 확인

## loss 그래프
plt.figure(figsize=(10,7))
plt.plot(losses)
plt.xlabel("# of Actions (j)",fontsize=22)
plt.ylabel("Loss",fontsize=22)

## 경로길이(이동 횟수) 그래프
plt.figure(figsize=(10,7))
plt.plot(moves)
plt.xlabel("# of Actions (j)",fontsize=22)
plt.ylabel("Moves",fontsize=22)

## 보상값(cum_rewards) 그래프
plt.figure(figsize=(10,7))
plt.plot(cum_rewards)
plt.xlabel("# of Actions (j)",fontsize=22)
plt.ylabel("Cumulative Rewards",fontsize=22)
# Out:
# Streaming output truncated to the last 5000 lines.
# 69104번째 에피소드까지 총 36274번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1625631  move = 24 @ 에피소드 # 69105
# 69105번째 에피소드까지 총 36275번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1625657  move = 26 @ 에피소드 # 69106
# 69106번째 에피소드까지 총 36276번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1625683  move = 26 @ 에피소드 # 69107
# 69107번째 에피소드까지 총 36277번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1625705  move = 22 @ 에피소드 # 69108
# 69108번째 에피소드까지 총 36278번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1625749  move = 26 @ 에피소드 # 69110
# 69110번째 에피소드까지 총 36279번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1625816  move = 48 @ 에피소드 # 69112
# 69112번째 에피소드까지 총 36280번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1625870  move = 54 @ 에피소드 # 69113
# 69113번째 에피소드까지 총 36281번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1625894  move = 24 @ 에피소드 # 69114
# 69114번째 에피소드까지 총 36282번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1625942  move = 48 @ 에피소드 # 69115
# 69115번째 에피소드까지 총 36283번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1625975  move = 30 @ 에피소드 # 69117
# 69117번째 에피소드까지 총 36284번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1626003  move = 28 @ 에피소드 # 69118
# 69118번째 에피소드까지 총 36285번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1626144  move = 28 @ 에피소드 # 69123
# 69123번째 에피소드까지 총 36286번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1626205  move = 26 @ 에피소드 # 69125
# 69125번째 에피소드까지 총 36287번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1626229  move = 24 @ 에피소드 # 69126
# 69126번째 에피소드까지 총 36288번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1626286  move = 23 @ 에피소드 # 69128
# 69128번째 에피소드까지 총 36289번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1626360  move = 74 @ 에피소드 # 69129
# 69129번째 에피소드까지 총 36290번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1626384  move = 24 @ 에피소드 # 69130
# 69130번째 에피소드까지 총 36291번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1626535  move = 22 @ 에피소드 # 69133
# 69133번째 에피소드까지 총 36292번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1626583  move = 28 @ 에피소드 # 69135
# 69135번째 에피소드까지 총 36293번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1626601  move = 18 @ 에피소드 # 69136
# 69136번째 에피소드까지 총 36294번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1626625  move = 24 @ 에피소드 # 69137
# 69137번째 에피소드까지 총 36295번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1626701  move = 27 @ 에피소드 # 69140
# 69140번째 에피소드까지 총 36296번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1626727  move = 26 @ 에피소드 # 69141
# 69141번째 에피소드까지 총 36297번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1626753  move = 26 @ 에피소드 # 69142
# 69142번째 에피소드까지 총 36298번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1626810  move = 30 @ 에피소드 # 69145
# 69145번째 에피소드까지 총 36299번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1626832  move = 22 @ 에피소드 # 69146
# 69146번째 에피소드까지 총 36300번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1626892  move = 60 @ 에피소드 # 69147
# 69147번째 에피소드까지 총 36301번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1626920  move = 28 @ 에피소드 # 69148
# 69148번째 에피소드까지 총 36302번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1626946  move = 26 @ 에피소드 # 69149
# 69149번째 에피소드까지 총 36303번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1626979  move = 26 @ 에피소드 # 69151
# 69151번째 에피소드까지 총 36304번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1627102  move = 24 @ 에피소드 # 69153
# 69153번째 에피소드까지 총 36305번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1627126  move = 24 @ 에피소드 # 69154
# 69154번째 에피소드까지 총 36306번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1627152  move = 26 @ 에피소드 # 69155
# 69155번째 에피소드까지 총 36307번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1627172  move = 20 @ 에피소드 # 69156
# 69156번째 에피소드까지 총 36308번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1627196  move = 24 @ 에피소드 # 69157
# 69157번째 에피소드까지 총 36309번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1627238  move = 28 @ 에피소드 # 69159
# 69159번째 에피소드까지 총 36310번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1627286  move = 48 @ 에피소드 # 69160
# 69160번째 에피소드까지 총 36311번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1627310  move = 24 @ 에피소드 # 69161
# 69161번째 에피소드까지 총 36312번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1627342  move = 32 @ 에피소드 # 69162
# 69162번째 에피소드까지 총 36313번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1627364  move = 22 @ 에피소드 # 69163
# 69163번째 에피소드까지 총 36314번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1627392  move = 28 @ 에피소드 # 69164
# 69164번째 에피소드까지 총 36315번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1627452  move = 60 @ 에피소드 # 69165
# 69165번째 에피소드까지 총 36316번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1627509  move = 22 @ 에피소드 # 69167
# 69167번째 에피소드까지 총 36317번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1627549  move = 40 @ 에피소드 # 69168
# 69168번째 에피소드까지 총 36318번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1627573  move = 24 @ 에피소드 # 69169
# 69169번째 에피소드까지 총 36319번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1627603  move = 30 @ 에피소드 # 69170
# 69170번째 에피소드까지 총 36320번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1627664  move = 28 @ 에피소드 # 69172
# 69172번째 에피소드까지 총 36321번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1627691  move = 22 @ 에피소드 # 69174
# 69174번째 에피소드까지 총 36322번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1627719  move = 28 @ 에피소드 # 69175
# 69175번째 에피소드까지 총 36323번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1627741  move = 22 @ 에피소드 # 69176
# 69176번째 에피소드까지 총 36324번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1627782  move = 41 @ 에피소드 # 69177
# 69177번째 에피소드까지 총 36325번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1627806  move = 24 @ 에피소드 # 69178
# 69178번째 에피소드까지 총 36326번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1627830  move = 24 @ 에피소드 # 69179
# 69179번째 에피소드까지 총 36327번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1627885  move = 28 @ 에피소드 # 69182
# 69182번째 에피소드까지 총 36328번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1627931  move = 28 @ 에피소드 # 69184
# 69184번째 에피소드까지 총 36329번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1627960  move = 29 @ 에피소드 # 69185
# 69185번째 에피소드까지 총 36330번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1627989  move = 26 @ 에피소드 # 69187
# 69187번째 에피소드까지 총 36331번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1628007  move = 18 @ 에피소드 # 69188
# 69188번째 에피소드까지 총 36332번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1628031  move = 24 @ 에피소드 # 69189
# 69189번째 에피소드까지 총 36333번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1628071  move = 40 @ 에피소드 # 69190
# 69190번째 에피소드까지 총 36334번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1628099  move = 28 @ 에피소드 # 69191
# 69191번째 에피소드까지 총 36335번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1628150  move = 24 @ 에피소드 # 69193
# 69193번째 에피소드까지 총 36336번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1628180  move = 30 @ 에피소드 # 69194
# 69194번째 에피소드까지 총 36337번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1628208  move = 28 @ 에피소드 # 69195
# 69195번째 에피소드까지 총 36338번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1628242  move = 34 @ 에피소드 # 69196
# 69196번째 에피소드까지 총 36339번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1628299  move = 28 @ 에피소드 # 69199
# 69199번째 에피소드까지 총 36340번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1628325  move = 26 @ 에피소드 # 69200
# 69200번째 에피소드까지 총 36341번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1628354  move = 20 @ 에피소드 # 69202
# 69202번째 에피소드까지 총 36342번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1628384  move = 30 @ 에피소드 # 69203
# 69203번째 에피소드까지 총 36343번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1628412  move = 28 @ 에피소드 # 69204
# 69204번째 에피소드까지 총 36344번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1628432  move = 20 @ 에피소드 # 69205
# 69205번째 에피소드까지 총 36345번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1628483  move = 51 @ 에피소드 # 69206
# 69206번째 에피소드까지 총 36346번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1628507  move = 24 @ 에피소드 # 69207
# 69207번째 에피소드까지 총 36347번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1628531  move = 24 @ 에피소드 # 69208
# 69208번째 에피소드까지 총 36348번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1628587  move = 56 @ 에피소드 # 69209
# 69209번째 에피소드까지 총 36349번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1628609  move = 22 @ 에피소드 # 69210
# 69210번째 에피소드까지 총 36350번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1628633  move = 24 @ 에피소드 # 69211
# 69211번째 에피소드까지 총 36351번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1628655  move = 22 @ 에피소드 # 69212
# 69212번째 에피소드까지 총 36352번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1628677  move = 22 @ 에피소드 # 69213
# 69213번째 에피소드까지 총 36353번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1628717  move = 26 @ 에피소드 # 69215
# 69215번째 에피소드까지 총 36354번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1628739  move = 22 @ 에피소드 # 69216
# 69216번째 에피소드까지 총 36355번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1628764  move = 25 @ 에피소드 # 69217
# 69217번째 에피소드까지 총 36356번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1628792  move = 28 @ 에피소드 # 69218
# 69218번째 에피소드까지 총 36357번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1628859  move = 24 @ 에피소드 # 69220
# 69220번째 에피소드까지 총 36358번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1628883  move = 24 @ 에피소드 # 69221
# 69221번째 에피소드까지 총 36359번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1628921  move = 38 @ 에피소드 # 69222
# 69222번째 에피소드까지 총 36360번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1628939  move = 18 @ 에피소드 # 69223
# 69223번째 에피소드까지 총 36361번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1628994  move = 55 @ 에피소드 # 69224
# 69224번째 에피소드까지 총 36362번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1629048  move = 31 @ 에피소드 # 69226
# 69226번째 에피소드까지 총 36363번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1629082  move = 34 @ 에피소드 # 69227
# 69227번째 에피소드까지 총 36364번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1629104  move = 22 @ 에피소드 # 69228
# 69228번째 에피소드까지 총 36365번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1629126  move = 22 @ 에피소드 # 69229
# 69229번째 에피소드까지 총 36366번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1629152  move = 26 @ 에피소드 # 69230
# 69230번째 에피소드까지 총 36367번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1629176  move = 24 @ 에피소드 # 69231
# 69231번째 에피소드까지 총 36368번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1629223  move = 22 @ 에피소드 # 69233
# 69233번째 에피소드까지 총 36369번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1629243  move = 20 @ 에피소드 # 69234
# 69234번째 에피소드까지 총 36370번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1629273  move = 30 @ 에피소드 # 69235
# 69235번째 에피소드까지 총 36371번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1629309  move = 26 @ 에피소드 # 69237
# 69237번째 에피소드까지 총 36372번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1629333  move = 24 @ 에피소드 # 69238
# 69238번째 에피소드까지 총 36373번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1629353  move = 20 @ 에피소드 # 69239
# 69239번째 에피소드까지 총 36374번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1629376  move = 23 @ 에피소드 # 69240
# 69240번째 에피소드까지 총 36375번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1629398  move = 22 @ 에피소드 # 69241
# 69241번째 에피소드까지 총 36376번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1629420  move = 22 @ 에피소드 # 69242
# 69242번째 에피소드까지 총 36377번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1629477  move = 26 @ 에피소드 # 69244
# 69244번째 에피소드까지 총 36378번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1629532  move = 28 @ 에피소드 # 69246
# 69246번째 에피소드까지 총 36379번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1629554  move = 22 @ 에피소드 # 69247
# 69247번째 에피소드까지 총 36380번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1629578  move = 24 @ 에피소드 # 69248
# 69248번째 에피소드까지 총 36381번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1629596  move = 18 @ 에피소드 # 69249
# 69249번째 에피소드까지 총 36382번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1629620  move = 24 @ 에피소드 # 69250
# 69250번째 에피소드까지 총 36383번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1629644  move = 24 @ 에피소드 # 69251
# 69251번째 에피소드까지 총 36384번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1629668  move = 24 @ 에피소드 # 69252
# 69252번째 에피소드까지 총 36385번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1629688  move = 20 @ 에피소드 # 69253
# 69253번째 에피소드까지 총 36386번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1629734  move = 20 @ 에피소드 # 69255
# 69255번째 에피소드까지 총 36387번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1629760  move = 26 @ 에피소드 # 69256
# 69256번째 에피소드까지 총 36388번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1629786  move = 26 @ 에피소드 # 69257
# 69257번째 에피소드까지 총 36389번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1629810  move = 24 @ 에피소드 # 69258
# 69258번째 에피소드까지 총 36390번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1629832  move = 22 @ 에피소드 # 69259
# 69259번째 에피소드까지 총 36391번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1629866  move = 24 @ 에피소드 # 69261
# 69261번째 에피소드까지 총 36392번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1629888  move = 22 @ 에피소드 # 69262
# 69262번째 에피소드까지 총 36393번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1629933  move = 24 @ 에피소드 # 69264
# 69264번째 에피소드까지 총 36394번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1629955  move = 22 @ 에피소드 # 69265
# 69265번째 에피소드까지 총 36395번 finish 했습니다.
# epiode #: 69267 loss: 0.19137409329414368 j: 1630000
# 종료: done = True ... j = 1630000  move = 26
# ['E'] 종료: env.goal_ob_reward = True ... j = 1630000  move = 26 @ 에피소드 # 69267
# 69267번째 에피소드까지 총 36396번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1630050  move = 50 @ 에피소드 # 69268
# 69268번째 에피소드까지 총 36397번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1630080  move = 22 @ 에피소드 # 69270
# 69270번째 에피소드까지 총 36398번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1630104  move = 24 @ 에피소드 # 69271
# 69271번째 에피소드까지 총 36399번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1630124  move = 20 @ 에피소드 # 69272
# 69272번째 에피소드까지 총 36400번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1630151  move = 22 @ 에피소드 # 69274
# 69274번째 에피소드까지 총 36401번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1630179  move = 28 @ 에피소드 # 69275
# 69275번째 에피소드까지 총 36402번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1630228  move = 18 @ 에피소드 # 69278
# 69278번째 에피소드까지 총 36403번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1630246  move = 18 @ 에피소드 # 69279
# 69279번째 에피소드까지 총 36404번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1630279  move = 33 @ 에피소드 # 69280
# 69280번째 에피소드까지 총 36405번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1630321  move = 24 @ 에피소드 # 69282
# 69282번째 에피소드까지 총 36406번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1630343  move = 22 @ 에피소드 # 69283
# 69283번째 에피소드까지 총 36407번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1630367  move = 24 @ 에피소드 # 69284
# 69284번째 에피소드까지 총 36408번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1630416  move = 18 @ 에피소드 # 69286
# 69286번째 에피소드까지 총 36409번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1630438  move = 22 @ 에피소드 # 69287
# 69287번째 에피소드까지 총 36410번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1630497  move = 22 @ 에피소드 # 69290
# 69290번째 에피소드까지 총 36411번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1630523  move = 26 @ 에피소드 # 69291
# 69291번째 에피소드까지 총 36412번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1630541  move = 18 @ 에피소드 # 69292
# 69292번째 에피소드까지 총 36413번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1630573  move = 32 @ 에피소드 # 69293
# 69293번째 에피소드까지 총 36414번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1630613  move = 40 @ 에피소드 # 69294
# 69294번째 에피소드까지 총 36415번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1630637  move = 24 @ 에피소드 # 69295
# 69295번째 에피소드까지 총 36416번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1630659  move = 22 @ 에피소드 # 69296
# 69296번째 에피소드까지 총 36417번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1630692  move = 24 @ 에피소드 # 69298
# 69298번째 에피소드까지 총 36418번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1630712  move = 20 @ 에피소드 # 69299
# 69299번째 에피소드까지 총 36419번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1630735  move = 20 @ 에피소드 # 69301
# 69301번째 에피소드까지 총 36420번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1630761  move = 26 @ 에피소드 # 69302
# 69302번째 에피소드까지 총 36421번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1630785  move = 24 @ 에피소드 # 69303
# 69303번째 에피소드까지 총 36422번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1630815  move = 30 @ 에피소드 # 69304
# 69304번째 에피소드까지 총 36423번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1630841  move = 26 @ 에피소드 # 69305
# 69305번째 에피소드까지 총 36424번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1630863  move = 22 @ 에피소드 # 69306
# 69306번째 에피소드까지 총 36425번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1630920  move = 24 @ 에피소드 # 69308
# 69308번째 에피소드까지 총 36426번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1630946  move = 26 @ 에피소드 # 69309
# 69309번째 에피소드까지 총 36427번 finish 했습니다.
# 종료: done = True ... j = 1631000  move = 24
# ['P'] 종료: env.goal_ob_reward = True ... j = 1631000  move = 24 @ 에피소드 # 69312
# 69312번째 에피소드까지 총 36428번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1631048  move = 48 @ 에피소드 # 69313
# 69313번째 에피소드까지 총 36429번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1631074  move = 26 @ 에피소드 # 69314
# 69314번째 에피소드까지 총 36430번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1631094  move = 20 @ 에피소드 # 69315
# 69315번째 에피소드까지 총 36431번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1631132  move = 38 @ 에피소드 # 69316
# 69316번째 에피소드까지 총 36432번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1631156  move = 24 @ 에피소드 # 69317
# 69317번째 에피소드까지 총 36433번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1631208  move = 26 @ 에피소드 # 69319
# 69319번째 에피소드까지 총 36434번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1631232  move = 24 @ 에피소드 # 69320
# 69320번째 에피소드까지 총 36435번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1631258  move = 26 @ 에피소드 # 69321
# 69321번째 에피소드까지 총 36436번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1631278  move = 20 @ 에피소드 # 69322
# 69322번째 에피소드까지 총 36437번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1631302  move = 24 @ 에피소드 # 69323
# 69323번째 에피소드까지 총 36438번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1631331  move = 20 @ 에피소드 # 69325
# 69325번째 에피소드까지 총 36439번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1631371  move = 40 @ 에피소드 # 69326
# 69326번째 에피소드까지 총 36440번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1631406  move = 26 @ 에피소드 # 69328
# 69328번째 에피소드까지 총 36441번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1631430  move = 24 @ 에피소드 # 69329
# 69329번째 에피소드까지 총 36442번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1631455  move = 18 @ 에피소드 # 69331
# 69331번째 에피소드까지 총 36443번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1631502  move = 28 @ 에피소드 # 69333
# 69333번째 에피소드까지 총 36444번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1631524  move = 22 @ 에피소드 # 69334
# 69334번째 에피소드까지 총 36445번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1631542  move = 18 @ 에피소드 # 69335
# 69335번째 에피소드까지 총 36446번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1631570  move = 28 @ 에피소드 # 69336
# 69336번째 에피소드까지 총 36447번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1631598  move = 28 @ 에피소드 # 69337
# 69337번째 에피소드까지 총 36448번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1631631  move = 22 @ 에피소드 # 69339
# 69339번째 에피소드까지 총 36449번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1631653  move = 22 @ 에피소드 # 69340
# 69340번째 에피소드까지 총 36450번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1631675  move = 22 @ 에피소드 # 69341
# 69341번째 에피소드까지 총 36451번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1631697  move = 22 @ 에피소드 # 69342
# 69342번째 에피소드까지 총 36452번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1631715  move = 18 @ 에피소드 # 69343
# 69343번째 에피소드까지 총 36453번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1631735  move = 20 @ 에피소드 # 69344
# 69344번째 에피소드까지 총 36454번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1631757  move = 22 @ 에피소드 # 69345
# 69345번째 에피소드까지 총 36455번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1631783  move = 26 @ 에피소드 # 69346
# 69346번째 에피소드까지 총 36456번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1631838  move = 28 @ 에피소드 # 69348
# 69348번째 에피소드까지 총 36457번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1631878  move = 40 @ 에피소드 # 69349
# 69349번째 에피소드까지 총 36458번 finish 했습니다.
# 종료: done = True ... j = 1631900  move = 22
# ['O'] 종료: env.goal_ob_reward = True ... j = 1631900  move = 22 @ 에피소드 # 69350
# 69350번째 에피소드까지 총 36459번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1631924  move = 24 @ 에피소드 # 69351
# 69351번째 에피소드까지 총 36460번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1631953  move = 29 @ 에피소드 # 69352
# 69352번째 에피소드까지 총 36461번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1631979  move = 26 @ 에피소드 # 69353
# 69353번째 에피소드까지 총 36462번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1632042  move = 18 @ 에피소드 # 69356
# 69356번째 에피소드까지 총 36463번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1632110  move = 18 @ 에피소드 # 69359
# 69359번째 에피소드까지 총 36464번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1632134  move = 24 @ 에피소드 # 69360
# 69360번째 에피소드까지 총 36465번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1632159  move = 25 @ 에피소드 # 69361
# 69361번째 에피소드까지 총 36466번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1632216  move = 28 @ 에피소드 # 69364
# 69364번째 에피소드까지 총 36467번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1632240  move = 24 @ 에피소드 # 69365
# 69365번째 에피소드까지 총 36468번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1632266  move = 26 @ 에피소드 # 69366
# 69366번째 에피소드까지 총 36469번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1632288  move = 22 @ 에피소드 # 69367
# 69367번째 에피소드까지 총 36470번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1632316  move = 28 @ 에피소드 # 69368
# 69368번째 에피소드까지 총 36471번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1632334  move = 18 @ 에피소드 # 69369
# 69369번째 에피소드까지 총 36472번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1632358  move = 24 @ 에피소드 # 69370
# 69370번째 에피소드까지 총 36473번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1632462  move = 32 @ 에피소드 # 69374
# 69374번째 에피소드까지 총 36474번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1632491  move = 29 @ 에피소드 # 69375
# 69375번째 에피소드까지 총 36475번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1632517  move = 26 @ 에피소드 # 69376
# 69376번째 에피소드까지 총 36476번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1632547  move = 30 @ 에피소드 # 69377
# 69377번째 에피소드까지 총 36477번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1632571  move = 24 @ 에피소드 # 69378
# 69378번째 에피소드까지 총 36478번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1632618  move = 25 @ 에피소드 # 69380
# 69380번째 에피소드까지 총 36479번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1632642  move = 24 @ 에피소드 # 69381
# 69381번째 에피소드까지 총 36480번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1632699  move = 28 @ 에피소드 # 69383
# 69383번째 에피소드까지 총 36481번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1632731  move = 32 @ 에피소드 # 69384
# 69384번째 에피소드까지 총 36482번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1632794  move = 27 @ 에피소드 # 69387
# 69387번째 에피소드까지 총 36483번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1632849  move = 24 @ 에피소드 # 69389
# 69389번째 에피소드까지 총 36484번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1632873  move = 24 @ 에피소드 # 69390
# 69390번째 에피소드까지 총 36485번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1632910  move = 26 @ 에피소드 # 69393
# 69393번째 에피소드까지 총 36486번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1632944  move = 34 @ 에피소드 # 69394
# 69394번째 에피소드까지 총 36487번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1632991  move = 26 @ 에피소드 # 69396
# 69396번째 에피소드까지 총 36488번 finish 했습니다.
# 종료: done = True ... j = 1633000  move = 9
# ['L'] 종료: env.goal_ob_reward = True ... j = 1633052  move = 52 @ 에피소드 # 69398
# 69398번째 에피소드까지 총 36489번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1633086  move = 34 @ 에피소드 # 69399
# 69399번째 에피소드까지 총 36490번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1633108  move = 22 @ 에피소드 # 69400
# 69400번째 에피소드까지 총 36491번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1633137  move = 29 @ 에피소드 # 69401
# 69401번째 에피소드까지 총 36492번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1633276  move = 28 @ 에피소드 # 69404
# 69404번째 에피소드까지 총 36493번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1633330  move = 22 @ 에피소드 # 69406
# 69406번째 에피소드까지 총 36494번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1633350  move = 20 @ 에피소드 # 69407
# 69407번째 에피소드까지 총 36495번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1633395  move = 26 @ 에피소드 # 69409
# 69409번째 에피소드까지 총 36496번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1633417  move = 22 @ 에피소드 # 69410
# 69410번째 에피소드까지 총 36497번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1633449  move = 32 @ 에피소드 # 69411
# 69411번째 에피소드까지 총 36498번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1633473  move = 24 @ 에피소드 # 69412
# 69412번째 에피소드까지 총 36499번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1633499  move = 26 @ 에피소드 # 69413
# 69413번째 에피소드까지 총 36500번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1633529  move = 30 @ 에피소드 # 69414
# 69414번째 에피소드까지 총 36501번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1633598  move = 26 @ 에피소드 # 69417
# 69417번째 에피소드까지 총 36502번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1633650  move = 26 @ 에피소드 # 69419
# 69419번째 에피소드까지 총 36503번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1633672  move = 22 @ 에피소드 # 69420
# 69420번째 에피소드까지 총 36504번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1633692  move = 20 @ 에피소드 # 69421
# 69421번째 에피소드까지 총 36505번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1633712  move = 20 @ 에피소드 # 69422
# 69422번째 에피소드까지 총 36506번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1633856  move = 22 @ 에피소드 # 69425
# 69425번째 에피소드까지 총 36507번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1633882  move = 26 @ 에피소드 # 69426
# 69426번째 에피소드까지 총 36508번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1633926  move = 34 @ 에피소드 # 69428
# 69428번째 에피소드까지 총 36509번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1633954  move = 28 @ 에피소드 # 69429
# 69429번째 에피소드까지 총 36510번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1634002  move = 26 @ 에피소드 # 69431
# 69431번째 에피소드까지 총 36511번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1634038  move = 28 @ 에피소드 # 69433
# 69433번째 에피소드까지 총 36512번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1634089  move = 26 @ 에피소드 # 69435
# 69435번째 에피소드까지 총 36513번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1634116  move = 27 @ 에피소드 # 69436
# 69436번째 에피소드까지 총 36514번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1634156  move = 40 @ 에피소드 # 69437
# 69437번째 에피소드까지 총 36515번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1634178  move = 22 @ 에피소드 # 69438
# 69438번째 에피소드까지 총 36516번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1634202  move = 24 @ 에피소드 # 69439
# 69439번째 에피소드까지 총 36517번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1634234  move = 32 @ 에피소드 # 69440
# 69440번째 에피소드까지 총 36518번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1634256  move = 22 @ 에피소드 # 69441
# 69441번째 에피소드까지 총 36519번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1634301  move = 45 @ 에피소드 # 69442
# 69442번째 에피소드까지 총 36520번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1634323  move = 22 @ 에피소드 # 69443
# 69443번째 에피소드까지 총 36521번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1634355  move = 32 @ 에피소드 # 69444
# 69444번째 에피소드까지 총 36522번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1634381  move = 26 @ 에피소드 # 69445
# 69445번째 에피소드까지 총 36523번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1634418  move = 30 @ 에피소드 # 69447
# 69447번째 에피소드까지 총 36524번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1634458  move = 40 @ 에피소드 # 69448
# 69448번째 에피소드까지 총 36525번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1634486  move = 28 @ 에피소드 # 69449
# 69449번째 에피소드까지 총 36526번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1634502  move = 16 @ 에피소드 # 69450
# 69450번째 에피소드까지 총 36527번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1634530  move = 28 @ 에피소드 # 69451
# 69451번째 에피소드까지 총 36528번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1634554  move = 24 @ 에피소드 # 69452
# 69452번째 에피소드까지 총 36529번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1634604  move = 50 @ 에피소드 # 69453
# 69453번째 에피소드까지 총 36530번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1634638  move = 24 @ 에피소드 # 69455
# 69455번째 에피소드까지 총 36531번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1634690  move = 22 @ 에피소드 # 69457
# 69457번째 에피소드까지 총 36532번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1634712  move = 22 @ 에피소드 # 69458
# 69458번째 에피소드까지 총 36533번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1634757  move = 22 @ 에피소드 # 69460
# 69460번째 에피소드까지 총 36534번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1634803  move = 46 @ 에피소드 # 69461
# 69461번째 에피소드까지 총 36535번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1634825  move = 22 @ 에피소드 # 69462
# 69462번째 에피소드까지 총 36536번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1634849  move = 24 @ 에피소드 # 69463
# 69463번째 에피소드까지 총 36537번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1634881  move = 32 @ 에피소드 # 69464
# 69464번째 에피소드까지 총 36538번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1634926  move = 24 @ 에피소드 # 69466
# 69466번째 에피소드까지 총 36539번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1634956  move = 30 @ 에피소드 # 69467
# 69467번째 에피소드까지 총 36540번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1634982  move = 26 @ 에피소드 # 69468
# 69468번째 에피소드까지 총 36541번 finish 했습니다.
# epiode #: 69470 loss: 0.2002716213464737 j: 1635000
# ['L'] 종료: env.goal_ob_reward = True ... j = 1635017  move = 26 @ 에피소드 # 69470
# 69470번째 에피소드까지 총 36542번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1635043  move = 26 @ 에피소드 # 69471
# 69471번째 에피소드까지 총 36543번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1635067  move = 24 @ 에피소드 # 69472
# 69472번째 에피소드까지 총 36544번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1635190  move = 22 @ 에피소드 # 69474
# 69474번째 에피소드까지 총 36545번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1635244  move = 54 @ 에피소드 # 69475
# 69475번째 에피소드까지 총 36546번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1635322  move = 42 @ 에피소드 # 69477
# 69477번째 에피소드까지 총 36547번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1635352  move = 30 @ 에피소드 # 69478
# 69478번째 에피소드까지 총 36548번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1635433  move = 24 @ 에피소드 # 69480
# 69480번째 에피소드까지 총 36549번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1635451  move = 18 @ 에피소드 # 69481
# 69481번째 에피소드까지 총 36550번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1635484  move = 33 @ 에피소드 # 69482
# 69482번째 에피소드까지 총 36551번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1635516  move = 32 @ 에피소드 # 69483
# 69483번째 에피소드까지 총 36552번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1635571  move = 26 @ 에피소드 # 69485
# 69485번째 에피소드까지 총 36553번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1635621  move = 50 @ 에피소드 # 69486
# 69486번째 에피소드까지 총 36554번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1635643  move = 22 @ 에피소드 # 69487
# 69487번째 에피소드까지 총 36555번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1635669  move = 26 @ 에피소드 # 69488
# 69488번째 에피소드까지 총 36556번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1635693  move = 24 @ 에피소드 # 69489
# 69489번째 에피소드까지 총 36557번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1635719  move = 26 @ 에피소드 # 69490
# 69490번째 에피소드까지 총 36558번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1635749  move = 30 @ 에피소드 # 69491
# 69491번째 에피소드까지 총 36559번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1635798  move = 22 @ 에피소드 # 69494
# 69494번째 에피소드까지 총 36560번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1635846  move = 48 @ 에피소드 # 69495
# 69495번째 에피소드까지 총 36561번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1635887  move = 22 @ 에피소드 # 69497
# 69497번째 에피소드까지 총 36562번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1635905  move = 18 @ 에피소드 # 69498
# 69498번째 에피소드까지 총 36563번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1635931  move = 26 @ 에피소드 # 69499
# 69499번째 에피소드까지 총 36564번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1635961  move = 30 @ 에피소드 # 69500
# 69500번째 에피소드까지 총 36565번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1635985  move = 24 @ 에피소드 # 69501
# 69501번째 에피소드까지 총 36566번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1636015  move = 30 @ 에피소드 # 69502
# 69502번째 에피소드까지 총 36567번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1636035  move = 20 @ 에피소드 # 69503
# 69503번째 에피소드까지 총 36568번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1636059  move = 24 @ 에피소드 # 69504
# 69504번째 에피소드까지 총 36569번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1636117  move = 27 @ 에피소드 # 69506
# 69506번째 에피소드까지 총 36570번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1636139  move = 22 @ 에피소드 # 69507
# 69507번째 에피소드까지 총 36571번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1636176  move = 20 @ 에피소드 # 69509
# 69509번째 에피소드까지 총 36572번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1636202  move = 26 @ 에피소드 # 69510
# 69510번째 에피소드까지 총 36573번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1636224  move = 22 @ 에피소드 # 69511
# 69511번째 에피소드까지 총 36574번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1636246  move = 22 @ 에피소드 # 69512
# 69512번째 에피소드까지 총 36575번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1636270  move = 24 @ 에피소드 # 69513
# 69513번째 에피소드까지 총 36576번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1636299  move = 24 @ 에피소드 # 69515
# 69515번째 에피소드까지 총 36577번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1636332  move = 33 @ 에피소드 # 69516
# 69516번째 에피소드까지 총 36578번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1636350  move = 18 @ 에피소드 # 69517
# 69517번째 에피소드까지 총 36579번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1636384  move = 34 @ 에피소드 # 69518
# 69518번째 에피소드까지 총 36580번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1636410  move = 26 @ 에피소드 # 69519
# 69519번째 에피소드까지 총 36581번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1636439  move = 24 @ 에피소드 # 69521
# 69521번째 에피소드까지 총 36582번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1636463  move = 24 @ 에피소드 # 69522
# 69522번째 에피소드까지 총 36583번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1636490  move = 27 @ 에피소드 # 69523
# 69523번째 에피소드까지 총 36584번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1636514  move = 24 @ 에피소드 # 69524
# 69524번째 에피소드까지 총 36585번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1636530  move = 16 @ 에피소드 # 69525
# 69525번째 에피소드까지 총 36586번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1636554  move = 24 @ 에피소드 # 69526
# 69526번째 에피소드까지 총 36587번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1636591  move = 24 @ 에피소드 # 69528
# 69528번째 에피소드까지 총 36588번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1636627  move = 36 @ 에피소드 # 69529
# 69529번째 에피소드까지 총 36589번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1636649  move = 22 @ 에피소드 # 69530
# 69530번째 에피소드까지 총 36590번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1636687  move = 22 @ 에피소드 # 69532
# 69532번째 에피소드까지 총 36591번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1636714  move = 27 @ 에피소드 # 69533
# 69533번째 에피소드까지 총 36592번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1636742  move = 28 @ 에피소드 # 69534
# 69534번째 에피소드까지 총 36593번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1636766  move = 24 @ 에피소드 # 69535
# 69535번째 에피소드까지 총 36594번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1636790  move = 24 @ 에피소드 # 69536
# 69536번째 에피소드까지 총 36595번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1636818  move = 28 @ 에피소드 # 69537
# 69537번째 에피소드까지 총 36596번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1636846  move = 28 @ 에피소드 # 69538
# 69538번째 에피소드까지 총 36597번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1636868  move = 22 @ 에피소드 # 69539
# 69539번째 에피소드까지 총 36598번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1636884  move = 16 @ 에피소드 # 69540
# 69540번째 에피소드까지 총 36599번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1636912  move = 28 @ 에피소드 # 69541
# 69541번째 에피소드까지 총 36600번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1636934  move = 22 @ 에피소드 # 69542
# 69542번째 에피소드까지 총 36601번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1636968  move = 30 @ 에피소드 # 69544
# 69544번째 에피소드까지 총 36602번 finish 했습니다.
# 종료: done = True ... j = 1637000  move = 24
# ['N'] 종료: env.goal_ob_reward = True ... j = 1637000  move = 24 @ 에피소드 # 69546
# 69546번째 에피소드까지 총 36603번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1637024  move = 24 @ 에피소드 # 69547
# 69547번째 에피소드까지 총 36604번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1637048  move = 24 @ 에피소드 # 69548
# 69548번째 에피소드까지 총 36605번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1637127  move = 24 @ 에피소드 # 69551
# 69551번째 에피소드까지 총 36606번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1637169  move = 24 @ 에피소드 # 69553
# 69553번째 에피소드까지 총 36607번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1637185  move = 16 @ 에피소드 # 69554
# 69554번째 에피소드까지 총 36608번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1637245  move = 25 @ 에피소드 # 69556
# 69556번째 에피소드까지 총 36609번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1637297  move = 52 @ 에피소드 # 69557
# 69557번째 에피소드까지 총 36610번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1637321  move = 24 @ 에피소드 # 69558
# 69558번째 에피소드까지 총 36611번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1637337  move = 16 @ 에피소드 # 69559
# 69559번째 에피소드까지 총 36612번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1637379  move = 22 @ 에피소드 # 69561
# 69561번째 에피소드까지 총 36613번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1637395  move = 16 @ 에피소드 # 69562
# 69562번째 에피소드까지 총 36614번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1637417  move = 22 @ 에피소드 # 69563
# 69563번째 에피소드까지 총 36615번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1637453  move = 24 @ 에피소드 # 69565
# 69565번째 에피소드까지 총 36616번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1637479  move = 26 @ 에피소드 # 69566
# 69566번째 에피소드까지 총 36617번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1637514  move = 35 @ 에피소드 # 69567
# 69567번째 에피소드까지 총 36618번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1637540  move = 26 @ 에피소드 # 69568
# 69568번째 에피소드까지 총 36619번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1637560  move = 20 @ 에피소드 # 69569
# 69569번째 에피소드까지 총 36620번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1637590  move = 30 @ 에피소드 # 69570
# 69570번째 에피소드까지 총 36621번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1637624  move = 26 @ 에피소드 # 69572
# 69572번째 에피소드까지 총 36622번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1637644  move = 20 @ 에피소드 # 69573
# 69573번째 에피소드까지 총 36623번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1637676  move = 32 @ 에피소드 # 69574
# 69574번째 에피소드까지 총 36624번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1637719  move = 43 @ 에피소드 # 69575
# 69575번째 에피소드까지 총 36625번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1637774  move = 36 @ 에피소드 # 69577
# 69577번째 에피소드까지 총 36626번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1637798  move = 24 @ 에피소드 # 69578
# 69578번째 에피소드까지 총 36627번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1637844  move = 28 @ 에피소드 # 69580
# 69580번째 에피소드까지 총 36628번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1637868  move = 24 @ 에피소드 # 69581
# 69581번째 에피소드까지 총 36629번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1637888  move = 20 @ 에피소드 # 69582
# 69582번째 에피소드까지 총 36630번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1637930  move = 42 @ 에피소드 # 69583
# 69583번째 에피소드까지 총 36631번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1637958  move = 28 @ 에피소드 # 69584
# 69584번째 에피소드까지 총 36632번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1637982  move = 24 @ 에피소드 # 69585
# 69585번째 에피소드까지 총 36633번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1638007  move = 20 @ 에피소드 # 69587
# 69587번째 에피소드까지 총 36634번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1638060  move = 22 @ 에피소드 # 69590
# 69590번째 에피소드까지 총 36635번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1638082  move = 22 @ 에피소드 # 69591
# 69591번째 에피소드까지 총 36636번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1638106  move = 24 @ 에피소드 # 69592
# 69592번째 에피소드까지 총 36637번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1638126  move = 20 @ 에피소드 # 69593
# 69593번째 에피소드까지 총 36638번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1638150  move = 20 @ 에피소드 # 69595
# 69595번째 에피소드까지 총 36639번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1638219  move = 38 @ 에피소드 # 69597
# 69597번째 에피소드까지 총 36640번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1638239  move = 20 @ 에피소드 # 69598
# 69598번째 에피소드까지 총 36641번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1638306  move = 36 @ 에피소드 # 69600
# 69600번째 에피소드까지 총 36642번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1638332  move = 26 @ 에피소드 # 69601
# 69601번째 에피소드까지 총 36643번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1638411  move = 28 @ 에피소드 # 69604
# 69604번째 에피소드까지 총 36644번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1638431  move = 20 @ 에피소드 # 69605
# 69605번째 에피소드까지 총 36645번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1638453  move = 22 @ 에피소드 # 69606
# 69606번째 에피소드까지 총 36646번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1638481  move = 28 @ 에피소드 # 69607
# 69607번째 에피소드까지 총 36647번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1638513  move = 32 @ 에피소드 # 69608
# 69608번째 에피소드까지 총 36648번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1638537  move = 24 @ 에피소드 # 69609
# 69609번째 에피소드까지 총 36649번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1638562  move = 25 @ 에피소드 # 69610
# 69610번째 에피소드까지 총 36650번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1638588  move = 26 @ 에피소드 # 69611
# 69611번째 에피소드까지 총 36651번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1638616  move = 20 @ 에피소드 # 69613
# 69613번째 에피소드까지 총 36652번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1638640  move = 24 @ 에피소드 # 69614
# 69614번째 에피소드까지 총 36653번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1638692  move = 24 @ 에피소드 # 69616
# 69616번째 에피소드까지 총 36654번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1638728  move = 18 @ 에피소드 # 69618
# 69618번째 에피소드까지 총 36655번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1638754  move = 26 @ 에피소드 # 69619
# 69619번째 에피소드까지 총 36656번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1638794  move = 40 @ 에피소드 # 69620
# 69620번째 에피소드까지 총 36657번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1638818  move = 24 @ 에피소드 # 69621
# 69621번째 에피소드까지 총 36658번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 1638840  move = 22 @ 에피소드 # 69622
# 69622번째 에피소드까지 총 36659번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1638858  move = 18 @ 에피소드 # 69623
# 69623번째 에피소드까지 총 36660번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1638884  move = 26 @ 에피소드 # 69624
# 69624번째 에피소드까지 총 36661번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1638906  move = 22 @ 에피소드 # 69625
# 69625번째 에피소드까지 총 36662번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1638932  move = 26 @ 에피소드 # 69626
# 69626번째 에피소드까지 총 36663번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1638954  move = 22 @ 에피소드 # 69627
# 69627번째 에피소드까지 총 36664번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1638972  move = 18 @ 에피소드 # 69628
# 69628번째 에피소드까지 총 36665번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1638994  move = 22 @ 에피소드 # 69629
# 69629번째 에피소드까지 총 36666번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1639016  move = 22 @ 에피소드 # 69630
# 69630번째 에피소드까지 총 36667번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1639066  move = 50 @ 에피소드 # 69631
# 69631번째 에피소드까지 총 36668번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1639090  move = 24 @ 에피소드 # 69632
# 69632번째 에피소드까지 총 36669번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1639118  move = 28 @ 에피소드 # 69633
# 69633번째 에피소드까지 총 36670번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1639169  move = 22 @ 에피소드 # 69636
# 69636번째 에피소드까지 총 36671번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1639207  move = 22 @ 에피소드 # 69638
# 69638번째 에피소드까지 총 36672번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1639233  move = 26 @ 에피소드 # 69639
# 69639번째 에피소드까지 총 36673번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1639257  move = 24 @ 에피소드 # 69640
# 69640번째 에피소드까지 총 36674번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1639338  move = 26 @ 에피소드 # 69643
# 69643번째 에피소드까지 총 36675번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1639358  move = 20 @ 에피소드 # 69644
# 69644번째 에피소드까지 총 36676번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1639376  move = 18 @ 에피소드 # 69645
# 69645번째 에피소드까지 총 36677번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1639396  move = 20 @ 에피소드 # 69646
# 69646번째 에피소드까지 총 36678번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1639420  move = 24 @ 에피소드 # 69647
# 69647번째 에피소드까지 총 36679번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1639442  move = 22 @ 에피소드 # 69648
# 69648번째 에피소드까지 총 36680번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1639464  move = 22 @ 에피소드 # 69649
# 69649번째 에피소드까지 총 36681번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1639486  move = 22 @ 에피소드 # 69650
# 69650번째 에피소드까지 총 36682번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1639508  move = 22 @ 에피소드 # 69651
# 69651번째 에피소드까지 총 36683번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1639540  move = 28 @ 에피소드 # 69653
# 69653번째 에피소드까지 총 36684번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1639568  move = 28 @ 에피소드 # 69654
# 69654번째 에피소드까지 총 36685번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1639590  move = 22 @ 에피소드 # 69655
# 69655번째 에피소드까지 총 36686번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1639610  move = 20 @ 에피소드 # 69656
# 69656번째 에피소드까지 총 36687번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1639631  move = 16 @ 에피소드 # 69658
# ...
# ['E'] 종료: env.goal_ob_reward = True ... j = 1706373  move = 30 @ 에피소드 # 72318
# 72318번째 에피소드까지 총 38613번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1706399  move = 26 @ 에피소드 # 72319
# 72319번째 에피소드까지 총 38614번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1706438  move = 36 @ 에피소드 # 72321
# 72321번째 에피소드까지 총 38615번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1706466  move = 28 @ 에피소드 # 72322
# 72322번째 에피소드까지 총 38616번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1706490  move = 24 @ 에피소드 # 72323
# 72323번째 에피소드까지 총 38617번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1706545  move = 22 @ 에피소드 # 72325
# 72325번째 에피소드까지 총 38618번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1706610  move = 21 @ 에피소드 # 72328
# 72328번째 에피소드까지 총 38619번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1706641  move = 20 @ 에피소드 # 72330
# 72330번째 에피소드까지 총 38620번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1706711  move = 22 @ 에피소드 # 72333
# 72333번째 에피소드까지 총 38621번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1706753  move = 42 @ 에피소드 # 72334
# 72334번째 에피소드까지 총 38622번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1706777  move = 24 @ 에피소드 # 72335
# 72335번째 에피소드까지 총 38623번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1706829  move = 52 @ 에피소드 # 72336
# 72336번째 에피소드까지 총 38624번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1706859  move = 30 @ 에피소드 # 72337
# 72337번째 에피소드까지 총 38625번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1706898  move = 28 @ 에피소드 # 72339
# 72339번째 에피소드까지 총 38626번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1707017  move = 30 @ 에피소드 # 72342
# 72342번째 에피소드까지 총 38627번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1707043  move = 26 @ 에피소드 # 72343
# 72343번째 에피소드까지 총 38628번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1707079  move = 36 @ 에피소드 # 72344
# 72344번째 에피소드까지 총 38629번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1707129  move = 50 @ 에피소드 # 72345
# 72345번째 에피소드까지 총 38630번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1707145  move = 16 @ 에피소드 # 72346
# 72346번째 에피소드까지 총 38631번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1707295  move = 26 @ 에피소드 # 72349
# 72349번째 에피소드까지 총 38632번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1707445  move = 18 @ 에피소드 # 72355
# 72355번째 에피소드까지 총 38633번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1707471  move = 26 @ 에피소드 # 72356
# 72356번째 에피소드까지 총 38634번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1707493  move = 22 @ 에피소드 # 72357
# 72357번째 에피소드까지 총 38635번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1707517  move = 24 @ 에피소드 # 72358
# 72358번째 에피소드까지 총 38636번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1707665  move = 18 @ 에피소드 # 72361
# 72361번째 에피소드까지 총 38637번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1707703  move = 38 @ 에피소드 # 72362
# 72362번째 에피소드까지 총 38638번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1707727  move = 24 @ 에피소드 # 72363
# 72363번째 에피소드까지 총 38639번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1707781  move = 16 @ 에피소드 # 72366
# 72366번째 에피소드까지 총 38640번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1707806  move = 25 @ 에피소드 # 72367
# 72367번째 에피소드까지 총 38641번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1707825  move = 16 @ 에피소드 # 72369
# 72369번째 에피소드까지 총 38642번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1707847  move = 22 @ 에피소드 # 72370
# 72370번째 에피소드까지 총 38643번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1707865  move = 18 @ 에피소드 # 72371
# 72371번째 에피소드까지 총 38644번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1707918  move = 20 @ 에피소드 # 72373
# 72373번째 에피소드까지 총 38645번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1707958  move = 32 @ 에피소드 # 72375
# 72375번째 에피소드까지 총 38646번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1708001  move = 18 @ 에피소드 # 72378
# 72378번째 에피소드까지 총 38647번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1708023  move = 22 @ 에피소드 # 72379
# 72379번째 에피소드까지 총 38648번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1708045  move = 22 @ 에피소드 # 72380
# 72380번째 에피소드까지 총 38649번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1708089  move = 24 @ 에피소드 # 72382
# 72382번째 에피소드까지 총 38650번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1708107  move = 18 @ 에피소드 # 72383
# 72383번째 에피소드까지 총 38651번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1708133  move = 26 @ 에피소드 # 72384
# 72384번째 에피소드까지 총 38652번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1708157  move = 24 @ 에피소드 # 72385
# 72385번째 에피소드까지 총 38653번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1708238  move = 26 @ 에피소드 # 72388
# 72388번째 에피소드까지 총 38654번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1708367  move = 28 @ 에피소드 # 72390
# 72390번째 에피소드까지 총 38655번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1708595  move = 26 @ 에피소드 # 72393
# 72393번째 에피소드까지 총 38656번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1708621  move = 26 @ 에피소드 # 72394
# 72394번째 에피소드까지 총 38657번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1708645  move = 24 @ 에피소드 # 72395
# 72395번째 에피소드까지 총 38658번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1708677  move = 32 @ 에피소드 # 72396
# 72396번째 에피소드까지 총 38659번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1708703  move = 26 @ 에피소드 # 72397
# 72397번째 에피소드까지 총 38660번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1708748  move = 18 @ 에피소드 # 72399
# 72399번째 에피소드까지 총 38661번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1708770  move = 22 @ 에피소드 # 72400
# 72400번째 에피소드까지 총 38662번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1708794  move = 24 @ 에피소드 # 72401
# 72401번째 에피소드까지 총 38663번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1708814  move = 20 @ 에피소드 # 72402
# 72402번째 에피소드까지 총 38664번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1708845  move = 26 @ 에피소드 # 72404
# 72404번째 에피소드까지 총 38665번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1708874  move = 29 @ 에피소드 # 72405
# 72405번째 에피소드까지 총 38666번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1708904  move = 30 @ 에피소드 # 72406
# 72406번째 에피소드까지 총 38667번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1708924  move = 20 @ 에피소드 # 72407
# 72407번째 에피소드까지 총 38668번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1708942  move = 18 @ 에피소드 # 72408
# 72408번째 에피소드까지 총 38669번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1708962  move = 20 @ 에피소드 # 72409
# 72409번째 에피소드까지 총 38670번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1708990  move = 28 @ 에피소드 # 72410
# 72410번째 에피소드까지 총 38671번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1709012  move = 22 @ 에피소드 # 72411
# 72411번째 에피소드까지 총 38672번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1709039  move = 27 @ 에피소드 # 72412
# 72412번째 에피소드까지 총 38673번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1709061  move = 22 @ 에피소드 # 72413
# 72413번째 에피소드까지 총 38674번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1709143  move = 48 @ 에피소드 # 72415
# 72415번째 에피소드까지 총 38675번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1709159  move = 16 @ 에피소드 # 72416
# 72416번째 에피소드까지 총 38676번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1709185  move = 26 @ 에피소드 # 72417
# 72417번째 에피소드까지 총 38677번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1709201  move = 16 @ 에피소드 # 72418
# 72418번째 에피소드까지 총 38678번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1709223  move = 22 @ 에피소드 # 72419
# 72419번째 에피소드까지 총 38679번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1709251  move = 28 @ 에피소드 # 72420
# 72420번째 에피소드까지 총 38680번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1709321  move = 28 @ 에피소드 # 72422
# 72422번째 에피소드까지 총 38681번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1709347  move = 26 @ 에피소드 # 72423
# 72423번째 에피소드까지 총 38682번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1709373  move = 26 @ 에피소드 # 72424
# 72424번째 에피소드까지 총 38683번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1709395  move = 22 @ 에피소드 # 72425
# 72425번째 에피소드까지 총 38684번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1709484  move = 34 @ 에피소드 # 72427
# 72427번째 에피소드까지 총 38685번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1709502  move = 18 @ 에피소드 # 72428
# 72428번째 에피소드까지 총 38686번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 1709528  move = 26 @ 에피소드 # 72429
# 72429번째 에피소드까지 총 38687번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1709554  move = 26 @ 에피소드 # 72430
# 72430번째 에피소드까지 총 38688번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1709588  move = 34 @ 에피소드 # 72431
# 72431번째 에피소드까지 총 38689번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1709612  move = 24 @ 에피소드 # 72432
# 72432번째 에피소드까지 총 38690번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1709628  move = 16 @ 에피소드 # 72433
# 72433번째 에피소드까지 총 38691번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1709654  move = 26 @ 에피소드 # 72434
# 72434번째 에피소드까지 총 38692번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1709680  move = 26 @ 에피소드 # 72435
# 72435번째 에피소드까지 총 38693번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1709704  move = 24 @ 에피소드 # 72436
# 72436번째 에피소드까지 총 38694번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1709732  move = 28 @ 에피소드 # 72437
# 72437번째 에피소드까지 총 38695번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1709780  move = 22 @ 에피소드 # 72439
# 72439번째 에피소드까지 총 38696번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1709804  move = 24 @ 에피소드 # 72440
# 72440번째 에피소드까지 총 38697번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1709868  move = 22 @ 에피소드 # 72443
# 72443번째 에피소드까지 총 38698번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1709916  move = 22 @ 에피소드 # 72446
# 72446번째 에피소드까지 총 38699번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1709960  move = 36 @ 에피소드 # 72448
# 72448번째 에피소드까지 총 38700번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1709984  move = 16 @ 에피소드 # 72450
# 72450번째 에피소드까지 총 38701번 finish 했습니다.
# epiode #: 72451 loss: 0.20890311896800995 j: 1710000
# ['B'] 종료: env.goal_ob_reward = True ... j = 1710002  move = 18 @ 에피소드 # 72451
# 72451번째 에피소드까지 총 38702번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1710026  move = 24 @ 에피소드 # 72452
# 72452번째 에피소드까지 총 38703번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1710083  move = 26 @ 에피소드 # 72454
# 72454번째 에피소드까지 총 38704번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1710107  move = 24 @ 에피소드 # 72455
# 72455번째 에피소드까지 총 38705번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1710157  move = 18 @ 에피소드 # 72458
# 72458번째 에피소드까지 총 38706번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1710181  move = 24 @ 에피소드 # 72459
# 72459번째 에피소드까지 총 38707번 finish 했습니다.
# 종료: done = True ... j = 1710200  move = 19
# ['A'] 종료: env.goal_ob_reward = True ... j = 1710222  move = 22 @ 에피소드 # 72461
# 72461번째 에피소드까지 총 38708번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1710244  move = 22 @ 에피소드 # 72462
# 72462번째 에피소드까지 총 38709번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1710270  move = 26 @ 에피소드 # 72463
# 72463번째 에피소드까지 총 38710번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1710294  move = 24 @ 에피소드 # 72464
# 72464번째 에피소드까지 총 38711번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1710529  move = 30 @ 에피소드 # 72468
# 72468번째 에피소드까지 총 38712번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1710603  move = 74 @ 에피소드 # 72469
# 72469번째 에피소드까지 총 38713번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1710829  move = 24 @ 에피소드 # 72472
# 72472번째 에피소드까지 총 38714번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1710883  move = 24 @ 에피소드 # 72474
# 72474번째 에피소드까지 총 38715번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1710910  move = 24 @ 에피소드 # 72476
# 72476번째 에피소드까지 총 38716번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1710932  move = 22 @ 에피소드 # 72477
# 72477번째 에피소드까지 총 38717번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1710950  move = 18 @ 에피소드 # 72478
# 72478번째 에피소드까지 총 38718번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 1710976  move = 26 @ 에피소드 # 72479
# 72479번째 에피소드까지 총 38719번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1710992  move = 16 @ 에피소드 # 72480
# 72480번째 에피소드까지 총 38720번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1711072  move = 21 @ 에피소드 # 72483
# 72483번째 에피소드까지 총 38721번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1711094  move = 22 @ 에피소드 # 72484
# 72484번째 에피소드까지 총 38722번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1711151  move = 22 @ 에피소드 # 72486
# 72486번째 에피소드까지 총 38723번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1711218  move = 22 @ 에피소드 # 72488
# 72488번째 에피소드까지 총 38724번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1711273  move = 26 @ 에피소드 # 72490
# 72490번째 에피소드까지 총 38725번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1711297  move = 24 @ 에피소드 # 72491
# 72491번째 에피소드까지 총 38726번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1711328  move = 22 @ 에피소드 # 72493
# 72493번째 에피소드까지 총 38727번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1711358  move = 30 @ 에피소드 # 72494
# 72494번째 에피소드까지 총 38728번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1711412  move = 28 @ 에피소드 # 72497
# 72497번째 에피소드까지 총 38729번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1711434  move = 22 @ 에피소드 # 72498
# 72498번째 에피소드까지 총 38730번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1711458  move = 24 @ 에피소드 # 72499
# 72499번째 에피소드까지 총 38731번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 1711482  move = 24 @ 에피소드 # 72500
# 72500번째 에피소드까지 총 38732번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 1711504  move = 22 @ 에피소드 # 72501
# 72501번째 에피소드까지 총 38733번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1711608  move = 28 @ 에피소드 # 72504
# 72504번째 에피소드까지 총 38734번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1711632  move = 24 @ 에피소드 # 72505
# 72505번째 에피소드까지 총 38735번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1711662  move = 30 @ 에피소드 # 72506
# 72506번째 에피소드까지 총 38736번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1711702  move = 26 @ 에피소드 # 72508
# 72508번째 에피소드까지 총 38737번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1711724  move = 22 @ 에피소드 # 72509
# 72509번째 에피소드까지 총 38738번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 1711748  move = 24 @ 에피소드 # 72510
# 72510번째 에피소드까지 총 38739번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1711766  move = 18 @ 에피소드 # 72511
# 72511번째 에피소드까지 총 38740번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 1711821  move = 22 @ 에피소드 # 72513
# 72513번째 에피소드까지 총 38741번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 1711847  move = 26 @ 에피소드 # 72514
# 72514번째 에피소드까지 총 38742번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 1711874  move = 27 @ 에피소드 # 72515
# 72515번째 에피소드까지 총 38743번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 1711892  move = 18 @ 에피소드 # 72516
# 72516번째 에피소드까지 총 38744번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 1711916  move = 24 @ 에피소드 # 72517
# 72517번째 에피소드까지 총 38745번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 1711960  move = 44 @ 에피소드 # 72518
# 72518번째 에피소드까지 총 38746번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 1711990  move = 30 @ 에피소드 # 72519
# 72519번째 에피소드까지 총 38747번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 1712025  move = 26 @ 에피소드 # 72521
# 72521번째 에피소드까지 총 38748번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 1712061  move = 24 @ 에피소드 # 72523
# 72523번째 에피소드까지 총 38749번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 1712106  move = 16 @ 에피소드 # 72525
# 72525번째 에피소드까지 총 38750번 finish 했습니다.

# %% [markdown]
# ## 테스트 코드

# %%
## test 코드 #################################################################################
def test(epochs=10, train_mode=False, display=True, model_load=True):  # train_mode = False 테스트 모드
##############################################################################################
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # GPU를 사용할 경우 ???
    print('tensor in', device)  # GPU 사용 확인
    test_env = Simulator()  # 데이터셋 읽기. 그리드월드 크기 지정
    test_q = Qnet()
    test_q.to(device)

    if model_load:
        ###############################################################
        ## 학습한 모델 불러오기
        ###############################################################
        checkpoint = torch.load(PATH)
        q.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        epoch = checkpoint['epoch']
        loss = checkpoint['loss']
        q.eval()

    ### 액션 저장하는 txt파일 만들기 #######################
    f = open(__file__ + '/ogz_conv_test_gif' + '.txt', 'w')
    ########################################################
    epochs = len(test_env.files)
    wins = 0
    for n_epi in range(epochs):
        gridmap = test_env.reset(n_epi)  # 에피소드 시작시 12개 값 초기화
        history = np.stack((gridmap,gridmap,gridmap,gridmap), axis = 0) # 초기 state로 히스토리 초기화 (4,10,9)
        history = np.reshape([history], (1,4,10,9)) # (배치, 채널, 가로, 세로) 로 reshape
        history = torch.from_numpy(history).float() # 텐서로 변환   
        done = False
        mov = 0
        while (not done):  # 최종 목적지 [9,4] 도착
            mov += 1
            # 상태 state1에서 action 결정
            #####################################################################################
            if test_env.curloc == [9,4]:  # 출발점에서는 무조건 위로 (action=0)
                action = 0
            elif test_env.curloc[0] == 0 and test_env.curloc[1] in [0,1,2,3,4,5,6,7,8]:  # (0,0)~(0,8)에서는 무조건 아래로
                action = 1
            elif test_env.curloc[0] in [2,3,4,5] and test_env.curloc[1] == 8:  # (2,8)~(5,8)에서는 무조건 왼쪽으로
                action = 2
            elif test_env.curloc[0] in [2,3,4,5] and test_env.curloc[1] == 0:  # (2,0)~(5,0)에서는 무조건 오른쪽으로
                action = 3
            else:  # 위 경우를 제외하곤 test 액션 선택
                action = q.test_action(history1)
            #####################################################################################
            # action = q.test_action(state)  # 위 조건을 적용하지 않을 경우
            # make Move... action에 따른 이동
            gridmap, reward, cum_reward, done = test_env.step(action)

            next_gridmap = np.reshape([gridmap],(1,1,10,9)) # 다음 그리드를 히스토리 사이즈에 맞게 reshape
            next_gridmap = torch.from_numpy(next_gridmap).float() # 텐서로 변환
            history = torch.cat([next_gridmap,history[:,:3,:,:]],dim=1) # (1,1+3,10,9)
            # 지금 있는 히스토리중 마지막 채널을 지우고 new를 제일 앞에 붙임
            
            state_ = torch.from_numpy(gridmap).float()  # 넘파이 array를 Torch 텐서로 변환  # (10, 9)
            state = torch.unsqueeze(state_,0)  # conv2d용 차원 증가 (1, 10, 9)
            state = torch.unsqueeze(state,0)  # conv2d용 (1, 1, 10, 9)
            if display:
                print('Move #%s; Taking action: %s' % (mov, action))
                print(gridmap.reshape(10,9))

            if test_env.goal_ob_reward:
                wins += 1
                if display:
                    print("Game won! Reward: %s" % (cum_reward))
                else:
                    print("Game LOST. Reward: %s" % (cum_reward))
                    
            #if (mov > 100):  # 경로 길이가 너무 길어서 제외시키는 조건 추가 필요시 사용
                #if display:
                    #print("Game lost; too many moves.")
                #break
        
    win_perc = float(wins) / float(epochs)
    print("Test performed: {0}, # of wins: {1}".format(epochs,wins))
    print("Win percentage: {}%".format(100.0*win_perc))
    return win_perc

# %%
test(epochs=10, train_mode=False, display=True, model_load=True)

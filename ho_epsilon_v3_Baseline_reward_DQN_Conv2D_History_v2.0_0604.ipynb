# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

__file__ = '/content/drive/Othercomputers/MacBook_Air/path-finding-rl/data'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Env
# - 경로 이동 제한 사항 반영: del apply_action() 수정
# - def grid_box(self):  # 그리드 박스 초기화 용도로 정의
# - 그리드값 변경
#   - target_gridval (목표물)  = 10, 9, 8, ...
#   - curloc_gridval (현 위치) = 1
#   - default_gridval (기본)   = 0
#   - rack_gridval (선반)      = -1
#   - obs_gridval (장애물)     = -10
# - 종료 조건
#   - **그리드월드 밖**으로 나가는 경우 **종료하지 않음**
#   - **장애물**에 부딪히는 경우 **종료**

# %%
from string import ascii_uppercase
import numpy as np
import pandas as pd
import os
import random
from datetime import datetime
import pytz
import matplotlib.pyplot as plt

###################################
# 보상 Reward
move_reward = -1  # 0.1
obs_reward = -10  # 0.1
goal_reward = 10  # 10
###################################
# 그리드값
# target_gridval = 10, 9, 8... # 목표물: 10, 9, 8, ...
curloc_gridval  = 1            # 현 위치: 1
default_gridval = 0            # 기본: 0
rack_gridval    = -1           # 선반: -1
obs_gridval     = -10          # 장애물: -10
###################################
# train / test 모드 지정
train_mode = True
###################################
print('reward:' , move_reward, obs_reward, goal_reward)

#__file__ = '/home/ogangza/heung_path_finding/path-finding-rl/data'

local_path = os.path.abspath(os.path.join(os.path.dirname(__file__)))

class Simulator:
    def __init__(self):
        # Load train or test data
        # if train_mode:  # 훈련 데이타 읽기
        #     self.files = pd.read_csv(os.path.join(local_path, "data/factory_order_train.csv"))
        #     print('data/factory_order_train.csv used')
        # else:           # 테스트 데이터 읽기
        #     self.files = pd.read_csv(os.path.join(local_path, "data/factory_order_test.csv"))
        #     print('data/factory_order_test.csv used')
        ##########################################################################################
        self.height = 10  # 그리드 높이
        self.width = 9    #  그리드 너비
        self.inds = list(ascii_uppercase)[:17]  # A ~ Q alphabet list

    def set_box(self):  # 선반 위치, 목적지 그리드값 설정. 목적지 리스트 생성
        box_data = pd.read_csv(os.path.join(local_path, "data/box.csv"))
        for box in box_data.itertuples(index = True, name ='Pandas'):  # 선반 위치: 그리드값 = rack_gridval
            self.grid[getattr(box, "row")][getattr(box, "col")] = rack_gridval
        order_item = list(set(self.inds) & set(self.items))
        order_csv = box_data[box_data['item'].isin(order_item)]
        for i, order_box in enumerate(order_csv.itertuples(index = True, name ='Pandas')):  # 목적지: 그리드값 = target_gridval
            self.grid[getattr(order_box, "row")][getattr(order_box, "col")] = 10 - i
            self.local_target.append([getattr(order_box, "row"), getattr(order_box, "col")])  # 목적지 리스트 생성: local_target
        # self.local_target.sort() # 불필요. 인풋 데이터 A, B, C순 정렬되어 있음... 정렬 필요시 코드 바꾸어야 함
        self.local_target.append([9,4]) # 목적지 리스트에 최종 목적지(9,4) 추가
        self.local_target_original = self.local_target.copy()  # gif 생성을 위해 추가.  에피소드의 경로 저장
        self.target_length = len(self.local_target_original)  # 목적지 그리드값 10, 9, 8, ... 지정 위해 추가
        self.grid[9,4] = 10 + 1 - self.target_length  # 최종 목적지 [9,4] 그리드값 지정 위해 추가

    def set_obstacle(self):  # 장애물 위치 그리드값 설정 = obs_gridval
        obstacles_data = pd.read_csv(os.path.join(local_path, "data/obstacles.csv"))
        for obstacle in obstacles_data.itertuples(index = True, name ='Pandas'):
            self.grid[getattr(obstacle, "row")][getattr(obstacle, "col")] = obs_gridval

    def grid_box(self):  # 그리드 박스 초기화 용도로 정의: 선반, 목적지, 장애물 그리드값 초기화
        box_data = pd.read_csv(os.path.join(local_path, "data/box.csv"))
        for box in box_data.itertuples(index = True, name ='Pandas'):  # 선반 위치: 그리드값 = rack_gridval
            self.grid[getattr(box, "row")][getattr(box, "col")] = rack_gridval
        order_item = list(set(self.inds) & set(self.items))
        order_csv = box_data[box_data['item'].isin(order_item)]
        for i, order_box in enumerate(order_csv.itertuples(index = True, name ='Pandas')):  # 목적지: 그리드값 = target_gridval
            self.grid[getattr(order_box, "row")][getattr(order_box, "col")] = 10 - i
        self.grid[9,4] = 10 + 1 - self.target_length  # 최종 목적지 [9,4] 그리드값 지정 위해 추가
        self.set_obstacle()  # 장애물 위치 그리드값 설정 = obs_gridval
        
    def reset(self, epi):  # 에피소드 시작시 12개 값 초기화
        self.epi = epi                                            #1. 에피소드 번호 받기
        # self.items = list(self.files.iloc[self.epi])[0]           #2. 에피소드의 목적지 받기: [ 'H', 'L', 'M']
        #####################################################################################
        coin = random.randint(0,16)
        self.items = [chr(coin+65)]  # A~Q 까지 1개 랜덤으로 받아서 items에 1개 넣어주기, 반복 횟수는 main의 epochs 조절하기
        ####################################################################################
        self.cumulative_reward = 0                                #3. 누적 보상값 = 0
        self.terminal_location = None                             #4. 최초 목적지
        self.local_target = []                                    #5. 목적지 리스트 초기화
        self.actions = []                                         #6. 지나온 경로 리스트 초기화
        self.grid = np.zeros((self.height, self.width), dtype="float16")  #7. 그리드월드 전체 그리드값(default_gridval) 초기화
        self.set_box()                                            #8. 선반 위치, 목적지 그리드값 설정. 목적지 리스트 생성
        self.set_obstacle()                                       #9. 장애물 그리드값 설정
        ######################
        # print('최초 그리드맵:')  # 그리드맵 확인
        # print(self.grid.reshape(10,9))
        ######################
        self.curloc = [9, 4]                                      #10. 현재 위치를 출발점으로 세팅
        self.grid[int(self.curloc[0])][int(self.curloc[1])] = curloc_gridval  #11. 현재 위치(출발점) 그리드값 세팅
        self.done = False                                         #12. 경로 찾기 종료 여부 = False
        self.goal_ob_reward = False                      # (추가) #13. 최종 목적지 도착 여부 = False
        ######################
        # print('현 위치 추가:')   # 그리드맵 확인
        # print(self.grid.reshape(10,9))
        ######################
        self.move_track = [[9,4]]                                        #14. 이동하는 경로를 저장하는 변수, 에피소드 시작시 에이전트가 [9,4]에 있으므로 [[9,4]]로 초기화
        self.isReset =  False                                       #15. 처음으로 terminal_location == 9,4가 되면, moveTrack을 초기화해주기 위해 필요한 변수 isFinal -> isReset 로 변경(처음으로 불러졌냐 안불러졌냐)
        self.prior_distance = 9999                                  #16. 이전 time step의 거리와 현재 거리를 비교하기 위해서 필요한 변수
        ######################
        return self.grid

    def apply_action(self, action, cur_x, cur_y):  # action에 따른 새 좌표값 반환
        new_x = cur_x
        new_y = cur_y
        if action == 0:          # up
            #new_x = cur_x - 1
            new_x = self.move_up(cur_x, cur_y, new_x, new_y)
        elif action == 1:        # down
            #new_x = cur_x + 1
            new_x = self.move_down(cur_x, cur_y, new_x, new_y)
        elif action == 2:        # left
            #new_y = cur_y - 1
            new_y = self.move_left(cur_x, cur_y, new_x, new_y)
        else:                    # right
            #new_y = cur_y + 1
            new_y = self.move_right(cur_x, cur_y, new_x, new_y)
        return int(new_x), int(new_y)
    
    # >>> 현재 위치에서 이동이 불가한 위치 추가 (시작) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
    def move_up(self, cur_x, cur_y, new_x, new_y):  # action == 0:
        if cur_x in [6,5,4,3,2] and cur_y in [0,8]:
            pass
        else:
            new_x = cur_x - 1
        return new_x
    def move_down(self, cur_x, cur_y, new_x, new_y): # action == 1:
        if cur_x in [1,2,3,4,5] and cur_y in [0,8]:
            pass
        else:
            new_x = cur_x + 1
        return new_x
    def move_left(self, cur_x, cur_y, new_x, new_y): # left elif action == 2:
        if cur_y in [1,2,3,4,5,6,7,8] and cur_x == 0:
            pass
        else:
            new_y = cur_y - 1
        return new_y
    def move_right(self, cur_x, cur_y, new_x, new_y): # right else: action == 3:
        if cur_y in [0,1,2,3,4,5,6,7] and cur_x == 0:
            pass
        else:
            new_y = cur_y + 1
        return new_y
    # >>> 추가 (끝) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

    def get_reward(self, new_x, new_y, out_of_boundary):  # action에 의해 이동시 얻는 보상
        if any(out_of_boundary):                                        # 바깥으로 나가는 경우
            reward = obs_reward
        else:
            if self.grid[new_x][new_y] == obs_gridval :     # 장애물에 부딪히는 경우
                reward = obs_reward
                self.grid[new_x][new_y] = curloc_gridval   # 현 위치(장애물)에서 종료되었음을 표시. 원래는 장애물이었음                
            elif self.grid[new_x][new_y] == rack_gridval:   # 선반에 부딪히는 경우
                reward = obs_reward
                new_x = self.curloc[0]  # 선반인 경우 못들어가고, 현재 위치로 유지
                new_y = self.curloc[1]  # 선반인 경우 못들어가고, 현재 위치로 유지
            elif new_x == self.terminal_location[0] and new_y == self.terminal_location[1]:  # 현재 목적지에 도달한 경우
                reward = goal_reward
            # 그냥 움직이는 경우 
            else: 
                cur_distance = self.get_distance()
                if self.prior_distance > cur_distance :                         # 이전의 거리 > 현재의 거리 = 현재 아이템에 더 가깝다 => + 보상얻기
                    reward = self.get_positive_distance_reward(cur_distance)
                    # print('posi', reward)
                else:                                                           # 이전의 거리 < 현재의 거리 = 현재 아이템에서 멀어졌다 => - 보상얻기
                    reward = self.get_negative_distance_reward(cur_distance)
                    # print('nega', reward)
                self.prior_distance = cur_distance      

                if [new_x, new_y] not in self.move_track:                           # 이동한 곳이 처음온 곳이면 move_track에 추가
                    self.move_track.append([new_x, new_y])
                else:                                                           # 이동한 곳이 이미 왔던 곳이면 기존 보상에서 -1
                    reward = reward -1
        return reward

    def step(self, action):  # action에 따른 이동 실행
        self.terminal_location = self.local_target[0]           # 목적지 리스트의 첫 번째 요소를 목적지로 설정
        cur_x, cur_y = self.curloc                              # 현재 위치 기억
        new_x, new_y = self.apply_action(action, cur_x, cur_y)  # 다음 위치 받기
        self.actions.append((cur_x, cur_y))                     # 현재 위치(지나온 위치)를 경로 리스트에 추가
        self.goal_ob_reward = False                             # 최종 목적지에 도착한 경우에 True. self.reset()에서 초기화
        out_of_boundary = [new_x < 0, new_x >= self.height, new_y < 0, new_y >= self.width]  # 그리드월드 밖으로 나갔는가? OB = True

        if any(out_of_boundary):  #1. 바깥으로 나가는 경우, 빈 선반에 부딪치는 경우 종료하지 않음
            #print('OB')
            new_x = cur_x  # 종료 처리할 경우 코멘트 처리
            new_y = cur_y  # 종료 처리할 경우 코멘트 처리
            ######################################################종료 처리할 경우 실행
            #self.done = True                             # while loop 종료
            #self.grid_box()                              # 선반, 목적지, 장애물 그리드값 초기화
            #self.actions.append((new_x,new_y))           # 경로 리스트에 최종 위치 추가. (주의) 좌표값이 그리드월드를 벗어나는 값 발생!
            ######################################################
        else:
            if self.grid[new_x][new_y] == obs_gridval:  #2. 장애물에 부딪히는 경우 종료
                # print('장애물')
                # new_x = cur_x  # 종료 처리할 경우 코멘트 처리
                # new_y = cur_y  # 종료 처리할 경우 코멘트 처리
                ###################################################종료 처리할 경우 실행
                self.done = True                           # while loop 종료
                self.grid[cur_x][cur_y] = default_gridval  # 현 위치의 그리드값을 기본값으로 초기화
                self.grid_box()                            # 선반, 목적지, 장애물 그리드값 초기화
                self.actions.append((new_x,new_y))         # 경로 리스트에 최종 위치 추가
                ###################################################
            elif self.grid[new_x][new_y] == rack_gridval:
                pass
            elif new_x == self.terminal_location[0] and new_y == self.terminal_location[1]:  #3. 현재 목적지에 도착한 경우 다음 목적지 설정
                #print('목적지 도착')
                if [new_x, new_y] == [9, 4]:            #3-1. 최종 목적지에 도착한 경우 종료
                    self.done = True                       # while loop 종료
                    self.goal_ob_reward = True             # True = 1 (OB, 장애물 종료 처리 할 경우 self.done=True가 많아지므로 이때 사용)
                    self.actions.append((new_x,new_y))     # 경로 리스트에 최종 위치 추가

                self.local_target.remove(self.local_target[0])  # 다음 목적지 설정. 최종 목적지에 도착한 경우에는 마지막 요소인 [9,4]를  제거
                self.grid[cur_x][cur_y] = default_gridval  # 현 위치의 그리드값을 기본값으로 초기화
                self.grid_box()                            # 선반, 목적지, 장애물 그리드값 초기화
                self.grid[new_x][new_y] = curloc_gridval   # 현 위치(목적지)에서 종료되었음을 표시. 원래는 목적지이었음
                self.curloc = [new_x, new_y]               # 새로 도착한 위치를 현재 위치로 변경
            
            else:                                       #4. 그냥 움직이는 경우
                #print('이동')
                self.grid[cur_x][cur_y] = default_gridval  # 현 위치의 그리드값을 기본값으로 초기화
                self.grid_box()                            # 선반, 목적지, 장애물 그리드값 초기화
                self.grid[new_x][new_y] = curloc_gridval   # 현 위치에서 종료되었음을 표시
                self.curloc = [new_x,new_y]

        ############################### 보상받는 처리 시작 ###############################
        # 마지막 위치에서 위로 올라가는 행동을 한다면 - 보상받음 태양
        if self.terminal_location == [9, 4]:
            if not self.isReset:                                    # 처음으로 terminal_location == [9,4]가 되었다면,,
                self.move_track = []                                # 아이템을 찾으러 돌아다니는 경로 초기화
                self.isReset = True                                 # move_track이 초기화 되었으니 isReset = True
            reward = self.get_reward(new_x, new_y, out_of_boundary)
            if action == 0:
                reward = obs_reward                                # 처음위치로 갈 때 위로 올라가는거 금지
        else : 
            reward = self.get_reward(new_x, new_y, out_of_boundary)
        ############################### 보상받는 처리 끝 ###############################   

        self.cumulative_reward += reward
        return self.grid, reward, self.cumulative_reward, self.done

    # >>> distance를 입력으로 받아 + 보상을 계산하는 메소드 (시작) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<< 
    def get_positive_distance_reward(self, distance):
        positive_reward = (20 - distance) / 200     # 0.095 ~ 0.001
        return positive_reward
    # >>> 추가 (끝) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

    # >>> distance를 입력으로 받아 - 보상을 계산하는 메소드 (시작) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
    def get_negative_distance_reward(self, distance):
        negative_reward = -(distance / 200)
        return negative_reward
    # >>> 추가 (끝) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<    

    # >>> 현재 위치에서 타겟까지의 거리를 구하는 메소드 (시작) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
    def get_distance(self): 
        cur_x, cur_y, target_x, target_y = self.get_current_state()
        
        distance = (abs(cur_x-target_x) + abs(cur_y-target_y))
        # print(cur_x, cur_y, target_x, target_y)
        # print('distance : ', distance)
        return distance
    # >>> 추가 (끝) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<    

    # >>> 현재 상황에 대한 정보를 구하는 메소드 (시작) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
    def get_current_state(self):
        # if len(self.local_target) != 0:
        #     state = (self.curloc[0], self.curloc[1], self.local_target[0][0], self.local_target[0][1])
        # else :
        state = (self.curloc[0], self.curloc[1], self.terminal_location[0], self.terminal_location[1])
        return np.array(state) #(cur_x, cur_y, tar_x, tar_y)
    # >>> 추가 (끝) <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Out:
# reward: -1 -10 10

# %% [markdown]
# ## Agent
# - def test_action(self, obs): 추가

# %%
import collections
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

class ReplayBuffer():  # 리플레이 버퍼: 경험 저장소
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit)
    
    def put(self, transition):  # 리플레이 버퍼(메모리)를 경험(transition)으로 채우기
        self.buffer.append(transition)
    
    def sample(self, n):  # memory.sample(batch_size)로 사용
        mini_batch = random.sample(self.buffer, n)  # 미니배치 샘플링
        '''
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []
        for transition in mini_batch:  # 경험의 각 요소들을 각각의 미니배치로 구성
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])
        return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
               torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
               torch.tensor(done_mask_lst)
        '''
        state1_batch = torch.cat([s1 for (s1,a,r,s2,d) in mini_batch])
        action_batch = torch.Tensor([a for (s1,a,r,s2,d) in mini_batch])
        reward_batch = torch.Tensor([r for (s1,a,r,s2,d) in mini_batch])
        state2_batch = torch.cat([s2 for (s1,a,r,s2,d) in mini_batch])
        done_batch = torch.Tensor([d for (s1,a,r,s2,d) in mini_batch])

        return state1_batch, action_batch, reward_batch, state2_batch, done_batch
    
    def size(self):  # 메모리 크기
        return len(self.buffer)

class Qnet(nn.Module):
    '''##### Linear 모델 #####
    def __init__(self):
        super(Qnet, self).__init__()

        in_size = 90  # input 크기
        L1 = 250
        L2 = 150
        out_size  = 4

        self.fc1 = nn.Linear(in_size, L1)
        self.fc2 = nn.Linear(L1, L2)
        self.fc3 = nn.Linear(L2, out_size)

    def forward(self, x):
        x = x.to(device)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
    '''
    ##### Convolution 모델 #####
    def __init__(self):
        super(Qnet, self).__init__()

        self.conv1 = nn.Conv2d(4, 32, 3, 1) #### 1이었던 부분을 4로 변경
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.conv3 = nn.Conv2d(64, 64, 3, 1)
        self.fc1 = nn.Linear(768, 512)
        self.fc2 = nn.Linear(512, 4)

    def forward(self, x):
        x = x.to(device)               # (N, 4, 10, 9)
        x = F.relu(self.conv1(x))      # (N, 32, 8, 7)
        x = F.relu(self.conv2(x))      # (N, 64, 6, 5)
        x = F.relu(self.conv3(x))
        x = torch.flatten(x, 1)        # (N, 64, 30)
        x = F.relu(self.fc1(x))        # (N, 1920) -> (N, 128)
        x = self.fc2(x)                # (N, 128)  -> (N, 4)
        return x

    def sample_action(self, obs, epsilon):  # Qnet()을 실행해서 모든 action에 대한 Qval을 구한 후 action 선택
        out = self.forward(obs)  # out = Q_value, obs = state = 그리드맵
        coin = random.random()  # e-greedy로 action 선택
        if coin < epsilon:
            return random.randint(0,3)
        else : 
            return out.argmax().item()
    
    def test_action(self, obs):  # Qnet()을 실행해서 모든 action에 대한 Qvalue을 구한 후 action 선택
        out = self.forward(obs)  # out = Q_value, obs = state = 그리드맵
        return out.argmax().item()

def train(q, q_target, memory, optimizer):  # 메모리에 경험이 미니배치 크기 이상 쌓이면 미니배치 훈련 시작
    '''
    for i in range(10):
        s, a, r, cr, s_prime, done_mask, gr = memory.sample(batch_size)
        q_out = q(s)
        q_a = q_out.gather(1,a.to(device))
        
        max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1)
        target = r.to(device) + gamma * max_q_prime * done_mask.to(device)
        
        loss = F.smooth_l1_loss(q_a, target)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    '''
    s,a,r,s_prime,done_mask = memory.sample(batch_size)  # 메모리에서 미니배치를 뽑기: batch_size=1600
    Q1 = q(s)  # Qnet의 Qvalue
    X = Q1.gather(dim=1,index=a.long().unsqueeze(dim=1).to(device)).squeeze() # Qnet의 Qvalue 변환
    with torch.no_grad():
        Q2 = q_target(s_prime)
    Y = r.to(device) + gamma * done_mask.to(device) * torch.max(Q2,dim=1)[0]
    loss = F.smooth_l1_loss(X, Y.detach())
    #loss = nn.MSELoss(X.to(torch.float32), Y.detach().to(torch.float32))  # 손실함수 변경. target.detach()로 변경
    optimizer.zero_grad()  # gradient값 초기화
    loss.backward()  # 자동미분
    optimizer.step()  # gradient 업데이트
    return loss.item()

# %% [markdown]
# ## Main: DQN...
#   - GPU를 사용할 경우 구현
#   - 학습한 모델 불러올 수 있는 코드 추가
#     - '#' 제거하고 실행시키면 됨

# %%
# #def main(): # DQN... Total Path 학습 모델

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # GPU를 사용할 경우 ???
# print('tensor in', device)  # GPU 사용 확인
# PATH = __file__ + '/model_conv_colab_epsilon_v3_buffer_1000000.pt' ## PATH 경로 쉽게 수정
# ##############################################
# tz = pytz.timezone('Asia/Seoul')
# cur_time = datetime.now(tz)
# start_time = cur_time.strftime("%H:%M:%S")

# ### 중요 Hyperparameters #####################
# buffer_limit  = 1000000     #1. 100000
# batch_size    = 2000        #2. 200
# learning_rate = 0.00025    #3. 0.0005
# sync_freq = 500            #4. q 네트워크 파라미터를 q_target 네트워크에 복사하는 주기
# train_start = 50000   # (추가)
# ##############################################
# env = Simulator()  # 데이터셋 읽기. 그리드월드 크기 지정
# q = Qnet()
# q.to(device)
# optimizer = optim.Adam(q.parameters(), lr=learning_rate)

# train_model_load = False  # 학습한 모델을 불러와서 계속 학습시키고자 하는 경우 True로 바꾼다!!
# if train_model_load:
#     ###############################################################
#     ## 학습한 모델 불러오기
#     ###############################################################
#     checkpoint = torch.load(PATH)
#     q.load_state_dict(checkpoint['model_state_dict'])
#     optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
#     epoch = checkpoint['epoch']
#     loss = checkpoint['loss']
#     q.train()
# ###############################################################
# q_target = Qnet()
# q_target.to(device)
# q_target.load_state_dict(q.state_dict())
# memory = ReplayBuffer()

# ### Hyperparameters #####################
# gamma = 0.99             #5. 0.98
# ####################################################################
# # epochs = len(env.files)  #6. 훈련용 데이터 갯수
# epochs = 80000  # 한 군데 갔다 오는 경우에 사용. 반복 횟수는 각자 지정
# ####################################################################
# losses = []
# cum_rewards =[]
# moves = []
# max_moves = 100          #7.
# print_interval = 5000    #8.
# j = 0
# goal_ob_reward_count = 0 #9. epoch를 반복하면서 finish 카운팅
# # epsilon = 0.3            #10. annealing 대신 고정
# loss = 0.0
# ##############################################
# # __file__ = '/content/drive/MyDrive/aiffelthon/data' 
# ### 액션 저장하는 txt파일 만들기 #######################
# f = open(__file__ + '/ogz_conv_epsilon_v3_buffer_1000000_gif' + '.txt', 'w')
# ########################################################

# for n_epi in range(epochs):
#     # n_epi = n_epi % 39999
#     epsilon = max(0.05, 1.00 - 0.1*(n_epi/2000)) # Linear annealing from 100% to 5%
#     gridmap = env.reset(n_epi)  # 에피소드 시작시 12개 값 초기화
#         # self.epi = epi                                            #1. 에피소드 번호 받기
#         # self.items = list(self.files.iloc[self.epi])[0]           #2. 에피소드의 목적지 받기: [ 'H', 'L', 'M']
#         # self.cumulative_reward = 0                                #3. 누적 보상값 = 0
#         # self.terminal_location = None                             #4. 최초 목적지
#         # self.local_target = []                                    #5. 목적지 리스트 초기화
#         # self.actions = []                                         #6. 지나온 경로 리스트 초기화
#         # self.grid = np.ones((self.height, self.width), dtype="float16")  #7. 그리드월드 전체 그리드값(1)로 초기화
#         # self.set_box()                                            #8. 선반 위치(0), 목적지(2) 그리드값 설정.  목적지 리스트 생성
#         # self.set_obstacle()                                       #9. 장애물 그리드값(0) 설정
#         # self.curloc = [9, 4]                                      #10. 현재 위치를 출발점으로 세팅
#         # self.grid[int(self.curloc[0])][int(self.curloc[1])] = -1  #11. 현재 위치(출발점) 그리드값(-1) 세팅
#         # self.done = False                                         #12. 경로 찾기 종료 여부 = False
#         # return self.grid

#     # 초기 input은 (시작화면*4장)으로 들어감
#     #####################################################################################
#     history1 = np.stack((gridmap,gridmap,gridmap,gridmap), axis = 0) # 초기 state로 히스토리 초기화 (4,10,9)
#     history1 = np.reshape([history1], (1,4,10,9)) # (배치, 채널, 가로, 세로) 로 reshape
#     history1 = torch.from_numpy(history1).float() # 텐서로 변환   
#     #####################################################################################

#     done = False
#     mov = 0

#     while (not done):  # 최종 목적지 [9,4] 도착 또는 max_moves (=350) 초과하면 종료
#         j += 1
#         mov += 1
#         # 상태 state1에서 action 결정
#         #####################################################################################
#         if env.curloc == [9,4]:  # 출발점에서는 무조건 위로 올라간다 (action=0)
#             action = 0
#         elif env.curloc[0] == 0 and env.curloc[1] in [0,1,2,3,4,5,6,7,8]:  # (0,0)~(0,8)에서는 무조건 아래로
#             action = 1
#         elif env.curloc[0] in [2,3,4,5] and env.curloc[1] == 8:  # (2,8)~(5,8)에서는 무조건 왼쪽으로
#             action = 2
#         elif env.curloc[0] in [2,3,4,5] and env.curloc[1] == 0:  # (2,0)~(5,0)에서는 무조건 오른쪽으로
#             action = 3
#         else:  # 위 경우를 제외하곤 e-greedy로 액션 선택
#             action = q.sample_action(history1, epsilon)
#         #####################################################################################
#         # action = q.sample_action(state1, epsilon)  # 위 조건을 적용 안 할 경우
#         # make Move... action에 따른 이동
#         gridmap, reward, cum_reward, done = env.step(action)
#             # self.actions.append((new_x, new_y))...새로 도착한 위치를 경로 리스트에 추가
#             # 누적 보상 계산
#         ###########################
#         # print(gridmap.reshape(10,9))
#         ###########################

#         #####################################################################################
#         # next input 만들어주기
#         next_gridmap = np.reshape([gridmap],(1,1,10,9))                                             # 다음 그리드를 히스토리 사이즈에 맞게 reshape
#         next_gridmap = torch.from_numpy(next_gridmap).float()                                       # 텐서로 변환
#         history2 = torch.cat([next_gridmap,history1[:,:3,:,:]],dim=1) # (1,1+3,10,9)                # 지금 있는 히스토리중 마지막 채널을 지우고 new를 제일 앞에 붙임

#         done_mask = 0.0 if done else 1.0
#         memory.put((history1, action, reward, history2, done_mask))  # 경험을 메모리에 저장
#         history1 = history2
#         #####################################################################################

#         # if memory.size() > train_start:  # 메모리에 train_start 크기 이상 쌓이면... 미니배치 훈련
#         if j > train_start:  # 메모리에 미니배치 크기 이상 쌓이면... 미니배치 훈련
#             #print('memory size:', memory.size())
#             loss = train(q, q_target, memory, optimizer)
#             if j % print_interval == 0:
#                 print('epiode #:', n_epi, 'loss:', loss, 'j:', j)
#             losses.append(loss)
#             cum_rewards.append(cum_reward)
#             moves.append(mov)
            

#             if j % sync_freq == 0:  # sync_freq마다 q 네트워크 파라미터를 q_target 네트워크로 복사
#                 q_target.load_state_dict(q.state_dict())

#         ############## 현황 모니터링 #############################################################
#         # if done and j % 100 == 0:  # 100번 마다 mov 횟수 저장:
#         #     moves.append(mov)
#             # print('종료: done =', done, '... j =', j, ' move =', mov)
#         if env.goal_ob_reward:  # 최종 목적지 도달한 경우에만 화면에 표시
#             goal_ob_reward_count += 1
#             print(env.items, '종료: env.goal_ob_reward =', env.goal_ob_reward, '... j =', j, ' move =', mov, '@ 에피소드 #', n_epi)
#             print(f"{n_epi}번째 에피소드까지 총 {goal_ob_reward_count}번 finish 했습니다.")
#             ### finish record 저장하는 txt파일 만들기
#             with open(__file__ + '/epsilon_v3_train.txt', 'a') as finish_record:
#                 finish_record.write(str(goal_ob_reward_count)+" "+str(env.items)+" "+str(cum_reward)+" "+\
#                                     str(mov)+" "+str(j)+" "+str(n_epi)+"\n")
#         ##########################################################################################

#         if done or mov > max_moves:
#             mov = 0
#             done = True
    
#     # while loop 종료 ----- 최종 목적지 [9,4] 도착 또는 max_moves (=350) 초과

#     if j > train_start:  # 메모리에 train_start 크기 이상 쌓이면... 미니배치 훈련
#         if (n_epi % 10000 == 0 and n_epi != 0) or n_epi >= epochs - 1:
#             torch.save({'epoch': n_epi, 
#                         'model_state_dict': q.state_dict(), 
#                         'optimizer_state_dict': optimizer.state_dict(), 
#                         'loss': loss, 
#                         }, PATH)
#             print('▶ 모델 저장됨!!! @ 에피소드', n_epi)

#         ##### gif 생성을 위한 경로(env.actions) 저장 ####################################    
#         if n_epi % 1000 == 0 or env.goal_ob_reward:
#             f.write(str(n_epi)+'/'+str(env.local_target_original)+'\n')
#             f.write(str(env.actions))
#             f.write('\n')
#         ######################################### 
# f.close()
# #########################################
# ## 프로그램 시작 및 종료 시간 출력
# cur_time = datetime.now(tz)
# end_time = cur_time.strftime("%H:%M:%S")
# print ('실행 종료!', 'Start@', start_time, 'End@', end_time)
#         #cur_time = datetime.now(tz)
#         #simple_cur_time = cur_time.strftime("%H:%M:%S")
#         #print('▶ Episode #', iter, 'start time:', simple_cur_time, end='→')

# print(gridmap.reshape(10,9))  # 최종 그리드맵 확인

# ## loss 그래프
# plt.figure(figsize=(10,7))
# plt.plot(losses)
# plt.xlabel("# of Actions (j)",fontsize=22)
# plt.ylabel("Loss",fontsize=22)

# ## 경로길이(이동 횟수) 그래프
# plt.figure(figsize=(10,7))
# plt.plot(moves)
# plt.xlabel("# of Actions (j)",fontsize=22)
# plt.ylabel("Moves",fontsize=22)

# ## 보상값(cum_rewards) 그래프
# plt.figure(figsize=(10,7))
# plt.plot(cum_rewards)
# plt.xlabel("# of Actions (j)",fontsize=22)
# plt.ylabel("Cumulative Rewards",fontsize=22)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 875653  move = 16 @ 에피소드 # 38916
# 38916번째 에피소드까지 총 15115번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 875679  move = 26 @ 에피소드 # 38917
# 38917번째 에피소드까지 총 15116번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 875697  move = 18 @ 에피소드 # 38918
# 38918번째 에피소드까지 총 15117번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 875820  move = 22 @ 에피소드 # 38920
# 38920번째 에피소드까지 총 15118번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 875844  move = 24 @ 에피소드 # 38921
# 38921번째 에피소드까지 총 15119번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 875870  move = 26 @ 에피소드 # 38922
# 38922번째 에피소드까지 총 15120번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 875903  move = 26 @ 에피소드 # 38924
# 38924번째 에피소드까지 총 15121번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 875981  move = 28 @ 에피소드 # 38928
# 38928번째 에피소드까지 총 15122번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 876001  move = 20 @ 에피소드 # 38929
# 38929번째 에피소드까지 총 15123번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 876025  move = 24 @ 에피소드 # 38930
# 38930번째 에피소드까지 총 15124번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 876045  move = 20 @ 에피소드 # 38931
# 38931번째 에피소드까지 총 15125번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 876071  move = 26 @ 에피소드 # 38932
# 38932번째 에피소드까지 총 15126번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 876131  move = 60 @ 에피소드 # 38933
# 38933번째 에피소드까지 총 15127번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 876172  move = 24 @ 에피소드 # 38935
# 38935번째 에피소드까지 총 15128번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 876190  move = 18 @ 에피소드 # 38936
# 38936번째 에피소드까지 총 15129번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 876210  move = 20 @ 에피소드 # 38937
# 38937번째 에피소드까지 총 15130번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 876244  move = 34 @ 에피소드 # 38938
# 38938번째 에피소드까지 총 15131번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 876266  move = 22 @ 에피소드 # 38939
# 38939번째 에피소드까지 총 15132번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 876294  move = 28 @ 에피소드 # 38940
# 38940번째 에피소드까지 총 15133번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 876346  move = 52 @ 에피소드 # 38941
# 38941번째 에피소드까지 총 15134번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 876404  move = 58 @ 에피소드 # 38942
# 38942번째 에피소드까지 총 15135번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 876446  move = 42 @ 에피소드 # 38943
# 38943번째 에피소드까지 총 15136번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 876496  move = 20 @ 에피소드 # 38945
# 38945번째 에피소드까지 총 15137번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 876522  move = 26 @ 에피소드 # 38946
# 38946번째 에피소드까지 총 15138번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 876548  move = 26 @ 에피소드 # 38947
# 38947번째 에피소드까지 총 15139번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 876614  move = 42 @ 에피소드 # 38949
# 38949번째 에피소드까지 총 15140번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 876672  move = 58 @ 에피소드 # 38950
# 38950번째 에피소드까지 총 15141번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 876690  move = 18 @ 에피소드 # 38951
# 38951번째 에피소드까지 총 15142번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 876718  move = 28 @ 에피소드 # 38952
# 38952번째 에피소드까지 총 15143번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 876748  move = 30 @ 에피소드 # 38953
# 38953번째 에피소드까지 총 15144번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 876789  move = 36 @ 에피소드 # 38955
# 38955번째 에피소드까지 총 15145번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 876811  move = 22 @ 에피소드 # 38956
# 38956번째 에피소드까지 총 15146번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 876837  move = 26 @ 에피소드 # 38957
# 38957번째 에피소드까지 총 15147번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 876883  move = 46 @ 에피소드 # 38958
# 38958번째 에피소드까지 총 15148번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 876903  move = 20 @ 에피소드 # 38959
# 38959번째 에피소드까지 총 15149번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 876932  move = 29 @ 에피소드 # 38960
# 38960번째 에피소드까지 총 15150번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 876960  move = 28 @ 에피소드 # 38961
# 38961번째 에피소드까지 총 15151번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 876986  move = 26 @ 에피소드 # 38962
# 38962번째 에피소드까지 총 15152번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 877098  move = 26 @ 에피소드 # 38965
# 38965번째 에피소드까지 총 15153번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 877152  move = 54 @ 에피소드 # 38966
# 38966번째 에피소드까지 총 15154번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 877181  move = 29 @ 에피소드 # 38967
# 38967번째 에피소드까지 총 15155번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 877205  move = 24 @ 에피소드 # 38968
# 38968번째 에피소드까지 총 15156번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 877261  move = 56 @ 에피소드 # 38969
# 38969번째 에피소드까지 총 15157번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 877313  move = 52 @ 에피소드 # 38970
# 38970번째 에피소드까지 총 15158번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 877365  move = 28 @ 에피소드 # 38972
# 38972번째 에피소드까지 총 15159번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 877426  move = 35 @ 에피소드 # 38974
# 38974번째 에피소드까지 총 15160번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 877465  move = 31 @ 에피소드 # 38976
# 38976번째 에피소드까지 총 15161번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 877487  move = 22 @ 에피소드 # 38977
# 38977번째 에피소드까지 총 15162번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 877505  move = 18 @ 에피소드 # 38978
# 38978번째 에피소드까지 총 15163번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 877527  move = 22 @ 에피소드 # 38979
# 38979번째 에피소드까지 총 15164번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 877551  move = 24 @ 에피소드 # 38980
# 38980번째 에피소드까지 총 15165번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 877569  move = 18 @ 에피소드 # 38981
# 38981번째 에피소드까지 총 15166번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 877585  move = 16 @ 에피소드 # 38982
# 38982번째 에피소드까지 총 15167번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 877613  move = 28 @ 에피소드 # 38983
# 38983번째 에피소드까지 총 15168번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 877631  move = 18 @ 에피소드 # 38984
# 38984번째 에피소드까지 총 15169번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 877655  move = 24 @ 에피소드 # 38985
# 38985번째 에피소드까지 총 15170번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 877681  move = 26 @ 에피소드 # 38986
# 38986번째 에피소드까지 총 15171번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 877784  move = 100 @ 에피소드 # 38988
# 38988번째 에피소드까지 총 15172번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 877919  move = 34 @ 에피소드 # 38990
# 38990번째 에피소드까지 총 15173번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 878038  move = 18 @ 에피소드 # 38992
# 38992번째 에피소드까지 총 15174번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 878067  move = 29 @ 에피소드 # 38993
# 38993번째 에피소드까지 총 15175번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 878087  move = 20 @ 에피소드 # 38994
# 38994번째 에피소드까지 총 15176번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 878112  move = 25 @ 에피소드 # 38995
# 38995번째 에피소드까지 총 15177번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 878130  move = 18 @ 에피소드 # 38996
# 38996번째 에피소드까지 총 15178번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 878154  move = 24 @ 에피소드 # 38997
# 38997번째 에피소드까지 총 15179번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 878186  move = 32 @ 에피소드 # 38998
# 38998번째 에피소드까지 총 15180번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 878217  move = 31 @ 에피소드 # 38999
# 38999번째 에피소드까지 총 15181번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 878237  move = 20 @ 에피소드 # 39000
# 39000번째 에피소드까지 총 15182번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 878265  move = 28 @ 에피소드 # 39001
# 39001번째 에피소드까지 총 15183번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 878293  move = 28 @ 에피소드 # 39002
# 39002번째 에피소드까지 총 15184번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 878317  move = 24 @ 에피소드 # 39003
# 39003번째 에피소드까지 총 15185번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 878343  move = 26 @ 에피소드 # 39004
# 39004번째 에피소드까지 총 15186번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 878414  move = 24 @ 에피소드 # 39007
# 39007번째 에피소드까지 총 15187번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 878446  move = 32 @ 에피소드 # 39008
# 39008번째 에피소드까지 총 15188번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 878462  move = 16 @ 에피소드 # 39009
# 39009번째 에피소드까지 총 15189번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 878535  move = 22 @ 에피소드 # 39012
# 39012번째 에피소드까지 총 15190번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 878563  move = 28 @ 에피소드 # 39013
# 39013번째 에피소드까지 총 15191번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 878591  move = 28 @ 에피소드 # 39014
# 39014번째 에피소드까지 총 15192번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 878712  move = 20 @ 에피소드 # 39016
# 39016번째 에피소드까지 총 15193번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 878738  move = 26 @ 에피소드 # 39017
# 39017번째 에피소드까지 총 15194번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 878762  move = 24 @ 에피소드 # 39018
# 39018번째 에피소드까지 총 15195번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 878813  move = 51 @ 에피소드 # 39019
# 39019번째 에피소드까지 총 15196번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 878837  move = 24 @ 에피소드 # 39020
# 39020번째 에피소드까지 총 15197번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 878866  move = 29 @ 에피소드 # 39021
# 39021번째 에피소드까지 총 15198번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 878918  move = 52 @ 에피소드 # 39022
# 39022번째 에피소드까지 총 15199번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 878944  move = 26 @ 에피소드 # 39023
# 39023번째 에피소드까지 총 15200번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 879205  move = 24 @ 에피소드 # 39030
# 39030번째 에피소드까지 총 15201번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 879236  move = 31 @ 에피소드 # 39031
# 39031번째 에피소드까지 총 15202번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 879266  move = 30 @ 에피소드 # 39032
# 39032번째 에피소드까지 총 15203번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 879318  move = 52 @ 에피소드 # 39033
# 39033번째 에피소드까지 총 15204번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 879369  move = 32 @ 에피소드 # 39035
# 39035번째 에피소드까지 총 15205번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 879391  move = 22 @ 에피소드 # 39036
# 39036번째 에피소드까지 총 15206번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 879407  move = 16 @ 에피소드 # 39037
# 39037번째 에피소드까지 총 15207번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 879466  move = 24 @ 에피소드 # 39041
# 39041번째 에피소드까지 총 15208번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 879511  move = 30 @ 에피소드 # 39043
# 39043번째 에피소드까지 총 15209번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 879541  move = 30 @ 에피소드 # 39044
# 39044번째 에피소드까지 총 15210번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 879581  move = 18 @ 에피소드 # 39046
# 39046번째 에피소드까지 총 15211번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 879625  move = 16 @ 에피소드 # 39048
# 39048번째 에피소드까지 총 15212번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 879653  move = 28 @ 에피소드 # 39049
# 39049번째 에피소드까지 총 15213번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 879675  move = 22 @ 에피소드 # 39050
# 39050번째 에피소드까지 총 15214번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 879699  move = 24 @ 에피소드 # 39051
# 39051번째 에피소드까지 총 15215번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 879743  move = 22 @ 에피소드 # 39053
# 39053번째 에피소드까지 총 15216번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 879761  move = 18 @ 에피소드 # 39054
# 39054번째 에피소드까지 총 15217번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 879812  move = 48 @ 에피소드 # 39056
# 39056번째 에피소드까지 총 15218번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 879832  move = 20 @ 에피소드 # 39057
# 39057번째 에피소드까지 총 15219번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 879858  move = 26 @ 에피소드 # 39058
# 39058번째 에피소드까지 총 15220번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 879882  move = 24 @ 에피소드 # 39059
# 39059번째 에피소드까지 총 15221번 finish 했습니다.
# epiode #: 39061 loss: 0.495069295167923 j: 880000
# ['H'] 종료: env.goal_ob_reward = True ... j = 880096  move = 27 @ 에피소드 # 39062
# 39062번째 에피소드까지 총 15222번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 880124  move = 28 @ 에피소드 # 39063
# 39063번째 에피소드까지 총 15223번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 880251  move = 26 @ 에피소드 # 39065
# 39065번째 에피소드까지 총 15224번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 880341  move = 28 @ 에피소드 # 39068
# 39068번째 에피소드까지 총 15225번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 880361  move = 20 @ 에피소드 # 39069
# 39069번째 에피소드까지 총 15226번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 880383  move = 22 @ 에피소드 # 39070
# 39070번째 에피소드까지 총 15227번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 880403  move = 20 @ 에피소드 # 39071
# 39071번째 에피소드까지 총 15228번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 880429  move = 26 @ 에피소드 # 39072
# 39072번째 에피소드까지 총 15229번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 880464  move = 26 @ 에피소드 # 39074
# 39074번째 에피소드까지 총 15230번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 880482  move = 18 @ 에피소드 # 39075
# 39075번째 에피소드까지 총 15231번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 880508  move = 26 @ 에피소드 # 39076
# 39076번째 에피소드까지 총 15232번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 880524  move = 16 @ 에피소드 # 39077
# 39077번째 에피소드까지 총 15233번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 880582  move = 24 @ 에피소드 # 39081
# 39081번째 에피소드까지 총 15234번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 880598  move = 16 @ 에피소드 # 39082
# 39082번째 에피소드까지 총 15235번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 880624  move = 26 @ 에피소드 # 39083
# 39083번째 에피소드까지 총 15236번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 880651  move = 27 @ 에피소드 # 39084
# 39084번째 에피소드까지 총 15237번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 880675  move = 24 @ 에피소드 # 39085
# 39085번째 에피소드까지 총 15238번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 880719  move = 44 @ 에피소드 # 39086
# 39086번째 에피소드까지 총 15239번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 880745  move = 26 @ 에피소드 # 39087
# 39087번째 에피소드까지 총 15240번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 880777  move = 32 @ 에피소드 # 39088
# 39088번째 에피소드까지 총 15241번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 880797  move = 20 @ 에피소드 # 39089
# 39089번째 에피소드까지 총 15242번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 880813  move = 16 @ 에피소드 # 39090
# 39090번째 에피소드까지 총 15243번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 880840  move = 27 @ 에피소드 # 39091
# 39091번째 에피소드까지 총 15244번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 880872  move = 32 @ 에피소드 # 39092
# 39092번째 에피소드까지 총 15245번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 880900  move = 28 @ 에피소드 # 39093
# 39093번째 에피소드까지 총 15246번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 880947  move = 47 @ 에피소드 # 39094
# 39094번째 에피소드까지 총 15247번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 880965  move = 18 @ 에피소드 # 39095
# 39095번째 에피소드까지 총 15248번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 880981  move = 16 @ 에피소드 # 39096
# 39096번째 에피소드까지 총 15249번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 881011  move = 30 @ 에피소드 # 39097
# 39097번째 에피소드까지 총 15250번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 881029  move = 18 @ 에피소드 # 39098
# 39098번째 에피소드까지 총 15251번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 881053  move = 24 @ 에피소드 # 39099
# 39099번째 에피소드까지 총 15252번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 881098  move = 34 @ 에피소드 # 39102
# 39102번째 에피소드까지 총 15253번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 881124  move = 26 @ 에피소드 # 39103
# 39103번째 에피소드까지 총 15254번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 881144  move = 20 @ 에피소드 # 39104
# 39104번째 에피소드까지 총 15255번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 881168  move = 24 @ 에피소드 # 39105
# 39105번째 에피소드까지 총 15256번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 881193  move = 25 @ 에피소드 # 39106
# 39106번째 에피소드까지 총 15257번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 881213  move = 20 @ 에피소드 # 39107
# 39107번째 에피소드까지 총 15258번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 881238  move = 25 @ 에피소드 # 39108
# 39108번째 에피소드까지 총 15259번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 881295  move = 26 @ 에피소드 # 39111
# 39111번째 에피소드까지 총 15260번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 881315  move = 20 @ 에피소드 # 39112
# 39112번째 에피소드까지 총 15261번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 881341  move = 26 @ 에피소드 # 39113
# 39113번째 에피소드까지 총 15262번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 881377  move = 18 @ 에피소드 # 39115
# 39115번째 에피소드까지 총 15263번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 881405  move = 28 @ 에피소드 # 39116
# 39116번째 에피소드까지 총 15264번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 881511  move = 26 @ 에피소드 # 39119
# 39119번째 에피소드까지 총 15265번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 881537  move = 26 @ 에피소드 # 39120
# 39120번째 에피소드까지 총 15266번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 881571  move = 34 @ 에피소드 # 39121
# 39121번째 에피소드까지 총 15267번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 881595  move = 24 @ 에피소드 # 39122
# 39122번째 에피소드까지 총 15268번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 881627  move = 24 @ 에피소드 # 39124
# 39124번째 에피소드까지 총 15269번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 881645  move = 18 @ 에피소드 # 39125
# 39125번째 에피소드까지 총 15270번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 881663  move = 18 @ 에피소드 # 39126
# 39126번째 에피소드까지 총 15271번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 881687  move = 24 @ 에피소드 # 39127
# 39127번째 에피소드까지 총 15272번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 881709  move = 22 @ 에피소드 # 39128
# 39128번째 에피소드까지 총 15273번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 881735  move = 26 @ 에피소드 # 39129
# 39129번째 에피소드까지 총 15274번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 881759  move = 24 @ 에피소드 # 39130
# 39130번째 에피소드까지 총 15275번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 881792  move = 33 @ 에피소드 # 39131
# 39131번째 에피소드까지 총 15276번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 881820  move = 28 @ 에피소드 # 39132
# 39132번째 에피소드까지 총 15277번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 881844  move = 24 @ 에피소드 # 39133
# 39133번째 에피소드까지 총 15278번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 881860  move = 16 @ 에피소드 # 39134
# 39134번째 에피소드까지 총 15279번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 881884  move = 24 @ 에피소드 # 39135
# 39135번째 에피소드까지 총 15280번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 881906  move = 22 @ 에피소드 # 39136
# 39136번째 에피소드까지 총 15281번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 881931  move = 25 @ 에피소드 # 39137
# 39137번째 에피소드까지 총 15282번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 881957  move = 26 @ 에피소드 # 39138
# 39138번째 에피소드까지 총 15283번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 881979  move = 22 @ 에피소드 # 39139
# 39139번째 에피소드까지 총 15284번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 882007  move = 28 @ 에피소드 # 39140
# 39140번째 에피소드까지 총 15285번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 882032  move = 25 @ 에피소드 # 39141
# 39141번째 에피소드까지 총 15286번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 882059  move = 27 @ 에피소드 # 39142
# 39142번째 에피소드까지 총 15287번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 882091  move = 25 @ 에피소드 # 39144
# 39144번째 에피소드까지 총 15288번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 882116  move = 20 @ 에피소드 # 39146
# 39146번째 에피소드까지 총 15289번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 882142  move = 26 @ 에피소드 # 39147
# 39147번째 에피소드까지 총 15290번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 882168  move = 26 @ 에피소드 # 39148
# 39148번째 에피소드까지 총 15291번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 882231  move = 42 @ 에피소드 # 39150
# 39150번째 에피소드까지 총 15292번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 882263  move = 32 @ 에피소드 # 39151
# 39151번째 에피소드까지 총 15293번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 882290  move = 27 @ 에피소드 # 39152
# 39152번째 에피소드까지 총 15294번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 882565  move = 64 @ 에피소드 # 39156
# 39156번째 에피소드까지 총 15295번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 882597  move = 32 @ 에피소드 # 39157
# 39157번째 에피소드까지 총 15296번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 882621  move = 24 @ 에피소드 # 39158
# 39158번째 에피소드까지 총 15297번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 882645  move = 24 @ 에피소드 # 39159
# 39159번째 에피소드까지 총 15298번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 882723  move = 62 @ 에피소드 # 39161
# 39161번째 에피소드까지 총 15299번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 882741  move = 18 @ 에피소드 # 39162
# 39162번째 에피소드까지 총 15300번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 882761  move = 20 @ 에피소드 # 39163
# 39163번째 에피소드까지 총 15301번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 882791  move = 30 @ 에피소드 # 39164
# 39164번째 에피소드까지 총 15302번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 882827  move = 29 @ 에피소드 # 39166
# 39166번째 에피소드까지 총 15303번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 882857  move = 30 @ 에피소드 # 39167
# 39167번째 에피소드까지 총 15304번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 882883  move = 26 @ 에피소드 # 39168
# 39168번째 에피소드까지 총 15305번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 882931  move = 28 @ 에피소드 # 39170
# 39170번째 에피소드까지 총 15306번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 882953  move = 22 @ 에피소드 # 39171
# 39171번째 에피소드까지 총 15307번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 882983  move = 30 @ 에피소드 # 39172
# 39172번째 에피소드까지 총 15308번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 883005  move = 22 @ 에피소드 # 39173
# 39173번째 에피소드까지 총 15309번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 883031  move = 26 @ 에피소드 # 39174
# 39174번째 에피소드까지 총 15310번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 883055  move = 24 @ 에피소드 # 39175
# 39175번째 에피소드까지 총 15311번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 883124  move = 51 @ 에피소드 # 39177
# 39177번째 에피소드까지 총 15312번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 883148  move = 24 @ 에피소드 # 39178
# 39178번째 에피소드까지 총 15313번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 883168  move = 20 @ 에피소드 # 39179
# 39179번째 에피소드까지 총 15314번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 883186  move = 18 @ 에피소드 # 39180
# 39180번째 에피소드까지 총 15315번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 883212  move = 26 @ 에피소드 # 39181
# 39181번째 에피소드까지 총 15316번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 883261  move = 26 @ 에피소드 # 39183
# 39183번째 에피소드까지 총 15317번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 883290  move = 29 @ 에피소드 # 39184
# 39184번째 에피소드까지 총 15318번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 883306  move = 16 @ 에피소드 # 39185
# 39185번째 에피소드까지 총 15319번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 883436  move = 26 @ 에피소드 # 39188
# 39188번째 에피소드까지 총 15320번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 883456  move = 20 @ 에피소드 # 39189
# 39189번째 에피소드까지 총 15321번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 883480  move = 24 @ 에피소드 # 39190
# 39190번째 에피소드까지 총 15322번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 883504  move = 24 @ 에피소드 # 39191
# 39191번째 에피소드까지 총 15323번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 883628  move = 23 @ 에피소드 # 39193
# 39193번째 에피소드까지 총 15324번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 883652  move = 24 @ 에피소드 # 39194
# 39194번째 에피소드까지 총 15325번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 883715  move = 34 @ 에피소드 # 39196
# 39196번째 에피소드까지 총 15326번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 883738  move = 23 @ 에피소드 # 39197
# 39197번째 에피소드까지 총 15327번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 883791  move = 28 @ 에피소드 # 39199
# 39199번째 에피소드까지 총 15328번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 883809  move = 18 @ 에피소드 # 39200
# 39200번째 에피소드까지 총 15329번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 883836  move = 27 @ 에피소드 # 39201
# 39201번째 에피소드까지 총 15330번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 883883  move = 20 @ 에피소드 # 39203
# 39203번째 에피소드까지 총 15331번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 883909  move = 26 @ 에피소드 # 39204
# 39204번째 에피소드까지 총 15332번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 883937  move = 28 @ 에피소드 # 39205
# 39205번째 에피소드까지 총 15333번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 883955  move = 18 @ 에피소드 # 39206
# 39206번째 에피소드까지 총 15334번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 883971  move = 16 @ 에피소드 # 39207
# 39207번째 에피소드까지 총 15335번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 883987  move = 16 @ 에피소드 # 39208
# 39208번째 에피소드까지 총 15336번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 884027  move = 18 @ 에피소드 # 39210
# 39210번째 에피소드까지 총 15337번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 884122  move = 61 @ 에피소드 # 39212
# 39212번째 에피소드까지 총 15338번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 884148  move = 26 @ 에피소드 # 39213
# 39213번째 에피소드까지 총 15339번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 884170  move = 22 @ 에피소드 # 39214
# 39214번째 에피소드까지 총 15340번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 884198  move = 28 @ 에피소드 # 39215
# 39215번째 에피소드까지 총 15341번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 884305  move = 28 @ 에피소드 # 39218
# 39218번째 에피소드까지 총 15342번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 884331  move = 26 @ 에피소드 # 39219
# 39219번째 에피소드까지 총 15343번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 884355  move = 24 @ 에피소드 # 39220
# 39220번째 에피소드까지 총 15344번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 884385  move = 24 @ 에피소드 # 39222
# 39222번째 에피소드까지 총 15345번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 884426  move = 28 @ 에피소드 # 39224
# 39224번째 에피소드까지 총 15346번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 884454  move = 28 @ 에피소드 # 39225
# 39225번째 에피소드까지 총 15347번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 884501  move = 47 @ 에피소드 # 39226
# 39226번째 에피소드까지 총 15348번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 884527  move = 26 @ 에피소드 # 39227
# 39227번째 에피소드까지 총 15349번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 884551  move = 24 @ 에피소드 # 39228
# 39228번째 에피소드까지 총 15350번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 884571  move = 20 @ 에피소드 # 39229
# 39229번째 에피소드까지 총 15351번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 884591  move = 20 @ 에피소드 # 39230
# 39230번째 에피소드까지 총 15352번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 884615  move = 24 @ 에피소드 # 39231
# 39231번째 에피소드까지 총 15353번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 884640  move = 25 @ 에피소드 # 39232
# 39232번째 에피소드까지 총 15354번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 884658  move = 18 @ 에피소드 # 39233
# 39233번째 에피소드까지 총 15355번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 884689  move = 24 @ 에피소드 # 39235
# 39235번째 에피소드까지 총 15356번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 884714  move = 18 @ 에피소드 # 39237
# 39237번째 에피소드까지 총 15357번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 884744  move = 24 @ 에피소드 # 39239
# 39239번째 에피소드까지 총 15358번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 884797  move = 28 @ 에피소드 # 39241
# 39241번째 에피소드까지 총 15359번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 884819  move = 22 @ 에피소드 # 39242
# 39242번째 에피소드까지 총 15360번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 884843  move = 24 @ 에피소드 # 39243
# 39243번째 에피소드까지 총 15361번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 884880  move = 37 @ 에피소드 # 39244
# 39244번째 에피소드까지 총 15362번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 884906  move = 26 @ 에피소드 # 39245
# 39245번째 에피소드까지 총 15363번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 884924  move = 18 @ 에피소드 # 39246
# 39246번째 에피소드까지 총 15364번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 884967  move = 18 @ 에피소드 # 39248
# 39248번째 에피소드까지 총 15365번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 884991  move = 24 @ 에피소드 # 39249
# 39249번째 에피소드까지 총 15366번 finish 했습니다.
# epiode #: 39250 loss: 0.46864816546440125 j: 885000
# ['L'] 종료: env.goal_ob_reward = True ... j = 885015  move = 24 @ 에피소드 # 39250
# 39250번째 에피소드까지 총 15367번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 885041  move = 26 @ 에피소드 # 39251
# 39251번째 에피소드까지 총 15368번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 885077  move = 36 @ 에피소드 # 39252
# 39252번째 에피소드까지 총 15369번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 885105  move = 28 @ 에피소드 # 39253
# 39253번째 에피소드까지 총 15370번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 885133  move = 28 @ 에피소드 # 39254
# 39254번째 에피소드까지 총 15371번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 885157  move = 24 @ 에피소드 # 39255
# 39255번째 에피소드까지 총 15372번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 885175  move = 18 @ 에피소드 # 39256
# 39256번째 에피소드까지 총 15373번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 885199  move = 24 @ 에피소드 # 39257
# 39257번째 에피소드까지 총 15374번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 885223  move = 24 @ 에피소드 # 39258
# 39258번째 에피소드까지 총 15375번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 885267  move = 44 @ 에피소드 # 39259
# 39259번째 에피소드까지 총 15376번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 885327  move = 60 @ 에피소드 # 39260
# 39260번째 에피소드까지 총 15377번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 885359  move = 32 @ 에피소드 # 39261
# 39261번째 에피소드까지 총 15378번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 885389  move = 30 @ 에피소드 # 39262
# 39262번째 에피소드까지 총 15379번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 885415  move = 26 @ 에피소드 # 39263
# 39263번째 에피소드까지 총 15380번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 885437  move = 22 @ 에피소드 # 39264
# 39264번째 에피소드까지 총 15381번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 885453  move = 16 @ 에피소드 # 39265
# 39265번째 에피소드까지 총 15382번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 885506  move = 24 @ 에피소드 # 39268
# 39268번째 에피소드까지 총 15383번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 885551  move = 24 @ 에피소드 # 39270
# 39270번째 에피소드까지 총 15384번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 885569  move = 18 @ 에피소드 # 39271
# 39271번째 에피소드까지 총 15385번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 885597  move = 28 @ 에피소드 # 39272
# 39272번째 에피소드까지 총 15386번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 885615  move = 18 @ 에피소드 # 39273
# 39273번째 에피소드까지 총 15387번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 885643  move = 28 @ 에피소드 # 39274
# 39274번째 에피소드까지 총 15388번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 885667  move = 24 @ 에피소드 # 39275
# 39275번째 에피소드까지 총 15389번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 885691  move = 24 @ 에피소드 # 39276
# 39276번째 에피소드까지 총 15390번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 885720  move = 29 @ 에피소드 # 39277
# 39277번째 에피소드까지 총 15391번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 885746  move = 26 @ 에피소드 # 39278
# 39278번째 에피소드까지 총 15392번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 885846  move = 26 @ 에피소드 # 39282
# 39282번째 에피소드까지 총 15393번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 885874  move = 28 @ 에피소드 # 39283
# 39283번째 에피소드까지 총 15394번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 885898  move = 24 @ 에피소드 # 39284
# 39284번째 에피소드까지 총 15395번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 885944  move = 46 @ 에피소드 # 39285
# 39285번째 에피소드까지 총 15396번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 885980  move = 26 @ 에피소드 # 39287
# 39287번째 에피소드까지 총 15397번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 886008  move = 28 @ 에피소드 # 39288
# 39288번째 에피소드까지 총 15398번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 886054  move = 46 @ 에피소드 # 39289
# 39289번째 에피소드까지 총 15399번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 886080  move = 26 @ 에피소드 # 39290
# 39290번째 에피소드까지 총 15400번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 886104  move = 24 @ 에피소드 # 39291
# 39291번째 에피소드까지 총 15401번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 886130  move = 26 @ 에피소드 # 39292
# 39292번째 에피소드까지 총 15402번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 886159  move = 29 @ 에피소드 # 39293
# 39293번째 에피소드까지 총 15403번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 886208  move = 26 @ 에피소드 # 39295
# 39295번째 에피소드까지 총 15404번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 886236  move = 28 @ 에피소드 # 39296
# 39296번째 에피소드까지 총 15405번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 886260  move = 24 @ 에피소드 # 39297
# 39297번째 에피소드까지 총 15406번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 886288  move = 28 @ 에피소드 # 39298
# 39298번째 에피소드까지 총 15407번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 886330  move = 30 @ 에피소드 # 39300
# 39300번째 에피소드까지 총 15408번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 886346  move = 16 @ 에피소드 # 39301
# 39301번째 에피소드까지 총 15409번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 886375  move = 29 @ 에피소드 # 39302
# 39302번째 에피소드까지 총 15410번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 886391  move = 16 @ 에피소드 # 39303
# 39303번째 에피소드까지 총 15411번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 886407  move = 16 @ 에피소드 # 39304
# 39304번째 에피소드까지 총 15412번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 886451  move = 28 @ 에피소드 # 39306
# 39306번째 에피소드까지 총 15413번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 886476  move = 25 @ 에피소드 # 39307
# 39307번째 에피소드까지 총 15414번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 886512  move = 24 @ 에피소드 # 39309
# 39309번째 에피소드까지 총 15415번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 886536  move = 24 @ 에피소드 # 39310
# 39310번째 에피소드까지 총 15416번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 886562  move = 26 @ 에피소드 # 39311
# 39311번째 에피소드까지 총 15417번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 886598  move = 26 @ 에피소드 # 39313
# 39313번째 에피소드까지 총 15418번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 886624  move = 26 @ 에피소드 # 39314
# 39314번째 에피소드까지 총 15419번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 886648  move = 24 @ 에피소드 # 39315
# 39315번째 에피소드까지 총 15420번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 886668  move = 20 @ 에피소드 # 39316
# 39316번째 에피소드까지 총 15421번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 886708  move = 26 @ 에피소드 # 39318
# 39318번째 에피소드까지 총 15422번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 886734  move = 26 @ 에피소드 # 39319
# 39319번째 에피소드까지 총 15423번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 886762  move = 28 @ 에피소드 # 39320
# 39320번째 에피소드까지 총 15424번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 886801  move = 22 @ 에피소드 # 39322
# 39322번째 에피소드까지 총 15425번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 886862  move = 26 @ 에피소드 # 39324
# 39324번째 에피소드까지 총 15426번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 886910  move = 28 @ 에피소드 # 39326
# 39326번째 에피소드까지 총 15427번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 886934  move = 24 @ 에피소드 # 39327
# 39327번째 에피소드까지 총 15428번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 886958  move = 24 @ 에피소드 # 39328
# 39328번째 에피소드까지 총 15429번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 886982  move = 24 @ 에피소드 # 39329
# 39329번째 에피소드까지 총 15430번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 886998  move = 16 @ 에피소드 # 39330
# 39330번째 에피소드까지 총 15431번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 887022  move = 24 @ 에피소드 # 39331
# 39331번째 에피소드까지 총 15432번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 887056  move = 34 @ 에피소드 # 39332
# 39332번째 에피소드까지 총 15433번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 887086  move = 24 @ 에피소드 # 39334
# 39334번째 에피소드까지 총 15434번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 887110  move = 24 @ 에피소드 # 39335
# 39335번째 에피소드까지 총 15435번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 887128  move = 18 @ 에피소드 # 39336
# 39336번째 에피소드까지 총 15436번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 887152  move = 24 @ 에피소드 # 39337
# 39337번째 에피소드까지 총 15437번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 887179  move = 27 @ 에피소드 # 39338
# 39338번째 에피소드까지 총 15438번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 887197  move = 18 @ 에피소드 # 39339
# 39339번째 에피소드까지 총 15439번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 887221  move = 24 @ 에피소드 # 39340
# 39340번째 에피소드까지 총 15440번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 887245  move = 24 @ 에피소드 # 39341
# 39341번째 에피소드까지 총 15441번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 887327  move = 82 @ 에피소드 # 39342
# 39342번째 에피소드까지 총 15442번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 887353  move = 26 @ 에피소드 # 39343
# 39343번째 에피소드까지 총 15443번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 887385  move = 32 @ 에피소드 # 39344
# 39344번째 에피소드까지 총 15444번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 887403  move = 18 @ 에피소드 # 39345
# 39345번째 에피소드까지 총 15445번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 887425  move = 22 @ 에피소드 # 39346
# 39346번째 에피소드까지 총 15446번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 887453  move = 28 @ 에피소드 # 39347
# 39347번째 에피소드까지 총 15447번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 887486  move = 24 @ 에피소드 # 39349
# 39349번째 에피소드까지 총 15448번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 887534  move = 48 @ 에피소드 # 39350
# 39350번째 에피소드까지 총 15449번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 887560  move = 26 @ 에피소드 # 39351
# 39351번째 에피소드까지 총 15450번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 887588  move = 28 @ 에피소드 # 39352
# 39352번째 에피소드까지 총 15451번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 887604  move = 16 @ 에피소드 # 39353
# 39353번째 에피소드까지 총 15452번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 887630  move = 26 @ 에피소드 # 39354
# 39354번째 에피소드까지 총 15453번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 887657  move = 27 @ 에피소드 # 39355
# 39355번째 에피소드까지 총 15454번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 887709  move = 26 @ 에피소드 # 39357
# 39357번째 에피소드까지 총 15455번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 887735  move = 26 @ 에피소드 # 39358
# 39358번째 에피소드까지 총 15456번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 887761  move = 26 @ 에피소드 # 39359
# 39359번째 에피소드까지 총 15457번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 887805  move = 16 @ 에피소드 # 39362
# 39362번째 에피소드까지 총 15458번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 887825  move = 20 @ 에피소드 # 39363
# 39363번째 에피소드까지 총 15459번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 887851  move = 26 @ 에피소드 # 39364
# 39364번째 에피소드까지 총 15460번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 887883  move = 20 @ 에피소드 # 39366
# 39366번째 에피소드까지 총 15461번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 887910  move = 27 @ 에피소드 # 39367
# 39367번째 에피소드까지 총 15462번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 887926  move = 16 @ 에피소드 # 39368
# 39368번째 에피소드까지 총 15463번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 888002  move = 24 @ 에피소드 # 39370
# 39370번째 에피소드까지 총 15464번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 888026  move = 24 @ 에피소드 # 39371
# 39371번째 에피소드까지 총 15465번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 888046  move = 20 @ 에피소드 # 39372
# 39372번째 에피소드까지 총 15466번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 888072  move = 26 @ 에피소드 # 39373
# 39373번째 에피소드까지 총 15467번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 888090  move = 18 @ 에피소드 # 39374
# 39374번째 에피소드까지 총 15468번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 888110  move = 20 @ 에피소드 # 39375
# 39375번째 에피소드까지 총 15469번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 888154  move = 44 @ 에피소드 # 39376
# 39376번째 에피소드까지 총 15470번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 888172  move = 18 @ 에피소드 # 39377
# 39377번째 에피소드까지 총 15471번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 888210  move = 18 @ 에피소드 # 39379
# 39379번째 에피소드까지 총 15472번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 888272  move = 26 @ 에피소드 # 39382
# 39382번째 에피소드까지 총 15473번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 888297  move = 25 @ 에피소드 # 39383
# 39383번째 에피소드까지 총 15474번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 888321  move = 24 @ 에피소드 # 39384
# 39384번째 에피소드까지 총 15475번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 888347  move = 26 @ 에피소드 # 39385
# 39385번째 에피소드까지 총 15476번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 888383  move = 26 @ 에피소드 # 39387
# 39387번째 에피소드까지 총 15477번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 888399  move = 16 @ 에피소드 # 39388
# 39388번째 에피소드까지 총 15478번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 888417  move = 18 @ 에피소드 # 39389
# 39389번째 에피소드까지 총 15479번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 888443  move = 26 @ 에피소드 # 39390
# 39390번째 에피소드까지 총 15480번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 888471  move = 28 @ 에피소드 # 39391
# 39391번째 에피소드까지 총 15481번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 888500  move = 29 @ 에피소드 # 39392
# 39392번째 에피소드까지 총 15482번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 888520  move = 20 @ 에피소드 # 39393
# 39393번째 에피소드까지 총 15483번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 888542  move = 16 @ 에피소드 # 39395
# 39395번째 에피소드까지 총 15484번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 888570  move = 28 @ 에피소드 # 39396
# 39396번째 에피소드까지 총 15485번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 888602  move = 24 @ 에피소드 # 39398
# 39398번째 에피소드까지 총 15486번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 888715  move = 36 @ 에피소드 # 39402
# 39402번째 에피소드까지 총 15487번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 888739  move = 24 @ 에피소드 # 39403
# 39403번째 에피소드까지 총 15488번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 888763  move = 24 @ 에피소드 # 39404
# 39404번째 에피소드까지 총 15489번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 888789  move = 26 @ 에피소드 # 39405
# 39405번째 에피소드까지 총 15490번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 888809  move = 20 @ 에피소드 # 39406
# 39406번째 에피소드까지 총 15491번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 888833  move = 24 @ 에피소드 # 39407
# 39407번째 에피소드까지 총 15492번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 888869  move = 36 @ 에피소드 # 39408
# 39408번째 에피소드까지 총 15493번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 888895  move = 26 @ 에피소드 # 39409
# 39409번째 에피소드까지 총 15494번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 888921  move = 26 @ 에피소드 # 39410
# 39410번째 에피소드까지 총 15495번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 888945  move = 24 @ 에피소드 # 39411
# 39411번째 에피소드까지 총 15496번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 888969  move = 24 @ 에피소드 # 39412
# 39412번째 에피소드까지 총 15497번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 889000  move = 31 @ 에피소드 # 39413
# 39413번째 에피소드까지 총 15498번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 889026  move = 26 @ 에피소드 # 39414
# 39414번째 에피소드까지 총 15499번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 889052  move = 26 @ 에피소드 # 39415
# 39415번째 에피소드까지 총 15500번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 889098  move = 26 @ 에피소드 # 39417
# 39417번째 에피소드까지 총 15501번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 889118  move = 20 @ 에피소드 # 39418
# 39418번째 에피소드까지 총 15502번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 889147  move = 29 @ 에피소드 # 39419
# 39419번째 에피소드까지 총 15503번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 889173  move = 26 @ 에피소드 # 39420
# 39420번째 에피소드까지 총 15504번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 889193  move = 20 @ 에피소드 # 39421
# 39421번째 에피소드까지 총 15505번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 889217  move = 24 @ 에피소드 # 39422
# 39422번째 에피소드까지 총 15506번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 889243  move = 26 @ 에피소드 # 39423
# 39423번째 에피소드까지 총 15507번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 889259  move = 16 @ 에피소드 # 39424
# 39424번째 에피소드까지 총 15508번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 889289  move = 30 @ 에피소드 # 39425
# 39425번째 에피소드까지 총 15509번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 889348  move = 52 @ 에피소드 # 39427
# 39427번째 에피소드까지 총 15510번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 889366  move = 18 @ 에피소드 # 39428
# 39428번째 에피소드까지 총 15511번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 889388  move = 22 @ 에피소드 # 39429
# 39429번째 에피소드까지 총 15512번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 889414  move = 26 @ 에피소드 # 39430
# 39430번째 에피소드까지 총 15513번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 889454  move = 24 @ 에피소드 # 39432
# 39432번째 에피소드까지 총 15514번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 889494  move = 40 @ 에피소드 # 39433
# 39433번째 에피소드까지 총 15515번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 889518  move = 24 @ 에피소드 # 39434
# 39434번째 에피소드까지 총 15516번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 889542  move = 24 @ 에피소드 # 39435
# 39435번째 에피소드까지 총 15517번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 889586  move = 44 @ 에피소드 # 39436
# 39436번째 에피소드까지 총 15518번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 889723  move = 36 @ 에피소드 # 39438
# 39438번째 에피소드까지 총 15519번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 889741  move = 18 @ 에피소드 # 39439
# 39439번째 에피소드까지 총 15520번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 889759  move = 18 @ 에피소드 # 39440
# 39440번째 에피소드까지 총 15521번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 889874  move = 26 @ 에피소드 # 39442
# 39442번째 에피소드까지 총 15522번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 889962  move = 88 @ 에피소드 # 39443
# 39443번째 에피소드까지 총 15523번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 889988  move = 26 @ 에피소드 # 39444
# 39444번째 에피소드까지 총 15524번 finish 했습니다.
# epiode #: 39445 loss: 0.5456448197364807 j: 890000
# ['I'] 종료: env.goal_ob_reward = True ... j = 890010  move = 22 @ 에피소드 # 39445
# 39445번째 에피소드까지 총 15525번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 890092  move = 16 @ 에피소드 # 39447
# 39447번째 에피소드까지 총 15526번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 890121  move = 26 @ 에피소드 # 39449
# 39449번째 에피소드까지 총 15527번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 890141  move = 20 @ 에피소드 # 39450
# 39450번째 에피소드까지 총 15528번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 890167  move = 26 @ 에피소드 # 39451
# 39451번째 에피소드까지 총 15529번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 890194  move = 27 @ 에피소드 # 39452
# 39452번째 에피소드까지 총 15530번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 890233  move = 16 @ 에피소드 # 39454
# 39454번째 에피소드까지 총 15531번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 890259  move = 26 @ 에피소드 # 39455
# 39455번째 에피소드까지 총 15532번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 890339  move = 80 @ 에피소드 # 39456
# 39456번째 에피소드까지 총 15533번 finish 했습니다.
# ...
# ['H'] 종료: env.goal_ob_reward = True ... j = 957748  move = 28 @ 에피소드 # 41975
# 41975번째 에피소드까지 총 17486번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 957774  move = 26 @ 에피소드 # 41976
# 41976번째 에피소드까지 총 17487번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 957800  move = 26 @ 에피소드 # 41977
# 41977번째 에피소드까지 총 17488번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 957824  move = 24 @ 에피소드 # 41978
# 41978번째 에피소드까지 총 17489번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 957852  move = 28 @ 에피소드 # 41979
# 41979번째 에피소드까지 총 17490번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 957876  move = 24 @ 에피소드 # 41980
# 41980번째 에피소드까지 총 17491번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 957906  move = 30 @ 에피소드 # 41981
# 41981번째 에피소드까지 총 17492번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 957972  move = 48 @ 에피소드 # 41983
# 41983번째 에피소드까지 총 17493번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 958005  move = 33 @ 에피소드 # 41984
# 41984번째 에피소드까지 총 17494번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 958031  move = 26 @ 에피소드 # 41985
# 41985번째 에피소드까지 총 17495번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 958057  move = 26 @ 에피소드 # 41986
# 41986번째 에피소드까지 총 17496번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 958087  move = 30 @ 에피소드 # 41987
# 41987번째 에피소드까지 총 17497번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 958111  move = 24 @ 에피소드 # 41988
# 41988번째 에피소드까지 총 17498번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 958137  move = 26 @ 에피소드 # 41989
# 41989번째 에피소드까지 총 17499번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 958161  move = 24 @ 에피소드 # 41990
# 41990번째 에피소드까지 총 17500번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 958179  move = 18 @ 에피소드 # 41991
# 41991번째 에피소드까지 총 17501번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 958228  move = 26 @ 에피소드 # 41993
# 41993번째 에피소드까지 총 17502번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 958254  move = 26 @ 에피소드 # 41994
# 41994번째 에피소드까지 총 17503번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 958299  move = 26 @ 에피소드 # 41996
# 41996번째 에피소드까지 총 17504번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 958318  move = 19 @ 에피소드 # 41997
# 41997번째 에피소드까지 총 17505번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 958334  move = 16 @ 에피소드 # 41998
# 41998번째 에피소드까지 총 17506번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 958360  move = 26 @ 에피소드 # 41999
# 41999번째 에피소드까지 총 17507번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 958391  move = 26 @ 에피소드 # 42001
# 42001번째 에피소드까지 총 17508번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 958431  move = 24 @ 에피소드 # 42003
# 42003번째 에피소드까지 총 17509번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 958459  move = 28 @ 에피소드 # 42004
# 42004번째 에피소드까지 총 17510번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 958483  move = 24 @ 에피소드 # 42005
# 42005번째 에피소드까지 총 17511번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 958507  move = 24 @ 에피소드 # 42006
# 42006번째 에피소드까지 총 17512번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 958533  move = 26 @ 에피소드 # 42007
# 42007번째 에피소드까지 총 17513번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 958559  move = 26 @ 에피소드 # 42008
# 42008번째 에피소드까지 총 17514번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 958583  move = 24 @ 에피소드 # 42009
# 42009번째 에피소드까지 총 17515번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 958617  move = 34 @ 에피소드 # 42010
# 42010번째 에피소드까지 총 17516번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 958641  move = 24 @ 에피소드 # 42011
# 42011번째 에피소드까지 총 17517번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 958673  move = 24 @ 에피소드 # 42013
# 42013번째 에피소드까지 총 17518번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 958695  move = 22 @ 에피소드 # 42014
# 42014번째 에피소드까지 총 17519번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 958713  move = 18 @ 에피소드 # 42015
# 42015번째 에피소드까지 총 17520번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 958737  move = 24 @ 에피소드 # 42016
# 42016번째 에피소드까지 총 17521번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 958781  move = 26 @ 에피소드 # 42018
# 42018번째 에피소드까지 총 17522번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 958867  move = 54 @ 에피소드 # 42020
# 42020번째 에피소드까지 총 17523번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 958899  move = 32 @ 에피소드 # 42021
# 42021번째 에피소드까지 총 17524번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 958925  move = 26 @ 에피소드 # 42022
# 42022번째 에피소드까지 총 17525번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 958967  move = 42 @ 에피소드 # 42023
# 42023번째 에피소드까지 총 17526번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 959028  move = 36 @ 에피소드 # 42026
# 42026번째 에피소드까지 총 17527번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 959090  move = 62 @ 에피소드 # 42027
# 42027번째 에피소드까지 총 17528번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 959116  move = 26 @ 에피소드 # 42028
# 42028번째 에피소드까지 총 17529번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 959139  move = 16 @ 에피소드 # 42030
# 42030번째 에피소드까지 총 17530번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 959161  move = 22 @ 에피소드 # 42031
# 42031번째 에피소드까지 총 17531번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 959185  move = 24 @ 에피소드 # 42032
# 42032번째 에피소드까지 총 17532번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 959217  move = 24 @ 에피소드 # 42034
# 42034번째 에피소드까지 총 17533번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 959239  move = 22 @ 에피소드 # 42035
# 42035번째 에피소드까지 총 17534번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 959270  move = 31 @ 에피소드 # 42036
# 42036번째 에피소드까지 총 17535번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 959294  move = 24 @ 에피소드 # 42037
# 42037번째 에피소드까지 총 17536번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 959322  move = 28 @ 에피소드 # 42038
# 42038번째 에피소드까지 총 17537번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 959352  move = 30 @ 에피소드 # 42039
# 42039번째 에피소드까지 총 17538번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 959383  move = 24 @ 에피소드 # 42041
# 42041번째 에피소드까지 총 17539번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 959454  move = 50 @ 에피소드 # 42043
# 42043번째 에피소드까지 총 17540번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 959476  move = 22 @ 에피소드 # 42044
# 42044번째 에피소드까지 총 17541번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 959565  move = 89 @ 에피소드 # 42045
# 42045번째 에피소드까지 총 17542번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 959593  move = 28 @ 에피소드 # 42046
# 42046번째 에피소드까지 총 17543번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 959726  move = 32 @ 에피소드 # 42048
# 42048번째 에피소드까지 총 17544번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 959754  move = 28 @ 에피소드 # 42049
# 42049번째 에피소드까지 총 17545번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 959830  move = 29 @ 에피소드 # 42054
# 42054번째 에피소드까지 총 17546번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 959854  move = 24 @ 에피소드 # 42055
# 42055번째 에피소드까지 총 17547번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 959886  move = 32 @ 에피소드 # 42056
# 42056번째 에피소드까지 총 17548번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 959916  move = 30 @ 에피소드 # 42057
# 42057번째 에피소드까지 총 17549번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 959962  move = 40 @ 에피소드 # 42059
# 42059번째 에피소드까지 총 17550번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 959986  move = 24 @ 에피소드 # 42060
# 42060번째 에피소드까지 총 17551번 finish 했습니다.
# epiode #: 42061 loss: 0.43723535537719727 j: 960000
# ['D'] 종료: env.goal_ob_reward = True ... j = 960010  move = 24 @ 에피소드 # 42061
# 42061번째 에피소드까지 총 17552번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 960026  move = 16 @ 에피소드 # 42062
# 42062번째 에피소드까지 총 17553번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 960063  move = 30 @ 에피소드 # 42064
# 42064번째 에피소드까지 총 17554번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 960079  move = 16 @ 에피소드 # 42065
# 42065번째 에피소드까지 총 17555번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 960107  move = 28 @ 에피소드 # 42066
# 42066번째 에피소드까지 총 17556번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 960129  move = 22 @ 에피소드 # 42067
# 42067번째 에피소드까지 총 17557번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 960149  move = 20 @ 에피소드 # 42068
# 42068번째 에피소드까지 총 17558번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 960190  move = 27 @ 에피소드 # 42070
# 42070번째 에피소드까지 총 17559번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 960255  move = 22 @ 에피소드 # 42073
# 42073번째 에피소드까지 총 17560번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 960277  move = 22 @ 에피소드 # 42074
# 42074번째 에피소드까지 총 17561번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 960305  move = 28 @ 에피소드 # 42075
# 42075번째 에피소드까지 총 17562번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 960337  move = 26 @ 에피소드 # 42077
# 42077번째 에피소드까지 총 17563번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 960370  move = 33 @ 에피소드 # 42078
# 42078번째 에피소드까지 총 17564번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 960396  move = 26 @ 에피소드 # 42079
# 42079번째 에피소드까지 총 17565번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 960412  move = 16 @ 에피소드 # 42080
# 42080번째 에피소드까지 총 17566번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 960436  move = 24 @ 에피소드 # 42081
# 42081번째 에피소드까지 총 17567번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 960460  move = 24 @ 에피소드 # 42082
# 42082번째 에피소드까지 총 17568번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 960482  move = 22 @ 에피소드 # 42083
# 42083번째 에피소드까지 총 17569번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 960500  move = 18 @ 에피소드 # 42084
# 42084번째 에피소드까지 총 17570번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 960531  move = 31 @ 에피소드 # 42085
# 42085번째 에피소드까지 총 17571번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 960573  move = 32 @ 에피소드 # 42087
# 42087번째 에피소드까지 총 17572번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 960599  move = 26 @ 에피소드 # 42088
# 42088번째 에피소드까지 총 17573번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 960617  move = 18 @ 에피소드 # 42089
# 42089번째 에피소드까지 총 17574번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 960647  move = 30 @ 에피소드 # 42090
# 42090번째 에피소드까지 총 17575번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 960673  move = 26 @ 에피소드 # 42091
# 42091번째 에피소드까지 총 17576번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 960697  move = 24 @ 에피소드 # 42092
# 42092번째 에피소드까지 총 17577번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 960733  move = 36 @ 에피소드 # 42093
# 42093번째 에피소드까지 총 17578번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 960759  move = 26 @ 에피소드 # 42094
# 42094번째 에피소드까지 총 17579번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 960803  move = 28 @ 에피소드 # 42097
# 42097번째 에피소드까지 총 17580번 finish 했습니다.
# ['A'] 종료: env.goal_ob_reward = True ... j = 960852  move = 22 @ 에피소드 # 42099
# 42099번째 에피소드까지 총 17581번 finish 했습니다.
# ['I'] 종료: env.goal_ob_reward = True ... j = 960878  move = 26 @ 에피소드 # 42100
# 42100번째 에피소드까지 총 17582번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 960907  move = 29 @ 에피소드 # 42101
# 42101번째 에피소드까지 총 17583번 finish 했습니다.
# ['L'] 종료: env.goal_ob_reward = True ... j = 960931  move = 24 @ 에피소드 # 42102
# 42102번째 에피소드까지 총 17584번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 960951  move = 20 @ 에피소드 # 42103
# 42103번째 에피소드까지 총 17585번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 960984  move = 26 @ 에피소드 # 42105
# 42105번째 에피소드까지 총 17586번 finish 했습니다.
# ['J'] 종료: env.goal_ob_reward = True ... j = 961008  move = 24 @ 에피소드 # 42106
# 42106번째 에피소드까지 총 17587번 finish 했습니다.
# ['Q'] 종료: env.goal_ob_reward = True ... j = 961024  move = 16 @ 에피소드 # 42107
# 42107번째 에피소드까지 총 17588번 finish 했습니다.
# ['G'] 종료: env.goal_ob_reward = True ... j = 961050  move = 26 @ 에피소드 # 42108
# 42108번째 에피소드까지 총 17589번 finish 했습니다.
# ['M'] 종료: env.goal_ob_reward = True ... j = 961076  move = 26 @ 에피소드 # 42109
# 42109번째 에피소드까지 총 17590번 finish 했습니다.
# ['N'] 종료: env.goal_ob_reward = True ... j = 961100  move = 24 @ 에피소드 # 42110
# 42110번째 에피소드까지 총 17591번 finish 했습니다.
# ['P'] 종료: env.goal_ob_reward = True ... j = 961134  move = 22 @ 에피소드 # 42112
# 42112번째 에피소드까지 총 17592번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 961164  move = 24 @ 에피소드 # 42114
# 42114번째 에피소드까지 총 17593번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 961186  move = 22 @ 에피소드 # 42115
# 42115번째 에피소드까지 총 17594번 finish 했습니다.
# ['O'] 종료: env.goal_ob_reward = True ... j = 961212  move = 26 @ 에피소드 # 42116
# 42116번째 에피소드까지 총 17595번 finish 했습니다.
# ['B'] 종료: env.goal_ob_reward = True ... j = 961244  move = 18 @ 에피소드 # 42118
# 42118번째 에피소드까지 총 17596번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 961270  move = 26 @ 에피소드 # 42119
# 42119번째 에피소드까지 총 17597번 finish 했습니다.
# ['H'] 종료: env.goal_ob_reward = True ... j = 961318  move = 48 @ 에피소드 # 42120
# 42120번째 에피소드까지 총 17598번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 961354  move = 22 @ 에피소드 # 42122
# 42122번째 에피소드까지 총 17599번 finish 했습니다.
# ['F'] 종료: env.goal_ob_reward = True ... j = 961382  move = 28 @ 에피소드 # 42123
# 42123번째 에피소드까지 총 17600번 finish 했습니다.
# ['E'] 종료: env.goal_ob_reward = True ... j = 961411  move = 29 @ 에피소드 # 42124
# 42124번째 에피소드까지 총 17601번 finish 했습니다.
# ['K'] 종료: env.goal_ob_reward = True ... j = 961435  move = 24 @ 에피소드 # 42125
# 42125번째 에피소드까지 총 17602번 finish 했습니다.
# ['D'] 종료: env.goal_ob_reward = True ... j = 961485  move = 24 @ 에피소드 # 42128
# 42128번째 에피소드까지 총 17603번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 961505  move = 20 @ 에피소드 # 42129
# 42129번째 에피소드까지 총 17604번 finish 했습니다.
# ['C'] 종료: env.goal_ob_reward = True ... j = 961525  move = 20 @ 에피소드 # 42130
# 42130번째 에피소드까지 총 17605번 finish 했습니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/drive/Othercomputers/MacBook_Air/path-finding-rl/data in <module>()
#     126         if j > train_start:  # 메모리에 미니배치 크기 이상 쌓이면... 미니배치 훈련
#     127             #print('memory size:', memory.size())
# --> 128             loss = train(q, q_target, memory, optimizer)
#     129             if j % print_interval == 0:
#     130                 print('epiode #:', n_epi, 'loss:', loss, 'j:', j)
#
# /content/drive/Othercomputers/MacBook_Air/path-finding-rl/data in train(q, q_target, memory, optimizer)
#     118     optimizer.zero_grad()  # gradient값 초기화
#     119     loss.backward()  # 자동미분
# --> 120     optimizer.step()  # gradient 업데이트
#     121     return loss.item()
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/adam.py in step(self, closure)
#     151                    weight_decay=group['weight_decay'],
#     152                    eps=group['eps'],
# --> 153                    maximize=group['maximize'])
#     154         return loss
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#      95
#      96         # Decay the first and second moment running average coefficient
# ---> 97         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
#      98         exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#      99         if amsgrad:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 테스트 코드

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # GPU를 사용할 경우 ???
print('tensor in', device)  # GPU 사용 확인
## test 코드 #################################################################################
def test(epochs=1000, train_mode=False, display=True, model_load=True):  # train_mode = False 테스트 모드

    ###################################################################
    # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! 파일 이름 반드시 확인할 것 !!#
    PATH = __file__ + '/model_conv_colab_epsilon_v4_buffer_500000.pt'
    #^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^#

    test_env = Simulator()  # 데이터셋 읽기. 그리드월드 크기 지정
    test_q = Qnet()
    test_q.to(device)
    learning_rate = 0.00025    #3. 0.0005
    optimizer = optim.Adam(test_q.parameters(), lr=learning_rate)

    if model_load:
        ###############################################################
        ## 학습한 모델 불러오기
        ###############################################################
        checkpoint = torch.load(PATH)
        test_q.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        epoch = checkpoint['epoch']
        loss = checkpoint['loss']
        test_q.eval()

    #epochs = len(test_env.files)
    wins = 0

    for n_epi in range(epochs):
        gridmap = test_env.reset(n_epi)  # 에피소드 시작시 12개 값 초기화
        history_ = np.stack((gridmap,gridmap,gridmap,gridmap), axis = 0) # 초기 state로 히스토리 초기화 (4,10,9)
        history = np.reshape([history_], (1,4,10,9)) # (배치, 채널, 가로, 세로) 로 reshape
        history = torch.from_numpy(history).float() # 텐서로 변환   
        done = False
        mov = 0
        while (not done):  # 최종 목적지 [9,4] 도착
            mov += 1
            # 상태 state1에서 action 결정
            #####################################################################################
            if test_env.curloc == [9,4]:  # 출발점에서는 무조건 위로 (action=0)
                action = 0
            elif test_env.curloc[0] == 0 and test_env.curloc[1] in [0,1,2,3,4,5,6,7,8]:  # (0,0)~(0,8)에서는 무조건 아래로
                action = 1
            elif test_env.curloc[0] in [2,3,4,5] and test_env.curloc[1] == 8:  # (2,8)~(5,8)에서는 무조건 왼쪽으로
                action = 2
            elif test_env.curloc[0] in [2,3,4,5] and test_env.curloc[1] == 0:  # (2,0)~(5,0)에서는 무조건 오른쪽으로
                action = 3
            else:  # 위 경우를 제외하곤 test 액션 선택
                action = test_q.test_action(history)
            #####################################################################################
            # action = test_q.test_action(history)  # 위 조건을 적용하지 않을 경우
            # make Move... action에 따른 이동
            gridmap, reward, cum_reward, done = test_env.step(action)

            next_gridmap_ = np.reshape([gridmap],(1,1,10,9)) # 다음 그리드를 히스토리 사이즈에 맞게 reshape
            next_gridmap = torch.from_numpy(next_gridmap_).float() # 텐서로 변환
            new_history = torch.cat([next_gridmap, history[:,:3,:,:]],dim=1) # (1,1+3,10,9)
            # 지금 있는 히스토리중 마지막 채널을 지우고 new를 제일 앞에 붙임
            history = new_history

            if display:
                print('Move #%s; Taking action: %s' % (mov, action))
                print(gridmap.reshape(10,9))

            if test_env.goal_ob_reward:
                wins += 1
                if display:
                    print("Game won! Reward: %s" % (cum_reward))
                    
            if (mov > 50):  # 경로 길이가 너무 길어서 제외시키는 조건 추가 필요시 사용
                if display:
                    print("Game lost; too many moves.")
                break
                
    win_perc = float(wins) / float(epochs)
    print("Test performed: {0}, # of wins: {1}".format(epochs,wins))
    print("Win percentage: {}%".format(100.0*win_perc))
    return win_perc
# Out:
# tensor in cuda

# %%
test(epochs=100, train_mode=False, display=False, model_load=True)
# Out:
# Test performed: 100, # of wins: 96
# Win percentage: 96.0%
# 0.96
